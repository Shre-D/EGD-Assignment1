# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("china")
china_data = Data.read(filepath)
china_data
# Out:
#      Country Name Country Code  \
# 0           China          CHN
# 1           China          CHN
# 2           China          CHN
# 3           China          CHN
# 4           China          CHN
# ...           ...          ...
# 1473        China          CHN
# 1474        China          CHN
# 1475        China          CHN
# 1476        China          CHN
# 1477        China          CHN
#
#                                          Indicator Name     Indicator Code  \
# 0            Intentional homicides (per 100,000 people)     VC.IHR.PSRC.P5
# 1     Internally displaced persons, new displacement...        VC.IDP.NWDS
# 2     Voice and Accountability: Percentile Rank, Upp...   VA.PER.RNK.UPPER
# 3                    Voice and Accountability: Estimate             VA.EST
# 4                 High-technology exports (current US$)     TX.VAL.TECH.CD
# ...                                                 ...                ...
# ...

# %%
# cleaning the data
china_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
china_data = Data.clean_data(china_data, china_columns_to_drop)
china_data
# Out:
# 0   Year  Intentional homicides (per 100,000 people)  \
# 1   1960                                        <NA>
# 2   1961                                        <NA>
# 3   1962                                        <NA>
# 4   1963                                        <NA>
# 5   1964                                        <NA>
# ..   ...                                         ...
# 60  2019                                    0.518967
# 61  2020                                     0.50227
# 62  2021                                        <NA>
# 63  2022                                        <NA>
# 64  2023                                        <NA>
#
# 0   Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# ...

# %%
# selecting and modifying the data
china_data["Year"]=china_data["Year"].astype(int)
china_data = china_data.tail(35)
china_data
interval = 5
china_data=china_data.iloc[::interval]
china_data
# Out:
# 0   Year  Intentional homicides (per 100,000 people)  \
# 30  1989                                        <NA>
# 35  1994                                        <NA>
# 40  1999                                        <NA>
# 45  2004                                    1.905512
# 50  2009                                    1.095267
# 55  2014                                    0.727915
# 60  2019                                    0.518967
#
# 0   Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                            4031000
# 55                                            3612000
# 60                                            4034000
#
# ...

# %%
# checking the number of null values in each column
china_data.isna().sum()
# Out:
# 0
# Year                                                                                          0
# Intentional homicides (per 100,000 people)                                                    3
# Internally displaced persons, new displacement associated with disasters (number of cases)    4
# Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval             3
# Voice and Accountability: Estimate                                                            3
#                                                                                              ..
# Agricultural irrigated land (% of total agricultural land)                                    7
# Urban land area where elevation is below 5 meters (% of total land area)                      7
# Permanent cropland (% of land area)                                                           0
# Arable land (hectares)                                                                        0
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = china_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   0),
#  ('Export unit value index (2015 = 100)', 0),
#  ('Travel services (% of commercial service imports)', 0),
#  ('Import value index (2015 = 100)', 0),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   0),
#  ('Merchandise imports (current US$)', 0),
# ...

# %%
# selecting the columns we want to analyse, china does not have SS education data
selected_china_data = china_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)"]]
selected_china_data
# Out:
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 30  1989               4.206334      988622772159.194946
# 35  1994              13.036807     1650608234073.159912
# 40  1999               7.661652     2553332587339.779785
# 45  2004              10.113621     3968365429308.669922
# 50  2009               9.398726     6827904909025.129883
# 55  2014               7.425764    10333926843387.400391
# 60  2019               5.950501    14296369668095.800781
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 30                                   180000000.0
# 35                                 -3543000000.0
# 40                                 11234000000.0
# 45                           -19743601592.046902
# 50                           -27087363798.001301
# 55                           -82429447386.750107
# 60                              -57947645385.638
#
# 0   Inflation, consumer prices (annual %)  \
# 30                              18.245638
# ...

# %%
selected_china_data.shape
# Out:
# (7, 7)

# %%
selected_china_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                 7.0
# GDP growth (annual %)                                7.0
# GDP (constant 2015 US$)                              7.0
# Portfolio investment, net (BoP, current US$)         7.0
# Inflation, consumer prices (annual %)                7.0
# Unemployment, total (% of total labor force) (n...   7.0
# Population growth (annual %)                         7.0
#
#                                                                     mean  \
# 0
# Year                                                              2004.0
# GDP growth (annual %)                                           8.256201
# GDP (constant 2015 US$)                             5802732920484.163086
# Portfolio investment, net (BoP, current US$)         -25619579737.490902
# Inflation, consumer prices (annual %)                           7.002643
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_china_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_china_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
# sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_china_data)

# %%
sns.lineplot(data=selected_china_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_china_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_china_data['GDP growth (annual %)'] = selected_china_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_china_data["GDP (constant 2015 US$)"] = np.log(selected_china_data["GDP (constant 2015 US$)"])
selected_china_data
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# /tmp/ipykernel_1877971/566015460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_china_data['GDP growth (annual %)'] = selected_china_data['GDP (constant 2015 US$)'].pct_change() * 100
# ...

# %%
selected_china_data[regression_columns]
selected_china_data = selected_china_data.tail(6)
selected_china_data.reset_index(drop=True, inplace = True)
selected_china_data
# Out:
# 0  Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 0  1994               66.96037                28.132165
# 1  1999              54.690407                28.568421
# 2  2004              55.419057                29.009375
# 3  2009              72.058371                29.552039
# 4  2014              51.348429                29.966453
# 5  2019              38.344019                30.291027
#
# 0  Portfolio investment, net (BoP, current US$)  \
# 0                                 -3543000000.0
# 1                                 11234000000.0
# 2                           -19743601592.046902
# 3                           -27087363798.001301
# 4                           -82429447386.750107
# 5                              -57947645385.638
#
# 0  Inflation, consumer prices (annual %)  \
# 0                               24.25699
# 1                              -1.401473
# 2                               3.824637
# 3                              -0.728165
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_china_data[ 'GDP growth (annual %)']
X = selected_china_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=50) 
combined_data
# Out:
# 0  GDP (constant 2015 US$)  Portfolio investment, net (BoP, current US$)  \
# 0                28.132165                                 -3543000000.0
# 1                28.568421                                 11234000000.0
# 2                29.009375                           -19743601592.046902
# 3                29.552039                           -27087363798.001301
# 4                29.966453                           -82429447386.750107
# 5                30.291027                              -57947645385.638
#
# 0  Inflation, consumer prices (annual %)  \
# 0                               24.25699
# 1                              -1.401473
# 2                               3.824637
# 3                              -0.728165
# 4                               1.921642
# 5                               2.899234
#
# 0  Unemployment, total (% of total labor force) (national estimate)  \
# 0                                                2.8
# ...

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  3431.2127847135234
# mean_absolute_error :  58.576554906494145
# The value of R^2 for the model is -381.8453943091986 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 4761.681788705665
# The value of slope for GDP (constant 2015 US$) is given by -163.09195299181508
# The value of slope for Portfolio investment, net (BoP, current US$) is given by 1.6237038380495505e-09
# The value of slope for Inflation, consumer prices (annual %) is given by 3.4502614743564224
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by 84.02517615883852
# The value of slope for Population growth (annual %) is given by -371.42072569566886
