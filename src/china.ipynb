# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("china")
china_data = Data.read(filepath)
china_data
# Out:
#      Country Name Country Code  \
# 0           China          CHN
# 1           China          CHN
# 2           China          CHN
# 3           China          CHN
# 4           China          CHN
# ...           ...          ...
# 1473        China          CHN
# 1474        China          CHN
# 1475        China          CHN
# 1476        China          CHN
# 1477        China          CHN
#
#                                          Indicator Name     Indicator Code  \
# 0            Intentional homicides (per 100,000 people)     VC.IHR.PSRC.P5
# 1     Internally displaced persons, new displacement...        VC.IDP.NWDS
# 2     Voice and Accountability: Percentile Rank, Upp...   VA.PER.RNK.UPPER
# 3                    Voice and Accountability: Estimate             VA.EST
# 4                 High-technology exports (current US$)     TX.VAL.TECH.CD
# ...                                                 ...                ...
# ...

# %%
# cleaning the data
china_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
china_data = Data.clean_data(china_data, china_columns_to_drop)
china_data
# Out:
# 0   Year  Intentional homicides (per 100,000 people)  \
# 1   1960                                        <NA>
# 2   1961                                        <NA>
# 3   1962                                        <NA>
# 4   1963                                        <NA>
# 5   1964                                        <NA>
# ..   ...                                         ...
# 60  2019                                    0.518967
# 61  2020                                     0.50227
# 62  2021                                        <NA>
# 63  2022                                        <NA>
# 64  2023                                        <NA>
#
# 0   Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# ...

# %%
# selecting and modifying the data
china_data["Year"]=china_data["Year"].astype(int)
china_data = china_data.tail(30)
china_data
# Out:
# 0   Year  Intentional homicides (per 100,000 people)  \
# 35  1994                                        <NA>
# 36  1995                                    2.245711
# 37  1996                                    2.068796
# 38  1997                                    2.106154
# 39  1998                                        <NA>
# 40  1999                                        <NA>
# 41  2000                                        <NA>
# 42  2001                                        <NA>
# 43  2002                                    2.051328
# 44  2003                                    1.892583
# 45  2004                                    1.905512
# 46  2005                                    1.591708
# 47  2006                                     1.36876
# 48  2007                                    1.219738
# 49  2008                                    1.113469
# 50  2009                                    1.095267
# 51  2010                                    0.994666
# ...

# %%
# checking the number of null values in each column
china_data.isna().sum()
# Out:
# 0
# Year                                                                                           0
# Intentional homicides (per 100,000 people)                                                     8
# Internally displaced persons, new displacement associated with disasters (number of cases)    15
# Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval              6
# Voice and Accountability: Estimate                                                             6
#                                                                                               ..
# Agricultural irrigated land (% of total agricultural land)                                    30
# Urban land area where elevation is below 5 meters (% of total land area)                      28
# Permanent cropland (% of land area)                                                            2
# Arable land (hectares)                                                                         2
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = china_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Labor force, female (% of total labor force)', 0),
#  ('Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Population in the largest city (% of urban population)', 0),
#  ('Net migration', 0),
#  ('Unemployment, total (% of total labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, female (% of female labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force, total', 0),
#  ('Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#   0),
# ...

# %%
# selecting the columns we want to analyse
selected_china_data = china_data[["Year","GDP growth (annual %)","GDP (constant 2015 US$)","Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_china_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_china_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_china_data
# Out:
# /tmp/ipykernel_105188/577720477.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_china_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_105188/577720477.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
selected_china_data.shape
# Out:
# (30, 8)

# %%
selected_china_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                30.0
# GDP growth (annual %)                               29.0
# GDP (constant 2015 US$)                             29.0
# Portfolio investment, net (BoP, current US$)        29.0
# Inflation, consumer prices (annual %)               29.0
# Unemployment, total (% of total labor force) (n...  26.0
# Population growth (annual %)                        29.0
# Educational attainment, at least completed lowe...  30.0
#
#                                                                     mean  \
# 0
# Year                                                              2008.5
# GDP growth (annual %)                                            8.71106
# GDP (constant 2015 US$)                             7317775668132.945312
# Portfolio investment, net (BoP, current US$)          -5824122337.154613
# Inflation, consumer prices (annual %)                           3.447232
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_china_data.columns)
print(columns)

sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# <Axes: xlabel='GDP (constant 2015 US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_china_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_china_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
sns.pairplot(data = selected_china_data, height = 2)

# %%
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_china_data[ 'GDP growth (annual %)']
X = selected_china_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=42)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  5.728586487761676
# mean_absolute_error :  1.6020546482215248
# The value of R^2 for the model is 61.752883797332345 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 5.543163896952544
# The value of slope for GDP (constant 2015 US$) is given by -2.5034943369538345e-13
# The value of slope for Portfolio investment, net (BoP, current US$) is given by 2.065410774061798e-11
# The value of slope for Inflation, consumer prices (annual %) is given by 0.23580461297381228
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by 0.29532360564841204
# The value of slope for Population growth (annual %) is given by -4.020936009992036
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 0.10619030486675804
