# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("germany")
germany_data = Data.read(filepath)
germany_data
# Out:
#      Country Name Country Code  \
# 0         Germany          DEU
# 1         Germany          DEU
# 2         Germany          DEU
# 3         Germany          DEU
# 4         Germany          DEU
# ...           ...          ...
# 1473      Germany          DEU
# 1474      Germany          DEU
# 1475      Germany          DEU
# 1476      Germany          DEU
# 1477      Germany          DEU
#
#                                          Indicator Name        Indicator Code  \
# 0     Unemployment with intermediate education, male...     SL.UEM.INTM.MA.ZS
# 1     Unemployment with basic education, female (% o...     SL.UEM.BASC.FE.ZS
# 2     Unemployment, youth total (% of total labor fo...        SL.UEM.1524.ZS
# 3     Unemployment, youth female (% of female labor ...     SL.UEM.1524.FE.ZS
# 4     Part time employment, total (% of total employ...        SL.TLF.PART.ZS
# ...                                                 ...                   ...
# ...

# %%
# cleaning the data
germany_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
germany_data = Data.clean_data(germany_data, germany_columns_to_drop)
germany_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Unemployment with intermediate education, male (% of male labor force with intermediate education)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               3.05
# 61                                              3.619
# 62                                              3.543
# 63                                              3.002
# 64                                               <NA>
#
# 0   Unemployment with basic education, female (% of female labor force with basic education)  \
# ...

# %%
# selecting and modifying the data
germany_data["Year"]=germany_data["Year"].astype(int)
germany_data = germany_data.tail(35)
germany_data
interval = 5
germany_data=germany_data.iloc[::interval]
germany_data
# Out:
# 0   Year  \
# 30  1989
# 35  1994
# 40  1999
# 45  2004
# 50  2009
# 55  2014
# 60  2019
#
# 0   Unemployment with intermediate education, male (% of male labor force with intermediate education)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                              8.339
# 45                                             11.946
# 50                                              8.146
# 55                                              4.998
# 60                                               3.05
#
# 0   Unemployment with basic education, female (% of female labor force with basic education)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                             12.949
# 45                                             15.107
# 50                                             13.796
# ...

# %%
# checking the number of null values in each column
germany_data.isna().sum()
# Out:
# 0
# Year                                                                                                                                             0
# Unemployment with intermediate education, male (% of male labor force with intermediate education)                                               2
# Unemployment with basic education, female (% of female labor force with basic education)                                                         2
# Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)                                                             1
# Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)                                                           1
#                                                                                                                                                 ..
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = germany_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Part time employment, total (% of total employment)', 0),
#  ('Labor force participation rate for ages 15-24, total (%) (national estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, female (%) (national estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, male (%) (national estimate)',
#   0),
#  ('External balance on goods and services (current US$)', 0),
#  ('Imports of goods and services (constant 2015 US$)', 0),
#  ('Gross capital formation (constant LCU)', 0),
#  ('Gross capital formation (current US$)', 0),
#  ('Gross fixed capital formation (% of GDP)', 0),
#  ('Gross fixed capital formation (current LCU)', 0),
#  ('Exports of goods and services (% of GDP)', 0),
#  ('Exports of goods and services (current LCU)', 0),
#  ('Gross national expenditure (constant 2015 US$)', 0),
#  ('Final consumption expenditure (% of GDP)', 0),
#  ('Final consumption expenditure (current LCU)', 0),
# ...

# %%
# selecting the columns we want to analyse
selected_germany_data = germany_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_germany_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_germany_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_germany_data
# Out:
# /tmp/ipykernel_1903569/12260274.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_germany_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1903569/12260274.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
selected_germany_data.shape
# Out:
# (7, 8)

# %%
selected_germany_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                 7.0
# GDP growth (annual %)                                7.0
# GDP (constant 2015 US$)                              7.0
# Portfolio investment, net (BoP, current US$)         7.0
# Inflation, consumer prices (annual %)                7.0
# Unemployment, total (% of total labor force) (n...   7.0
# Population growth (annual %)                         7.0
# Educational attainment, at least completed lowe...   7.0
#
#                                                                     mean  \
# 0
# Year                                                              2004.0
# GDP growth (annual %)                                            0.99171
# GDP (constant 2015 US$)                             2897855240042.291504
# Portfolio investment, net (BoP, current US$)          56376554017.106583
# Inflation, consumer prices (annual %)                           1.484284
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_germany_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_germany_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_germany_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_germany_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_germany_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_germany_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_germany_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_germany_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_germany_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_germany_data['GDP growth (annual %)'] = selected_germany_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_germany_data["GDP (constant 2015 US$)"] = np.log(selected_germany_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# /tmp/ipykernel_1903569/1466251244.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mean_value = selected_germany_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_germany_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_germany_data[regression_columns]
selected_germany_data = selected_germany_data.tail(6)
selected_germany_data.reset_index(drop=True, inplace = True)
selected_germany_data
# Out:
# /tmp/ipykernel_1903569/398512448.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_germany_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1903569/398512448.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_germany_data[ 'GDP growth (annual %)']
X = selected_germany_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=50)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  40.08067444567455
# mean_absolute_error :  5.020785021004686
# The value of R^2 for the model is 12.96479464501098 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by -285.0508985779716
# The value of slope for GDP (constant 2015 US$) is given by 0.24274248208309673
# The value of slope for Portfolio investment, net (BoP, current US$) is given by 6.604033986334912e-11
# The value of slope for Inflation, consumer prices (annual %) is given by 5.407787289042528
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by 0.11491936584442519
# The value of slope for Population growth (annual %) is given by 4.099697078833678
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 2.8042586420255526
