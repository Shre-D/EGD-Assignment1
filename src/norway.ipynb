# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("norway")
norway_data = Data.read(filepath)
norway_data
# Out:
#      Country Name Country Code  \
# 0          Norway          NOR
# 1          Norway          NOR
# 2          Norway          NOR
# 3          Norway          NOR
# 4          Norway          NOR
# ...           ...          ...
# 1473       Norway          NOR
# 1474       Norway          NOR
# 1475       Norway          NOR
# 1476       Norway          NOR
# 1477       Norway          NOR
#
#                                          Indicator Name     Indicator Code  \
# 0     Intentional homicides, female (per 100,000 fem...  VC.IHR.PSRC.FE.P5
# 1              Battle-related deaths (number of people)        VC.BTL.DETH
# 2             Voice and Accountability: Percentile Rank         VA.PER.RNK
# 3     Transport services (% of commercial service ex...  TX.VAL.TRAN.ZS.WT
# 4     Computer, communications and other services (%...  TX.VAL.OTHR.ZS.WT
# ...                                                 ...                ...
# ...

# %%
# cleaning the data
norway_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
norway_data = Data.clean_data(norway_data, norway_columns_to_drop)
norway_data
# Out:
# 0   Year  Intentional homicides, female (per 100,000 female)  \
# 1   1960                                               <NA>
# 2   1961                                               <NA>
# 3   1962                                               <NA>
# 4   1963                                               <NA>
# 5   1964                                               <NA>
# ..   ...                                                ...
# 60  2019                                           0.603263
# 61  2020                                           0.562489
# 62  2021                                           0.597581
# 63  2022                                               <NA>
# 64  2023                                               <NA>
#
# 0   Battle-related deaths (number of people)  \
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# ...

# %%
# selecting and modifying the data
norway_data["Year"]=norway_data["Year"].astype(int)
norway_data = norway_data.tail(35)
norway_data
interval = 5
norway_data=norway_data.iloc[::interval]
norway_data
# Out:
# 0   Year  Intentional homicides, female (per 100,000 female)  \
# 30  1989                                               <NA>
# 35  1994                                           0.708399
# 40  1999                                           0.539471
# 45  2004                                           0.518239
# 50  2009                                           0.496261
# 55  2014                                           0.508897
# 60  2019                                           0.603263
#
# 0   Battle-related deaths (number of people)  \
# 30                                      <NA>
# 35                                      <NA>
# 40                                      <NA>
# 45                                      <NA>
# 50                                      <NA>
# 55                                      <NA>
# 60                                      <NA>
#
# 0   Voice and Accountability: Percentile Rank  \
# 30                                       <NA>
# ...

# %%
# checking the number of null values in each column
norway_data.isna().sum()
# Out:
# 0
# Year                                                                0
# Intentional homicides, female (per 100,000 female)                  1
# Battle-related deaths (number of people)                            7
# Voice and Accountability: Percentile Rank                           3
# Transport services (% of commercial service exports)                0
#                                                                    ..
# PPG, IDA (DOD, current US$)                                         7
# Short-term debt (% of total reserves)                               7
# External debt stocks, long-term (DOD, current US$)                  7
# Net ODA provided, total (constant 2021 US$)                         0
# Net ODA provided, to the least developed countries (current US$)    0
# Length: 1479, dtype: int64

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = norway_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Transport services (% of commercial service exports)', 0),
#  ('Computer, communications and other services (% of commercial service exports)',
#   0),
#  ('Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to high-income economies (% of total merchandise exports)',
#   0),
#  ('Manufactures exports (% of merchandise exports)', 0),
#  ('Food exports (% of merchandise exports)', 0),
#  ('Commercial service imports (current US$)', 0),
#  ('Merchandise imports by the reporting economy (current US$)', 0),
#  ('Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#   0),
# ...

# %%
# selecting the columns we want to analyse
selected_norway_data = norway_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_norway_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_norway_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_norway_data
# Out:
# /tmp/ipykernel_1921863/3803785547.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_norway_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1921863/3803785547.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
selected_norway_data.shape
# Out:
# (7, 8)

# %%
selected_norway_data.describe().T
# Out:
#                                                    count                mean  \
# 0
# Year                                                 7.0              2004.0
# GDP growth (annual %)                                7.0            1.915958
# GDP (constant 2015 US$)                              7.0  317512216005.55072
# Portfolio investment, net (BoP, current US$)         7.0   7765749651.057403
# Inflation, consumer prices (annual %)                7.0            2.164158
# Unemployment, total (% of total labor force) (n...   7.0            3.993714
# Population growth (annual %)                         7.0            0.760259
# Educational attainment, at least completed lowe...   7.0           99.480665
#
#                                                                    std  \
# 0
# Year                                                         10.801234
# GDP growth (annual %)                                          2.25723
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_norway_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_norway_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_norway_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_norway_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_norway_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_norway_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_norway_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_norway_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_norway_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_norway_data['GDP growth (annual %)'] = selected_norway_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_norway_data["GDP (constant 2015 US$)"] = np.log(selected_norway_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# /tmp/ipykernel_1921863/2023651295.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mean_value = selected_norway_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_norway_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_norway_data[regression_columns]
selected_norway_data = selected_norway_data.tail(6)
selected_norway_data.reset_index(drop=True, inplace = True)
selected_norway_data
# Out:
# /tmp/ipykernel_1921863/1978958672.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_norway_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1921863/1978958672.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_norway_data[ 'GDP growth (annual %)']
X = selected_norway_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=50)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  50.31243634951881
# mean_absolute_error :  7.093125992784762
# The value of R^2 for the model is 70.52876078375436 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by -57.48201912126636
# The value of slope for GDP (constant 2015 US$) is given by -0.13012059714116375
# The value of slope for Portfolio investment, net (BoP, current US$) is given by 3.754149768830928e-11
# The value of slope for Inflation, consumer prices (annual %) is given by -1.622248252751817
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by 0.8554613215647061
# The value of slope for Population growth (annual %) is given by -0.7275686034143198
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 0.6975758922372677
