# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("us")
us_data = Data.read(filepath)
us_data
# Out:
#        Country Name Country Code  \
# 0     United States          USA
# 1     United States          USA
# 2     United States          USA
# 3     United States          USA
# 4     United States          USA
# ...             ...          ...
# 1479  United States          USA
# 1480  United States          USA
# 1481  United States          USA
# 1482  United States          USA
# 1483  United States          USA
#
#                                          Indicator Name        Indicator Code  \
# 0     Internally displaced persons, new displacement...           VC.IDP.NWDS
# 1                    Voice and Accountability: Estimate                VA.EST
# 2                 High-technology exports (current US$)        TX.VAL.TECH.CD
# 3     Merchandise exports to low- and middle-income ...     TX.VAL.MRCH.WR.ZS
# 4     Merchandise exports to low- and middle-income ...     TX.VAL.MRCH.R5.ZS
# ...                                                 ...                   ...
# ...

# %%
# cleaning the data
us_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
us_data = Data.clean_data(us_data, us_columns_to_drop)
us_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 59  2018
# 60  2019
# 61  2020
# 62  2021
# 63  2022
#
# 0   Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 59                                            1247000
# 60                                             916000
# 61                                            1715000
# 62                                             573000
# 63                                             675000
#
# 0   Voice and Accountability: Estimate  High-technology exports (current US$)  \
# ...

# %%
# selecting and modifying the data
us_data["Year"]=us_data["Year"].astype(int)
us_data = us_data.tail(35)
us_data
interval = 5
us_data=us_data.iloc[::interval]
us_data
# Out:
# 0   Year  \
# 29  1988
# 34  1993
# 39  1998
# 44  2003
# 49  2008
# 54  2013
# 59  2018
#
# 0   Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 29                                               <NA>
# 34                                               <NA>
# 39                                               <NA>
# 44                                               <NA>
# 49                                            2020000
# 54                                             188000
# 59                                            1247000
#
# 0   Voice and Accountability: Estimate  High-technology exports (current US$)  \
# 29                                <NA>                                   <NA>
# 34                                <NA>                                   <NA>
# 39                            1.336877                                   <NA>
# 44                            1.338228                                   <NA>
# ...

# %%
# checking the number of null values in each column
us_data.isna().sum()
# Out:
# 0
# Year                                                                                                      0
# Internally displaced persons, new displacement associated with disasters (number of cases)                4
# Voice and Accountability: Estimate                                                                        2
# High-technology exports (current US$)                                                                     4
# Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)    7
#                                                                                                          ..
# Total tax and contribution rate (% of profit)                                                             5
# Number of visits or required meetings with tax officials (average for affected firms)                     7
# Start-up procedures to register a business, male (number)                                                 5
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = us_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   0),
#  ('Export unit value index (2015 = 100)', 0),
#  ('Travel services (% of commercial service imports)', 0),
#  ('Import value index (2015 = 100)', 0),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   0),
#  ('Merchandise imports (current US$)', 0),
#  ('Insurance and financial services (% of commercial service imports)', 0),
#  ('Urban population', 0),
#  ('Rural population', 0),
#  ('Population, male', 0),
# ...

# %%
# selecting the columns we want to analyse
selected_us_data = us_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_us_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_us_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_us_data
# Out:
# /tmp/ipykernel_76988/1134963368.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_us_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_76988/1134963368.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
selected_us_data.shape
# Out:
# (7, 8)

# %%
selected_us_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                 7.0
# GDP growth (annual %)                                7.0
# GDP (constant 2015 US$)                              7.0
# Portfolio investment, net (BoP, current US$)         7.0
# Inflation, consumer prices (annual %)                7.0
# Unemployment, total (% of total labor force) (n...   7.0
# Population growth (annual %)                         7.0
# Educational attainment, at least completed lowe...   7.0
#
#                                                                      mean  \
# 0
# Year                                                               2003.0
# GDP growth (annual %)                                            2.730842
# GDP (constant 2015 US$)                             14289775891428.572266
# Portfolio investment, net (BoP, current US$)         -180707142857.142853
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_us_data.columns)
print(columns)

grid = sns.scatterplot(x='GDP (constant 2015 US$)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_us_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_us_data, height = 2)

# %%
import numpy as np

print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_us_data['GDP growth (annual %)'] = selected_us_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_us_data["GDP (constant 2015 US$)"] = np.log(selected_us_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# /tmp/ipykernel_76988/1994489311.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mean_value = selected_us_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_us_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_us_data[regression_columns]
selected_us_data = selected_us_data.tail(6)
selected_us_data.reset_index(drop=True, inplace = True)
selected_us_data
# Out:
# /tmp/ipykernel_76988/3931593227.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_us_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_76988/3931593227.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_us_data[ 'GDP growth (annual %)']
X = selected_us_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=55) 
combined_data
# Out:
# 0  GDP (constant 2015 US$)  Portfolio investment, net (BoP, current US$)  \
# 0                29.975212                                   35247000000
# 1                30.165579                                  -57361000000
# 2                30.306266                                 -417105000000
# 3                30.426882                                 -807954000000
# 4                 30.48345                                  -30689000000
# 5                30.600511                                   78785000000
#
# 0  Inflation, consumer prices (annual %)  \
# 0                               2.951657
# 1                               1.552279
# 2                               2.270095
# 3                                 3.8391
# 4                               1.464833
# 5                               2.442583
#
# 0  Unemployment, total (% of total labor force) (national estimate)  \
# 0                                                6.9
# ...

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  76.21761276592513
# mean_absolute_error :  8.730269913692538
# The value of R^2 for the model is 36.562182824894876 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 438.8988184753484
# The value of slope for GDP (constant 2015 US$) is given by -1.8870312585529982
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -1.8043344596208044e-12
# The value of slope for Inflation, consumer prices (annual %) is given by -3.9298676432650264
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by -1.6427374855285601
# The value of slope for Population growth (annual %) is given by 3.2576509197394836
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by -3.6895957926518728
