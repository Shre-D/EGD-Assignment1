# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("russia")
russia_data = Data.read(filepath)
russia_data
# Out:
#             Country Name Country Code  \
# 0     Russian Federation          RUS
# 1     Russian Federation          RUS
# 2     Russian Federation          RUS
# 3     Russian Federation          RUS
# 4     Russian Federation          RUS
# ...                  ...          ...
# 1473  Russian Federation          RUS
# 1474  Russian Federation          RUS
# 1475  Russian Federation          RUS
# 1476  Russian Federation          RUS
# 1477  Russian Federation          RUS
#
#                                          Indicator Name     Indicator Code  \
# 0        Intentional homicides, male (per 100,000 male)  VC.IHR.PSRC.MA.P5
# 1     Internally displaced persons, new displacement...        VC.IDP.NWCV
# 2     Voice and Accountability: Percentile Rank, Low...   VA.PER.RNK.LOWER
# 3     Travel services (% of commercial service exports)  TX.VAL.TRVL.ZS.WT
# 4              Commercial service exports (current US$)  TX.VAL.SERV.CD.WT
# ...                                                 ...                ...
# 1473  Short-term debt (% of exports of goods, servic...  DT.DOD.DSTC.XP.ZS
# 1474  External debt stocks, private nonguaranteed (P...     DT.DOD.DPNG.CD
# 1475     External debt stocks, total (DOD, current US$)     DT.DOD.DECT.CD
# 1476  Net ODA provided to the least developed countr...  DC.ODA.TLDC.GN.ZS
# 1477  Net bilateral aid flows from DAC donors, Swede...     DC.DAC.SWEL.CD
#
#       1960  1961  1962  1963  1964  1965  ...          2015          2016  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN  ...  1.842790e+01  1.739453e+01
# 1      NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN  ...  1.280788e+01  1.280788e+01
# 3      NaN   NaN   NaN   NaN   NaN   NaN  ...  1.657157e+01  1.563075e+01
# 4      NaN   NaN   NaN   NaN   NaN   NaN  ...  5.080902e+10  4.981886e+10
# ...    ...   ...   ...   ...   ...   ...  ...           ...           ...
# 1473   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.129138e+01  1.369127e+01
# 1474   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.235545e+11  2.910556e+11
# 1475   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.921911e+11  5.352252e+11
# 1476   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 1477   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
#
#               2017          2018          2019          2020          2021  \
# 0     1.453004e+01  1.298539e+01  1.222800e+01  1.172033e+01  1.080088e+01
# 1              NaN           NaN           NaN           NaN           NaN
# 2     1.280788e+01  1.310680e+01  1.256039e+01  1.449275e+01  1.304348e+01
# 3     1.578681e+01  1.821852e+01  1.797716e+01  8.278738e+00  7.298943e+00
# 4     5.665887e+10  6.362372e+10  6.097186e+10  4.721444e+10  5.461585e+10
# ...            ...           ...           ...           ...           ...
# 1473  1.224301e+01  9.653306e+00  1.275398e+01  1.451030e+01  1.218285e+01
# 1474  2.390000e+11  2.204699e+11  2.083191e+11  1.974090e+11  1.931837e+11
# 1475  5.192025e+11  4.777854e+11  4.857933e+11  4.609339e+11  4.721581e+11
# 1476           NaN           NaN           NaN           NaN           NaN
# 1477           NaN           NaN           NaN           NaN           NaN
#
#               2022  2023  Unnamed: 68
# 0              NaN   NaN          NaN
# 1     7.100000e+03   NaN          NaN
# 2     8.212561e+00   NaN          NaN
# 3     1.170782e+01   NaN          NaN
# 4     4.781153e+10   NaN          NaN
# ...            ...   ...          ...
# 1473  9.644039e+00   NaN          NaN
# 1474  1.504578e+11   NaN          NaN
# 1475  3.761170e+11   NaN          NaN
# 1476           NaN   NaN          NaN
# 1477           NaN   NaN          NaN
#
# [1478 rows x 69 columns]

# %%
# cleaning the data
russia_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
russia_data = Data.clean_data(russia_data, russia_columns_to_drop)
russia_data
# Out:
# 0   Year  Intentional homicides, male (per 100,000 male)  \
# 1   1960                                            <NA>
# 2   1961                                            <NA>
# 3   1962                                            <NA>
# 4   1963                                            <NA>
# 5   1964                                            <NA>
# ..   ...                                             ...
# 60  2019                                       12.227995
# 61  2020                                       11.720326
# 62  2021                                        10.80088
# 63  2022                                            <NA>
# 64  2023                                            <NA>
#
# 0   Internally displaced persons, new displacement associated with conflict and violence (number of cases)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               7100
# 64                                               <NA>
#
# 0   Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          12.560387
# 61                                          14.492754
# 62                                          13.043478
# 63                                           8.212561
# 64                                               <NA>
#
# 0   Travel services (% of commercial service exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          17.977162
# 61                                           8.278738
# 62                                           7.298943
# 63                                          11.707824
# 64                                               <NA>
#
# 0   Commercial service exports (current US$)  \
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# 5                                       <NA>
# ..                                       ...
# 60                               60971860000
# 61                               47214440000
# 62                               54615850000
# 63                               47811530000
# 64                                      <NA>
#
# 0   Merchandise exports by the reporting economy (current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                       419732000000
# 61                                       337885000000
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                           3.076044
# 61                                           3.259663
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          21.933062
# 61                                          24.522115
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Ores and metals exports (% of merchandise exports)  ...  \
# 1                                                <NA>   ...
# 2                                                <NA>   ...
# 3                                                <NA>   ...
# 4                                                <NA>   ...
# 5                                                <NA>   ...
# ..                                                ...   ...
# 60                                           6.173552   ...
# 61                                           8.637201   ...
# 62                                           7.403773   ...
# 63                                               <NA>   ...
# 64                                               <NA>   ...
#
# 0   Net financial flows, others (NFL, current US$)  \
# 1                                             <NA>
# 2                                             <NA>
# 3                                             <NA>
# 4                                             <NA>
# 5                                             <NA>
# ..                                             ...
# 60                                      -6227312.6
# 61                                      -6288070.6
# 62                                      -5034800.8
# 63                                      -4966893.3
# 64                                            <NA>
#
# 0   Net financial flows, IMF nonconcessional (NFL, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                                0.0
# 61                                                0.0
# 62                                                0.0
# 63                                                0.0
# 64                                               <NA>
#
# 0   Net official flows from UN agencies, IAEA (current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Net financial flows, bilateral (NFL, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                        -69924222.2
# 61                                        119941777.8
# 62                                        350275777.8
# 63                                         97369511.0
# 64                                               <NA>
#
# 0   IBRD loans and IDA credits (DOD, current US$)  \
# 1                                            <NA>
# 2                                            <NA>
# 3                                            <NA>
# 4                                            <NA>
# 5                                            <NA>
# ..                                            ...
# 60                                      315239000
# 61                                      235786000
# 62                                      177959000
# 63                                              0
# 64                                           <NA>
#
# 0   Short-term debt (% of exports of goods, services and primary income)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          12.753978
# 61                                          14.510301
# 62                                          12.182849
# 63                                           9.644039
# 64                                               <NA>
#
# 0   External debt stocks, private nonguaranteed (PNG) (DOD, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                208319131209.899994
# 61                                     197408961385.0
# 62                                     193183672126.5
# 63                                     150457801673.0
# 64                                               <NA>
#
# 0   External debt stocks, total (DOD, current US$)  \
# 1                                             <NA>
# 2                                             <NA>
# 3                                             <NA>
# 4                                             <NA>
# 5                                             <NA>
# ..                                             ...
# 60                             485793305491.700012
# 61                             460933940334.799988
# 62                                  472158073713.0
# 63                             376117000821.900024
# 64                                            <NA>
#
# 0   Net ODA provided to the least developed countries (% of GNI)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Net bilateral aid flows from DAC donors, Sweden (current US$)
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# [64 rows x 1479 columns]

# %%
# selecting and modifying the data
russia_data["Year"]=russia_data["Year"].astype(int)
russia_data = russia_data.tail(30)
russia_data
# Out:
# 0   Year  Intentional homicides, male (per 100,000 male)  \
# 35  1994                                       52.433004
# 36  1995                                       49.570005
# 37  1996                                       42.455912
# 38  1997                                       38.034508
# 39  1998                                       36.407168
# 40  1999                                       41.182993
# 41  2000                                       44.842109
# 42  2001                                       47.142857
# 43  2002                                       49.428709
# 44  2003                                       46.642003
# 45  2004                                        44.16583
# 46  2005                                       40.177033
# 47  2006                                       32.596619
# 48  2007                                       28.976322
# 49  2008                                       20.700985
# 50  2009                                       19.700991
# 51  2010                                       18.618588
# 52  2011                                       18.270905
# 53  2012                                       18.059707
# 54  2013                                        18.01181
# 55  2014                                        18.42811
# 56  2015                                       18.427902
# 57  2016                                       17.394528
# 58  2017                                       14.530042
# 59  2018                                       12.985394
# 60  2019                                       12.227995
# 61  2020                                       11.720326
# 62  2021                                        10.80088
# 63  2022                                            <NA>
# 64  2023                                            <NA>
#
# 0   Internally displaced persons, new displacement associated with conflict and violence (number of cases)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               7100
# 64                                               <NA>
#
# 0   Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               33.5
# 38                                               <NA>
# 39                                          27.860697
# 40                                               <NA>
# 41                                          29.353233
# 42                                               <NA>
# 43                                          26.865671
# 44                                          25.373135
# 45                                          23.076923
# 46                                          22.596153
# 47                                          16.826923
# 48                                          15.865385
# 49                                          17.307692
# 50                                          14.691943
# 51                                          15.639811
# 52                                          17.370892
# 53                                          15.023474
# 54                                           14.55399
# 55                                          13.793103
# 56                                          12.807881
# 57                                          12.807881
# 58                                          12.807881
# 59                                          13.106796
# 60                                          12.560387
# 61                                          14.492754
# 62                                          13.043478
# 63                                           8.212561
# 64                                               <NA>
#
# 0   Travel services (% of commercial service exports)  \
# 35                                          28.627223
# 36                                          40.803078
# 37                                          53.474031
# 38                                           50.87807
# 39                                          52.043938
# 40                                          33.554515
# 41                                          30.344909
# 42                                          28.587174
# 43                                          27.863473
# 44                                          24.619768
# 45                                          24.209785
# 46                                          20.511948
# 47                                          21.497375
# 48                                          21.685664
# 49                                          20.947884
# 50                                          20.650372
# 51                                           18.15317
# 52                                          19.753836
# 53                                            17.5041
# 54                                          17.346634
# 55                                          18.141682
# 56                                          16.571565
# 57                                          15.630747
# 58                                          15.786813
# 59                                           18.21852
# 60                                          17.977162
# 61                                           8.278738
# 62                                           7.298943
# 63                                          11.707824
# 64                                               <NA>
#
# 0   Commercial service exports (current US$)  \
# 35                                8423800000
# 36                               10567340000
# 37                               13281400000
# 38                               14079740000
# 39                               12505030000
# 40                               11094960000
# 41                               11300380000
# 42                               12493680000
# 43                               14956750000
# 44                               18284900000
# 45                               22843780000
# 46                               28615810000
# 47                               35481960000
# 48                               43563020000
# 49                               56531200000
# 50                               45356810000
# 51                               48644230000
# 52                               57344710000
# 53                               61464800000
# 54                               69110930000
# 55                               64817970000
# 56                               50809020000
# 57                               49818860000
# 58                               56658870000
# 59                               63623720000
# 60                               60971860000
# 61                               47214440000
# 62                               54615850000
# 63                               47811530000
# 64                                      <NA>
#
# 0   Merchandise exports by the reporting economy (current US$)  \
# 35                                        63077883000
# 36                                        77595355000
# 37                                        83979296000
# 38                                        85076577000
# 39                                        71463457000
# 40                                        72465641569
# 41                                       102811000000
# 42                                        82261711950
# 43                                       106960000000
# 44                                       131084000000
# 45                                       165776000000
# 46                                       238652000000
# 47                                       291679000000
# 48                                       352224000000
# 49                                       465692000000
# 50                                       284919000000
# 51                                       379010000000
# 52                                       503209000000
# 53                                       524483000000
# 54                                       527266000000
# 55                                       497834000000
# 56                                       343427000000
# 57                                       285534000000
# 58                                       355745000000
# 59                                       449185000000
# 60                                       419732000000
# 61                                       337885000000
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)  \
# 35                                           1.139588
# 36                                           1.365675
# 37                                           1.258792
# 38                                           1.413361
# 39                                           1.863436
# 40                                             2.1146
# 41                                           1.773903
# 42                                           2.649127
# 43                                           2.395325
# 44                                           2.200596
# 45                                           2.660883
# 46                                           2.115122
# 47                                           1.857075
# 48                                           2.675391
# 49                                           2.399798
# 50                                           2.513765
# 51                                           2.454921
# 52                                           2.124312
# 53                                           2.234206
# 54                                           1.586848
# 55                                           2.546666
# 56                                           3.186107
# 57                                           4.475505
# 58                                           4.588613
# 59                                            3.89918
# 60                                           3.076044
# 61                                           3.259663
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)  \
# 35                                           8.712109
# 36                                          10.103311
# 37                                          10.477298
# 38                                           9.486663
# 39                                           9.329151
# 40                                          11.207991
# 41                                           9.902774
# 42                                          10.403849
# 43                                          12.485433
# 44                                          12.638781
# 45                                          12.525309
# 46                                          10.591825
# 47                                           9.910284
# 48                                           10.07788
# 49                                          10.318898
# 50                                          12.110932
# 51                                           11.72663
# 52                                          12.007734
# 53                                          13.381251
# 54                                          12.671997
# 55                                          14.854374
# 56                                          16.909456
# 57                                          20.481279
# 58                                          21.473404
# 59                                          22.521351
# 60                                          21.933062
# 61                                          24.522115
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Ores and metals exports (% of merchandise exports)  ...  \
# 35                                               <NA>   ...
# 36                                               <NA>   ...
# 37                                           9.923714   ...
# 38                                          11.337939   ...
# 39                                          16.117538   ...
# 40                                          11.399865   ...
# 41                                           9.138243   ...
# 42                                           7.763591   ...
# 43                                           7.238123   ...
# 44                                           6.792673   ...
# 45                                           7.546164   ...
# 46                                           6.511793   ...
# 47                                           8.004678   ...
# 48                                            8.13642   ...
# 49                                           5.457524   ...
# 50                                            5.25762   ...
# 51                                           5.462953   ...
# 52                                           4.797331   ...
# 53                                           5.139447   ...
# 54                                           4.575398   ...
# 55                                           4.622362   ...
# 56                                           5.901158   ...
# 57                                           6.048968   ...
# 58                                           6.027592   ...
# 59                                            5.65645   ...
# 60                                           6.173552   ...
# 61                                           8.637201   ...
# 62                                           7.403773   ...
# 63                                               <NA>   ...
# 64                                               <NA>   ...
#
# 0   Net financial flows, others (NFL, current US$)  \
# 35                                     -92165922.9
# 36                                    -434090092.7
# 37                                    -287265829.2
# 38                                     -48614845.9
# 39                                     -50679366.5
# 40                                     -17702148.0
# 41                                      -2409848.5
# 42                                            <NA>
# 43                                        100000.0
# 44                                            <NA>
# 45                                            <NA>
# 46                                      27300000.0
# 47                                      36220000.0
# 48                                      21380000.0
# 49                                       -177000.0
# 50                                       1319000.0
# 51                                      -2055000.0
# 52                                      -8618000.0
# 53                                      -6086511.5
# 54                                     -11239839.5
# 55                                      -6185392.7
# 56                                      -6162232.3
# 57                                      -6251559.0
# 58                                      -6297509.2
# 59                                      -6237760.4
# 60                                      -6227312.6
# 61                                      -6288070.6
# 62                                      -5034800.8
# 63                                      -4966893.3
# 64                                            <NA>
#
# 0   Net financial flows, IMF nonconcessional (NFL, current US$)  \
# 35                                       1544157231.5
# 36                                       5453330828.5
# 37                                       3235101136.7
# 38                                       1524367847.8
# 39                                       5326814251.2
# 40                                      -3595845757.9
# 41                                      -2887957490.5
# 42                                      -3816652383.3
# 43                                      -1485973109.7
# 44                                      -1896865120.8
# 45                                      -1656036335.8
# 46                                      -3388678171.8
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                                0.0
# 54                                                0.0
# 55                                                0.0
# 56                                                0.0
# 57                                                0.0
# 58                                                0.0
# 59                                                0.0
# 60                                                0.0
# 61                                                0.0
# 62                                                0.0
# 63                                                0.0
# 64                                               <NA>
#
# 0   Net official flows from UN agencies, IAEA (current US$)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Net financial flows, bilateral (NFL, current US$)  \
# 35                                        398121618.1
# 36                                       -357099640.5
# 37                                       2674249794.8
# 38                                        -34682177.4
# 39                                       -239929399.6
# 40                                        217815665.1
# 41                                       -692170713.5
# 42                                      -1034126226.8
# 43                                      -1644279545.2
# 44                                      -1926010892.6
# 45                                      -2809875654.0
# 46                                -17839545042.599998
# 47                                     -25206396560.5
# 48                                       -850006186.4
# 49                                       -549812736.8
# 50                                       -311028795.1
# 51                                        883411090.3
# 52                                      -1686692557.3
# 53                                       -417737000.0
# 54                                       -357567830.0
# 55                                       -279234251.5
# 56                                       -189421751.1
# 57                                       -197209000.0
# 58                                       -842350222.2
# 59                                        -69924222.2
# 60                                        -69924222.2
# 61                                        119941777.8
# 62                                        350275777.8
# 63                                         97369511.0
# 64                                               <NA>
#
# 0   IBRD loans and IDA credits (DOD, current US$)  \
# 35                                      684286000
# 36                                     1523877000
# 37                                     2508965000
# 38                                     5053064000
# 39                                     6336702000
# 40                                     6706940000
# 41                                     6843667000
# 42                                     6745633000
# 43                                     6598613000
# 44                                     6289172000
# 45                                     5743457000
# 46                                     5091359000
# 47                                     4758913000
# 48                                     4291763000
# 49                                     3850971000
# 50                                     3210674000
# 51                                     2618311000
# 52                                     2066955000
# 53                                     1609894000
# 54                                     1203869000
# 55                                      876048000
# 56                                      730681000
# 57                                      646060000
# 58                                      550993000
# 59                                      428202000
# 60                                      315239000
# 61                                      235786000
# 62                                      177959000
# 63                                              0
# 64                                           <NA>
#
# 0   Short-term debt (% of exports of goods, services and primary income)  \
# 35                                          12.640439
# 36                                          10.789614
# 37                                          11.427249
# 38                                           5.815289
# 39                                           16.54232
# 40                                          18.462304
# 41                                          13.559286
# 42                                           16.34452
# 43                                          13.281947
# 44                                          19.210914
# 45                                          12.427207
# 46                                           9.474635
# 47                                          11.185709
# 48                                           22.99737
# 49                                          12.679557
# 50                                           14.10823
# 51                                          12.547195
# 52                                          11.342615
# 53                                          12.846694
# 54                                            13.2464
# 55                                          10.334689
# 56                                          11.291378
# 57                                          13.691268
# 58                                           12.24301
# 59                                           9.653306
# 60                                          12.753978
# 61                                          14.510301
# 62                                          12.182849
# 63                                           9.644039
# 64                                               <NA>
#
# 0   External debt stocks, private nonguaranteed (PNG) (DOD, current US$)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                       1905000000.0
# 39                                      22163094250.0
# 40                                      22583122258.0
# 41                                 21762085470.299999
# 42                                      22326181600.0
# 43                                 28514282452.700001
# 44                                      56987681521.0
# 45                                      83256985972.5
# 46                                138589019611.200012
# 47                                     164936481125.0
# 48                                181864067580.799988
# 49                                     211082698132.0
# 50                                198577860211.200012
# 51                                183272989705.600006
# 52                                270290681286.200012
# 53                                291182364801.400024
# 54                                     301930812895.0
# 55                                251312902025.799988
# 56                                223554532947.799988
# 57                                291055567132.200012
# 58                                239000000545.600006
# 59                                220469949064.299988
# 60                                208319131209.899994
# 61                                     197408961385.0
# 62                                     193183672126.5
# 63                                     150457801673.0
# 64                                               <NA>
#
# 0   External debt stocks, total (DOD, current US$)  \
# 35                             122365566099.300003
# 36                             122074627736.600006
# 37                             127025505816.300003
# 38                                  128143868208.0
# 39                                  175719267829.0
# 40                                  180043060834.5
# 41                             146665107929.799988
# 42                             141151650545.700012
# 43                             138446858475.700012
# 44                             185905051377.899994
# 45                             214206935067.299988
# 46                                  249832035581.0
# 47                             311276773723.700012
# 48                             416328308281.200012
# 49                             419311363943.599976
# 50                             406462229699.799988
# 51                             417886400642.799988
# 52                             544355500577.799988
# 53                             591836363065.800049
# 54                             668513124292.199951
# 55                             554415745561.199951
# 56                             492191137727.200012
# 57                             535225173047.299988
# 58                             519202537324.599976
# 59                             477785389198.200012
# 60                             485793305491.700012
# 61                             460933940334.799988
# 62                                  472158073713.0
# 63                             376117000821.900024
# 64                                            <NA>
#
# 0   Net ODA provided to the least developed countries (% of GNI)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Net bilateral aid flows from DAC donors, Sweden (current US$)
# 35                                          6000000.0
# 36                                    12189999.580383
# 37                                    18969999.313354
# 38                                    14289999.961853
# 39                                    21239999.771118
# 40                                     18850000.38147
# 41                                    31639999.389648
# 42                                    32529998.779297
# 43                                     31649999.61853
# 44                                         40250000.0
# 45                                    69650001.525879
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# [30 rows x 1479 columns]

# %%
# checking the number of null values in each column
russia_data.isna().sum()
# Out:
# 0
# Year                                                                                                       0
# Intentional homicides, male (per 100,000 male)                                                             2
# Internally displaced persons, new displacement associated with conflict and violence (number of cases)    29
# Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval                          6
# Travel services (% of commercial service exports)                                                          1
#                                                                                                           ..
# Short-term debt (% of exports of goods, services and primary income)                                       1
# External debt stocks, private nonguaranteed (PNG) (DOD, current US$)                                       4
# External debt stocks, total (DOD, current US$)                                                             1
# Net ODA provided to the least developed countries (% of GNI)                                              30
# Net bilateral aid flows from DAC donors, Sweden (current US$)                                             19
# Length: 1479, dtype: int64

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = russia_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Population in urban agglomerations of more than 1 million', 0),
#  ('Population in the largest city (% of urban population)', 0),
#  ('Unemployment, male (% of male labor force) (modeled ILO estimate)', 0),
#  ('Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Population in largest city', 0),
#  ('Net migration', 0),
#  ('Unemployment, total (% of total labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, female (% of female labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force, total', 0),
#  ('Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, male (%) (modeled ILO estimate)', 0),
#  ('Women Business and the Law Index Score (scale 1-100)', 0),
#  ('Population in urban agglomerations of more than 1 million (% of total population)',
#   0),
#  ('Labor force, female (% of total labor force)', 0),
#  ('Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, total (%) (modeled ILO estimate)', 0),
#  ('Employment to population ratio, 15+, female (%) (modeled ILO estimate)', 0),
#  ('Travel services (% of commercial service exports)', 1),
#  ('Commercial service exports (current US$)', 1),
#  ('Transport services (% of commercial service imports)', 1),
#  ('Urban population growth (annual %)', 1),
#  ('Population, female (% of total population)', 1),
#  ('Age dependency ratio (% of working-age population)', 1),
#  ('Population ages 75-79, male (% of male population)', 1),
#  ('Population ages 65 and above (% of total population)', 1),
#  ('Population ages 65 and above, female (% of female population)', 1),
#  ('Population ages 60-64, male (% of male population)', 1),
#  ('Population ages 50-54, male (% of male population)', 1),
#  ('Population ages 40-44, male (% of male population)', 1),
#  ('Population ages 30-34, male (% of male population)', 1),
#  ('Population ages 20-24, male (% of male population)', 1),
#  ('Population ages 15-64, male (% of male population)', 1),
#  ('Population ages 15-19, male (% of male population)', 1),
#  ('Population ages 05-09, male (% of male population)', 1),
#  ('Population ages 0-14, male (% of male population)', 1),
#  ('Population ages 00-04, male (% of male population)', 1),
#  ('PPP conversion factor, private consumption (LCU per international $)', 1),
#  ('DEC alternative conversion factor (LCU per US$)', 1),
#  ('Net secondary income (Net current transfers from abroad) (current US$)', 1),
#  ('Gross savings (% of GNI)', 1),
#  ('GNI per capita, PPP (current international $)', 1),
#  ('GNI per capita (current LCU)', 1),
#  ('GNI (current LCU)', 1),
#  ('Gross domestic savings (% of GDP)', 1),
#  ('GDP per capita growth (annual %)', 1),
#  ('GDP growth (annual %)', 1),
#  ('GDP (current US$)', 1),
#  ('Gross value added at basic prices (GVA) (constant 2015 US$)', 1),
#  ('Discrepancy in expenditure estimate of GDP (current LCU)', 1),
#  ('Inflation, GDP deflator (annual %)', 1),
#  ('Services, value added (constant LCU)', 1),
#  ('Services, value added (current US$)', 1),
#  ('Industry (including construction), value added (% of GDP)', 1),
#  ('Industry (including construction), value added (current LCU)', 1),
#  ('External balance on goods and services (current US$)', 1),
#  ('Imports of goods and services (constant 2015 US$)', 1),
#  ('Gross capital formation (constant LCU)', 1),
#  ('Gross capital formation (current US$)', 1),
#  ('Gross fixed capital formation (% of GDP)', 1),
#  ('Gross fixed capital formation (current LCU)', 1),
#  ('Exports of goods and services (% of GDP)', 1),
#  ('Exports of goods and services (current LCU)', 1),
#  ('Gross national expenditure (constant 2015 US$)', 1),
#  ('Final consumption expenditure (% of GDP)', 1),
#  ('Final consumption expenditure (current LCU)', 1),
#  ('Households and NPISHs Final consumption expenditure, PPP (current international $)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (current US$)', 1),
#  ('General government final consumption expenditure (constant 2015 US$)', 1),
#  ('Individuals using the Internet (% of population)', 1),
#  ('Mobile cellular subscriptions', 1),
#  ('Secondary income receipts (BoP, current US$)', 1),
#  ('Travel services (% of service exports, BoP)', 1),
#  ('Service exports (BoP, current US$)', 1),
#  ('Primary income receipts (BoP, current US$)', 1),
#  ('Net trade in goods (BoP, current US$)', 1),
#  ('Current account balance (% of GDP)', 1),
#  ('Foreign direct investment, net outflows (% of GDP)', 1),
#  ('Imports of goods, services and primary income (BoP, current US$)', 1),
#  ('Insurance and financial services (% of service imports, BoP)', 1),
#  ('Trade in services (% of GDP)', 1),
#  ('Food production index (2014-2016 = 100)', 1),
#  ('Travel services (% of commercial service imports)', 1),
#  ('Merchandise imports (current US$)', 1),
#  ('Insurance and financial services (% of commercial service imports)', 1),
#  ('Urban population', 1),
#  ('Rural population', 1),
#  ('Population, male', 1),
#  ('Age dependency ratio, old (% of working-age population)', 1),
#  ('Population ages 80 and above, female (% of female population)', 1),
#  ('Population ages 70-74, female (% of female population)', 1),
#  ('Population ages 65 and above, male', 1),
#  ('Population ages 65-69, female (% of female population)', 1),
#  ('Population ages 55-59, female (% of female population)', 1),
#  ('Population ages 45-49, female (% of female population)', 1),
#  ('Population ages 35-39, female (% of female population)', 1),
#  ('Population ages 25-29, female (% of female population)', 1),
#  ('Population ages 15-64, total', 1),
#  ('Population ages 15-64, female', 1),
#  ('Population ages 10-14, female (% of female population)', 1),
#  ('Population ages 0-14, total', 1),
#  ('Population ages 0-14, female', 1),
#  ('Unemployment, male (% of male labor force) (national estimate)', 1),
#  ('Agriculture, forestry, and fishing, value added (constant LCU)', 1),
#  ('Agriculture, forestry, and fishing, value added (current US$)', 1),
#  ('Imports of goods and services (constant LCU)', 1),
#  ('Imports of goods and services (current US$)', 1),
#  ('Gross capital formation (constant 2015 US$)', 1),
#  ('Changes in inventories (current LCU)', 1),
#  ('Gross fixed capital formation (annual % growth)', 1),
#  ('Exports of goods and services (annual % growth)', 1),
#  ('Gross national expenditure (% of GDP)', 1),
#  ('Gross national expenditure (current US$)', 1),
#  ('Final consumption expenditure (annual % growth)', 1),
#  ('Households and NPISHs final consumption expenditure (% of GDP)', 1),
#  ('Households and NPISHs final consumption expenditure: linked series (current LCU)',
#   1),
#  ('General government final consumption expenditure (constant LCU)', 1),
#  ('General government final consumption expenditure (current US$)', 1),
#  ('Military expenditure (current LCU)', 1),
#  ('Total reserves (% of total external debt)', 1),
#  ('Net secondary income (Net current transfers from abroad) (current LCU)', 1),
#  ('Taxes less subsidies on products (current US$)', 1),
#  ('Gross savings (% of GDP)', 1),
#  ('GNI, PPP (current international $)', 1),
#  ('GNI: linked series (current LCU)', 1),
#  ('Gross domestic income (constant LCU)', 1),
#  ('GDP per capita (constant LCU)', 1),
#  ('GDP per capita (current US$)', 1),
#  ('GDP (constant LCU)', 1),
#  ('GDP (current LCU)', 1),
#  ('Gross value added at basic prices (GVA) (constant LCU)', 1),
#  ('Inflation, GDP deflator: linked series (annual %)', 1),
#  ('Services, value added (% of GDP)', 1),
#  ('Services, value added (current LCU)', 1),
#  ('Industry (including construction), value added (constant 2015 US$)', 1),
#  ('Agriculture, forestry, and fishing, value added (% of GDP)', 1),
#  ('Agriculture, forestry, and fishing, value added (current LCU)', 1),
#  ('External balance on goods and services (% of GDP)', 1),
#  ('Imports of goods and services (% of GDP)', 1),
#  ('Imports of goods and services (current LCU)', 1),
#  ('Total reserves (includes gold, current US$)', 1),
#  ('Public and publicly guaranteed debt service (% of exports of goods, services and primary income)',
#   1),
#  ('Foreign direct investment, net inflows (BoP, current US$)', 1),
#  ('Charges for the use of intellectual property, receipts (BoP, current US$)',
#   1),
#  ('Exports of goods and services (BoP, current US$)', 1),
#  ('ICT service exports (BoP, current US$)', 1),
#  ('Net secondary income (BoP, current US$)', 1),
#  ('Net errors and omissions (BoP, current US$)', 1),
#  ('Net financial account (BoP, current US$)', 1),
#  ('Transport services (% of service imports, BoP)', 1),
#  ('Goods imports (BoP, current US$)', 1),
#  ('Communications, computer, etc. (% of service imports, BoP)', 1),
#  ('Livestock production index (2014-2016 = 100)', 1),
#  ('Merchandise exports (current US$)', 1),
#  ('Insurance and financial services (% of commercial service exports)', 1),
#  ('Computer, communications and other services (% of commercial service imports)',
#   1),
#  ('Merchandise trade (% of GDP)', 1),
#  ('Urban population (% of total population)', 1),
#  ('Rural population growth (annual %)', 1),
#  ('Population, male (% of total population)', 1),
#  ('Population, total', 1),
#  ('Age dependency ratio, young (% of working-age population)', 1),
#  ('Population ages 80 and above, male (% of male population)', 1),
#  ('Population ages 70-74, male (% of male population)', 1),
#  ('Population ages 65 and above, male (% of male population)', 1),
#  ('Population ages 65-69, male (% of male population)', 1),
#  ('Population ages 55-59, male (% of male population)', 1),
#  ('Population ages 45-49, male (% of male population)', 1),
#  ('Population ages 35-39, male (% of male population)', 1),
#  ('Population ages 25-29, male (% of male population)', 1),
#  ('Population ages 15-64 (% of total population)', 1),
#  ('Population ages 15-64, female (% of female population)', 1),
#  ('Population ages 10-14, male (% of male population)', 1),
#  ('Population ages 0-14 (% of total population)', 1),
#  ('Population ages 0-14, female (% of female population)', 1),
#  ('Refugee population by country or territory of origin', 1),
#  ('Immunization, DPT (% of children ages 12-23 months)', 1),
#  ('Secondary education, duration (years)', 1),
#  ('Primary education, duration (years)', 1),
#  ('Multilateral debt service (TDS, current US$)', 1),
#  ('Debt service (PPG and IMF only, % of exports of goods, services and primary income)',
#   1),
#  ('Debt service on external debt, total (TDS, current US$)', 1),
#  ('PPG, private creditors (NFL, US$)', 1),
#  ('Commercial banks and other lending (PPG + PNG) (NFL, current US$)', 1),
#  ('IFC, private nonguaranteed (NFL, US$)', 1),
#  ('Net financial flows, IBRD (NFL, current US$)', 1),
#  ('Short-term debt (% of total external debt)', 1),
#  ('External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)',
#   1),
#  ('External debt stocks (% of GNI)', 1),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (national estimate)',
#   1),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (national estimate)',
#   1),
#  ('Labor force participation rate, male (% of male population ages 15+) (national estimate)',
#   1),
#  ('Labor force participation rate, female (% of female population ages 15+) (national estimate)',
#   1),
#  ('Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Employment to population ratio, 15+, total (%) (national estimate)', 1),
#  ('Employment to population ratio, 15+, female (%) (national estimate)', 1),
#  ('Self-employed, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Total reserves minus gold (current US$)', 1),
#  ('Personal remittances, received (current US$)', 1),
#  ('Foreign direct investment, net inflows (% of GDP)', 1),
#  ('Exports of goods, services and primary income (BoP, current US$)', 1),
#  ('Insurance and financial services (% of service exports, BoP)', 1),
#  ('ICT service exports (% of service exports, BoP)', 1),
#  ('Net capital account (BoP, current US$)', 1),
#  ('Foreign direct investment, net (BoP, current US$)', 1),
#  ('Net primary income (BoP, current US$)', 1),
#  ('Personal remittances, paid (current US$)', 1),
#  ('Travel services (% of service imports, BoP)', 1),
#  ('Service imports (BoP, current US$)', 1),
#  ('Primary income payments (BoP, current US$)', 1),
#  ('Cereal production (metric tons)', 1),
#  ('Agriculture, forestry, and fishing, value added (annual % growth)', 1),
#  ('External balance on goods and services (current LCU)', 1),
#  ('Imports of goods and services (annual % growth)', 1),
#  ('Gross capital formation (% of GDP)', 1),
#  ('Gross capital formation (current LCU)', 1),
#  ('Changes in inventories (current US$)', 1),
#  ('Gross fixed capital formation (constant 2015 US$)', 1),
#  ('Exports of goods and services (constant 2015 US$)', 1),
#  ('Gross national expenditure (constant LCU)', 1),
#  ('Gross national expenditure deflator (base year varies by country)', 1),
#  ('Final consumption expenditure (constant 2015 US$)', 1),
#  ('Households and NPISHs Final consumption expenditure (current LCU)', 1),
#  ('General government final consumption expenditure (annual % growth)', 1),
#  ('Arms exports (SIPRI trend indicator values)', 1),
#  ('Military expenditure (current USD)', 1),
#  ('Multilateral debt service (% of public and publicly guaranteed debt service)',
#   1),
#  ('Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)',
#   1),
#  ('Total debt service (% of exports of goods, services and primary income)',
#   1),
#  ('PPG, official creditors (NFL, US$)', 1),
#  ('Land under cereal production (hectares)', 1),
#  ('Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, male (%) (national estimate)',
#   1),
#  ('Employment in services, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employers, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Employment to population ratio, ages 15-24, total (%) (national estimate)',
#   1),
#  ('Employment to population ratio, ages 15-24, female (%) (national estimate)',
#   1),
#  ('Lower secondary school starting age (years)', 1),
#  ('Transport services (% of commercial service exports)', 1),
#  ('Computer, communications and other services (% of commercial service exports)',
#   1),
#  ('Commercial service imports (current US$)', 1),
#  ('Rural population (% of total population)', 1),
#  ('Population, female', 1),
#  ('Population growth (annual %)', 1),
#  ('Population ages 75-79, female (% of female population)', 1),
#  ('Population ages 65 and above, total', 1),
#  ('Population ages 65 and above, female', 1),
#  ('Population ages 60-64, female (% of female population)', 1),
#  ('Population ages 50-54, female (% of female population)', 1),
#  ('Population ages 40-44, female (% of female population)', 1),
#  ('Population ages 30-34, female (% of female population)', 1),
#  ('Population ages 20-24, female (% of female population)', 1),
#  ('Population ages 15-64, male', 1),
#  ('Population ages 15-19, female (% of female population)', 1),
#  ('Population ages 05-09, female (% of female population)', 1),
#  ('Population ages 0-14, male', 1),
#  ('Population ages 00-04, female (% of female population)', 1),
#  ('Immunization, measles (% of children ages 12-23 months)', 1),
#  ('Primary school starting age (years)', 1),
#  ('Real effective exchange rate index (2010 = 100)', 1),
#  ('PPP conversion factor, GDP (LCU per international $)', 1),
#  ('Taxes less subsidies on products (current LCU)', 1),
#  ('Net primary income (Net income from abroad) (current US$)', 1),
#  ('Gross savings (current US$)', 1),
#  ('GNI, Atlas method (current US$)', 1),
#  ('Gross domestic savings (current US$)', 1),
#  ('GDP per capita, PPP (current international $)', 1),
#  ('GDP per capita (current LCU)', 1),
#  ('GDP, PPP (current international $)', 1),
#  ('GDP: linked series (current LCU)', 1),
#  ('Gross value added at basic prices (GVA) (current US$)', 1),
#  ('GDP deflator (base year varies by country)', 1),
#  ('Exports as a capacity to import (constant LCU)', 1),
#  ('Services, value added (constant 2015 US$)', 1),
#  ('Industry (including construction), value added (annual % growth)', 1),
#  ('Agriculture, forestry, and fishing, value added (constant 2015 US$)', 1),
#  ('Trade (% of GDP)', 1),
#  ('Total reserves in months of imports', 1),
#  ('PPG, IBRD (DOD, current US$)', 1),
#  ('External debt stocks, short-term (DOD, current US$)', 1),
#  ('Use of IMF credit (DOD, current US$)', 1),
#  ('Personal remittances, received (% of GDP)', 1),
#  ('Portfolio equity, net inflows (BoP, current US$)', 1),
#  ('Transport services (% of service exports, BoP)', 1),
#  ('Goods exports (BoP, current US$)', 1),
#  ('Communications, computer, etc. (% of service exports, BoP)', 1),
#  ('Portfolio investment, net (BoP, current US$)', 1),
#  ('Net trade in goods and services (BoP, current US$)', 1),
#  ('Current account balance (BoP, current US$)', 1),
#  ('Foreign direct investment, net outflows (BoP, current US$)', 1),
#  ('Charges for the use of intellectual property, payments (BoP, current US$)',
#   1),
#  ('Imports of goods and services (BoP, current US$)', 1),
#  ('Cereal yield (kg per hectare)', 1),
#  ('Crop production index (2014-2016 = 100)', 1),
#  ('Unemployment, total (% of total labor force) (national estimate)', 1),
#  ('Unemployment, female (% of female labor force) (national estimate)', 1),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (national estimate)',
#   1),
#  ('Labor force participation rate, total (% of total population ages 15+) (national estimate)',
#   1),
#  ('Ratio of female to male labor force participation rate (%) (national estimate)',
#   1),
#  ('GDP per person employed (constant 2017 PPP $)', 1),
#  ('Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment to population ratio, 15+, male (%) (national estimate)', 1),
#  ('Self-employed, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Employers, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Price level ratio of PPP conversion factor (GDP) to market exchange rate',
#   1),
#  ('Terms of trade adjustment (constant LCU)', 1),
#  ('Taxes less subsidies on products (constant LCU)', 1),
#  ('Net primary income (Net income from abroad) (current LCU)', 1),
#  ('Gross savings (current LCU)', 1),
#  ('GNI per capita, Atlas method (current US$)', 1),
#  ('GNI growth (annual %)', 1),
#  ('GNI (current US$)', 1),
#  ('Gross domestic savings (current LCU)', 1),
#  ('GDP per capita, PPP (constant 2017 international $)', 1),
#  ('GDP per capita (constant 2015 US$)', 1),
#  ('GDP, PPP (constant 2017 international $)', 1),
#  ('GDP (constant 2015 US$)', 1),
#  ('Gross value added at basic prices (GVA) (current LCU)', 1),
#  ('GDP deflator: linked series (base year varies by country)', 1),
#  ('Services, value added (annual % growth)', 1),
#  ('Industry (including construction), value added (constant LCU)', 1),
#  ('Industry (including construction), value added (current US$)', 1),
#  ('Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, total (%) (national estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, female (%) (national estimate)',
#   1),
#  ('Employment in services (% of total employment) (modeled ILO estimate)', 1),
#  ('Employment in industry (% of total employment) (modeled ILO estimate)', 1),
#  ('Contributing family workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employers, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment to population ratio, ages 15-24, male (%) (national estimate)',
#   1),
#  ('Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Public and publicly guaranteed debt service (% of GNI)', 1),
#  ('Total debt service (% of GNI)', 1),
#  ('Net financial flows, RDB nonconcessional (NFL, current US$)', 1),
#  ('Net financial flows, multilateral (NFL, current US$)', 1),
#  ('Short-term debt (% of total reserves)', 1),
#  ('External debt stocks, long-term (DOD, current US$)', 1),
#  ('Gross capital formation (annual % growth)', 1),
#  ('Changes in inventories (constant LCU)', 1),
#  ('Gross fixed capital formation (constant LCU)', 1),
#  ('Gross fixed capital formation (current US$)', 1),
#  ('Exports of goods and services (constant LCU)', 1),
#  ('Exports of goods and services (current US$)', 1),
#  ('Gross national expenditure (current LCU)', 1),
#  ('Final consumption expenditure (constant LCU)', 1),
#  ('Final consumption expenditure (current US$)', 1),
#  ('General government final consumption expenditure (% of GDP)', 1),
#  ('General government final consumption expenditure (current LCU)', 1),
#  ('Military expenditure (% of GDP)', 1),
#  ('IMF repurchases and charges (TDS, current US$)', 1),
#  ('PPG, commercial banks (NFL, current US$)', 1),
#  ('Net financial flows, bilateral (NFL, current US$)', 1),
#  ('IBRD loans and IDA credits (DOD, current US$)', 1),
#  ('Short-term debt (% of exports of goods, services and primary income)', 1),
#  ('External debt stocks, total (DOD, current US$)', 1),
#  ('Intentional homicides, male (per 100,000 male)', 2),
#  ('Survival to age 65, female (% of cohort)', 2),
#  ('Life expectancy at birth, female (years)', 2),
#  ('Oil rents (% of GDP)', 2),
#  ('Natural gas rents (% of GDP)', 2),
#  ('Adjusted net savings, excluding particulate emission damage (current US$)',
#   2),
#  ('Adjusted net national income per capita (constant 2015 US$)', 2),
#  ('Adjusted net national income (current US$)', 2),
#  ('Adjusted savings: natural resources depletion (% of GNI)', 2),
#  ('Adjusted savings: energy depletion (current US$)', 2),
#  ('Adjusted savings: consumption of fixed capital (current US$)', 2),
#  ('Adjusted savings: carbon dioxide damage (current US$)', 2),
#  ('Other manufacturing (% of value added in manufacturing)', 2),
#  ('Air transport, registered carrier departures worldwide', 2),
#  ('Reserves and related items (BoP, current US$)', 2),
#  ('Permanent cropland (% of land area)', 2),
#  ('Arable land (hectares)', 2),
#  ('Fertilizer consumption (% of fertilizer production)', 2),
#  ('Intentional homicides (per 100,000 people)', 2),
#  ('Survival to age 65, male (% of cohort)', 2),
#  ('Life expectancy at birth, total (years)', 2),
#  ('Mortality rate, infant, female (per 1,000 live births)', 2),
#  ('Birth rate, crude (per 1,000 people)', 2),
#  ('Fixed telephone subscriptions', 2),
#  ('Air transport, passengers carried', 2),
#  ('Patent applications, residents', 2),
#  ('Aquaculture production (metric tons)', 2),
#  ('Total natural resources rents (% of GDP)', 2),
#  ('Adjusted net savings, excluding particulate emission damage (% of GNI)', 2),
#  ('Adjusted net national income per capita (annual % growth)', 2),
#  ('Adjusted net national income (constant 2015 US$)', 2),
#  ('Adjusted savings: gross savings (% of GNI)', 2),
#  ('Adjusted savings: energy depletion (% of GNI)', 2),
#  ('Adjusted savings: consumption of fixed capital (% of GNI)', 2),
#  ('Adjusted savings: carbon dioxide damage (% of GNI)', 2),
#  ('Medium and high-tech manufacturing value added (% manufacturing value added)',
#   2),
#  ('Chemicals (% of value added in manufacturing)', 2),
#  ('Access to electricity, urban (% of urban population)', 2),
#  ('Listed domestic companies, total', 2),
#  ('Secondary income, other sectors, payments (BoP, current US$)', 2),
#  ('Arable land (hectares per person)', 2),
#  ('Fertilizer consumption (kilograms per hectare of arable land)', 2),
#  ('Life expectancy at birth, male (years)', 2),
#  ('Mortality rate, infant (per 1,000 live births)', 2),
#  ('Death rate, crude (per 1,000 people)', 2),
#  ('Adolescent fertility rate (births per 1,000 women ages 15-19)', 2),
#  ('Probability of dying among adolescents ages 10-14 years (per 1,000)', 2),
#  ('Number of under-five deaths', 2),
#  ('Number of deaths ages 20-24 years', 2),
#  ('Access to electricity (% of population)', 2),
#  ('Portfolio investment, bonds (PPG + PNG) (NFL, current US$)', 2),
#  ('Inflation, consumer prices (annual %)', 2),
#  ('Total fisheries production (metric tons)', 2),
#  ('Surface area (sq. km)', 2),
#  ('Land area (sq. km)', 2),
#  ('Forest area (sq. km)', 2),
#  ('Arable land (% of land area)', 2),
#  ('Agricultural land (sq. km)', 2),
#  ('Mobile cellular subscriptions (per 100 people)', 2),
#  ('Air transport, freight (million ton-km)', 2),
#  ('Patent applications, nonresidents', 2),
#  ('Forest area (% of land area)', 2),
#  ('Agricultural land (% of land area)', 2),
#  ('Mortality rate, neonatal (per 1,000 live births)', 2),
#  ('Mortality rate, under-5, male (per 1,000 live births)', 2),
#  ("Women's share of population ages 15+ living with HIV (%)", 2),
#  ('Probability of dying among children ages 5-9 years (per 1,000)', 2),
#  ('Number of deaths ages 15-19 years', 2),
#  ('Intentional homicides, female (per 100,000 female)', 2),
#  ('Medium and high-tech exports (% manufactured exports)', 2),
#  ('Sex ratio at birth (male births per female births)', 2),
#  ('Fertility rate, total (births per woman)', 2),
#  ('Mortality rate, infant, male (per 1,000 live births)', 2),
#  ('Mortality rate, under-5 (per 1,000 live births)', 2),
#  ('Probability of dying among adolescents ages 15-19 years (per 1,000)', 2),
#  ('Number of deaths ages 5-9 years', 2),
#  ('Forest rents (% of GDP)', 2),
#  ('Adjusted net savings, including particulate emission damage (current US$)',
#   2),
#  ('Adjusted net national income (annual % growth)', 2),
#  ('Adjusted savings: net national savings (current US$)', 2),
#  ('Adjusted savings: particulate emission damage (current US$)', 2),
#  ('Adjusted savings: mineral depletion (current US$)', 2),
#  ('Adjusted savings: net forest depletion (current US$)', 2),
#  ('Adjusted savings: education expenditure (current US$)', 2),
#  ('Textiles and clothing (% of value added in manufacturing)', 2),
#  ('Food, beverages and tobacco (% of value added in manufacturing)', 2),
#  ('Consumer price index (2010 = 100)', 2),
#  ('Capture fisheries production (metric tons)', 2),
#  ('Population density (people per sq. km of land area)', 2),
#  ('Mineral rents (% of GDP)', 2),
#  ('Coal rents (% of GDP)', 2),
#  ('Adjusted net savings, including particulate emission damage (% of GNI)', 2),
#  ('Adjusted net national income per capita (current US$)', 2),
#  ('Adjusted savings: net national savings (% of GNI)', 2),
#  ('Adjusted savings: particulate emission damage (% of GNI)', 2),
#  ('Adjusted savings: mineral depletion (% of GNI)', 2),
#  ('Adjusted savings: net forest depletion (% of GNI)', 2),
#  ('Adjusted savings: education expenditure (% of GNI)', 2),
#  ('Machinery and transport equipment (% of value added in manufacturing)', 2),
#  ('Access to electricity, rural (% of rural population)', 2),
#  ('PPG, bonds (NFL, current US$)', 2),
#  ('Mortality rate, under-5, female (per 1,000 live births)', 2),
#  ('Probability of dying among youth ages 20-24 years (per 1,000)', 2),
#  ('Number of neonatal deaths', 2),
#  ('Number of infant deaths', 2),
#  ('Number of deaths ages 10-14 years', 2),
#  ('Fixed telephone subscriptions (per 100 people)', 2),
#  ('Merchandise exports by the reporting economy (current US$)', 3),
#  ('Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies within region (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from economies in the Arab World (% of total merchandise imports)',
#   3),
#  ('Armed forces personnel (% of total labor force)', 3),
#  ('Railways, passengers carried (million passenger-km)', 3),
#  ('Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   3),
#  ('Import value index (2015 = 100)', 3),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   3),
#  ('Refugee population by country or territory of asylum', 3),
#  ('Households and NPISHs Final consumption expenditure per capita (constant 2015 US$)',
#   3),
#  ('Annual freshwater withdrawals, total (billion cubic meters)', 3),
#  ('Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
#   3),
#  ('Nitrous oxide emissions (thousand metric tons of CO2 equivalent)', 3),
#  ('Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (metric tons per capita)', 3),
#  ('CO2 emissions (kg per 2015 US$ of GDP)', 3),
#  ('Official exchange rate (LCU per US$, period average)', 3),
#  ('Renewable internal freshwater resources per capita (cubic meters)', 3),
#  ('Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
#   3),
#  ('Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)',
#   3),
#  ('Total greenhouse gas emissions (kt of CO2 equivalent)', 3),
#  ('Renewable energy consumption (% of total final energy consumption)', 3),
#  ('Average precipitation in depth (mm per year)', 3),
#  ('Export value index (2015 = 100)', 3),
#  ('Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#   3),
#  ('Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from high-income economies (% of total merchandise imports)',
#   3),
#  ('Renewable internal freshwater resources, total (billion cubic meters)', 3),
#  ('Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
#   3),
#  ('Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions (kt of CO2 equivalent)', 3),
#  ('Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (kg per 2017 PPP $ of GDP)', 3),
#  ('Households and NPISHs Final consumption expenditure, PPP (constant 2017 international $)',
#   3),
#  ('Households and NPISHs Final consumption expenditure (constant LCU)', 3),
#  ('Rail lines (total route-km)', 3),
#  ('Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to high-income economies (% of total merchandise exports)',
#   3),
#  ('Merchandise imports by the reporting economy (current US$)', 3),
#  ('Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#   3),
#  ('Births attended by skilled health staff (% of total)', 3),
#  ('Physicians (per 1,000 people)', 3),
#  ('Annual freshwater withdrawals, total (% of internal resources)', 3),
#  ('Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
#   3),
#  ('CO2 emissions (kg per PPP $ of GDP)', 3),
#  ('CO2 emissions (kt)', 3),
#  ('Households and NPISHs Final consumption expenditure (constant 2015 US$)',
#   3),
#  ('Armed forces personnel, total', 3),
#  ('Railways, goods transported (million ton-km)', 3),
#  ('Ores and metals exports (% of merchandise exports)', 4),
#  ('Fuel exports (% of merchandise exports)', 4),
#  ('International tourism, number of arrivals', 4),
#  ('Industry (including construction), value added per worker (constant 2015 US$)',
#   4),
#  ('Households and NPISHs Final consumption expenditure (annual % growth)', 4),
#  ('Agricultural raw materials imports (% of merchandise imports)', 4),
#  ('International tourism, number of departures', 4),
#  ('Expense (current LCU)', 4),
#  ('Net lending (+) / net borrowing (-) (% of GDP)', 4),
#  ('Deposit interest rate (%)', 4),
#  ('Net lending (+) / net borrowing (-) (current LCU)', 4),
#  ('Real interest rate (%)', 4),
#  ('Agricultural raw materials exports (% of merchandise exports)', 4),
#  ('Manufactures imports (% of merchandise imports)', 4),
#  ('Food imports (% of merchandise imports)', 4),
#  ('International tourism, receipts for travel items (current US$)', 4),
#  ('Revenue, excluding grants (% of GDP)', 4),
#  ('Interest rate spread (lending rate minus deposit rate, %)', 4),
#  ('Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)',
#   4),
#  ('Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)',
#   4),
#  ('Battle-related deaths (number of people)', 4),
#  ('Manufactures exports (% of merchandise exports)', 4),
#  ('Food exports (% of merchandise exports)', 4),
#  ('Ores and metals imports (% of merchandise imports)', 4),
#  ('Fuel imports (% of merchandise imports)', 4),
#  ('International tourism, expenditures for travel items (current US$)', 4),
#  ('Expense (% of GDP)', 4),
#  ('Revenue, excluding grants (current LCU)', 4),
#  ('Lending interest rate (%)', 4),
#  ('Services, value added per worker (constant 2015 US$)', 4),
#  ('Households and NPISHs Final consumption expenditure per capita growth (annual %)',
#   4),
#  ('PPG, other private creditors (NFL, current US$)', 4),
#  ('Net financial flows, others (NFL, current US$)', 4),
#  ('External debt stocks, private nonguaranteed (PNG) (DOD, current US$)', 4),
#  ('Researchers in R&D (per million people)', 5),
#  ('Military expenditure (% of general government expenditure)', 5),
#  ('Scientific and technical journal articles', 5),
#  ('Gross fixed capital formation, private sector (% of GDP)', 5),
#  ('Investment in energy with private participation (current US$)', 5),
#  ('Customs and other import duties (current LCU)', 5),
#  ('Taxes on exports (current LCU)', 5),
#  ('School enrollment, tertiary (% gross)', 5),
#  ('Goods and services expense (% of expense)', 5),
#  ('Research and development expenditure (% of GDP)', 5),
#  ('S&P Global Equity Indices (annual % change)', 5),
#  ('Gross fixed capital formation, private sector (current LCU)', 5),
#  ('PNG, bonds (NFL, current US$)', 5),
#  ('Compulsory education, duration (years)', 5),
#  ('Preprimary education, duration (years)', 5),
#  ('Goods and services expense (current LCU)', 5),
#  ('PNG, commercial banks and other creditors (NFL, current US$)', 5),
#  ('Hospital beds (per 1,000 people)', 5),
#  ('Proportion of seats held by women in national parliaments (%)', 5),
#  ('Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Rule of Law: Standard Error', 6),
#  ('Rule of Law: Number of Sources', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Political Stability and Absence of Violence/Terrorism: Estimate', 6),
#  ('Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Control of Corruption: Estimate', 6),
#  ('Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Voice and Accountability: Estimate', 6),
#  ('Government Effectiveness: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Government Effectiveness: Estimate', 6),
#  ('Taxes on income, profits and capital gains (current LCU)', 6),
#  ('Other taxes (current LCU)', 6),
#  ('Net incurrence of liabilities, total (% of GDP)', 6),
#  ('Net acquisition of financial assets (% of GDP)', 6),
#  ('Rule of Law: Percentile Rank', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Standard Error', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Number of Sources',
#   6),
#  ('Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Taxes on international trade (% of revenue)', 6),
#  ('Net incurrence of liabilities, total (current LCU)', 6),
#  ('Net acquisition of financial assets (current LCU)', 6),
#  ('Control of Corruption: Standard Error', 6),
#  ('Control of Corruption: Number of Sources', 6),
#  ('Voice and Accountability: Standard Error', 6),
#  ('Voice and Accountability: Number of Sources', 6),
#  ('School enrollment, primary (% gross)', 6),
#  ('Poverty gap at $2.15 a day (2017 PPP) (%)', 6),
#  ('Proportion of people living below 50 percent of median income (%)', 6),
#  ('Income share held by third 20%', 6),
#  ('Government Effectiveness: Percentile Rank', 6),
#  ('Taxes on international trade (current LCU)', 6),
#  ('Grants and other revenue (% of revenue)', 6),
#  ('Control of Corruption: Percentile Rank', 6),
#  ('Poverty gap at $3.65 a day (2017 PPP) (%)', 6),
#  ('Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)', 6),
#  ('Income share held by highest 10%', 6),
#  ('Income share held by second 20%', 6),
#  ('Voice and Accountability: Percentile Rank', 6),
#  ('Primary education, pupils', 6),
#  ('Regulatory Quality: Standard Error', 6),
#  ('Regulatory Quality: Number of Sources', 6),
#  ('Rule of Law: Percentile Rank, Lower Bound of 90% Confidence Interval', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank', 6),
#  ('Government Effectiveness: Standard Error', 6),
#  ('Government Effectiveness: Number of Sources', 6),
#  ('Taxes on income, profits and capital gains (% of revenue)', 6),
#  ('Other taxes (% of revenue)', 6),
#  ('Grants and other revenue (current LCU)', 6),
#  ('Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Poverty gap at $6.85 a day (2017 PPP) (%)', 6),
#  ('Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)', 6),
#  ('Income share held by lowest 20%', 6),
#  ('Income share held by highest 20%', 6),
#  ('Regulatory Quality: Percentile Rank', 6),
#  ('Rule of Law: Percentile Rank, Upper Bound of 90% Confidence Interval', 6),
#  ('Rule of Law: Estimate', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)', 6),
#  ('Gini index', 6),
#  ('Income share held by lowest 10%', 6),
#  ('Income share held by fourth 20%', 6),
#  ('Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Estimate', 6),
#  ('Technicians in R&D (per million people)', 7),
#  ('Social contributions (% of revenue)', 7),
#  ('CO2 emissions from solid fuel consumption (% of total)', 7),
#  ('Tax revenue (% of GDP)', 7),
#  ('Taxes on goods and services (% value added of industry and services)', 7),
#  ('Social contributions (current LCU)', 7),
#  ('CO2 emissions from solid fuel consumption (kt)', 7),
#  ('CO2 emissions from liquid fuel consumption (% of total)', 7),
#  ('CO2 emissions from gaseous fuel consumption (% of total)', 7),
#  ('Nurses and midwives (per 1,000 people)', 7),
#  ('Incidence of tuberculosis (per 100,000 people)', 7),
#  ('People practicing open defecation, rural (% of rural population)', 7),
#  ('Taxes on income, profits and capital gains (% of total taxes)', 7),
#  ('Tax revenue (current LCU)', 7),
#  ('Taxes on goods and services (% of revenue)', 7),
#  ('CO2 emissions from liquid fuel consumption (kt)', 7),
#  ('CO2 emissions from gaseous fuel consumption (kt)', 7),
#  ('Tuberculosis case detection rate (%, all forms)', 7),
#  ('Prevalence of overweight (modeled estimate, % of children under 5)', 7),
#  ('People using safely managed sanitation services (% of population)', 7),
#  ('People practicing open defecation (% of population)', 7),
#  ('People using at least basic sanitation services (% of population)', 7),
#  ('People using at least basic drinking water services (% of population)', 7),
#  ('Secondary education, general pupils', 7),
#  ('People using at least basic sanitation services, rural (% of rural population)',
#   7),
#  ('People using at least basic drinking water services, rural (% of rural population)',
#   7),
#  ('Taxes on goods and services (current LCU)', 7),
#  ('Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#   7),
#  ('People using safely managed sanitation services, urban (% of urban population)',
#   7),
#  ('People practicing open defecation, urban (% of urban population)', 7),
#  ('People using at least basic sanitation services, urban (% of urban population)',
#   7),
#  ('People using safely managed drinking water services (% of population)', 7),
#  ('People using at least basic drinking water services, urban (% of urban population)',
#   7),
#  ('Net financial flows, IMF nonconcessional (NFL, current US$)', 7),
#  ('Export volume index (2015 = 100)', 8),
#  ('ICT goods imports (% total goods imports)', 8),
#  ('Import unit value index (2015 = 100)', 8),
#  ('ICT goods exports (% of total goods exports)', 8),
#  ('Export unit value index (2015 = 100)', 8),
#  ('Interest payments (% of revenue)', 8),
#  ('Compensation of employees (% of expense)', 8),
#  ('Taxes on exports (% of tax revenue)', 8),
#  ('Subsidies and other transfers (% of expense)', 8),
#  ('Other expense (% of expense)', 8),
#  ('Interest payments (current LCU)', 8),
#  ('Compensation of employees (current LCU)', 8),
#  ('Electricity production from oil sources (% of total)', 8),
#  ('Electricity production from hydroelectric sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, urban (% of urban population)',
#   8),
#  ('Net barter terms of trade index (2015 = 100)', 8),
#  ('Maternal mortality ratio (national estimate, per 100,000 live births)', 8),
#  ('Renewable electricity output (% of total electricity output)', 8),
#  ('Access to clean fuels and technologies for cooking (% of population)', 8),
#  ('Subsidies and other transfers (current LCU)', 8),
#  ('Other expense (current LCU)', 8),
#  ('Central government debt, total (% of GDP)', 8),
#  ('Stocks traded, total value (current US$)', 8),
#  ('Electricity production from renewable sources, excluding hydroelectric (kWh)',
#   8),
#  ('Electricity production from natural gas sources (% of total)', 8),
#  ('Electricity production from coal sources (% of total)', 8),
#  ('Energy intensity level of primary energy (MJ/$2017 PPP GDP)', 8),
#  ('Immunization, HepB3 (% of one-year-old children)', 8),
#  ('Import volume index (2015 = 100)', 8),
#  ('Secondary education, pupils', 8),
#  ('Interest payments (% of expense)', 8),
#  ('Customs and other import duties (% of tax revenue)', 8),
#  ('Central government debt, total (current LCU)', 8),
#  ('Stocks traded, total value (% of GDP)', 8),
#  ('Tuberculosis treatment success rate (% of new cases)', 8),
#  ('Electricity production from renewable sources, excluding hydroelectric (% of total)',
#   8),
#  ('Electricity production from oil, gas and coal sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, rural (% of rural population)',
#   8),
#  ('School enrollment, secondary (% gross)', 8),
#  ('Container port traffic (TEU: 20 foot equivalent units)', 8),
#  ('Tariff rate, most favored nation, simple mean, primary products (%)', 9),
#  ('Tariff rate, most favored nation, simple mean, all products (%)', 9),
#  ('Tariff rate, most favored nation, simple mean, manufactured products (%)',
#   9),
#  ('Mortality rate, adult, male (per 1,000 male adults)', 9),
#  ('Fixed broadband subscriptions', 9),
#  ('Share of tariff lines with specific rates, primary products (%)', 9),
#  ('Share of tariff lines with specific rates, all products (%)', 9),
#  ('Share of tariff lines with specific rates, manufactured products (%)', 9),
#  ('Prevalence of undernourishment (% of population)', 9),
#  ('Domestic credit to private sector (% of GDP)', 9),
#  ('CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)',
#   9),
#  ('Manufacturing, value added (constant LCU)', 9),
#  ('Manufacturing, value added (current US$)', 9),
#  ('Monetary Sector credit to private sector (% GDP)', 9),
#  ('CO2 emissions from manufacturing industries and construction (% of total fuel combustion)',
#   9),
#  ('Electric power consumption (kWh per capita)', 9),
#  ('Alternative and nuclear energy (% of total energy use)', 9),
#  ('Personal transfers, receipts (BoP, current US$)', 9),
#  ('Tariff rate, applied, weighted mean, primary products (%)', 9),
#  ('Share of tariff lines with international peaks, primary products (%)', 9),
#  ('Tariff rate, applied, weighted mean, all products (%)', 9),
#  ('Share of tariff lines with international peaks, all products (%)', 9),
#  ('Tariff rate, applied, weighted mean, manufactured products (%)', 9),
#  ('Share of tariff lines with international peaks, manufactured products (%)',
#   9),
#  ('Lifetime risk of maternal death (%)', 9),
#  ('School enrollment, primary (gross), gender parity index (GPI)', 9),
#  ('Energy use (kg of oil equivalent per capita)', 9),
#  ('Fossil fuel energy consumption (% of total)', 9),
#  ('GDP per unit of energy use (PPP $ per kg of oil equivalent)', 9),
#  ('Electric power transmission and distribution losses (% of output)', 9),
#  ('Unemployment with intermediate education, female (% of female labor force with intermediate education)',
#   9),
#  ('Unemployment with advanced education (% of total labor force with advanced education)',
#   9),
# ...
#  ('GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)',
#   9),
#  ('Unemployment with basic education (% of total labor force with basic education)',
#   9),
#  ('Unemployment with advanced education, male (% of male labor force with advanced education)',
#   9),
#  ('Out-of-pocket expenditure per capita, PPP (current international $)', 9),
#  ('Domestic general government health expenditure per capita (current US$)',
#   9),
#  ('Current health expenditure per capita (current US$)', 9),
#  ('Maternal mortality ratio (modeled estimate, per 100,000 live births)', 9),
#  ('Lifetime risk of maternal death (1 in: rate varies by country)', 9),
#  ('Tariff rate, most favored nation, weighted mean, primary products (%)', 9),
#  ('Tariff rate, applied, simple mean, primary products (%)', 9),
#  ('Tariff rate, most favored nation, weighted mean, all products (%)', 9),
#  ('Tariff rate, applied, simple mean, all products (%)', 9),
#  ('Tariff rate, most favored nation, weighted mean, manufactured products (%)',
#   9),
#  ('Tariff rate, applied, simple mean, manufactured products (%)', 9),
#  ('Mortality rate, adult, female (per 1,000 female adults)', 9),
#  ('School enrollment, primary, female (% gross)', 9),
#  ('Manufacturing, value added (% of GDP)', 9),
#  ('Manufacturing, value added (current LCU)', 9),
#  ('Net investment in nonfinancial assets (current LCU)', 9),
#  ('Claims on central government, etc. (% GDP)', 9),
#  ('Net domestic credit (current LCU)', 9),
#  ('Domestic credit to private sector by banks (% of GDP)', 9),
#  ('CO2 emissions from transport (% of total fuel combustion)', 9),
#  ('CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)',
#   9),
#  ('Unemployment with intermediate education (% of total labor force with intermediate education)',
#   9),
#  ('Unemployment with basic education, male (% of male labor force with basic education)',
#   9),
#  ('Unemployment with advanced education, female (% of female labor force with advanced education)',
#   9),
#  ('Domestic private health expenditure per capita, PPP (current international $)',
#   9),
#  ('Out-of-pocket expenditure per capita (current US$)', 9),
#  ('Domestic general government health expenditure (% of general government expenditure)',
#   9),
#  ('Current health expenditure (% of GDP)', 9),
#  ('Manufacturing, value added (constant 2015 US$)', 9),
#  ('Unemployment with intermediate education, male (% of male labor force with intermediate education)',
#   9),
#  ('Unemployment with basic education, female (% of female labor force with basic education)',
#   9),
#  ('Domestic private health expenditure per capita (current US$)', 9),
#  ('Out-of-pocket expenditure (% of current health expenditure)', 9),
#  ('Domestic general government health expenditure (% of GDP)', 9),
#  ('Low-birthweight babies (% of births)', 9),
#  ('Electricity production from nuclear sources (% of total)', 9),
#  ('Number of maternal deaths', 9),
#  ('School enrollment, primary, male (% gross)', 9),
#  ('International tourism, expenditures (current US$)', 10),
#  ('International tourism, receipts for passenger transport items (current US$)',
#   10),
#  ('Manufacturing, value added (annual % growth)', 10),
#  ('International tourism, expenditures (% of total imports)', 10),
#  ('International tourism, expenditures for passenger transport items (current US$)',
#   10),
#  ('Claims on private sector (annual growth as % of broad money)', 10),
#  ('Claims on other sectors of the domestic economy (annual growth as % of broad money)',
#   10),
#  ('Broad money to total reserves ratio', 10),
#  ('Claims on central government (annual growth as % of broad money)', 10),
#  ('International tourism, receipts (current US$)', 10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, female (%)',
#   10),
#  ('Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
#   10),
#  ('Suicide mortality rate, male (per 100,000 male population)', 10),
#  ('Broad money (% of GDP)', 10),
#  ('Fixed broadband subscriptions (per 100 people)', 10),
#  ('Suicide mortality rate, female (per 100,000 female population)', 10),
#  ('Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)',
#   10),
#  ('Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)',
#   10),
#  ('Government expenditure on education, total (% of GDP)', 10),
#  ('International tourism, receipts (% of total exports)', 10),
#  ('Prevalence of anemia among pregnant women (%)', 10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, male (%)',
#   10),
#  ('Prevalence of anemia among children (% of children ages 6-59 months)', 10),
#  ('Broad money (current LCU)', 10),
#  ('Mortality caused by road traffic injury (per 100,000 population)', 10),
#  ('Suicide mortality rate (per 100,000 population)', 10),
#  ('Mortality rate attributed to unintentional poisoning (per 100,000 population)',
#   10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)',
#   10),
#  ('Prevalence of anemia among non-pregnant women (% of women ages 15-49)', 10),
#  ('Government expenditure on education, total (% of government expenditure)',
#   10),
#  ('Broad money growth (annual %)', 11),
#  ('Total greenhouse gas emissions (% change from 1990)', 11),
#  ('Methane emissions (% change from 1990)', 11),
#  ('Secondary education, general pupils (% female)', 11),
#  ('Primary education, teachers', 11),
#  ('Other greenhouse gas emissions (% change from 1990)', 11),
#  ('School enrollment, preprimary (% gross)', 11),
#  ('Primary education, teachers (% female)', 11),
#  ('Gross intake ratio in first grade of primary education, total (% of relevant age group)',
#   11),
#  ('Net secondary income (Net current transfers from abroad) (constant LCU)',
#   11),
#  ('Nitrous oxide emissions (% change from 1990)', 11),
#  ('Lower secondary completion rate, total (% of relevant age group)', 11),
#  ('Primary education, pupils (% female)', 11),
#  ('Statistical performance indicators (SPI): Pillar 1 data use score (scale 0-100)',
#   11),
#  ('Trademark applications, resident, by count', 12),
#  ('Repeaters, primary, total (% of total enrollment)', 12),
#  ('Statistical performance indicators (SPI): Pillar 3 data products score  (scale 0-100)',
#   12),
#  ('Tertiary education, academic staff (% female)', 12),
#  ('School enrollment, primary, private (% of total primary)', 12),
#  ('School enrollment, tertiary (gross), gender parity index (GPI)', 12),
#  ('Risk of catastrophic expenditure for surgical care (% of people at risk)',
#   12),
#  ('School enrollment, tertiary, female (% gross)', 12),
#  ('Risk of impoverishing expenditure for surgical care (% of people at risk)',
#   12),
#  ('School enrollment, tertiary, male (% gross)', 12),
#  ('Trademark applications, nonresident, by count', 12),
#  ('Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)',
#   13),
#  ('Methodology assessment of statistical capacity (scale 0 - 100)', 13),
#  ('Automated teller machines (ATMs) (per 100,000 adults)', 13),
#  ('School enrollment, secondary, male (% gross)', 13),
#  ('Secondary education, vocational pupils', 13),
#  ('Commercial bank branches (per 100,000 adults)', 13),
#  ('Source data assessment of statistical capacity (scale 0 - 100)', 13),
#  ('Pupil-teacher ratio, tertiary', 13),
#  ('School enrollment, secondary, female (% gross)', 13),
#  ('Pupil-teacher ratio, primary', 13),
#  ('School enrollment, secondary (gross), gender parity index (GPI)', 13),
#  ('Statistical Capacity Score (Overall Average) (scale 0 - 100)', 13),
#  ('Investment in transport with private participation (current US$)', 14),
#  ('Liner shipping connectivity index (maximum value in 2004 = 100)', 14),
#  ('GHG net emissions/removals by LUCF (Mt of CO2 equivalent)', 14),
#  ('Agricultural machinery, tractors per 100 sq. km of arable land', 14),
#  ('School enrollment, secondary, private (% of total secondary)', 14),
#  ('Primary completion rate, total (% of relevant age group)', 14),
#  ('Primary government expenditures as a proportion of original approved budget (%)',
#   14),
#  ('Agricultural machinery, tractors', 14),
#  ('School enrollment, primary and secondary (gross), gender parity index (GPI)',
#   14),
#  ('Binding coverage, primary products (%)', 15),
#  ('Binding coverage, all products (%)', 15),
#  ('Binding coverage, manufactured products (%)', 15),
#  ('High-technology exports (current US$)', 15),
#  ('Bound rate, simple mean, primary products (%)', 15),
#  ('Bound rate, simple mean, all products (%)', 15),
#  ('Bound rate, simple mean, manufactured products (%)', 15),
#  ('Arms imports (SIPRI trend indicator values)', 15),
#  ('Public private partnerships investment in energy (current US$)', 15),
#  ('New businesses registered (number)', 15),
#  ('New business density (new registrations per 1,000 people ages 15-64)', 15),
#  ('Bank nonperforming loans to total gross loans (%)', 15),
#  ('Nitrous oxide emissions in energy sector (% of total)', 15),
#  ('Agricultural methane emissions (% of total)', 15),
#  ('High-technology exports (% of manufactured exports)', 15),
#  ('Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)',
#   15),
#  ('Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)',
#   15),
#  ('Children out of school, primary', 15),
#  ('Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
#   15),
#  ('Agricultural nitrous oxide emissions (% of total)', 15),
#  ('Energy related methane emissions (% of total)', 15),
#  ('Secondary education, pupils (% female)', 15),
#  ('Children out of school (% of primary school age)', 15),
#  ('Stocks traded, turnover ratio of domestic shares (%)', 16),
#  ('Market capitalization of listed domestic companies (% of GDP)', 16),
#  ('Industrial design applications, nonresident, by count', 16),
#  ('Part time employment, male (% of total male employment)', 16),
#  ('Part time employment, female (% of total female employment)', 16),
#  ('Trained teachers in primary education (% of total teachers)', 16),
#  ('Secondary education, vocational pupils (% female)', 16),
#  ('Bank capital to assets ratio (%)', 16),
#  ('Market capitalization of listed domestic companies (current US$)', 16),
#  ('Part time employment, total (% of total employment)', 16),
#  ('Industrial design applications, resident, by count', 16),
#  ('Internally displaced persons, new displacement associated with disasters (number of cases)',
#   17),
#  ('PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#   17),
#  ('Internally displaced persons, total displaced by conflict and violence (number of people)',
#   17),
#  ('Labor force with intermediate education, female (% of female working-age population with intermediate education)',
#   17),
#  ('Labor force with advanced education (% of total working-age population with advanced education)',
#   17),
#  ('Proportion of population pushed or further pushed below the 60% median consumption poverty line by out-of-pocket health expenditure (%)',
#   17),
#  ('Proportion of population pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   17),
#  ('Labor force with basic education (% of total working-age population with basic education)',
#   17),
#  ('Labor force with advanced education, male (% of male working-age population with advanced education)',
#   17),
#  ('Female share of employment in senior and middle management (%)', 17),
#  ('Proportion of population pushed or further pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   17),
#  ('Proportion of population pushed further below the 60% median consumption poverty line by out-of-pocket health care expenditure (%)',
#   17),
#  ('Labor force with intermediate education (% of total working-age population with intermediate education)',
#   17),
#  ('Labor force with basic education, male (% of male working-age population with basic education)',
#   17),
#  ('Labor force with advanced education, female (% of female working-age population with advanced education)',
#   17),
#  ('Proportion of population pushed or further pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   17),
#  ('Proportion of population pushed below the 60% median consumption poverty line by out-of-pocket health expenditure (%)',
#   17),
#  ('Proportion of population pushed further below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   17),
#  ('Labor force with intermediate education, male (% of male working-age population with intermediate education)',
#   17),
#  ('Labor force with basic education, female (% of female working-age population with basic education)',
#   17),
#  ('Proportion of population pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   17),
#  ('Proportion of population pushed further below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   17),
#  ('Adjusted net enrollment rate, primary (% of primary school age children)',
#   17),
#  ('School enrollment, primary (% net)', 17),
#  ('Government expenditure per student, tertiary (% of GDP per capita)', 18),
#  ('Children out of school, primary, male', 18),
#  ('School enrollment, preprimary, female (% gross)', 18),
#  ('Children out of school, female (% of female primary school age)', 18),
#  ('Expenditure on tertiary education (% of government expenditure on education)',
#   18),
#  ('Children out of school, male (% of male primary school age)', 18),
#  ('Persistence to last grade of primary, total (% of cohort)', 18),
#  ('School enrollment, preprimary, male (% gross)', 18),
#  ('Children out of school, primary, female', 18),
#  ('GNI (constant LCU)', 19),
#  ('Public private partnerships investment in transport (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, France (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, Germany (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, Canada (current US$)', 19),
#  ('Technical cooperation grants (BoP, current US$)', 19),
#  ('Secure Internet servers', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)',
#   19),
#  ('GNI per capita, PPP (constant 2017 international $)', 19),
#  ('GNI per capita (constant 2015 US$)', 19),
#  ('Pump price for gasoline (US$ per liter)', 19),
#  ('PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)',
#   19),
#  ('Net bilateral aid flows from DAC donors, United Kingdom (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, Denmark (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, European Union institutions (current US$)',
#   19),
#  ('Over-age students, primary, female (% of female enrollment)', 19),
#  ('Net official aid received (constant 2021 US$)', 19),
#  ('Pump price for diesel fuel (US$ per liter)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)',
#   19),
#  ('Net bilateral aid flows from DAC donors, Total (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, Italy (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, Switzerland (current US$)', 19),
#  ('Net bilateral aid flows from DAC donors, Austria (current US$)', 19),
#  ('Net official development assistance and official aid received (current US$)',
#   19),
#  ('Net official flows from UN agencies, UNTA (current US$)', 19),
#  ('Net official flows from UN agencies, UNHCR (current US$)', 19),
#  ('External health expenditure per capita, PPP (current international $)', 19),
#  ('Over-age students, primary, male (% of male enrollment)', 19),
#  ('GNI, PPP (constant 2017 international $)', 19),
#  ('GNI (constant 2015 US$)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-2 value (% of total)',
#   19),
#  ...]

# %%
# selecting the columns we want to analyse
selected_russia_data = russia_data[["Year","GDP growth (annual %)","GDP (constant 2015 US$)","Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_russia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_russia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_russia_data
# Out:
# /tmp/ipykernel_107346/2748281920.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_russia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_107346/2748281920.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_russia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 35  1994             -12.569756      752686755591.281982
# 36  1995              -4.143528      721498966070.725952
# 37  1996              -3.755069      694406178897.724976
# 38  1997               1.399916      704127280749.067993
# 39  1998              -5.299962      666808805066.776978
# 40  1999               6.399915      709483999746.067993
# 41  2000              10.000067      780432873752.842041
# 42  2001               5.100051      820235350096.640015
# 43  2002               4.699992      858786345187.109009
# 44  2003               7.299952       921477339133.55603
# 45  2004               7.199948      987823227180.875977
# 46  2005               6.399965     1051043572407.719971
# 47  2006               8.200068     1137229862730.350098
# 48  2007               8.499978      1233894148246.73999
# 49  2008               5.199969     1298056264706.469971
# 50  2009              -7.799994     1196807955075.780029
# 51  2010                    4.5     1250664313044.699951
# 52  2011               4.300029     1304443243520.469971
# 53  2012               4.024086      1356935163515.02002
# 54  2013               1.755422     1380755103919.449951
# 55  2014               0.736267     1390921151162.459961
# 56  2015              -1.972719     1363482182197.709961
# 57  2016                0.19369     1366123111808.030029
# 58  2017                1.82579     1391065651845.679932
# 59  2018               2.807245      1430116278515.48999
# 60  2019               2.198076     1461551317106.209961
# 61  2020              -2.653655      1422766794794.98999
# 62  2021                5.61429      1502645054025.01001
# 63  2022              -2.069712     1471544636157.840088
# 64  2023                   <NA>                     <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 35                                    -110540000
# 36                                    2443510000
# 37                                   -4410200000
# 38                                  -45775000000
# 39                                  -10829980000
# 40                                    -444660000
# 41                                   12471280000
# 42                                     696440000
# 43                                   -2960430000
# 44                                    4509300000
# 45                                    -608750000
# 46                                   11442530000
# 47                                  -16485730000
# 48                                   -4856520000
# 49                                   35690830000
# 50                                    1882410000
# 51                                    1495240000
# 52                                   15277390000
# 53                                  -17031080000
# 54                                   11011490000
# 55                                   39943380000
# 56                                   26423210000
# 57                                   -2361280000
# 58                                   -7982800000
# 59                                    7593190000
# 60                                  -12686290000
# 61                                   25295800000
# 62                                   32084450000
# 63                                   21211460000
# 64                                          <NA>
#
# 0   Inflation, consumer prices (annual %)  \
# 35                             307.722636
# 36                             197.414268
# 37                              47.752012
# 38                              14.761329
# 39                               27.68568
# 40                              85.746494
# 41                              20.798761
# 42                              21.477007
# 43                              15.788731
# 44                              13.663293
# 45                              10.888616
# 46                              12.685304
# 47                               9.668655
# 48                               9.007299
# 49                              14.110768
# 50                               11.64733
# 51                               6.849392
# 52                               8.440465
# 53                               5.074743
# 54                                6.75371
# 55                               7.823412
# 56                              15.534405
# 57                               7.042448
# 58                               3.683329
# 59                               2.878297
# 60                               4.470367
# 61                               3.381659
# 62                               6.694459
# 63                                   <NA>
# 64                                   <NA>
#
# 0   Unemployment, total (% of total labor force) (national estimate)  \
# 35                                              8.131
# 36                                              9.449
# 37                                              9.665
# 38                                             11.813
# 39                                             13.261
# 40                                             13.036
# 41                                             10.581
# 42                                              8.978
# 43                                              7.875
# 44                                               8.21
# 45                                              7.763
# 46                                              7.124
# 47                                              7.055
# 48                                              6.002
# 49                                              6.205
# 50                                              8.301
# 51                                              7.369
# 52                                              6.536
# 53                                              5.436
# 54                                              5.458
# 55                                               5.16
# 56                                              5.571
# 57                                              5.559
# 58                                              5.212
# 59                                              4.846
# 60                                              4.496
# 61                                              5.589
# 62                                              4.715
# 63                                              3.867
# 64                                               <NA>
#
# 0   Population growth (annual %)  \
# 35                     -0.034268
# 36                     -0.021649
# 37                     -0.145452
# 38                     -0.165342
# 39                     -0.165486
# 40                     -0.309278
# 41                     -0.420615
# 42                     -0.424091
# 43                     -0.460024
# 44                     -0.453781
# 45                     -0.402681
# 46                     -0.381453
# 47                     -0.327445
# 48                     -0.171082
# 49                     -0.043949
# 50                      0.030108
# 51                      0.044896
# 52                      0.077982
# 53                      0.168305
# 54                      0.212951
# 55                      0.217642
# 56                      0.192558
# 57                      0.170245
# 58                      0.106871
# 59                     -0.013067
# 60                     -0.049569
# 61                      -0.23095
# 62                      0.039793
# 63                       0.07383
# 64                          <NA>
#
# 0   Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)
# 35                                          96.525986
# 36                                          96.525986
# 37                                          96.525986
# 38                                          96.525986
# 39                                          96.525986
# 40                                          96.525986
# 41                                          96.525986
# 42                                          96.525986
# 43                                          97.154556
# 44                                          96.525986
# 45                                          96.525986
# 46                                          96.525986
# 47                                          96.525986
# 48                                          96.525986
# 49                                          96.525986
# 50                                          96.525986
# 51                                          93.847923
# 52                                          96.525986
# 53                                          96.525986
# 54                                          96.525986
# 55                                          96.525986
# 56                                          96.525986
# 57                                          96.525986
# 58                                          96.525986
# 59                                          96.525986
# 60                                          96.525986
# 61                                          96.525986
# 62                                          98.575478
# 63                                          96.525986
# 64                                          96.525986

# %%
selected_russia_data.shape
# Out:
# (30, 8)

# %%
selected_russia_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                30.0
# GDP growth (annual %)                               29.0
# GDP (constant 2015 US$)                             29.0
# Portfolio investment, net (BoP, current US$)        29.0
# Inflation, consumer prices (annual %)               28.0
# Unemployment, total (% of total labor force) (n...  29.0
# Population growth (annual %)                        29.0
# Educational attainment, at least completed lowe...  30.0
#
#                                                                     mean  \
# 0
# Year                                                              2008.5
# GDP growth (annual %)                                           2.003115
# GDP (constant 2015 US$)                             1125096997456.992676
# Portfolio investment, net (BoP, current US$)           4238918965.517241
# Inflation, consumer prices (annual %)                          32.123031
# Unemployment, total (% of total labor force) (n...              7.353897
# Population growth (annual %)                                   -0.099483
# Educational attainment, at least completed lowe...             96.525986
#
#                                                                     std  \
# 0
# Year                                                           8.803408
# GDP growth (annual %)                                          5.301121
# GDP (constant 2015 US$)                             294188835042.845886
# Portfolio investment, net (BoP, current US$)         17882619367.144962
# Inflation, consumer prices (annual %)                          66.15029
# Unemployment, total (% of total labor force) (n...             2.508886
# Population growth (annual %)                                   0.221769
# Educational attainment, at least completed lowe...             0.637006
#
#                                                                     min  \
# 0
# Year                                                             1994.0
# GDP growth (annual %)                                        -12.569756
# GDP (constant 2015 US$)                             666808805066.776978
# Portfolio investment, net (BoP, current US$)             -45775000000.0
# Inflation, consumer prices (annual %)                          2.878297
# Unemployment, total (% of total labor force) (n...                3.867
# Population growth (annual %)                                  -0.460024
# Educational attainment, at least completed lowe...            93.847923
#
#                                                                     25%  \
# 0
# Year                                                            2001.25
# GDP growth (annual %)                                         -1.972719
# GDP (constant 2015 US$)                             820235350096.640015
# Portfolio investment, net (BoP, current US$)              -4410200000.0
# Inflation, consumer prices (annual %)                          6.825472
# Unemployment, total (% of total labor force) (n...                5.458
# Population growth (annual %)                                  -0.309278
# Educational attainment, at least completed lowe...            96.525986
#
#                                                                     50%  \
# 0
# Year                                                             2008.5
# GDP growth (annual %)                                          2.807245
# GDP (constant 2015 US$)                             1233894148246.73999
# Portfolio investment, net (BoP, current US$)               1495240000.0
# Inflation, consumer prices (annual %)                         11.267973
# Unemployment, total (% of total labor force) (n...                7.055
# Population growth (annual %)                                  -0.043949
# Educational attainment, at least completed lowe...            96.525986
#
#                                                                      75%  \
# 0
# Year                                                             2015.75
# GDP growth (annual %)                                            5.61429
# GDP (constant 2015 US$)                             1380755103919.449951
# Portfolio investment, net (BoP, current US$)               12471280000.0
# Inflation, consumer prices (annual %)                          17.041238
# Unemployment, total (% of total labor force) (n...                 8.301
# Population growth (annual %)                                     0.07383
# Educational attainment, at least completed lowe...             96.525986
#
#                                                                     max
# 0
# Year                                                             2023.0
# GDP growth (annual %)                                         10.000067
# GDP (constant 2015 US$)                             1502645054025.01001
# Portfolio investment, net (BoP, current US$)              39943380000.0
# Inflation, consumer prices (annual %)                        307.722636
# Unemployment, total (% of total labor force) (n...               13.261
# Population growth (annual %)                                   0.217642
# Educational attainment, at least completed lowe...            98.575478

# %%
import seaborn as sns

# %%
columns = list(selected_russia_data.columns)
print(columns)

sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_russia_data)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# <Axes: xlabel='GDP (constant 2015 US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_russia_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_russia_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_russia_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_russia_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_russia_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_russia_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
sns.pairplot(data = selected_russia_data, height = 2)

# %%
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_russia_data[ 'GDP growth (annual %)']
X = selected_russia_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=42)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  14.066192740557382
# mean_absolute_error :  2.53415752450609
# The value of R^2 for the model is 43.73354139299417 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 40.26114890719006
# The value of slope for GDP (constant 2015 US$) is given by 2.1081737636653957e-12
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -8.974844983647235e-12
# The value of slope for Inflation, consumer prices (annual %) is given by -0.01144736426934504
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by -0.6732263114572454
# The value of slope for Population growth (annual %) is given by -15.159138087240839
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by -0.37454508403197695
