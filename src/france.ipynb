# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("france")
france_data = Data.read(filepath)
france_data
# Out:
#      Country Name Country Code  \
# 0          France          FRA
# 1          France          FRA
# 2          France          FRA
# 3          France          FRA
# 4          France          FRA
# ...           ...          ...
# 1487       France          FRA
# 1488       France          FRA
# 1489       France          FRA
# 1490       France          FRA
# 1491       France          FRA
#
#                                          Indicator Name     Indicator Code  \
# 0     Internally displaced persons, total displaced ...        VC.IDP.TOCV
# 1              Voice and Accountability: Standard Error         VA.STD.ERR
# 2           Voice and Accountability: Number of Sources          VA.NO.SRC
# 3     High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS
# 4                       Export value index (2015 = 100)  TX.VAL.MRCH.XD.WD
# ...                                                 ...                ...
# ...

# %%
# cleaning the data
france_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
france_data = Data.clean_data(france_data, france_columns_to_drop)
france_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 1                                       <NA>
# 2                                       <NA>
# ...

# %%
# selecting and modifying the data
france_data["Year"]=france_data["Year"].astype(int)
france_data = france_data.tail(35)
france_data
interval = 5
france_data=france_data.iloc[::interval]
france_data
# Out:
# 0   Year  \
# 30  1989
# 35  1994
# 40  1999
# 45  2004
# 50  2009
# 55  2014
# 60  2019
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                               <NA>
# 55                                               <NA>
# 60                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 30                                      <NA>
# 35                                      <NA>
# 40                                      <NA>
# 45                                  0.175458
# 50                                  0.141109
# 55                                  0.140036
# 60                                  0.121885
#
# ...

# %%
# checking the number of null values in each column
france_data.isna().sum()
# Out:
# 0
# Year                                                                                         0
# Internally displaced persons, total displaced by conflict and violence (number of people)    7
# Voice and Accountability: Standard Error                                                     3
# Voice and Accountability: Number of Sources                                                  3
# High-technology exports (% of manufactured exports)                                          4
#                                                                                             ..
# Stocks traded, turnover ratio of domestic shares (%)                                         1
# Market capitalization of listed domestic companies (% of GDP)                                1
# Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval               3
# Control of Corruption: Estimate                                                              3
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = france_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#   0),
#  ('Merchandise exports (current US$)', 0),
#  ('Insurance and financial services (% of commercial service exports)', 0),
#  ('Agricultural raw materials exports (% of merchandise exports)', 0),
#  ('Computer, communications and other services (% of commercial service imports)',
#   0),
#  ('Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from high-income economies (% of total merchandise imports)',
#   0),
#  ('Manufactures imports (% of merchandise imports)', 0),
# ...

# %%
# selecting the columns we want to analyse
selected_france_data = france_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_france_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_france_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_france_data
# Out:
# /tmp/ipykernel_1902494/2373715831.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_france_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1902494/2373715831.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
selected_france_data.shape
# Out:
# (7, 8)

# %%
selected_france_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                 7.0
# GDP growth (annual %)                                7.0
# GDP (constant 2015 US$)                              7.0
# Portfolio investment, net (BoP, current US$)         7.0
# Inflation, consumer prices (annual %)                7.0
# Unemployment, total (% of total labor force) (n...   7.0
# Population growth (annual %)                         7.0
# Educational attainment, at least completed lowe...   7.0
#
#                                                                     mean  \
# 0
# Year                                                              2004.0
# GDP growth (annual %)                                           1.839891
# GDP (constant 2015 US$)                             2115503764191.816895
# Portfolio investment, net (BoP, current US$)         -46230283227.483383
# Inflation, consumer prices (annual %)                           1.362383
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_france_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_france_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_france_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_france_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_france_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_france_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_france_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_france_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_france_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_france_data['GDP growth (annual %)'] = selected_france_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_france_data["GDP (constant 2015 US$)"] = np.log(selected_france_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# /tmp/ipykernel_1902494/2267048500.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mean_value = selected_france_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_france_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_france_data[regression_columns]
selected_france_data = selected_france_data.tail(6)
selected_france_data.reset_index(drop=True, inplace = True)
selected_france_data
# Out:
# /tmp/ipykernel_1902494/3108538704.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_france_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1902494/3108538704.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_france_data[ 'GDP growth (annual %)']
X = selected_france_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=50)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  50.42065194098078
# mean_absolute_error :  7.100750097065857
# The value of R^2 for the model is 16.30208941703216 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 26.08132410370598
# The value of slope for GDP (constant 2015 US$) is given by 0.028371500995054474
# The value of slope for Portfolio investment, net (BoP, current US$) is given by 1.3030104772937534e-11
# The value of slope for Inflation, consumer prices (annual %) is given by 0.7541278684755777
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by -1.4385219740464867
# The value of slope for Population growth (annual %) is given by -0.016881875114210014
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by -0.0728525149987052
