# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("japan")
japan_data = Data.read(filepath)
japan_data
# Out:
#      Country Name Country Code  \
# 0           Japan          JPN
# 1           Japan          JPN
# 2           Japan          JPN
# 3           Japan          JPN
# 4           Japan          JPN
# ...           ...          ...
# 1473        Japan          JPN
# 1474        Japan          JPN
# 1475        Japan          JPN
# 1476        Japan          JPN
# 1477        Japan          JPN
#
#                                          Indicator Name     Indicator Code  \
# 0        Intentional homicides, male (per 100,000 male)  VC.IHR.PSRC.MA.P5
# 1     Internally displaced persons, new displacement...        VC.IDP.NWCV
# 2     Voice and Accountability: Percentile Rank, Low...   VA.PER.RNK.LOWER
# 3     Travel services (% of commercial service exports)  TX.VAL.TRVL.ZS.WT
# 4              Commercial service exports (current US$)  TX.VAL.SERV.CD.WT
# ...                                                 ...                ...
# ...

# %%
# cleaning the data
japan_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
japan_data = Data.clean_data(japan_data, japan_columns_to_drop)
japan_data
# Out:
# 0   Year  Intentional homicides, male (per 100,000 male)  \
# 1   1960                                            <NA>
# 2   1961                                            <NA>
# 3   1962                                            <NA>
# 4   1963                                            <NA>
# 5   1964                                            <NA>
# ..   ...                                             ...
# 60  2019                                        0.225643
# 61  2020                                        0.215172
# 62  2021                                        0.249308
# 63  2022                                            <NA>
# 64  2023                                            <NA>
#
# 0   Internally displaced persons, new displacement associated with conflict and violence (number of cases)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# ...

# %%
# selecting and modifying the data
japan_data["Year"]=japan_data["Year"].astype(int)
japan_data = japan_data.tail(35)
japan_data
interval = 5
japan_data=japan_data.iloc[::interval]
japan_data
# Out:
# 0   Year  Intentional homicides, male (per 100,000 male)  \
# 30  1989                                            <NA>
# 35  1994                                         0.72235
# 40  1999                                         0.64173
# 45  2004                                        0.586665
# 50  2009                                        0.405163
# 55  2014                                        0.304598
# 60  2019                                        0.225643
#
# 0   Internally displaced persons, new displacement associated with conflict and violence (number of cases)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                               <NA>
# 55                                               <NA>
# 60                                               <NA>
#
# ...

# %%
# checking the number of null values in each column
japan_data.isna().sum()
# Out:
# 0
# Year                                                                                                      0
# Intentional homicides, male (per 100,000 male)                                                            1
# Internally displaced persons, new displacement associated with conflict and violence (number of cases)    7
# Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval                         3
# Travel services (% of commercial service exports)                                                         2
#                                                                                                          ..
# Charges for the use of intellectual property, payments (BoP, current US$)                                 2
# Imports of goods and services (BoP, current US$)                                                          2
# Cereal yield (kg per hectare)                                                                             0
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = japan_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Merchandise exports by the reporting economy (current US$)', 0),
#  ('Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#   0),
#  ('Ores and metals exports (% of merchandise exports)', 0),
#  ('Fuel exports (% of merchandise exports)', 0),
#  ('Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from economies in the Arab World (% of total merchandise imports)',
#   0),
#  ('Tariff rate, most favored nation, simple mean, primary products (%)', 0),
#  ('Tariff rate, most favored nation, simple mean, all products (%)', 0),
# ...

# %%
# selecting the columns we want to analyse
selected_japan_data = japan_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)"]]
selected_japan_data
# Out:
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 30  1989               4.925785     3347469412110.950195
# 35  1994               1.083383     3688589488080.589844
# 40  1999               -0.33393     3879501014654.609863
# 45  2004               2.186116      4154163710034.47998
# 50  2009              -5.693236          4052826324007.5
# 55  2014               0.296206     4376627829637.509766
# 60  2019              -0.402169     4564332550094.450195
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 30                                          <NA>
# 35                                          <NA>
# 40                            27481454263.076401
# 45                           -22947944390.504501
# 50                            210586667970.76001
# 55                             -40342220314.6493
# 60                            86642953831.485596
#
# 0   Inflation, consumer prices (annual %)  \
# 30                                2.27229
# ...

# %%
selected_japan_data.shape
# Out:
# (7, 7)

# %%
selected_japan_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                 7.0
# GDP growth (annual %)                                7.0
# GDP (constant 2015 US$)                              7.0
# Portfolio investment, net (BoP, current US$)         5.0
# Inflation, consumer prices (annual %)                7.0
# Unemployment, total (% of total labor force) (n...   7.0
# Population growth (annual %)                         7.0
#
#                                                                     mean  \
# 0
# Year                                                              2004.0
# GDP growth (annual %)                                           0.294593
# GDP (constant 2015 US$)                             4009072904088.584473
# Portfolio investment, net (BoP, current US$)          52284182272.033646
# Inflation, consumer prices (annual %)                           0.641863
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_japan_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_japan_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_japan_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_japan_data['GDP growth (annual %)'] = selected_japan_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_japan_data["GDP (constant 2015 US$)"] = np.log(selected_japan_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# /tmp/ipykernel_1907771/3769282178.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_japan_data['GDP growth (annual %)'] = selected_japan_data['GDP (constant 2015 US$)'].pct_change() * 100
# ...

# %%
selected_japan_data[regression_columns]
selected_japan_data = selected_japan_data.tail(6)
selected_japan_data.reset_index(drop=True, inplace = True)
selected_japan_data
# Out:
# 0  Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 0  1994              10.190387                28.936265
# 1  1999               5.175733                28.986728
# 2  2004               7.079846                29.055132
# 3  2009              -2.439417                29.030436
# 4  2014               7.989523                  29.1073
# 5  2019               4.288798                29.149293
#
# 0  Portfolio investment, net (BoP, current US$)  \
# 0                                          <NA>
# 1                            27481454263.076401
# 2                           -22947944390.504501
# 3                            210586667970.76001
# 4                             -40342220314.6493
# 5                            86642953831.485596
#
# 0  Inflation, consumer prices (annual %)  \
# 0                               0.695458
# 1                              -0.341297
# 2                              -0.008573
# 3                              -1.352837
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_japan_data[ 'GDP growth (annual %)']
X = selected_japan_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=50)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  0.3672738229253089
# mean_absolute_error :  0.6060312062305941
# The value of R^2 for the model is 99.45553751452202 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 6.3178486366516715
# The value of slope for GDP (constant 2015 US$) is given by -0.00011154502210299792
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -4.160249002119285e-11
# The value of slope for Inflation, consumer prices (annual %) is given by -0.002223144139983115
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by 0.0007692318551445567
# The value of slope for Population growth (annual %) is given by 0.00031607042813909704
