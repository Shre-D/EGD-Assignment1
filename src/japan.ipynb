# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("japan")
japan_data = Data.read(filepath)
japan_data
# Out:
#      Country Name Country Code  \
# 0           Japan          JPN
# 1           Japan          JPN
# 2           Japan          JPN
# 3           Japan          JPN
# 4           Japan          JPN
# ...           ...          ...
# 1473        Japan          JPN
# 1474        Japan          JPN
# 1475        Japan          JPN
# 1476        Japan          JPN
# 1477        Japan          JPN
#
#                                          Indicator Name     Indicator Code  \
# 0        Intentional homicides, male (per 100,000 male)  VC.IHR.PSRC.MA.P5
# 1     Internally displaced persons, new displacement...        VC.IDP.NWCV
# 2     Voice and Accountability: Percentile Rank, Low...   VA.PER.RNK.LOWER
# 3     Travel services (% of commercial service exports)  TX.VAL.TRVL.ZS.WT
# 4              Commercial service exports (current US$)  TX.VAL.SERV.CD.WT
# ...                                                 ...                ...
# 1473  Charges for the use of intellectual property, ...     BM.GSR.ROYL.CD
# 1474   Imports of goods and services (BoP, current US$)     BM.GSR.GNFS.CD
# 1475                      Cereal yield (kg per hectare)     AG.YLD.CREL.KG
# 1476            Crop production index (2014-2016 = 100)     AG.PRD.CROP.XD
# 1477                           Rural land area (sq. km)  AG.LND.TOTL.RU.K2
#
#       1960     1961     1962     1963     1964     1965  ...          2015  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN  ...  2.341451e-01
# 1      NaN      NaN      NaN      NaN      NaN      NaN  ...           NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN  ...  7.192118e+01
# 3      NaN      NaN      NaN      NaN      NaN      NaN  ...  1.576914e+01
# 4      NaN      NaN      NaN      NaN      NaN      NaN  ...  1.583346e+11
# ...    ...      ...      ...      ...      ...      ...  ...           ...
# 1473   NaN      NaN      NaN      NaN      NaN      NaN  ...  1.703376e+10
# 1474   NaN      NaN      NaN      NaN      NaN      NaN  ...  8.079867e+11
# 1475   NaN  4173.50  4339.60  4224.00  4318.40  4398.20  ...  6.316700e+03
# 1476   NaN   129.53   133.39   134.63   134.96   135.45  ...  9.982000e+01
# 1477   NaN      NaN      NaN      NaN      NaN      NaN  ...  3.167362e+05
#
#               2016          2017          2018          2019          2020  \
# 0     2.670321e-01  2.158583e-01  2.524413e-01  2.256426e-01  2.151717e-01
# 1              NaN           NaN           NaN           NaN           NaN
# 2     7.093596e+01  7.192118e+01  7.184466e+01  7.004831e+01  7.101450e+01
# 3     1.802882e+01  1.871780e+01  2.221018e+01  2.247379e+01  6.632181e+00
# 4     1.705727e+11  1.819941e+11  1.895211e+11  2.049239e+11  1.597901e+11
# ...            ...           ...           ...           ...           ...
# 1473  2.024637e+10  2.138139e+10  2.199373e+10  2.677403e+10  2.855022e+10
# 1474  7.710804e+11  8.378774e+11  9.284225e+11  9.132476e+11  8.018888e+11
# 1475  6.253400e+03  6.284500e+03  6.404700e+03  6.546700e+03  6.472900e+03
# 1476  9.830000e+01  9.865000e+01  9.695000e+01  9.786000e+01  9.599000e+01
# 1477           NaN           NaN           NaN           NaN           NaN
#
#               2021          2022  2023  Unnamed: 68
# 0     2.493084e-01           NaN   NaN          NaN
# 1              NaN           NaN   NaN          NaN
# 2     7.246377e+01  7.101450e+01   NaN          NaN
# 3     2.910447e+00  5.379042e+00   NaN          NaN
# 4     1.669620e+11  1.660354e+11   NaN          NaN
# ...            ...           ...   ...          ...
# 1473  2.965303e+10  2.779773e+10   NaN          NaN
# 1474  9.424496e+11  1.079883e+12   NaN          NaN
# 1475  6.787300e+03  6.273000e+03   NaN          NaN
# 1476  9.582000e+01  9.460000e+01   NaN          NaN
# 1477           NaN           NaN   NaN          NaN
#
# [1478 rows x 69 columns]

# %%
# cleaning the data
japan_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
japan_data = Data.clean_data(japan_data, japan_columns_to_drop)
japan_data
# Out:
# 0   Year  Intentional homicides, male (per 100,000 male)  \
# 1   1960                                            <NA>
# 2   1961                                            <NA>
# 3   1962                                            <NA>
# 4   1963                                            <NA>
# 5   1964                                            <NA>
# ..   ...                                             ...
# 60  2019                                        0.225643
# 61  2020                                        0.215172
# 62  2021                                        0.249308
# 63  2022                                            <NA>
# 64  2023                                            <NA>
#
# 0   Internally displaced persons, new displacement associated with conflict and violence (number of cases)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          70.048309
# 61                                          71.014496
# 62                                          72.463768
# 63                                          71.014496
# 64                                               <NA>
#
# 0   Travel services (% of commercial service exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          22.473794
# 61                                           6.632181
# 62                                           2.910447
# 63                                           5.379042
# 64                                               <NA>
#
# 0   Commercial service exports (current US$)  \
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# 5                                       <NA>
# ..                                       ...
# 60                          204923901375.306
# 61                       159790050631.643005
# 62                        166961972709.94101
# 63                       166035428482.122986
# 64                                      <NA>
#
# 0   Merchandise exports by the reporting economy (current US$)  \
# 1                                          3912700000
# 2                                          4073800000
# 3                                          4730500000
# 4                                          5236800000
# 5                                          6347900000
# ..                                                ...
# 60                                       705632000000
# 61                                       638167000000
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)  \
# 1                                            2.586449
# 2                                            2.616721
# 3                                            1.976535
# 4                                            2.132982
# 5                                            2.081003
# ..                                                ...
# 60                                           0.513118
# 61                                           0.452629
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)  \
# 1                                           32.046924
# 2                                           34.135205
# 3                                           29.214671
# 4                                           28.525053
# 5                                           29.710613
# ..                                                ...
# 60                                          39.513242
# 61                                          41.166171
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Ores and metals exports (% of merchandise exports)  ...  \
# 1                                                <NA>   ...
# 2                                                <NA>   ...
# 3                                            0.796393   ...
# 4                                            0.872919   ...
# 5                                            0.929292   ...
# ..                                                ...   ...
# 60                                           2.422299   ...
# 61                                           3.127395   ...
# 62                                           3.504288   ...
# 63                                           3.440582   ...
# 64                                               <NA>   ...
#
# 0   Grants, excluding technical cooperation (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
# 5                                           <NA>
# ..                                           ...
# 60                            86642953831.485596
# 61                            35926915439.337196
# 62                          -195681901026.153015
# 63                          -138295913886.828003
# 64                                          <NA>
#
# 0   Net trade in goods and services (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                 -8615189108.462191
# 61                                  -7597675867.01364
# 62                                -21810914913.444199
# 63                               -158671027105.253998
# 64                                               <NA>
#
# 0   Current account balance (BoP, current US$)  \
# 1                                         <NA>
# 2                                         <NA>
# 3                                         <NA>
# 4                                         <NA>
# 5                                         <NA>
# ..                                         ...
# 60                         176609997619.696014
# 61                         150028926280.730011
# 62                         197154455955.773987
# 63                          90963103990.784393
# 64                                        <NA>
#
# 0   Foreign direct investment, net outflows (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                258284325075.721985
# 61                                150118191351.371002
# 62                                210040330661.506989
# 63                                171860502450.380005
# 64                                               <NA>
#
# 0   Charges for the use of intellectual property, payments (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                 26774027970.684601
# 61                                 28550217207.291599
# 62                                 29653031447.885101
# 63                                   27797728101.8265
# 64                                               <NA>
#
# 0   Imports of goods and services (BoP, current US$)  \
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
# 5                                               <NA>
# ..                                               ...
# 60                               913247592840.422974
# 61                               801888752616.516968
# 62                               942449595638.912964
# 63                              1079882755161.359985
# 64                                              <NA>
#
# 0   Cereal yield (kg per hectare)  Crop production index (2014-2016 = 100)  \
# 1                            <NA>                                     <NA>
# 2                          4173.5                                   129.53
# 3                          4339.6                                   133.39
# 4                          4224.0                                   134.63
# 5                          4318.4                                   134.96
# ..                            ...                                      ...
# 60                         6546.7                                    97.86
# 61                         6472.9                                    95.99
# 62                         6787.3                                    95.82
# 63                         6273.0                                     94.6
# 64                           <NA>                                     <NA>
#
# 0   Rural land area (sq. km)
# 1                       <NA>
# 2                       <NA>
# 3                       <NA>
# 4                       <NA>
# 5                       <NA>
# ..                       ...
# 60                      <NA>
# 61                      <NA>
# 62                      <NA>
# 63                      <NA>
# 64                      <NA>
#
# [64 rows x 1479 columns]

# %%
# selecting and modifying the data
japan_data["Year"]=japan_data["Year"].astype(int)
japan_data = japan_data.tail(30)
japan_data
# Out:
# 0   Year  Intentional homicides, male (per 100,000 male)  \
# 35  1994                                         0.72235
# 36  1995                                        0.623443
# 37  1996                                         0.58339
# 38  1997                                        0.643727
# 39  1998                                        0.676537
# 40  1999                                         0.64173
# 41  2000                                        0.560318
# 42  2001                                        0.614138
# 43  2002                                        0.557153
# 44  2003                                        0.607938
# 45  2004                                        0.586665
# 46  2005                                        0.519143
# 47  2006                                        0.472561
# 48  2007                                        0.467606
# 49  2008                                         0.50439
# 50  2009                                        0.405163
# 51  2010                                        0.365297
# 52  2011                                        0.333609
# 53  2012                                        0.303573
# 54  2013                                        0.287967
# 55  2014                                        0.304598
# 56  2015                                        0.234145
# 57  2016                                        0.267032
# 58  2017                                        0.215858
# 59  2018                                        0.252441
# 60  2019                                        0.225643
# 61  2020                                        0.215172
# 62  2021                                        0.249308
# 63  2022                                            <NA>
# 64  2023                                            <NA>
#
# 0   Internally displaced persons, new displacement associated with conflict and violence (number of cases)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               70.0
# 38                                               <NA>
# 39                                          65.174126
# 40                                               <NA>
# 41                                          65.671638
# 42                                               <NA>
# 43                                          69.154228
# 44                                          71.641792
# 45                                          73.557693
# 46                                          71.153847
# 47                                          69.230766
# 48                                          69.230766
# 49                                          68.269234
# 50                                          70.142181
# 51                                          72.037918
# 52                                          74.178406
# 53                                          74.178406
# 54                                          73.708923
# 55                                          71.428574
# 56                                          71.921181
# 57                                          70.935959
# 58                                          71.921181
# 59                                          71.844658
# 60                                          70.048309
# 61                                          71.014496
# 62                                          72.463768
# 63                                          71.014496
# 64                                               <NA>
#
# 0   Travel services (% of commercial service exports)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                           6.102956
# 38                                           6.317213
# 39                                           6.031334
# 40                                           5.674191
# 41                                           4.924435
# 42                                           5.175528
# 43                                           5.368759
# 44                                          11.620355
# 45                                          11.840983
# 46                                          12.476763
# 47                                           7.902168
# 48                                           7.818991
# 49                                           7.799244
# 50                                           8.716844
# 51                                          10.020351
# 52                                           7.985214
# 53                                          10.891634
# 54                                          11.363813
# 55                                          11.807049
# 56                                          15.769137
# 57                                           18.02882
# 58                                            18.7178
# 59                                          22.210176
# 60                                          22.473794
# 61                                           6.632181
# 62                                           2.910447
# 63                                           5.379042
# 64                                               <NA>
#
# 0   Commercial service exports (current US$)  \
# 35                                      <NA>
# 36                                      <NA>
# 37                        66870911035.055397
# 38                        68528084777.109299
# 39                        62054342805.237503
# 40                        60470384812.465202
# 41                        68487248766.183701
# 42                        63869496123.927498
# 43                        65140600157.278503
# 44                        76146293529.628693
# 45                        95131548909.832306
# 46                        99626361969.031799
# 47                       107187188742.595001
# 48                       119522241999.253006
# 49                       138725165871.507996
# 50                       118494313701.466003
# 51                       131971330790.850006
# 52                       137758074587.976013
# 53                       133871789181.335007
# 54                       132819637583.274002
# 55                       159331288650.178009
# 56                       158334647446.381989
# 57                          170572739925.806
# 58                       181994112163.049988
# 59                       189521058074.165009
# 60                          204923901375.306
# 61                       159790050631.643005
# 62                        166961972709.94101
# 63                       166035428482.122986
# 64                                      <NA>
#
# 0   Merchandise exports by the reporting economy (current US$)  \
# 35                                       395286000000
# 36                                       443256000000
# 37                                       411565000000
# 38                                       421466000000
# 39                                       388040000000
# 40                                       419456000000
# 41                                       478363000000
# 42                                       403524000000
# 43                                       416797000000
# 44                                       471916000000
# 45                                       565822000000
# 46                                       594889000000
# 47                                       646798000000
# 48                                       714267000000
# 49                                       782049000000
# 50                                       580719000000
# 51                                       769773000000
# 52                                       822564000000
# 53                                       798620000000
# 54                                       714613000000
# 55                                       690213000000
# 56                                       624801000000
# 57                                       644933000000
# 58                                       698073000000
# 59                                       737941000000
# 60                                       705632000000
# 61                                       638167000000
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)  \
# 35                                           0.757056
# 36                                           0.585835
# 37                                           0.638922
# 38                                           0.739084
# 39                                           0.817594
# 40                                           0.646578
# 41                                           0.475232
# 42                                           0.636651
# 43                                            0.67504
# 44                                           0.702975
# 45                                           0.667316
# 46                                           0.725303
# 47                                           0.698225
# 48                                           0.803761
# 49                                           1.021492
# 50                                           0.982737
# 51                                           0.860324
# 52                                           0.634564
# 53                                           0.623974
# 54                                           0.597544
# 55                                           0.650823
# 56                                           0.631544
# 57                                           0.636806
# 58                                           0.547907
# 59                                           0.479318
# 60                                           0.513118
# 61                                           0.452629
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)  \
# 35                                           21.31723
# 36                                          23.046165
# 37                                          23.680111
# 38                                           22.75813
# 39                                          20.012135
# 40                                          19.930868
# 41                                          21.219983
# 42                                           22.82303
# 43                                          24.420011
# 44                                          27.009766
# 45                                           28.34069
# 46                                          29.431426
# 47                                          30.374661
# 48                                          32.648417
# 49                                          35.145319
# 50                                          36.364748
# 51                                          38.808221
# 52                                          39.980327
# 53                                          40.083547
# 54                                          39.375033
# 55                                          39.028547
# 56                                          37.643635
# 57                                          37.209704
# 58                                          38.907606
# 59                                          40.129497
# 60                                          39.513242
# 61                                          41.166171
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Ores and metals exports (% of merchandise exports)  ...  \
# 35                                           0.871033   ...
# 36                                           1.049249   ...
# 37                                           1.079389   ...
# 38                                           1.145787   ...
# 39                                            1.22558   ...
# 40                                           1.215605   ...
# 41                                           1.234426   ...
# 42                                           1.360191   ...
# 43                                           1.304585   ...
# 44                                           1.328405   ...
# 45                                           1.553158   ...
# 46                                           1.746729   ...
# 47                                           2.233624   ...
# 48                                           2.422063   ...
# 49                                            2.41477   ...
# 50                                           2.630292   ...
# 51                                           2.572831   ...
# 52                                           2.574534   ...
# 53                                           2.743373   ...
# 54                                           2.806648   ...
# 55                                           2.673784   ...
# 56                                           2.474874   ...
# 57                                           2.312804   ...
# 58                                           2.423689   ...
# 59                                           2.516185   ...
# 60                                           2.422299   ...
# 61                                           3.127395   ...
# 62                                           3.504288   ...
# 63                                           3.440582   ...
# 64                                               <NA>   ...
#
# 0   Grants, excluding technical cooperation (BoP, current US$)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 35                                          <NA>
# 36                                          <NA>
# 37                            33820312103.573799
# 38                           -32129071212.776402
# 39                            39172919339.479897
# 40                            27481454263.076401
# 41                            35975387034.795197
# 42                            46285624467.396301
# 43                           105974660790.453995
# 44                            95110162832.992905
# 45                           -22947944390.504501
# 46                              13268315803.7957
# 47                          -127520047988.414001
# 48                           -73129063903.396194
# 49                           282689352952.114014
# 50                            210586667970.76001
# 51                           144767857559.243988
# 52                          -168446360029.062012
# 53                              32210273636.5275
# 54                          -274651950434.829987
# 55                             -40342220314.6493
# 56                           132433986065.335999
# 57                           268042440742.743988
# 58                             -49213900461.9487
# 59                            92911832022.275696
# 60                            86642953831.485596
# 61                            35926915439.337196
# 62                          -195681901026.153015
# 63                          -138295913886.828003
# 64                                          <NA>
#
# 0   Net trade in goods and services (BoP, current US$)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                 21309371596.648899
# 38                                 47450014246.531403
# 39                                 72968602319.862396
# 40                                 69164578262.696701
# 41                                 69091201723.888199
# 42                                 26480675041.236599
# 43                                 51601038995.840698
# 44                                 72487452621.770798
# 45                                 94230374346.551193
# 46                                 69911671152.185898
# 47                                 63045444315.060501
# 48                                 83502740418.595001
# 49                                 17341178492.640701
# 50                                 23251948662.567402
# 51                                 78197081417.245499
# 52                                -39544359231.228104
# 53                               -101198487543.671997
# 54                               -125128284733.983002
# 55                               -128605076447.102005
# 56                                  -23275907631.1959
# 57                                 40443851155.243202
# 58                                 37636176718.934196
# 59                                   1405006849.05243
# 60                                 -8615189108.462191
# 61                                  -7597675867.01364
# 62                                -21810914913.444199
# 63                               -158671027105.253998
# 64                                               <NA>
#
# 0   Current account balance (BoP, current US$)  \
# 35                                        <NA>
# 36                                        <NA>
# 37                          68994126647.295197
# 38                          95455879688.361099
# 39                         114685034700.845993
# 40                         114126431432.296997
# 41                         130690474028.488007
# 42                          86219920754.329102
# 43                         108861295892.018005
# 44                         139380520054.084015
# 45                         181993749574.640015
# 46                         170122750083.947998
# 47                         174672769353.091003
# 48                         211735646402.300995
# 49                         142115935666.066986
# 50                         145677709652.338013
# 51                         220887986144.053986
# 52                         129596684408.632996
# 53                          60116999697.111603
# 54                          46378535980.112099
# 55                          36351469239.969299
# 56                         136471801667.014999
# 57                            197049392532.181
# 58                         203168727082.394989
# 59                         177268535276.423004
# 60                         176609997619.696014
# 61                         150028926280.730011
# 62                         197154455955.773987
# 63                          90963103990.784393
# 64                                        <NA>
#
# 0   Foreign direct investment, net outflows (BoP, current US$)  \
# 35                                 18120890732.624001
# 36                                 22630332257.419998
# 37                                   26402490800.3517
# 38                                 23987192131.398102
# 39                                 19805092207.504799
# 40                                 24261868314.284302
# 41                                 45027492991.154701
# 42                                 35660387815.131798
# 43                                   30901752305.0355
# 44                                 34464575323.937202
# 45                                 40613733179.703598
# 46                                 51665013692.564796
# 47                                 58152476830.204399
# 48                                 72989689116.723801
# 49                                113643633547.593994
# 50                                 73677116859.541595
# 51                                 79656513836.629105
# 52                                116835198104.238007
# 53                                117632352926.830994
# 54                                155684602276.700989
# 55                                137924439219.299988
# 56                                138415009626.674988
# 57                                178610388912.656006
# 58                                173750236904.079987
# 59                                160218306051.632996
# 60                                258284325075.721985
# 61                                150118191351.371002
# 62                                210040330661.506989
# 63                                171860502450.380005
# 64                                               <NA>
#
# 0   Charges for the use of intellectual property, payments (BoP, current US$)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                   9828945306.84495
# 38                                   9620507762.24151
# 39                                  8947380928.653561
# 40                                  9854801123.845221
# 41                                    11006793149.598
# 42                                   11098561970.8524
# 43                                 11020739908.853901
# 44                                 11003388851.900801
# 45                                 13644338678.239401
# 46                                 14653524495.449301
# 47                                   15500422630.0406
# 48                                 16677754114.485701
# 49                                 18311541938.962101
# 50                                   16834677241.2227
# 51                                 18768647813.326698
# 52                                 19172720512.125599
# 53                                 19897558092.802601
# 54                                 17831143179.995701
# 55                                 20941598563.302399
# 56                                   17033762145.6497
# 57                                 20246369822.208199
# 58                                 21381387583.907902
# 59                                 21993730961.751701
# 60                                 26774027970.684601
# 61                                 28550217207.291599
# 62                                 29653031447.885101
# 63                                   27797728101.8265
# 64                                               <NA>
#
# 0   Imports of goods and services (BoP, current US$)  \
# 35                                              <NA>
# 36                                              <NA>
# 37                               442138914582.809021
# 38                               426203390950.991028
# 39                                359326601912.89801
# 40                                390916935995.72699
# 41                               454631939272.424011
# 42                               417328597372.862976
# 43                               405295238086.671021
# 44                               449223648193.643005
# 45                               537110540360.612976
# 46                                603030821880.19104
# 47                               665519514454.973999
# 48                               718699651771.121948
# 49                                872816874723.22998
# 50                                645807434517.80896
# 51                               791792570423.910034
# 52                               970204797771.203979
# 53                              1014812620120.790039
# 54                               955466642252.266968
# 55                               991578642132.171021
# 56                               807986704431.962036
# 57                               771080394387.219971
# 58                               837877374600.557983
# 59                               928422545739.300049
# 60                               913247592840.422974
# 61                               801888752616.516968
# 62                               942449595638.912964
# 63                              1079882755161.359985
# 64                                              <NA>
#
# 0   Cereal yield (kg per hectare)  Crop production index (2014-2016 = 100)  \
# 35                         6448.7                                   128.21
# 36                         6003.2                                   123.67
# 37                         6154.5                                   120.18
# 38                         6061.5                                   121.48
# 39                         5809.5                                   111.93
# 40                         5998.9                                   115.01
# 41                         6256.6                                   114.41
# 42                         6107.0                                   113.41
# 43                         6085.5                                   111.91
# 44                         5451.0                                   106.01
# 45                         5942.3                                   107.94
# 46                         6154.0                                   110.45
# 47                         5852.4                                   105.08
# 48                         6062.1                                   108.09
# 49                         6262.4                                   108.94
# 50                         5919.5                                   104.43
# 51                         5853.7                                   100.44
# 52                         6010.6                                   100.36
# 53                         6248.5                                   101.42
# 54                         6281.5                                   101.07
# 55                         6325.1                                   101.89
# 56                         6316.7                                    99.82
# 57                         6253.4                                     98.3
# 58                         6284.5                                    98.65
# 59                         6404.7                                    96.95
# 60                         6546.7                                    97.86
# 61                         6472.9                                    95.99
# 62                         6787.3                                    95.82
# 63                         6273.0                                     94.6
# 64                           <NA>                                     <NA>
#
# 0   Rural land area (sq. km)
# 35                      <NA>
# 36                      <NA>
# 37                      <NA>
# 38                      <NA>
# 39                      <NA>
# 40                      <NA>
# 41             317471.402926
# 42                      <NA>
# 43                      <NA>
# 44                      <NA>
# 45                      <NA>
# 46                      <NA>
# 47                      <NA>
# 48                      <NA>
# 49                      <NA>
# 50                      <NA>
# 51                      <NA>
# 52                      <NA>
# 53                      <NA>
# 54                      <NA>
# 55                      <NA>
# 56              316736.20486
# 57                      <NA>
# 58                      <NA>
# 59                      <NA>
# 60                      <NA>
# 61                      <NA>
# 62                      <NA>
# 63                      <NA>
# 64                      <NA>
#
# [30 rows x 1479 columns]

# %%
# checking the number of null values in each column
japan_data.isna().sum()
# Out:
# 0
# Year                                                                                                       0
# Intentional homicides, male (per 100,000 male)                                                             2
# Internally displaced persons, new displacement associated with conflict and violence (number of cases)    30
# Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval                          6
# Travel services (% of commercial service exports)                                                          3
#                                                                                                           ..
# Charges for the use of intellectual property, payments (BoP, current US$)                                  3
# Imports of goods and services (BoP, current US$)                                                           3
# Cereal yield (kg per hectare)                                                                              1
# Crop production index (2014-2016 = 100)                                                                    1
# Rural land area (sq. km)                                                                                  28
# Length: 1479, dtype: int64

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = japan_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Unemployment, total (% of total labor force) (national estimate)', 0),
#  ('Unemployment, female (% of female labor force) (national estimate)', 0),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (national estimate)',
#   0),
#  ('Labor force, female (% of total labor force)', 0),
#  ('Labor force participation rate, total (% of total population ages 15+) (national estimate)',
#   0),
#  ('Ratio of female to male labor force participation rate (%) (national estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, male (%) (national estimate)', 0),
#  ('Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Population in urban agglomerations of more than 1 million', 0),
#  ('Unemployment, male (% of male labor force) (national estimate)', 0),
#  ('Unemployment, male (% of male labor force) (modeled ILO estimate)', 0),
#  ('Population in urban agglomerations of more than 1 million (% of total population)',
#   0),
#  ('Net migration', 0),
#  ('Unemployment, total (% of total labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, female (% of female labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force, total', 0),
#  ('Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, male (%) (national estimate)',
#   0),
#  ('Employment to population ratio, 15+, male (%) (modeled ILO estimate)', 0),
#  ('Employment to population ratio, ages 15-24, total (%) (national estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, female (%) (national estimate)',
#   0),
#  ('Population in the largest city (% of urban population)', 0),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, total (%) (national estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, female (%) (national estimate)',
#   0),
#  ('Employment to population ratio, 15+, total (%) (modeled ILO estimate)', 0),
#  ('Employment to population ratio, 15+, female (%) (modeled ILO estimate)', 0),
#  ('Employment to population ratio, ages 15-24, male (%) (national estimate)',
#   0),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (national estimate)',
#   0),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (national estimate)',
#   0),
#  ('Labor force participation rate, male (% of male population ages 15+) (national estimate)',
#   0),
#  ('Labor force participation rate, female (% of female population ages 15+) (national estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, total (%) (national estimate)', 0),
#  ('Employment to population ratio, 15+, female (%) (national estimate)', 0),
#  ('Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Women Business and the Law Index Score (scale 1-100)', 0),
#  ('Population in largest city', 0),
#  ('Ores and metals exports (% of merchandise exports)', 1),
#  ('Fuel exports (% of merchandise exports)', 1),
#  ('Urban population growth (annual %)', 1),
#  ('Population, female (% of total population)', 1),
#  ('Age dependency ratio (% of working-age population)', 1),
#  ('Population ages 75-79, male (% of male population)', 1),
#  ('Population ages 65 and above (% of total population)', 1),
#  ('Population ages 65 and above, female (% of female population)', 1),
#  ('Population ages 60-64, male (% of male population)', 1),
#  ('Population ages 50-54, male (% of male population)', 1),
#  ('Population ages 40-44, male (% of male population)', 1),
#  ('Population ages 30-34, male (% of male population)', 1),
#  ('Population ages 20-24, male (% of male population)', 1),
#  ('Population ages 15-64, male (% of male population)', 1),
#  ('Population ages 15-19, male (% of male population)', 1),
#  ('Population ages 05-09, male (% of male population)', 1),
#  ('Population ages 0-14, male (% of male population)', 1),
#  ('Population ages 00-04, male (% of male population)', 1),
#  ('Price level ratio of PPP conversion factor (GDP) to market exchange rate',
#   1),
#  ('Terms of trade adjustment (constant LCU)', 1),
#  ('Net primary income (Net income from abroad) (current LCU)', 1),
#  ('GNI per capita (constant LCU)', 1),
#  ('GNI per capita, Atlas method (current US$)', 1),
#  ('GNI growth (annual %)', 1),
#  ('GNI (current US$)', 1),
#  ('Gross domestic savings (current LCU)', 1),
#  ('GDP per capita, PPP (constant 2017 international $)', 1),
#  ('GDP per capita (constant 2015 US$)', 1),
#  ('GDP, PPP (constant 2017 international $)', 1),
#  ('GDP (constant 2015 US$)', 1),
#  ('Gross value added at basic prices (GVA) (current LCU)', 1),
#  ('GDP deflator: linked series (base year varies by country)', 1),
#  ('Industry (including construction), value added (constant LCU)', 1),
#  ('Industry (including construction), value added (current US$)', 1),
#  ('Manufacturing, value added (constant 2015 US$)', 1),
#  ('Land under cereal production (hectares)', 1),
#  ('GDP per person employed (constant 2017 PPP $)', 1),
#  ('Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Employers, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Real effective exchange rate index (2010 = 100)', 1),
#  ('PPP conversion factor, GDP (LCU per international $)', 1),
#  ('Taxes less subsidies on products (current LCU)', 1),
#  ('Net primary income (Net income from abroad) (current US$)', 1),
#  ('GNI, PPP (constant 2017 international $)', 1),
#  ('GNI (constant 2015 US$)', 1),
#  ('GNI, Atlas method (current US$)', 1),
#  ('Gross domestic savings (current US$)', 1),
#  ('GDP per capita, PPP (current international $)', 1),
#  ('GDP per capita (current LCU)', 1),
#  ('GDP, PPP (current international $)', 1),
#  ('GDP: linked series (current LCU)', 1),
#  ('Gross value added at basic prices (GVA) (current US$)', 1),
#  ('GDP deflator (base year varies by country)', 1),
#  ('Exports as a capacity to import (constant LCU)', 1),
#  ('Services, value added (constant 2015 US$)', 1),
#  ('Manufacturing, value added (% of GDP)', 1),
#  ('Manufacturing, value added (current LCU)', 1),
#  ('Agriculture, forestry, and fishing, value added (constant 2015 US$)', 1),
#  ('Trade (% of GDP)', 1),
#  ('Domestic credit to private sector (% of GDP)', 1),
#  ('Broad money growth (annual %)', 1),
#  ('Claims on private sector (annual growth as % of broad money)', 1),
#  ('Stocks traded, total value (current US$)', 1),
#  ('S&P Global Equity Indices (annual % change)', 1),
#  ('Personal remittances, received (current US$)', 1),
#  ('Foreign direct investment, net inflows (% of GDP)', 1),
#  ('Personal remittances, paid (current US$)', 1),
#  ('Cereal production (metric tons)', 1),
#  ('Merchandise imports (current US$)', 1),
#  ('Agricultural raw materials imports (% of merchandise imports)', 1),
#  ('Urban population', 1),
#  ('Rural population', 1),
#  ('Population, male', 1),
#  ('Age dependency ratio, old (% of working-age population)', 1),
#  ('Population ages 80 and above, female (% of female population)', 1),
#  ('Population ages 70-74, female (% of female population)', 1),
#  ('Population ages 65 and above, male', 1),
#  ('Population ages 65-69, female (% of female population)', 1),
#  ('Population ages 55-59, female (% of female population)', 1),
#  ('Population ages 45-49, female (% of female population)', 1),
#  ('Population ages 35-39, female (% of female population)', 1),
#  ('Population ages 25-29, female (% of female population)', 1),
#  ('Population ages 15-64, total', 1),
#  ('Population ages 15-64, female', 1),
#  ('Population ages 10-14, female (% of female population)', 1),
#  ('Population ages 0-14, total', 1),
#  ('Population ages 0-14, female', 1),
#  ('Refugee population by country or territory of asylum', 1),
#  ('Official exchange rate (LCU per US$, period average)', 1),
#  ('Net secondary income (Net current transfers from abroad) (current LCU)', 1),
#  ('Taxes less subsidies on products (current US$)', 1),
#  ('GNI per capita, PPP (constant 2017 international $)', 1),
#  ('GNI per capita (constant 2015 US$)', 1),
#  ('GNI, PPP (current international $)', 1),
#  ('GNI: linked series (current LCU)', 1),
#  ('Gross domestic income (constant LCU)', 1),
#  ('GDP per capita (constant LCU)', 1),
#  ('GDP per capita (current US$)', 1),
#  ('GDP (constant LCU)', 1),
#  ('GDP (current LCU)', 1),
#  ('Gross value added at basic prices (GVA) (constant LCU)', 1),
#  ('Discrepancy in expenditure estimate of GDP (constant LCU)', 1),
#  ('Inflation, GDP deflator: linked series (annual %)', 1),
#  ('Services, value added (% of GDP)', 1),
#  ('Services, value added (current LCU)', 1),
#  ('Industry (including construction), value added (constant 2015 US$)', 1),
#  ('Manufacturing, value added (constant LCU)', 1),
#  ('Manufacturing, value added (current US$)', 1),
#  ('Agriculture, forestry, and fishing, value added (% of GDP)', 1),
#  ('Agriculture, forestry, and fishing, value added (current LCU)', 1),
#  ('External balance on goods and services (% of GDP)', 1),
#  ('Imports of goods and services (% of GDP)', 1),
#  ('Imports of goods and services (current LCU)', 1),
#  ('External balance on goods and services (current LCU)', 1),
#  ('Imports of goods and services (annual % growth)', 1),
#  ('Gross capital formation (% of GDP)', 1),
#  ('Gross capital formation (current LCU)', 1),
#  ('Changes in inventories (current US$)', 1),
#  ('Gross fixed capital formation (constant 2015 US$)', 1),
#  ('Exports of goods and services (constant 2015 US$)', 1),
#  ('Gross national expenditure (constant LCU)', 1),
#  ('Gross national expenditure deflator (base year varies by country)', 1),
#  ('Final consumption expenditure (constant 2015 US$)', 1),
#  ('Households and NPISHs Final consumption expenditure, PPP (constant 2017 international $)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (constant LCU)', 1),
#  ('Households and NPISHs Final consumption expenditure (current LCU)', 1),
#  ('General government final consumption expenditure (annual % growth)', 1),
#  ('Military expenditure (current USD)', 1),
#  ('Mobile cellular subscriptions (per 100 people)', 1),
#  ('Merchandise exports (current US$)', 1),
#  ('Agricultural raw materials exports (% of merchandise exports)', 1),
#  ('Manufactures imports (% of merchandise imports)', 1),
#  ('Food imports (% of merchandise imports)', 1),
#  ('Merchandise trade (% of GDP)', 1),
#  ('Urban population (% of total population)', 1),
#  ('Rural population growth (annual %)', 1),
#  ('Population, male (% of total population)', 1),
#  ('Population, total', 1),
#  ('Age dependency ratio, young (% of working-age population)', 1),
#  ('Population ages 80 and above, male (% of male population)', 1),
#  ('Population ages 70-74, male (% of male population)', 1),
#  ('Population ages 65 and above, male (% of male population)', 1),
#  ('Population ages 65-69, male (% of male population)', 1),
#  ('Population ages 55-59, male (% of male population)', 1),
#  ('Population ages 45-49, male (% of male population)', 1),
#  ('Population ages 35-39, male (% of male population)', 1),
#  ('Population ages 25-29, male (% of male population)', 1),
#  ('Population ages 15-64 (% of total population)', 1),
#  ('Population ages 15-64, female (% of female population)', 1),
#  ('Population ages 10-14, male (% of male population)', 1),
#  ('Population ages 0-14 (% of total population)', 1),
#  ('Population ages 0-14, female (% of female population)', 1),
#  ('Gross capital formation (annual % growth)', 1),
#  ('Gross fixed capital formation (constant LCU)', 1),
#  ('Gross fixed capital formation (current US$)', 1),
#  ('Exports of goods and services (constant LCU)', 1),
#  ('Exports of goods and services (current US$)', 1),
#  ('Gross national expenditure (current LCU)', 1),
#  ('Final consumption expenditure (constant LCU)', 1),
#  ('Final consumption expenditure (current US$)', 1),
#  ('Households and NPISHs Final consumption expenditure per capita growth (annual %)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (constant 2015 US$)',
#   1),
#  ('General government final consumption expenditure (% of GDP)', 1),
#  ('General government final consumption expenditure (current LCU)', 1),
#  ('Military expenditure (% of GDP)', 1),
#  ('Fixed telephone subscriptions (per 100 people)', 1),
#  ('Claims on central government, etc. (% GDP)', 1),
#  ('Consumer price index (2010 = 100)', 1),
#  ('Broad money (current LCU)', 1),
#  ('Net domestic credit (current LCU)', 1),
#  ('Domestic credit to private sector by banks (% of GDP)', 1),
#  ('Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employers, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Domestic credit provided by financial sector (% of GDP)', 1),
#  ('Broad money to total reserves ratio', 1),
#  ('Monetary Sector credit to private sector (% GDP)', 1),
#  ('Claims on central government (annual growth as % of broad money)', 1),
#  ('Total reserves (includes gold, current US$)', 1),
#  ('Net ODA provided, total (constant 2021 US$)', 1),
#  ('Net ODA provided, to the least developed countries (current US$)', 1),
#  ('Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services (% of total employment) (modeled ILO estimate)', 1),
#  ('Employment in industry (% of total employment) (modeled ILO estimate)', 1),
#  ('Contributing family workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employers, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('PPP conversion factor, private consumption (LCU per international $)', 1),
#  ('DEC alternative conversion factor (LCU per US$)', 1),
#  ('Net secondary income (Net current transfers from abroad) (current US$)', 1),
#  ('GNI per capita, PPP (current international $)', 1),
#  ('GNI per capita (current LCU)', 1),
#  ('GNI (constant LCU)', 1),
#  ('GNI (current LCU)', 1),
#  ('Gross domestic savings (% of GDP)', 1),
#  ('GDP per capita growth (annual %)', 1),
#  ('GDP growth (annual %)', 1),
#  ('GDP (current US$)', 1),
#  ('Gross value added at basic prices (GVA) (constant 2015 US$)', 1),
#  ('Discrepancy in expenditure estimate of GDP (current LCU)', 1),
#  ('Inflation, GDP deflator (annual %)', 1),
#  ('Services, value added (constant LCU)', 1),
#  ('Services, value added (current US$)', 1),
#  ('Industry (including construction), value added (% of GDP)', 1),
#  ('Industry (including construction), value added (current LCU)', 1),
#  ('Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Net ODA provided to the least developed countries (% of GNI)', 1),
#  ('Manufactures exports (% of merchandise exports)', 1),
#  ('Food exports (% of merchandise exports)', 1),
#  ('Ores and metals imports (% of merchandise imports)', 1),
#  ('Fuel imports (% of merchandise imports)', 1),
#  ('Rural population (% of total population)', 1),
#  ('Population, female', 1),
#  ('Population growth (annual %)', 1),
#  ('Population ages 75-79, female (% of female population)', 1),
#  ('Population ages 65 and above, total', 1),
#  ('Population ages 65 and above, female', 1),
#  ('Population ages 60-64, female (% of female population)', 1),
#  ('Population ages 50-54, female (% of female population)', 1),
#  ('Population ages 40-44, female (% of female population)', 1),
#  ('Population ages 30-34, female (% of female population)', 1),
#  ('Population ages 20-24, female (% of female population)', 1),
#  ('Population ages 15-64, male', 1),
#  ('Population ages 15-19, female (% of female population)', 1),
#  ('Population ages 05-09, female (% of female population)', 1),
#  ('Population ages 0-14, male', 1),
#  ('Population ages 00-04, female (% of female population)', 1),
#  ('External balance on goods and services (current US$)', 1),
#  ('Imports of goods and services (constant 2015 US$)', 1),
#  ('Gross capital formation (constant LCU)', 1),
#  ('Gross capital formation (current US$)', 1),
#  ('Gross fixed capital formation (% of GDP)', 1),
#  ('Gross fixed capital formation (current LCU)', 1),
#  ('Exports of goods and services (% of GDP)', 1),
#  ('Exports of goods and services (current LCU)', 1),
#  ('Gross national expenditure (constant 2015 US$)', 1),
#  ('Final consumption expenditure (% of GDP)', 1),
#  ('Final consumption expenditure (current LCU)', 1),
#  ('Households and NPISHs Final consumption expenditure, PPP (current international $)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (annual % growth)', 1),
#  ('Households and NPISHs Final consumption expenditure (current US$)', 1),
#  ('General government final consumption expenditure (constant 2015 US$)', 1),
#  ('Military expenditure (% of general government expenditure)', 1),
#  ('Mobile cellular subscriptions', 1),
#  ('Net ODA provided, total (current US$)', 1),
#  ('Immunization, measles (% of children ages 12-23 months)', 1),
#  ('Listed domestic companies, total', 1),
#  ('Foreign direct investment, net inflows (BoP, current US$)', 1),
#  ('Livestock production index (2014-2016 = 100)', 1),
#  ('Inflation, consumer prices (annual %)', 1),
#  ('Broad money (% of GDP)', 1),
#  ('Net foreign assets (current LCU)', 1),
#  ('Total reserves minus gold (current US$)', 1),
#  ('Stocks traded, turnover ratio of domestic shares (%)', 1),
#  ('Market capitalization of listed domestic companies (% of GDP)', 1),
#  ('Foreign direct investment, net outflows (% of GDP)', 1),
#  ('Food production index (2014-2016 = 100)', 1),
#  ('Immunization, DPT (% of children ages 12-23 months)', 1),
#  ('Agriculture, forestry, and fishing, value added (constant LCU)', 1),
#  ('Agriculture, forestry, and fishing, value added (current US$)', 1),
#  ('External balance on goods and services (constant LCU)', 1),
#  ('Imports of goods and services (constant LCU)', 1),
#  ('Imports of goods and services (current US$)', 1),
#  ('Gross capital formation (constant 2015 US$)', 1),
#  ('Changes in inventories (current LCU)', 1),
#  ('Gross fixed capital formation (annual % growth)', 1),
#  ('Exports of goods and services (annual % growth)', 1),
#  ('Gross national expenditure (% of GDP)', 1),
#  ('Gross national expenditure (current US$)', 1),
#  ('Final consumption expenditure (annual % growth)', 1),
#  ('Households and NPISHs final consumption expenditure (% of GDP)', 1),
#  ('Households and NPISHs Final consumption expenditure per capita (constant 2015 US$)',
#   1),
#  ('Households and NPISHs final consumption expenditure: linked series (current LCU)',
#   1),
#  ('General government final consumption expenditure (constant LCU)', 1),
#  ('General government final consumption expenditure (current US$)', 1),
#  ('Military expenditure (current LCU)', 1),
#  ('Arms imports (SIPRI trend indicator values)', 1),
#  ('Fixed telephone subscriptions', 1),
#  ('Stocks traded, total value (% of GDP)', 1),
#  ('Market capitalization of listed domestic companies (current US$)', 1),
#  ('Personal remittances, received (% of GDP)', 1),
#  ('Portfolio equity, net inflows (BoP, current US$)', 1),
#  ('Foreign direct investment, net outflows (BoP, current US$)', 1),
#  ('Cereal yield (kg per hectare)', 1),
#  ('Crop production index (2014-2016 = 100)', 1),
#  ('Intentional homicides, male (per 100,000 male)', 2),
#  ('Tariff rate, most favored nation, simple mean, primary products (%)', 2),
#  ('Tariff rate, most favored nation, simple mean, all products (%)', 2),
#  ('Tariff rate, most favored nation, simple mean, manufactured products (%)',
#   2),
#  ('Survival to age 65, female (% of cohort)', 2),
#  ('Life expectancy at birth, female (years)', 2),
#  ('Mortality rate, adult, male (per 1,000 male adults)', 2),
#  ('Mortality rate, under-5, female (per 1,000 live births)', 2),
#  ('Probability of dying among youth ages 20-24 years (per 1,000)', 2),
#  ('Number of neonatal deaths', 2),
#  ('Number of infant deaths', 2),
#  ('Number of deaths ages 10-14 years', 2),
#  ('Mineral rents (% of GDP)', 2),
#  ('Coal rents (% of GDP)', 2),
#  ('Adjusted net national income per capita (current US$)', 2),
#  ('Adjusted savings: particulate emission damage (% of GNI)', 2),
#  ('Adjusted savings: mineral depletion (% of GNI)', 2),
#  ('Adjusted savings: net forest depletion (% of GNI)', 2),
#  ('Adjusted savings: education expenditure (% of GNI)', 2),
#  ('Services, value added (annual % growth)', 2),
#  ('Machinery and transport equipment (% of value added in manufacturing)', 2),
#  ('Forest area (% of land area)', 2),
#  ('Agricultural land (% of land area)', 2),
#  ('GNI per capita growth (annual %)', 2),
#  ('Forest rents (% of GDP)', 2),
#  ('Adjusted net national income (annual % growth)', 2),
#  ('Adjusted savings: particulate emission damage (current US$)', 2),
#  ('Adjusted savings: mineral depletion (current US$)', 2),
#  ('Adjusted savings: net forest depletion (current US$)', 2),
#  ('Adjusted savings: education expenditure (current US$)', 2),
#  ('Textiles and clothing (% of value added in manufacturing)', 2),
#  ('Food, beverages and tobacco (% of value added in manufacturing)', 2),
#  ('Industry (including construction), value added (annual % growth)', 2),
#  ('Expense (current LCU)', 2),
#  ('Compensation of employees (% of expense)', 2),
#  ('Net lending (+) / net borrowing (-) (% of GDP)', 2),
#  ('Aquaculture production (metric tons)', 2),
#  ('Surface area (sq. km)', 2),
#  ('Land area (sq. km)', 2),
#  ('Forest area (sq. km)', 2),
#  ('Arable land (% of land area)', 2),
#  ('Agricultural land (sq. km)', 2),
#  ('Intentional homicides (per 100,000 people)', 2),
#  ('Share of tariff lines with specific rates, primary products (%)', 2),
#  ('Share of tariff lines with specific rates, all products (%)', 2),
#  ('Share of tariff lines with specific rates, manufactured products (%)', 2),
#  ('Survival to age 65, male (% of cohort)', 2),
#  ('Life expectancy at birth, total (years)', 2),
#  ('Mortality rate, infant, female (per 1,000 live births)', 2),
#  ('Birth rate, crude (per 1,000 people)', 2),
#  ('Total natural resources rents (% of GDP)', 2),
#  ('Adjusted net national income per capita (annual % growth)', 2),
#  ('Adjusted net national income (constant 2015 US$)', 2),
#  ('Adjusted savings: energy depletion (% of GNI)', 2),
#  ('Adjusted savings: consumption of fixed capital (% of GNI)', 2),
#  ('Adjusted savings: carbon dioxide damage (% of GNI)', 2),
#  ('Medium and high-tech manufacturing value added (% manufacturing value added)',
#   2),
#  ('Chemicals (% of value added in manufacturing)', 2),
#  ('Agriculture, forestry, and fishing, value added (annual % growth)', 2),
#  ('Air transport, freight (million ton-km)', 2),
#  ('Patent applications, nonresidents', 2),
#  ('Tariff rate, applied, weighted mean, primary products (%)', 2),
#  ('Share of tariff lines with international peaks, primary products (%)', 2),
#  ('Tariff rate, applied, weighted mean, all products (%)', 2),
#  ('Share of tariff lines with international peaks, all products (%)', 2),
#  ('Tariff rate, applied, weighted mean, manufactured products (%)', 2),
#  ('Share of tariff lines with international peaks, manufactured products (%)',
#   2),
#  ('Life expectancy at birth, male (years)', 2),
#  ('Mortality rate, infant (per 1,000 live births)', 2),
#  ('Death rate, crude (per 1,000 people)', 2),
#  ('Adolescent fertility rate (births per 1,000 women ages 15-19)', 2),
#  ('Industrial design applications, resident, by count', 2),
#  ('Expense (% of GDP)', 2),
#  ('Interest payments (% of expense)', 2),
#  ('Goods and services expense (current LCU)', 2),
#  ('Central government debt, total (current LCU)', 2),
#  ('Capture fisheries production (metric tons)', 2),
#  ('Population density (people per sq. km of land area)', 2),
#  ('Subsidies and other transfers (% of expense)', 2),
#  ('Other expense (% of expense)', 2),
#  ('Interest payments (current LCU)', 2),
#  ('Compensation of employees (current LCU)', 2),
#  ('Net lending (+) / net borrowing (-) (current LCU)', 2),
#  ('Access to electricity, urban (% of urban population)', 2),
#  ('Access to electricity, rural (% of rural population)', 2),
#  ('Oil rents (% of GDP)', 2),
#  ('Natural gas rents (% of GDP)', 2),
#  ('Adjusted net national income per capita (constant 2015 US$)', 2),
#  ('Adjusted net national income (current US$)', 2),
#  ('Adjusted savings: natural resources depletion (% of GNI)', 2),
#  ('Adjusted savings: energy depletion (current US$)', 2),
#  ('Adjusted savings: consumption of fixed capital (current US$)', 2),
#  ('Adjusted savings: carbon dioxide damage (current US$)', 2),
#  ('Other manufacturing (% of value added in manufacturing)', 2),
#  ('Manufacturing, value added (annual % growth)', 2),
#  ('Intentional homicides, female (per 100,000 female)', 2),
#  ('Medium and high-tech exports (% manufactured exports)', 2),
#  ('Tariff rate, most favored nation, weighted mean, primary products (%)', 2),
#  ('Tariff rate, applied, simple mean, primary products (%)', 2),
#  ('Tariff rate, most favored nation, weighted mean, all products (%)', 2),
#  ('Tariff rate, applied, simple mean, all products (%)', 2),
#  ('Tariff rate, most favored nation, weighted mean, manufactured products (%)',
#   2),
#  ('Tariff rate, applied, simple mean, manufactured products (%)', 2),
#  ('Sex ratio at birth (male births per female births)', 2),
#  ('Fertility rate, total (births per woman)', 2),
#  ('Mortality rate, infant, male (per 1,000 live births)', 2),
#  ('Mortality rate, adult, female (per 1,000 female adults)', 2),
#  ('Mortality rate, neonatal (per 1,000 live births)', 2),
#  ('Mortality rate, under-5, male (per 1,000 live births)', 2),
#  ("Women's share of population ages 15+ living with HIV (%)", 2),
#  ('Probability of dying among children ages 5-9 years (per 1,000)', 2),
#  ('Number of deaths ages 15-19 years', 2),
#  ('Lower secondary school starting age (years)', 2),
#  ('Individuals using the Internet (% of population)', 2),
#  ('Air transport, registered carrier departures worldwide', 2),
#  ('Access to electricity (% of population)', 2),
#  ('Mortality rate, under-5 (per 1,000 live births)', 2),
#  ('Probability of dying among adolescents ages 15-19 years (per 1,000)', 2),
#  ('Number of deaths ages 5-9 years', 2),
#  ('Primary school starting age (years)', 2),
#  ('Arable land (hectares per person)', 2),
#  ('Fertilizer consumption (kilograms per hectare of arable land)', 2),
#  ('Subsidies and other transfers (current LCU)', 2),
#  ('Other expense (current LCU)', 2),
#  ('Goods and services expense (% of expense)', 2),
#  ('Central government debt, total (% of GDP)', 2),
#  ('Total fisheries production (metric tons)', 2),
#  ('Permanent cropland (% of land area)', 2),
#  ('Arable land (hectares)', 2),
#  ('Fertilizer consumption (% of fertilizer production)', 2),
#  ('Probability of dying among adolescents ages 10-14 years (per 1,000)', 2),
#  ('Number of under-five deaths', 2),
#  ('Number of deaths ages 20-24 years', 2),
#  ('Secondary education, duration (years)', 2),
#  ('Primary education, duration (years)', 2),
#  ('Air transport, passengers carried', 2),
#  ('Patent applications, residents', 2),
#  ('Industrial design applications, nonresident, by count', 2),
#  ('Travel services (% of commercial service exports)', 3),
#  ('Commercial service exports (current US$)', 3),
#  ('Merchandise exports by the reporting economy (current US$)', 3),
#  ('Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#   3),
#  ('Transport services (% of commercial service imports)', 3),
#  ('Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from economies in the Arab World (% of total merchandise imports)',
#   3),
#  ('Binding coverage, primary products (%)', 3),
#  ('Binding coverage, all products (%)', 3),
#  ('Binding coverage, manufactured products (%)', 3),
#  ('Gross savings (current LCU)', 3),
#  ('Gross savings (current US$)', 3),
#  ('Annual freshwater withdrawals, total (billion cubic meters)', 3),
#  ('Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
#   3),
#  ('Nitrous oxide emissions (thousand metric tons of CO2 equivalent)', 3),
#  ('Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (metric tons per capita)', 3),
#  ('CO2 emissions (kg per 2015 US$ of GDP)', 3),
#  ('Exports of goods, services and primary income (BoP, current US$)', 3),
#  ('Insurance and financial services (% of service exports, BoP)', 3),
#  ('ICT service exports (% of service exports, BoP)', 3),
#  ('Net capital account (BoP, current US$)', 3),
#  ('Foreign direct investment, net (BoP, current US$)', 3),
#  ('Net primary income (BoP, current US$)', 3),
#  ('Travel services (% of service imports, BoP)', 3),
#  ('Service imports (BoP, current US$)', 3),
#  ('Primary income payments (BoP, current US$)', 3),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   3),
#  ('Travel services (% of commercial service imports)', 3),
#  ('Import value index (2015 = 100)', 3),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   3),
#  ('Insurance and financial services (% of commercial service imports)', 3),
#  ('Bound rate, simple mean, primary products (%)', 3),
#  ('Bound rate, simple mean, all products (%)', 3),
#  ('Bound rate, simple mean, manufactured products (%)', 3),
#  ('Gross savings (% of GDP)', 3),
#  ('Export value index (2015 = 100)', 3),
#  ('Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#   3),
#  ('Insurance and financial services (% of commercial service exports)', 3),
#  ('Computer, communications and other services (% of commercial service imports)',
#   3),
#  ('Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from high-income economies (% of total merchandise imports)',
#   3),
#  ('Armed forces personnel, total', 3),
#  ('Total reserves in months of imports', 3),
#  ('Annual freshwater withdrawals, total (% of internal resources)', 3),
#  ('Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
#   3),
#  ('CO2 emissions (kg per PPP $ of GDP)', 3),
#  ('CO2 emissions (kt)', 3),
#  ('Renewable internal freshwater resources per capita (cubic meters)', 3),
#  ('Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
#   3),
#  ('Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)',
#   3),
#  ('Total greenhouse gas emissions (kt of CO2 equivalent)', 3),
#  ('Renewable energy consumption (% of total final energy consumption)', 3),
#  ('Gross savings (% of GNI)', 3),
#  ('Transport services (% of commercial service exports)', 3),
#  ('Computer, communications and other services (% of commercial service exports)',
#   3),
#  ('Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to high-income economies (% of total merchandise exports)',
#   3),
#  ('Commercial service imports (current US$)', 3),
#  ('Merchandise imports by the reporting economy (current US$)', 3),
#  ('Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#   3),
#  ('Armed forces personnel (% of total labor force)', 3),
#  ('Personal transfers, receipts (BoP, current US$)', 3),
#  ('Charges for the use of intellectual property, receipts (BoP, current US$)',
#   3),
#  ('Exports of goods and services (BoP, current US$)', 3),
#  ('ICT service exports (BoP, current US$)', 3),
#  ('Net secondary income (BoP, current US$)', 3),
#  ('Net errors and omissions (BoP, current US$)', 3),
#  ('Net financial account (BoP, current US$)', 3),
#  ('Secondary income, other sectors, payments (BoP, current US$)', 3),
#  ('Transport services (% of service imports, BoP)', 3),
#  ('Goods imports (BoP, current US$)', 3),
#  ('Communications, computer, etc. (% of service imports, BoP)', 3),
#  ('Average precipitation in depth (mm per year)', 3),
#  ('Renewable internal freshwater resources, total (billion cubic meters)', 3),
#  ('Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
#   3),
#  ('Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions (kt of CO2 equivalent)', 3),
#  ('Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (kg per 2017 PPP $ of GDP)', 3),
#  ('Secondary income receipts (BoP, current US$)', 3),
#  ('Travel services (% of service exports, BoP)', 3),
#  ('Service exports (BoP, current US$)', 3),
#  ('Primary income receipts (BoP, current US$)', 3),
#  ('Reserves and related items (BoP, current US$)', 3),
#  ('Net trade in goods (BoP, current US$)', 3),
#  ('Current account balance (% of GDP)', 3),
#  ('Imports of goods, services and primary income (BoP, current US$)', 3),
#  ('Insurance and financial services (% of service imports, BoP)', 3),
#  ('Trade in services (% of GDP)', 3),
#  ('Transport services (% of service exports, BoP)', 3),
#  ('Goods exports (BoP, current US$)', 3),
#  ('Communications, computer, etc. (% of service exports, BoP)', 3),
#  ('Portfolio investment, net (BoP, current US$)', 3),
#  ('Net trade in goods and services (BoP, current US$)', 3),
#  ('Current account balance (BoP, current US$)', 3),
#  ('Charges for the use of intellectual property, payments (BoP, current US$)',
#   3),
#  ('Imports of goods and services (BoP, current US$)', 3),
#  ('International tourism, expenditures (current US$)', 4),
#  ('International tourism, receipts for passenger transport items (current US$)',
#   4),
#  ('International tourism, number of arrivals', 4),
#  ('Researchers in R&D (per million people)', 4),
#  ('Proportion of seats held by women in national parliaments (%)', 4),
#  ('Adjusted net savings, including particulate emission damage (% of GNI)', 4),
#  ('Adjusted savings: net national savings (% of GNI)', 4),
#  ('Services, value added per worker (constant 2015 US$)', 4),
#  ('Adjusted net savings, including particulate emission damage (current US$)',
#   4),
#  ('Adjusted savings: net national savings (current US$)', 4),
#  ('International tourism, expenditures for passenger transport items (current US$)',
#   4),
#  ('International tourism, number of departures', 4),
#  ('Adjusted net savings, excluding particulate emission damage (% of GNI)', 4),
#  ('Adjusted savings: gross savings (% of GNI)', 4),
#  ('Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)',
#   4),
#  ('International tourism, receipts for travel items (current US$)', 4),
#  ('International tourism, receipts (current US$)', 4),
#  ('Railways, goods transported (million ton-km)', 4),
#  ('Adjusted net savings, excluding particulate emission damage (current US$)',
#   4),
#  ('Industry (including construction), value added per worker (constant 2015 US$)',
#   4),
#  ('International tourism, expenditures for travel items (current US$)', 4),
#  ('Government expenditure on education, total (% of GDP)', 4),
#  ('Railways, passengers carried (million passenger-km)', 4),
#  ('Research and development expenditure (% of GDP)', 4),
#  ('Hospital beds (per 1,000 people)', 5),
#  ('International tourism, expenditures (% of total imports)', 5),
#  ('Fixed broadband subscriptions (per 100 people)', 5),
#  ('Refugee population by country or territory of origin', 5),
#  ('International tourism, receipts (% of total exports)', 5),
#  ('Fixed broadband subscriptions', 5),
#  ('Scientific and technical journal articles', 5),
#  ('Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Estimate', 6),
#  ('Regulatory Quality: Percentile Rank', 6),
#  ('Rule of Law: Percentile Rank, Upper Bound of 90% Confidence Interval', 6),
#  ('Rule of Law: Estimate', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Standard Error', 6),
#  ('Regulatory Quality: Number of Sources', 6),
#  ('Rule of Law: Percentile Rank, Lower Bound of 90% Confidence Interval', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank', 6),
#  ('Government Effectiveness: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Government Effectiveness: Estimate', 6),
#  ('Risk premium on lending (lending rate minus treasury bill rate, %)', 6),
#  ('Deposit interest rate (%)', 6),
#  ('Control of Corruption: Percentile Rank', 6),
#  ('Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Voice and Accountability: Estimate', 6),
#  ('Rule of Law: Percentile Rank', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Standard Error', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Number of Sources',
#   6),
#  ('Voice and Accountability: Standard Error', 6),
#  ('Voice and Accountability: Number of Sources', 6),
#  ('Government Effectiveness: Standard Error', 6),
#  ('Government Effectiveness: Number of Sources', 6),
#  ('Lending interest rate (%)', 6),
#  ('Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Real interest rate (%)', 6),
#  ('Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Rule of Law: Standard Error', 6),
#  ('Rule of Law: Number of Sources', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Political Stability and Absence of Violence/Terrorism: Estimate', 6),
#  ('Voice and Accountability: Percentile Rank', 6),
#  ('Control of Corruption: Standard Error', 6),
#  ('Control of Corruption: Number of Sources', 6),
#  ('Government Effectiveness: Percentile Rank', 6),
#  ('Interest rate spread (lending rate minus deposit rate, %)', 6),
#  ('Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Control of Corruption: Estimate', 6),
#  ('Net ODA provided, total (% of GNI)', 6),
#  ('Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('People using safely managed drinking water services (% of population)', 7),
#  ('CO2 emissions from solid fuel consumption (% of total)', 7),
#  ('Technicians in R&D (per million people)', 7),
#  ('Net investment in nonfinancial assets (current LCU)', 7),
#  ('Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#   7),
#  ('Tuberculosis case detection rate (%, all forms)', 7),
#  ('Prevalence of overweight (modeled estimate, % of children under 5)', 7),
#  ('CO2 emissions from solid fuel consumption (kt)', 7),
#  ('CO2 emissions from liquid fuel consumption (% of total)', 7),
#  ('CO2 emissions from gaseous fuel consumption (% of total)', 7),
#  ('Prevalence of stunting, height for age (modeled estimate, % of children under 5)',
#   7),
#  ('Incidence of tuberculosis (per 100,000 people)', 7),
#  ('People using safely managed sanitation services (% of population)', 7),
#  ('People practicing open defecation (% of population)', 7),
#  ('People using at least basic sanitation services (% of population)', 7),
#  ('People using at least basic drinking water services (% of population)', 7),
#  ('Compulsory education, duration (years)', 7),
#  ('Preprimary education, duration (years)', 7),
#  ('Net investment in nonfinancial assets (% of GDP)', 7),
#  ('CO2 emissions from liquid fuel consumption (kt)', 7),
#  ('CO2 emissions from gaseous fuel consumption (kt)', 7),
#  ('Export volume index (2015 = 100)', 8),
#  ('ICT goods imports (% total goods imports)', 8),
#  ('Import unit value index (2015 = 100)', 8),
#  ('Tuberculosis treatment success rate (% of new cases)', 8),
#  ('ICT goods exports (% of total goods exports)', 8),
#  ('Export unit value index (2015 = 100)', 8),
#  ('Gross fixed capital formation, private sector (current LCU)', 8),
#  ('Net barter terms of trade index (2015 = 100)', 8),
#  ('Container port traffic (TEU: 20 foot equivalent units)', 8),
#  ('Alternative and nuclear energy (% of total energy use)', 8),
#  ('Electricity production from oil sources (% of total)', 8),
#  ('Electricity production from hydroelectric sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, urban (% of urban population)',
#   8),
#  ('Electricity production from renewable sources, excluding hydroelectric (% of total)',
#   8),
#  ('Electricity production from nuclear sources (% of total)', 8),
#  ('Electricity production from oil, gas and coal sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, rural (% of rural population)',
#   8),
#  ('CO2 intensity (kg per kg of oil equivalent energy use)', 8),
#  ('Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)', 8),
#  ('GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)',
#   8),
#  ('Electricity production from renewable sources, excluding hydroelectric (kWh)',
#   8),
#  ('Electricity production from natural gas sources (% of total)', 8),
#  ('Electricity production from coal sources (% of total)', 8),
#  ('Energy intensity level of primary energy (MJ/$2017 PPP GDP)', 8),
#  ('Import volume index (2015 = 100)', 8),
#  ('Energy use (kg of oil equivalent per capita)', 8),
#  ('Fossil fuel energy consumption (% of total)', 8),
#  ('GDP per unit of energy use (PPP $ per kg of oil equivalent)', 8),
#  ('Renewable electricity output (% of total electricity output)', 8),
#  ('Access to clean fuels and technologies for cooking (% of population)', 8),
#  ('Births attended by skilled health staff (% of total)', 8),
#  ('Claims on other sectors of the domestic economy (% of GDP)', 8),
#  ('Bank liquid reserves to bank assets ratio (%)', 8),
#  ('Combustible renewables and waste (% of total energy)', 8),
#  ('Energy imports, net (% of energy use)', 8),
#  ('Gross fixed capital formation, private sector (% of GDP)', 8),
#  ('Number of maternal deaths', 9),
#  ('Domestic private health expenditure per capita, PPP (current international $)',
#   9),
#  ('Out-of-pocket expenditure per capita (current US$)', 9),
#  ('Domestic general government health expenditure (% of general government expenditure)',
#   9),
#  ('Current health expenditure (% of GDP)', 9),
#  ('Claims on other sectors of the domestic economy (annual growth as % of broad money)',
#   9),
#  ('CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)',
#   9),
#  ('Prevalence of undernourishment (% of population)', 9),
#  ('CO2 emissions from transport (% of total fuel combustion)', 9),
#  ('CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)',
#   9),
#  ('Female share of employment in senior and middle management (%)', 9),
#  ('Out-of-pocket expenditure per capita, PPP (current international $)', 9),
#  ('Domestic general government health expenditure per capita (current US$)',
#   9),
#  ('Current health expenditure per capita (current US$)', 9),
#  ('CO2 emissions from manufacturing industries and construction (% of total fuel combustion)',
#   9),
#  ('Electric power consumption (kWh per capita)', 9),
#  ('Domestic private health expenditure per capita (current US$)', 9),
#  ('Out-of-pocket expenditure (% of current health expenditure)', 9),
#  ('Domestic general government health expenditure (% of GDP)', 9),
#  ('Low-birthweight babies (% of births)', 9),
#  ('Domestic private health expenditure (% of current health expenditure)', 9),
#  ('Domestic general government health expenditure per capita, PPP (current international $)',
#   9),
#  ('Domestic general government health expenditure (% of current health expenditure)',
#   9),
#  ('Current health expenditure per capita, PPP (current international $)', 9),
#  ('Maternal mortality ratio (modeled estimate, per 100,000 live births)', 9),
#  ('Lifetime risk of maternal death (1 in: rate varies by country)', 9),
#  ('Electric power transmission and distribution losses (% of output)', 9),
#  ('CO2 emissions from electricity and heat production, total (% of total fuel combustion)',
#   9),
#  ('Maternal mortality ratio (national estimate, per 100,000 live births)', 9),
#  ('Lifetime risk of maternal death (%)', 9),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)',
#   10),
#  ('Prevalence of anemia among non-pregnant women (% of women ages 15-49)', 10),
#  ('Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)',
#   10),
#  ('External health expenditure per capita (current US$)', 10),
#  ('Mortality caused by road traffic injury (per 100,000 population)', 10),
#  ('Net secondary income (Net current transfers from abroad) (constant LCU)',
#   10),
#  ('External health expenditure per capita, PPP (current international $)', 10),
#  ('Suicide mortality rate, female (per 100,000 female population)', 10),
# ...
#   12),
#  ('Commercial bank branches (per 100,000 adults)', 12),
#  ('Government expenditure on education, total (% of government expenditure)',
#   13),
#  ('Unemployment with advanced education, female (% of female labor force with advanced education)',
#   14),
#  ('High-technology exports (current US$)', 14),
#  ('High-technology exports (% of manufactured exports)', 14),
#  ('Unemployment with advanced education, male (% of male labor force with advanced education)',
#   14),
#  ('GHG net emissions/removals by LUCF (Mt of CO2 equivalent)', 14),
#  ('Unemployment with advanced education (% of total labor force with advanced education)',
#   14),
#  ('Liner shipping connectivity index (maximum value in 2004 = 100)', 14),
#  ('Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
#   15),
#  ('Agricultural nitrous oxide emissions (% of total)', 15),
#  ('Energy related methane emissions (% of total)', 15),
#  ('Nitrous oxide emissions in energy sector (% of total)', 15),
#  ('Agricultural methane emissions (% of total)', 15),
#  ('School enrollment, primary, male (% gross)', 16),
#  ('New businesses registered (number)', 16),
#  ('Internally displaced persons, new displacement associated with disasters (number of cases)',
#   16),
#  ('New business density (new registrations per 1,000 people ages 15-64)', 16),
#  ('School enrollment, primary, private (% of total primary)', 16),
#  ('Physicians (per 1,000 people)', 16),
#  ('School enrollment, primary, female (% gross)', 16),
#  ('Primary education, pupils', 16),
#  ('Agricultural irrigated land (% of total agricultural land)', 16),
#  ('Nurses and midwives (per 1,000 people)', 16),
#  ('Primary education, teachers', 16),
#  ('School enrollment, primary (% gross)', 16),
#  ('Risk of impoverishing expenditure for surgical care (% of people at risk)',
#   17),
#  ('School enrollment, secondary (% gross)', 17),
#  ('PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#   17),
#  ('Risk of catastrophic expenditure for surgical care (% of people at risk)',
#   17),
#  ('Secondary education, pupils', 17),
#  ('School enrollment, primary (gross), gender parity index (GPI)', 17),
#  ('School enrollment, tertiary, male (% gross)', 18),
#  ('Agricultural machinery, tractors', 18),
#  ('Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)',
#   18),
#  ('Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)',
#   18),
#  ('School enrollment, secondary, female (% gross)', 18),
#  ('School enrollment, tertiary (gross), gender parity index (GPI)', 18),
#  ('School enrollment, tertiary, female (% gross)', 18),
#  ('Agricultural machinery, tractors per 100 sq. km of arable land', 18),
#  ('School enrollment, tertiary (% gross)', 18),
#  ('School enrollment, secondary, male (% gross)', 18),
#  ('School enrollment, secondary (gross), gender parity index (GPI)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)',
#   19),
#  ('Secure Internet servers (per 1 million people)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-2 value (% of total)',
#   19),
#  ('Pump price for gasoline (US$ per liter)', 19),
#  ('PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)',
#   19),
#  ('Secondary education, teachers', 19),
#  ('School enrollment, primary and secondary (gross), gender parity index (GPI)',
#   19),
#  ('Pump price for diesel fuel (US$ per liter)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)',
#   19),
#  ('Secure Internet servers', 19),
#  ('Unemployment with intermediate education (% of total labor force with intermediate education)',
#   20),
#  ('Share of youth not in education, employment or training, total (% of youth population)',
#   20),
#  ('Share of youth not in education, employment or training, female (% of female youth population)',
#   20),
#  ('Unemployment with intermediate education, male (% of male labor force with intermediate education)',
#   20),
#  ('Share of youth not in education, employment or training, male (% of male youth population)',
#   20),
#  ('Unemployment with intermediate education, female (% of female labor force with intermediate education)',
#   20),
#  ('Primary government expenditures as a proportion of original approved budget (%)',
#   20),
#  ('Contraceptive prevalence, any method (% of married women ages 15-49)', 21),
#  ('Children out of school (% of primary school age)', 21),
#  ('Trademark applications, nonresident, by count', 21),
#  ('School enrollment, preprimary (% gross)', 21),
#  ('Trademark applications, resident, by count', 21),
#  ('Children out of school, primary', 21),
#  ('Labor force with intermediate education (% of total working-age population with intermediate education)',
#   22),
#  ('Labor force with advanced education, female (% of female working-age population with advanced education)',
#   22),
#  ('Arms exports (SIPRI trend indicator values)', 22),
#  ('Labor force with advanced education, male (% of male working-age population with advanced education)',
#   22),
#  ('Wholesale price index (2010 = 100)', 22),
#  ('Labor force with intermediate education, male (% of male working-age population with intermediate education)',
#   22),
#  ('Labor force with intermediate education, female (% of female working-age population with intermediate education)',
#   22),
#  ('Labor force with advanced education (% of total working-age population with advanced education)',
#   22),
#  ('Average transaction cost of sending remittances from a specific country (%)',
#   22),
#  ('Contraceptive prevalence, any modern method (% of married women ages 15-49)',
#   22),
#  ('School enrollment, secondary, private (% of total secondary)', 22),
#  ('Prevalence of severe food insecurity in the population (%)', 23),
#  ('Prevalence of current tobacco use (% of adults)', 23),
#  ('Adolescents out of school (% of lower secondary school age)', 23),
#  ('Time required to get electricity (days)', 23),
#  ('Terrestrial protected areas (% of total land area)', 23),
#  ('Logistics performance index: Ability to track and trace consignments (1=low to 5=high)',
#   23),
#  ('Logistics performance index: Ease of arranging competitively priced shipments (1=low to 5=high)',
#   23),
#  ('Procedures to build a warehouse (number)', 23),
#  ('Tax payments (number)', 23),
#  ('Prevalence of moderate or severe food insecurity in the population (%)',
#   23),
#  ('Logistics performance index: Overall (1=low to 5=high)', 23),
#  ('Logistics performance index: Efficiency of customs clearance process (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 5 data infrastructure score (scale 0-100)',
#   23),
#  ('Total tax and contribution rate (% of profit)', 23),
#  ('Start-up procedures to register a business, male (number)', 23),
#  ('Time required to start a business, female (days)', 23),
#  ('Cost of business start-up procedures, female (% of GNI per capita)', 23),
#  ('Start-up procedures to register a business (number)', 23),
#  ('Cost of business start-up procedures (% of GNI per capita)', 23),
#  ('Time required to register property (days)', 23),
#  ('Depth of credit information index (0=low to 8=high)', 23),
#  ('Marine protected areas (% of territorial waters)', 23),
#  ('Strength of legal rights index (0=weak to 12=strong)', 23),
#  ('Public credit registry coverage (% of adults)', 23),
#  ('UHC service coverage index', 23),
#  ('Prevalence of current tobacco use, females (% of female adults)', 23),
#  ('Logistics performance index: Frequency with which shipments reach consignee within scheduled or expected time (1=low to 5=high)',
#   23),
#  ('Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 2 data services score (scale 0-100)',
#   23),
#  ('Time required to build a warehouse (days)', 23),
#  ('Other taxes payable by businesses (% of commercial profits)', 23),
#  ('Time to prepare and pay taxes (hours)', 23),
#  ('Time required to start a business, male (days)', 23),
#  ('Cost of business start-up procedures, male (% of GNI per capita)', 23),
#  ('Time required to enforce a contract (days)', 23),
#  ('Private credit bureau coverage (% of adults)', 23),
#  ('Terrestrial and marine protected areas (% of total territorial area)', 23),
#  ('Prevalence of current tobacco use, males (% of male adults)', 23),
#  ('Logistics performance index: Competence and quality of logistics services (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 4 data sources score (scale 0-100)',
#   23),
#  ('Statistical performance indicators (SPI): Overall score (scale 0-100)', 23),
#  ('Profit tax (% of commercial profits)', 23),
#  ('Labor tax and contributions (% of commercial profits)', 23),
#  ('Start-up procedures to register a business, female (number)', 23),
#  ('Time required to start a business (days)', 23),
#  ('Procedures to register property (number)', 23),
#  ('Time to resolve insolvency (years)', 23),
#  ('Time to import, border compliance (hours)', 24),
#  ('Time to export, documentary compliance (hours)', 24),
#  ('Lead time to export, median case (days)', 24),
#  ('Time to import, documentary compliance (hours)', 24),
#  ('Cost to export, border compliance (US$)', 24),
#  ('Cost to import, documentary compliance (US$)', 24),
#  ('Time to export, border compliance (hours)', 24),
#  ('School enrollment, preprimary, male (% gross)', 24),
#  ('Cost to import, border compliance (US$)', 24),
#  ('Cost to export, documentary compliance (US$)', 24),
#  ('School enrollment, preprimary, female (% gross)', 24),
#  ('Lead time to import, median case (days)', 24),
#  ('Completeness of death registration with cause-of-death information (%)',
#   25),
#  ('Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)',
#   25),
#  ('Secondary education, pupils (% female)', 25),
#  ('Over-age students, primary (% of enrollment)', 25),
#  ('Primary education, pupils (% female)', 25),
#  ('Pupil-teacher ratio, preprimary', 25),
#  ('Primary school age children out-of-school (%)', 25),
#  ('Pupils below minimum reading proficiency at end of primary (%). Low GAML threshold',
#   25),
#  ('International migrant stock, total', 25),
#  ('Ease of doing business score (0 = lowest performance to 100 = best performance)',
#   25),
#  ('International migrant stock (% of population)', 25),
#  ('Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)',
#   25),
#  ('Pupil-teacher ratio, tertiary', 25),
#  ('Secondary education, general pupils', 25),
#  ('Pupil-teacher ratio, primary', 25),
#  ('Female primary school age children out-of-school (%)', 25),
#  ('Female pupils below minimum reading proficiency at end of primary (%). Low GAML threshold',
#   25),
#  ('Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)',
#   25),
#  ('Secondary education, vocational pupils (% female)', 25),
#  ('Pupil-teacher ratio, lower secondary', 25),
#  ('Primary education, teachers (% female)', 25),
#  ('Over-age students, primary, male (% of male enrollment)', 25),
#  ('Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)',
#   25),
#  ('Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)',
#   25),
#  ('Secondary education, vocational pupils', 25),
#  ('Secondary education, general pupils (% female)', 25),
#  ('Over-age students, primary, female (% of female enrollment)', 25),
#  ('Male primary school age children out-of-school (%)', 25),
#  ('Male pupils below minimum reading proficiency at end of primary (%). Low GAML threshold',
#   25),
#  ('Learning poverty: Share of Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)',
#   25),
#  ('Pupil-teacher ratio, secondary', 26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider, young adults (% of population ages 15-24)',
#   26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+)',
#   26),
#  ('SF6 gas emissions (thousand metric tons of CO2 equivalent)', 26),
#  ('Human capital index (HCI), upper bound (scale 0-1)', 26),
#  ('Human capital index (HCI), lower bound (scale 0-1)', 26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)',
#   26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider, older adults (% of population ages 25+)',
#   26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider, poorest 40% (% of population ages 15+)',
#   26),
#  ('HFC gas emissions (thousand metric tons of CO2 equivalent)', 26),
#  ('Human capital index (HCI) (scale 0-1)', 26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider, secondary education or more (% of population ages 15+)',
#   26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)',
#   26),
#  ('Completeness of birth registration (%)', 26),
#  ('Immunization, HepB3 (% of one-year-old children)', 26),
#  ('Cause of death, by injury (% of total)', 26),
#  ('Pupil-teacher ratio, upper secondary', 26),
#  ('Cause of death, by non-communicable diseases (% of total)', 26),
#  ('Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
#   26),
#  ('Proportion of time spent on unpaid domestic and care work, male (% of 24 hour day)',
#   26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider, primary education or less (% of population ages 15+)',
#   26),
#  ('Account ownership at a financial institution or with a mobile-money-service provider, richest 60% (% of population ages 15+)',
#   26),
#  ('PFC gas emissions (thousand metric tons of CO2 equivalent)', 26),
#  ('Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)',
#   26),
#  ('Government expenditure per student, secondary (% of GDP per capita)', 27),
#  ('Progression to secondary school, male (%)', 27),
#  ('Primary completion rate, female (% of relevant age group)', 27),
#  ('Poverty gap at $6.85 a day (2017 PPP) (%)', 27),
#  ('Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)', 27),
#  ('Income share held by lowest 20%', 27),
#  ('Income share held by highest 20%', 27),
#  ('Poverty gap at $3.65 a day (2017 PPP) (%)', 27),
#  ('Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)', 27),
#  ('Income share held by highest 10%', 27),
#  ('Income share held by second 20%', 27),
#  ('Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)', 27),
#  ('Gini index', 27),
#  ('Income share held by lowest 10%', 27),
#  ('Income share held by fourth 20%', 27),
#  ('Poverty gap at $2.15 a day (2017 PPP) (%)', 27),
#  ('Proportion of people living below 50 percent of median income (%)', 27),
#  ('Income share held by third 20%', 27),
#  ('Expenditure on secondary education (% of government expenditure on education)',
#   27),
#  ('Progression to secondary school (%)', 27),
#  ('Primary completion rate, male (% of relevant age group)', 27),
#  ('Expenditure on tertiary education (% of government expenditure on education)',
#   27),
#  ('Expenditure on primary education (% of government expenditure on education)',
#   27),
#  ('Progression to secondary school, female (%)', 27),
#  ('Government expenditure per student, tertiary (% of GDP per capita)', 27),
#  ('Government expenditure per student, primary (% of GDP per capita)', 27),
#  ('Primary completion rate, total (% of relevant age group)', 27),
#  ('Specialist surgical workforce (per 100,000 population)', 28),
#  ...]

# %%
# selecting the columns we want to analyse
selected_japan_data = japan_data[["Year","GDP growth (annual %)","GDP (constant 2015 US$)","Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_japan_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_japan_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_japan_data
# Out:
# /tmp/ipykernel_106121/124698930.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_japan_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_106121/124698930.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_japan_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 35  1994               1.083383     3688589488080.589844
# 36  1995                  2.631     3785636263364.359863
# 37  1996               3.133871     3904273220115.029785
# 38  1997               0.981229     3942583070731.740234
# 39  1998               -1.27033      3892499235707.72998
# 40  1999               -0.33393     3879501014654.609863
# 41  2000               2.764648     3986755544464.209961
# 42  2001               0.386103     4002148544213.450195
# 43  2002               0.041962     4003827945768.799805
# 44  2003               1.535125     4065291729511.600098
# 45  2004               2.186116      4154163710034.47998
# 46  2005               1.803901     4229100705435.470215
# 47  2006                1.37235     4287138774363.709961
# 48  2007               1.483969     4350758602409.600098
# 49  2008              -1.224289     4297492743392.060059
# 50  2009              -5.693236          4052826324007.5
# 51  2010               4.097918     4218907820177.169922
# 52  2011                0.02381     4219912322037.649902
# 53  2012               1.374751     4277925608850.600098
# 54  2013                 2.0051     4363702302795.859863
# 55  2014               0.296206     4376627829637.509766
# 56  2015               1.560627     4444930651964.179688
# 57  2016               0.753827     4478437728055.549805
# 58  2017               1.675332     4553466417292.209961
# 59  2018               0.643391     4582763011477.349609
# 60  2019              -0.402169     4564332550094.450195
# 61  2020              -4.147119     4375044252274.509766
# 62  2021                2.55932     4487015645273.129883
# 63  2022               0.954737     4529854841042.580078
# 64  2023                   <NA>                     <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 35                                          <NA>
# 36                                          <NA>
# 37                            33820312103.573799
# 38                           -32129071212.776402
# 39                            39172919339.479897
# 40                            27481454263.076401
# 41                            35975387034.795197
# 42                            46285624467.396301
# 43                           105974660790.453995
# 44                            95110162832.992905
# 45                           -22947944390.504501
# 46                              13268315803.7957
# 47                          -127520047988.414001
# 48                           -73129063903.396194
# 49                           282689352952.114014
# 50                            210586667970.76001
# 51                           144767857559.243988
# 52                          -168446360029.062012
# 53                              32210273636.5275
# 54                          -274651950434.829987
# 55                             -40342220314.6493
# 56                           132433986065.335999
# 57                           268042440742.743988
# 58                             -49213900461.9487
# 59                            92911832022.275696
# 60                            86642953831.485596
# 61                            35926915439.337196
# 62                          -195681901026.153015
# 63                          -138295913886.828003
# 64                                          <NA>
#
# 0   Inflation, consumer prices (annual %)  \
# 35                               0.695458
# 36                              -0.127899
# 37                                 0.1366
# 38                               1.747805
# 39                               0.661974
# 40                              -0.341297
# 41                              -0.676579
# 42                              -0.740056
# 43                              -0.923494
# 44                              -0.256542
# 45                              -0.008573
# 46                              -0.282946
# 47                               0.249355
# 48                               0.060039
# 49                               1.380079
# 50                              -1.352837
# 51                              -0.728243
# 52                              -0.272456
# 53                              -0.044065
# 54                               0.335038
# 55                               2.759227
# 56                                0.79528
# 57                              -0.127259
# 58                                 0.4842
# 59                               0.989095
# 60                               0.468776
# 61                              -0.024996
# 62                              -0.233353
# 63                               2.497703
# 64                                   <NA>
#
# 0   Unemployment, total (% of total labor force) (national estimate)  \
# 35                                               2.89
# 36                                               3.15
# 37                                              3.383
# 38                                              3.374
# 39                                              4.078
# 40                                              4.677
# 41                                              4.748
# 42                                               5.02
# 43                                              5.386
# 44                                              5.251
# 45                                              4.734
# 46                                              4.446
# 47                                              4.192
# 48                                              3.888
# 49                                              4.002
# 50                                              5.068
# 51                                              5.103
# 52                                               4.55
# 53                                              4.358
# 54                                              4.038
# 55                                              3.589
# 56                                              3.385
# 57                                              3.132
# 58                                              2.822
# 59                                              2.467
# 60                                              2.351
# 61                                              2.809
# 62                                              2.828
# 63                                                2.6
# 64                                                2.6
#
# 0   Population growth (annual %)  \
# 35                      0.279192
# 36                       0.23459
# 37                      0.226885
# 38                      0.238271
# 39                       0.27173
# 40                      0.182586
# 41                      0.167276
# 42                      0.240953
# 43                      0.232527
# 44                      0.213981
# 45                      0.033662
# 46                      0.009392
# 47                      0.063374
# 48                      0.114909
# 49                      0.048425
# 50                     -0.012495
# 51                      0.017961
# 52                     -0.185226
# 53                     -0.159711
# 54                     -0.144272
# 55                     -0.132694
# 56                     -0.106125
# 57                     -0.051137
# 58                     -0.081874
# 59                      -0.12688
# 60                     -0.140465
# 61                     -0.294195
# 62                     -0.459952
# 63                     -0.443852
# 64                          <NA>
#
# 0   Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)
# 35                                          98.615227
# 36                                          98.615227
# 37                                          98.615227
# 38                                          98.615227
# 39                                          98.615227
# 40                                          98.615227
# 41                                          98.615227
# 42                                          98.615227
# 43                                          98.615227
# 44                                          98.615227
# 45                                          98.615227
# 46                                          98.615227
# 47                                          98.615227
# 48                                          98.615227
# 49                                          98.615227
# 50                                          98.615227
# 51                                          98.615227
# 52                                          98.615227
# 53                                          98.615227
# 54                                          98.615227
# 55                                          98.615227
# 56                                          98.615227
# 57                                          98.615227
# 58                                          98.615227
# 59                                          98.615227
# 60                                          98.615227
# 61                                          98.615227
# 62                                          98.615227
# 63                                          98.615227
# 64                                          98.615227

# %%
selected_japan_data.shape
# Out:
# (30, 8)

# %%
selected_japan_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                30.0
# GDP growth (annual %)                               29.0
# GDP (constant 2015 US$)                             29.0
# Portfolio investment, net (BoP, current US$)        27.0
# Inflation, consumer prices (annual %)               29.0
# Unemployment, total (% of total labor force) (n...  30.0
# Population growth (annual %)                        29.0
# Educational attainment, at least completed lowe...  30.0
#
#                                                                     mean  \
# 0
# Year                                                              2008.5
# GDP growth (annual %)                                           0.768193
# GDP (constant 2015 US$)                             4206741651628.540527
# Portfolio investment, net (BoP, current US$)          20775657155.808372
# Inflation, consumer prices (annual %)                           0.245518
# Unemployment, total (% of total labor force) (n...              3.830633
# Population growth (annual %)                                    0.008167
# Educational attainment, at least completed lowe...             98.615227
#
#                                                                     std  \
# 0
# Year                                                           8.803408
# GDP growth (annual %)                                          2.013445
# GDP (constant 2015 US$)                             254736846574.297546
# Portfolio investment, net (BoP, current US$)        132604468989.451614
# Inflation, consumer prices (annual %)                          0.942863
# Unemployment, total (% of total labor force) (n...             0.937034
# Population growth (annual %)                                   0.207312
# Educational attainment, at least completed lowe...                  0.0
#
#                                                                      min  \
# 0
# Year                                                              1994.0
# GDP growth (annual %)                                          -5.693236
# GDP (constant 2015 US$)                             3688589488080.589844
# Portfolio investment, net (BoP, current US$)        -274651950434.829987
# Inflation, consumer prices (annual %)                          -1.352837
# Unemployment, total (% of total labor force) (n...                 2.351
# Population growth (annual %)                                   -0.459952
# Educational attainment, at least completed lowe...             98.615227
#
#                                                                      25%  \
# 0
# Year                                                             2001.25
# GDP growth (annual %)                                           0.041962
# GDP (constant 2015 US$)                             4002148544213.450195
# Portfolio investment, net (BoP, current US$)         -44778060388.298996
# Inflation, consumer prices (annual %)                          -0.272456
# Unemployment, total (% of total labor force) (n...                2.9505
# Population growth (annual %)                                   -0.132694
# Educational attainment, at least completed lowe...             98.615227
#
#                                                                      50%  \
# 0
# Year                                                              2008.5
# GDP growth (annual %)                                           1.083383
# GDP (constant 2015 US$)                             4229100705435.470215
# Portfolio investment, net (BoP, current US$)          33820312103.573799
# Inflation, consumer prices (annual %)                          -0.008573
# Unemployment, total (% of total labor force) (n...                 3.945
# Population growth (annual %)                                    0.017961
# Educational attainment, at least completed lowe...             98.615227
#
#                                                                      75%  \
# 0
# Year                                                             2015.75
# GDP growth (annual %)                                           1.803901
# GDP (constant 2015 US$)                             4376627829637.509766
# Portfolio investment, net (BoP, current US$)          94010997427.634308
# Inflation, consumer prices (annual %)                           0.661974
# Unemployment, total (% of total labor force) (n...               4.64525
# Population growth (annual %)                                    0.213981
# Educational attainment, at least completed lowe...             98.615227
#
#                                                                      max
# 0
# Year                                                              2023.0
# GDP growth (annual %)                                           4.097918
# GDP (constant 2015 US$)                             4582763011477.349609
# Portfolio investment, net (BoP, current US$)         282689352952.114014
# Inflation, consumer prices (annual %)                           2.759227
# Unemployment, total (% of total labor force) (n...                 5.386
# Population growth (annual %)                                    0.279192
# Educational attainment, at least completed lowe...             98.615227

# %%
import seaborn as sns

# %%
columns = list(selected_japan_data.columns)
print(columns)

sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# <Axes: xlabel='GDP (constant 2015 US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_japan_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_japan_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
sns.pairplot(data = selected_japan_data, height = 2)

# %%
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_japan_data[ 'GDP growth (annual %)']
X = selected_japan_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=42)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  6.824507159070503
# mean_absolute_error :  1.6721437187170858
# The value of R^2 for the model is 8.349158123727419 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by -31.692434003097315
# The value of slope for GDP (constant 2015 US$) is given by 6.458005738932072e-12
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -3.114023284137166e-12
# The value of slope for Inflation, consumer prices (annual %) is given by 0.1250187636075628
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by 1.3051732603278063
# The value of slope for Population growth (annual %) is given by 2.9754505927829773
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 0.0
