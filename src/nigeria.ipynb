# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("nigeria")
nigeria_data = Data.read(filepath)
nigeria_data
# Out:
#      Country Name Country Code  \
# 0         Nigeria          NGA
# 1         Nigeria          NGA
# 2         Nigeria          NGA
# 3         Nigeria          NGA
# 4         Nigeria          NGA
# ...           ...          ...
# 1473      Nigeria          NGA
# 1474      Nigeria          NGA
# 1475      Nigeria          NGA
# 1476      Nigeria          NGA
# 1477      Nigeria          NGA
#
#                                          Indicator Name        Indicator Code  \
# 0     Regulatory Quality: Percentile Rank, Lower Bou...      RQ.PER.RNK.LOWER
# 1                           Rule of Law: Standard Error            RL.STD.ERR
# 2                        Rule of Law: Number of Sources             RL.NO.SRC
# 3     Political Stability and Absence of Violence/Te...      PV.PER.RNK.UPPER
# 4     Political Stability and Absence of Violence/Te...                PV.EST
# ...                                                 ...                   ...
# ...

# %%
# cleaning the data
nigeria_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
nigeria_data = Data.clean_data(nigeria_data, nigeria_columns_to_drop)
nigeria_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                           9.047619
# 61                                           8.095238
# 62                                           9.047619
# 63                                           5.188679
# 64                                               <NA>
#
# 0   Rule of Law: Standard Error  Rule of Law: Number of Sources  \
# 1                          <NA>                            <NA>
# ...

# %%
# selecting and modifying the data
nigeria_data["Year"]=nigeria_data["Year"].astype(int)
nigeria_data = nigeria_data.tail(35)
nigeria_data
interval = 5
nigeria_data=nigeria_data.iloc[::interval]
nigeria_data
# Out:
# 0   Year  \
# 30  1989
# 35  1994
# 40  1999
# 45  2004
# 50  2009
# 55  2014
# 60  2019
#
# 0   Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                           4.975124
# 50                                          15.311005
# 55                                          11.538462
# 60                                           9.047619
#
# 0   Rule of Law: Standard Error  Rule of Law: Number of Sources  \
# 30                         <NA>                            <NA>
# 35                         <NA>                            <NA>
# 40                         <NA>                            <NA>
# 45                     0.166907                              13
# 50                     0.134719                              17
# ...

# %%
# checking the number of null values in each column
nigeria_data.isna().sum()
# Out:
# 0
# Year                                                                                                                                             0
# Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval                                                                      3
# Rule of Law: Standard Error                                                                                                                      3
# Rule of Law: Number of Sources                                                                                                                   3
# Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval                                   3
#                                                                                                                                                 ..
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = nigeria_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('DEC alternative conversion factor (LCU per US$)', 0),
#  ('Oil rents (% of GDP)', 0),
#  ('GDP per capita growth (annual %)', 0),
#  ('Natural gas rents (% of GDP)', 0),
#  ('GDP growth (annual %)', 0),
#  ('GDP (current US$)', 0),
#  ('Gross value added at basic prices (GVA) (constant 2015 US$)', 0),
#  ('Inflation, GDP deflator (annual %)', 0),
#  ('Adjusted net national income (current US$)', 0),
#  ('Adjusted savings: natural resources depletion (% of GNI)', 0),
#  ('Adjusted savings: energy depletion (current US$)', 0),
#  ('Adjusted savings: consumption of fixed capital (current US$)', 0),
#  ('Services, value added (constant LCU)', 0),
#  ('Services, value added (current US$)', 0),
#  ('Industry (including construction), value added (% of GDP)', 0),
#  ('Industry (including construction), value added (current LCU)', 0),
#  ('Manufacturing, value added (annual % growth)', 0),
#  ('Net migration', 0),
# ...

# %%
# selecting the columns we want to analyse
selected_nigeria_data = nigeria_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_nigeria_data
# Out:
# /tmp/ipykernel_1917990/2460885233.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1917990/2460885233.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
selected_nigeria_data.shape
# Out:
# (7, 8)

# %%
selected_nigeria_data.describe().T
# Out:
#                                                    count                 mean  \
# 0
# Year                                                 7.0               2004.0
# GDP growth (annual %)                                7.0             3.784888
# GDP (constant 2015 US$)                              7.0  295308808837.586731
# Portfolio investment, net (BoP, current US$)         7.0     -647290094.39804
# Inflation, consumer prices (annual %)                7.0            23.013781
# Unemployment, total (% of total labor force) (n...   2.0               7.6285
# Population growth (annual %)                         7.0              2.60433
# Educational attainment, at least completed lowe...   7.0            44.635159
#
#                                                                     std  \
# 0
# Year                                                          10.801234
# GDP growth (annual %)                                          4.121008
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_nigeria_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_nigeria_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_nigeria_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_nigeria_data['GDP growth (annual %)'] = selected_nigeria_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_nigeria_data["GDP (constant 2015 US$)"] = np.log(selected_nigeria_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# /tmp/ipykernel_1917990/1060421261.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mean_value = selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
mean_value = selected_nigeria_data["Unemployment, total (% of total labor force) (national estimate)"].mean() 
selected_nigeria_data["Unemployment, total (% of total labor force) (national estimate)"].fillna(value=mean_value, inplace=True)
selected_nigeria_data[regression_columns]
selected_nigeria_data = selected_nigeria_data.tail(6)
selected_nigeria_data.reset_index(drop=True, inplace = True)
selected_nigeria_data
# Out:
# /tmp/ipykernel_1917990/657008311.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1917990/657008311.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_nigeria_data[ 'GDP growth (annual %)']
X = selected_nigeria_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=50)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  725.3298378068791
# mean_absolute_error :  26.931948273507416
# The value of R^2 for the model is 55.72208453150539 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 34.43775277734702
# The value of slope for GDP (constant 2015 US$) is given by 0.0
# The value of slope for Portfolio investment, net (BoP, current US$) is given by 0.0
# The value of slope for Inflation, consumer prices (annual %) is given by 0.0
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by 0.0
# The value of slope for Population growth (annual %) is given by 0.0
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 0.0
