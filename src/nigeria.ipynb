# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("nigeria")
nigeria_data = Data.read(filepath)
nigeria_data
# Out:
#      Country Name Country Code  \
# 0         Nigeria          NGA
# 1         Nigeria          NGA
# 2         Nigeria          NGA
# 3         Nigeria          NGA
# 4         Nigeria          NGA
# ...           ...          ...
# 1473      Nigeria          NGA
# 1474      Nigeria          NGA
# 1475      Nigeria          NGA
# 1476      Nigeria          NGA
# 1477      Nigeria          NGA
#
#                                          Indicator Name        Indicator Code  \
# 0     Regulatory Quality: Percentile Rank, Lower Bou...      RQ.PER.RNK.LOWER
# 1                           Rule of Law: Standard Error            RL.STD.ERR
# 2                        Rule of Law: Number of Sources             RL.NO.SRC
# 3     Political Stability and Absence of Violence/Te...      PV.PER.RNK.UPPER
# 4     Political Stability and Absence of Violence/Te...                PV.EST
# ...                                                 ...                   ...
# 1473  Learning poverty: Share of Male Children at th...        SE.LPV.PRIM.MA
# 1474  Learning poverty: Share of Female Children at ...        SE.LPV.PRIM.FE
# 1475  School enrollment, primary and secondary (gros...     SE.ENR.PRSC.FM.ZS
# 1476  Literacy rate, adult male (% of males ages 15 ...     SE.ADT.LITR.MA.ZS
# 1477  Literacy rate, youth (ages 15-24), gender pari...  SE.ADT.1524.LT.FM.ZS
#
#       1960  1961  1962  1963  1964  1965  ...       2015       2016  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN  ...  10.952381   9.523809
# 1      NaN   NaN   NaN   NaN   NaN   NaN  ...   0.140394   0.152783
# 2      NaN   NaN   NaN   NaN   NaN   NaN  ...  16.000000  15.000000
# 3      NaN   NaN   NaN   NaN   NaN   NaN  ...   7.619048   8.571428
# 4      NaN   NaN   NaN   NaN   NaN   NaN  ...  -1.921705  -1.873889
# ...    ...   ...   ...   ...   ...   ...  ...        ...        ...
# 1473   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN
# 1474   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN
# 1475   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN   0.930320
# 1476   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN
# 1477   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN
#
#            2017       2018       2019       2020       2021       2022  2023  \
# 0     10.476191   9.523809   9.047619   8.095238   9.047619   5.188679   NaN
# 1      0.143886   0.145680   0.147810   0.144580   0.151954   0.156281   NaN
# 2     15.000000  14.000000  14.000000  13.000000  13.000000  13.000000   NaN
# 3      8.095238   6.603774   8.018867  10.377358   9.433962   9.905661   NaN
# 4     -1.996717  -2.097414  -1.933071  -1.891961  -1.787299  -1.798141   NaN
# ...         ...        ...        ...        ...        ...        ...   ...
# 1473        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 1474        NaN        NaN        NaN        NaN        NaN        NaN   NaN
# 1475        NaN   0.969380        NaN        NaN        NaN        NaN   NaN
# 1476        NaN  71.255707        NaN        NaN        NaN        NaN   NaN
# 1477        NaN   0.836750        NaN        NaN        NaN        NaN   NaN
#
#       Unnamed: 68
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 1473          NaN
# 1474          NaN
# 1475          NaN
# 1476          NaN
# 1477          NaN
#
# [1478 rows x 69 columns]

# %%
# cleaning the data
nigeria_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
nigeria_data = Data.clean_data(nigeria_data, nigeria_columns_to_drop)
nigeria_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                           9.047619
# 61                                           8.095238
# 62                                           9.047619
# 63                                           5.188679
# 64                                               <NA>
#
# 0   Rule of Law: Standard Error  Rule of Law: Number of Sources  \
# 1                          <NA>                            <NA>
# 2                          <NA>                            <NA>
# 3                          <NA>                            <NA>
# 4                          <NA>                            <NA>
# 5                          <NA>                            <NA>
# ..                          ...                             ...
# 60                      0.14781                              14
# 61                      0.14458                              13
# 62                     0.151954                              13
# 63                     0.156281                              13
# 64                         <NA>                            <NA>
#
# 0   Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                           8.018867
# 61                                          10.377358
# 62                                           9.433962
# 63                                           9.905661
# 64                                               <NA>
#
# 0   Political Stability and Absence of Violence/Terrorism: Estimate  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          -1.933071
# 61                                          -1.891961
# 62                                          -1.787299
# 63                                          -1.798141
# 64                                               <NA>
#
# 0   Coverage of social insurance programs in 2nd quintile (% of population)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Adequacy of social insurance programs (% of total welfare of beneficiary households)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Coverage of social safety net programs in 2nd quintile (% of population)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Adequacy of social safety net programs (% of total welfare of beneficiary households)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   ...  Primary education, pupils  \
# 1   ...                       <NA>
# 2   ...                       <NA>
# 3   ...                       <NA>
# 4   ...                       <NA>
# 5   ...                       <NA>
# ..  ...                        ...
# 60  ...                   28078436
# 61  ...                   30100084
# 62  ...                   30455582
# 63  ...                       <NA>
# 64  ...                       <NA>
#
# 0   Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                           55.02425
# 61                                               <NA>
# 62                                          57.819359
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Primary school starting age (years)  \
# 1                                  <NA>
# 2                                  <NA>
# 3                                  <NA>
# 4                                  <NA>
# 5                                  <NA>
# ..                                  ...
# 60                                    6
# 61                                    6
# 62                                    6
# 63                                    6
# 64                                 <NA>
#
# 0   School enrollment, preprimary, male (% gross)  \
# 1                                            <NA>
# 2                                            <NA>
# 3                                            <NA>
# 4                                            <NA>
# 5                                            <NA>
# ..                                            ...
# 60                                           <NA>
# 61                                           <NA>
# 62                                           <NA>
# 63                                           <NA>
# 64                                           <NA>
#
# 0   Preprimary education, duration (years)  \
# 1                                     <NA>
# 2                                     <NA>
# 3                                     <NA>
# 4                                     <NA>
# 5                                     <NA>
# ..                                     ...
# 60                                       5
# 61                                       5
# 62                                       5
# 63                                       5
# 64                                    <NA>
#
# 0   Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Literacy rate, adult male (% of males ages 15 and above)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Literacy rate, youth (ages 15-24), gender parity index (GPI)
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# [64 rows x 1479 columns]

# %%
# selecting and modifying the data
nigeria_data["Year"]=nigeria_data["Year"].astype(int)
nigeria_data = nigeria_data.tail(30)
nigeria_data
# Out:
# 0   Year  \
# 35  1994
# 36  1995
# 37  1996
# 38  1997
# 39  1998
# 40  1999
# 41  2000
# 42  2001
# 43  2002
# 44  2003
# 45  2004
# 46  2005
# 47  2006
# 48  2007
# 49  2008
# 50  2009
# 51  2010
# 52  2011
# 53  2012
# 54  2013
# 55  2014
# 56  2015
# 57  2016
# 58  2017
# 59  2018
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                           5.978261
# 38                                               <NA>
# 39                                           7.608696
# 40                                               <NA>
# 41                                          10.326087
# 42                                               <NA>
# 43                                           4.864865
# 44                                           3.243243
# 45                                           4.975124
# 46                                           16.17647
# 47                                           9.803922
# 48                                          11.650485
# 49                                          16.504854
# 50                                          15.311005
# 51                                          18.181818
# 52                                          19.905212
# 53                                          17.061611
# 54                                          17.535545
# 55                                          11.538462
# 56                                          10.952381
# 57                                           9.523809
# 58                                          10.476191
# 59                                           9.523809
# 60                                           9.047619
# 61                                           8.095238
# 62                                           9.047619
# 63                                           5.188679
# 64                                               <NA>
#
# 0   Rule of Law: Standard Error  Rule of Law: Number of Sources  \
# 35                         <NA>                            <NA>
# 36                         <NA>                            <NA>
# 37                     0.212429                               6
# 38                         <NA>                            <NA>
# 39                     0.221403                               6
# 40                         <NA>                            <NA>
# 41                     0.169623                               8
# 42                         <NA>                            <NA>
# 43                     0.182166                              10
# 44                     0.184147                              11
# 45                     0.166907                              13
# 46                     0.145315                              14
# 47                     0.139509                              17
# 48                     0.140577                              17
# 49                      0.13777                              17
# 50                     0.134719                              17
# 51                     0.131937                              17
# 52                     0.126085                              18
# 53                     0.129535                              18
# 54                      0.12911                              18
# 55                     0.140561                              16
# 56                     0.140394                              16
# 57                     0.152783                              15
# 58                     0.143886                              15
# 59                      0.14568                              14
# 60                      0.14781                              14
# 61                      0.14458                              13
# 62                     0.151954                              13
# 63                     0.156281                              13
# 64                         <NA>                            <NA>
#
# 0   Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                          31.914894
# 38                                               <NA>
# 39                                           43.61702
# 40                                               <NA>
# 41                                          19.576719
# 42                                               <NA>
# 43                                          17.460318
# 44                                          15.577889
# 45                                          12.621359
# 46                                          13.592233
# 47                                           8.212561
# 48                                           7.729469
# 49                                           9.615385
# 50                                           7.582938
# 51                                           4.265403
# 52                                            5.21327
# 53                                           5.687204
# 54                                           6.161138
# 55                                           6.190476
# 56                                           7.619048
# 57                                           8.571428
# 58                                           8.095238
# 59                                           6.603774
# 60                                           8.018867
# 61                                          10.377358
# 62                                           9.433962
# 63                                           9.905661
# 64                                               <NA>
#
# 0   Political Stability and Absence of Violence/Terrorism: Estimate  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                          -1.056908
# 38                                               <NA>
# 39                                          -0.588244
# 40                                               <NA>
# 41                                          -1.455326
# 42                                               <NA>
# 43                                          -1.626329
# 44                                          -1.635588
# 45                                          -1.754416
# 46                                            -1.6665
# 47                                          -2.034078
# 48                                          -2.014056
# 49                                          -1.860712
# 50                                          -1.994554
# 51                                          -2.211123
# 52                                          -1.956455
# 53                                          -2.042074
# 54                                          -2.088478
# 55                                          -2.130276
# 56                                          -1.921705
# 57                                          -1.873889
# 58                                          -1.996717
# 59                                          -2.097414
# 60                                          -1.933071
# 61                                          -1.891961
# 62                                          -1.787299
# 63                                          -1.798141
# 64                                               <NA>
#
# 0   Coverage of social insurance programs in 2nd quintile (% of population)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                           2.276801
# 57                                               <NA>
# 58                                               <NA>
# 59                                            2.07389
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Adequacy of social insurance programs (% of total welfare of beneficiary households)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                          29.287549
# 57                                               <NA>
# 58                                               <NA>
# 59                                          27.029803
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Coverage of social safety net programs in 2nd quintile (% of population)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                           1.874932
# 52                                               <NA>
# 53                                           6.221479
# 54                                               <NA>
# 55                                               <NA>
# 56                                           4.057931
# 57                                               <NA>
# 58                                               <NA>
# 59                                          24.877177
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Adequacy of social safety net programs (% of total welfare of beneficiary households)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                            2.64931
# 52                                               <NA>
# 53                                           0.627015
# 54                                               <NA>
# 55                                               <NA>
# 56                                           2.189682
# 57                                               <NA>
# 58                                               <NA>
# 59                                           2.332819
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   ...  Primary education, pupils  \
# 35  ...                   16190947
# 36  ...                   15741078
# 37  ...                   14078473
# 38  ...                       <NA>
# 39  ...                       <NA>
# 40  ...                   17907008
# 41  ...                   19151442
# 42  ...                   19041224
# 43  ...                   19806082
# 44  ...                   20600796
# 45  ...                   21395510
# 46  ...                   22115432
# 47  ...                   22861884
# 48  ...                   21513996
# 49  ...                   20008142
# 50  ...                   20957642
# 51  ...                   21558460
# 52  ...                   23668904
# 53  ...                   24822374
# 54  ...                   26167544
# 55  ...                   25801196
# 56  ...                   25442536
# 57  ...                   25591180
# 58  ...                   24543722
# 59  ...                   27889388
# 60  ...                   28078436
# 61  ...                   30100084
# 62  ...                   30455582
# 63  ...                       <NA>
# 64  ...                       <NA>
#
# 0   Educational attainment, at least completed primary, population 25+ years, female (%) (cumulative)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                          52.830818
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                          52.887161
# 58                                               <NA>
# 59                                          54.019161
# 60                                           55.02425
# 61                                               <NA>
# 62                                          57.819359
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Primary school starting age (years)  \
# 35                                    6
# 36                                    6
# 37                                    6
# 38                                    6
# 39                                    6
# 40                                    6
# 41                                    6
# 42                                    6
# 43                                    6
# 44                                    6
# 45                                    6
# 46                                    6
# 47                                    6
# 48                                    6
# 49                                    6
# 50                                    6
# 51                                    6
# 52                                    6
# 53                                    6
# 54                                    6
# 55                                    6
# 56                                    6
# 57                                    6
# 58                                    6
# 59                                    6
# 60                                    6
# 61                                    6
# 62                                    6
# 63                                    6
# 64                                 <NA>
#
# 0   School enrollment, preprimary, male (% gross)  \
# 35                                           <NA>
# 36                                           <NA>
# 37                                           <NA>
# 38                                           <NA>
# 39                                           <NA>
# 40                                           <NA>
# 41                                           <NA>
# 42                                      26.306141
# 43                                           <NA>
# 44                                      36.814671
# 45                                      44.592312
# 46                                      44.161411
# 47                                           <NA>
# 48                                           <NA>
# 49                                      37.483349
# 50                                      44.038101
# 51                                      42.164089
# 52                                      42.889999
# 53                                           <NA>
# 54                                           <NA>
# 55                                       15.26255
# 56                                       23.81399
# 57                                       15.69863
# 58                                      19.453529
# 59                                       24.38101
# 60                                           <NA>
# 61                                           <NA>
# 62                                           <NA>
# 63                                           <NA>
# 64                                           <NA>
#
# 0   Preprimary education, duration (years)  \
# 35                                    <NA>
# 36                                    <NA>
# 37                                    <NA>
# 38                                    <NA>
# 39                                    <NA>
# 40                                       5
# 41                                       5
# 42                                       5
# 43                                       5
# 44                                       5
# 45                                       5
# 46                                       5
# 47                                       5
# 48                                       5
# 49                                       5
# 50                                       5
# 51                                       5
# 52                                       5
# 53                                       5
# 54                                       5
# 55                                       5
# 56                                       5
# 57                                       5
# 58                                       5
# 59                                       5
# 60                                       5
# 61                                       5
# 62                                       5
# 63                                       5
# 64                                    <NA>
#
# 0   Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                            0.82335
# 41                                            0.81514
# 42                                            0.82727
# 43                                            0.81157
# 44                                               <NA>
# 45                                            0.82804
# 46                                            0.83964
# 47                                            0.84907
# 48                                            0.85558
# 49                                            0.87303
# 50                                            0.88796
# 51                                            0.89722
# 52                                            0.90817
# 53                                             0.9544
# 54                                            0.95258
# 55                                            0.95682
# 56                                               <NA>
# 57                                            0.93032
# 58                                               <NA>
# 59                                            0.96938
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Literacy rate, adult male (% of males ages 15 and above)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                          66.767433
# 45                                               <NA>
# 46                                               <NA>
# 47                                          76.131866
# 48                                               <NA>
# 49                                          61.254051
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                          71.255707
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Literacy rate, youth (ages 15-24), gender parity index (GPI)
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                            0.77449
# 45                                               <NA>
# 46                                               <NA>
# 47                                            0.89631
# 48                                               <NA>
# 49                                            0.76693
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                           0.821051
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                            0.83675
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# [30 rows x 1479 columns]

# %%
# checking the number of null values in each column
nigeria_data.isna().sum()
# Out:
# 0
# Year                                                                                                                                              0
# Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval                                                                       6
# Rule of Law: Standard Error                                                                                                                       6
# Rule of Law: Number of Sources                                                                                                                    6
# Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval                                    6
#                                                                                                                                                  ..
# Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)      30
# Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)    30
# School enrollment, primary and secondary (gross), gender parity index (GPI)                                                                      13
# Literacy rate, adult male (% of males ages 15 and above)                                                                                         26
# Literacy rate, youth (ages 15-24), gender parity index (GPI)                                                                                     25
# Length: 1479, dtype: int64

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = nigeria_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Net migration', 0),
#  ('Unemployment, total (% of total labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, female (% of female labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force, total', 0),
#  ('Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, male (%) (modeled ILO estimate)', 0),
#  ('Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Labor force, female (% of total labor force)', 0),
#  ('Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Population in the largest city (% of urban population)', 0),
#  ('Population in urban agglomerations of more than 1 million (% of total population)',
#   0),
#  ('Population in urban agglomerations of more than 1 million', 0),
#  ('Unemployment, male (% of male labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, total (%) (modeled ILO estimate)', 0),
#  ('Employment to population ratio, 15+, female (%) (modeled ILO estimate)', 0),
#  ('Women Business and the Law Index Score (scale 1-100)', 0),
#  ('Population in largest city', 0),
#  ('PPP conversion factor, private consumption (LCU per international $)', 1),
#  ('DEC alternative conversion factor (LCU per US$)', 1),
#  ('GDP per capita growth (annual %)', 1),
#  ('GDP growth (annual %)', 1),
#  ('GDP (current US$)', 1),
#  ('Gross value added at basic prices (GVA) (constant 2015 US$)', 1),
#  ('Inflation, GDP deflator (annual %)', 1),
#  ('Services, value added (constant LCU)', 1),
#  ('Services, value added (current US$)', 1),
#  ('Industry (including construction), value added (% of GDP)', 1),
#  ('Industry (including construction), value added (current LCU)', 1),
#  ('Manufacturing, value added (annual % growth)', 1),
#  ('Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employers, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Official exchange rate (LCU per US$, period average)', 1),
#  ('Taxes less subsidies on products (current US$)', 1),
#  ('GDP per capita (constant LCU)', 1),
#  ('GDP per capita (current US$)', 1),
#  ('GDP (constant LCU)', 1),
#  ('GDP (current LCU)', 1),
#  ('Gross value added at basic prices (GVA) (constant LCU)', 1),
#  ('Inflation, GDP deflator: linked series (annual %)', 1),
#  ('Services, value added (% of GDP)', 1),
#  ('Services, value added (current LCU)', 1),
#  ('Industry (including construction), value added (constant 2015 US$)', 1),
#  ('Manufacturing, value added (constant LCU)', 1),
#  ('Manufacturing, value added (current US$)', 1),
#  ('Agriculture, forestry, and fishing, value added (% of GDP)', 1),
#  ('Agriculture, forestry, and fishing, value added (current LCU)', 1),
#  ('Immunization, DPT (% of children ages 12-23 months)', 1),
#  ('Secondary education, duration (years)', 1),
#  ('Primary education, duration (years)', 1),
#  ('Military expenditure (% of GDP)', 1),
#  ('Fixed telephone subscriptions (per 100 people)', 1),
#  ('Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Real effective exchange rate index (2010 = 100)', 1),
#  ('PPP conversion factor, GDP (LCU per international $)', 1),
#  ('Taxes less subsidies on products (current LCU)', 1),
#  ('GDP per capita, PPP (current international $)', 1),
#  ('GDP per capita (current LCU)', 1),
#  ('GDP, PPP (current international $)', 1),
#  ('GDP: linked series (current LCU)', 1),
#  ('Gross value added at basic prices (GVA) (current US$)', 1),
#  ('GDP deflator (base year varies by country)', 1),
#  ('Services, value added (constant 2015 US$)', 1),
#  ('Industry (including construction), value added (annual % growth)', 1),
#  ('Manufacturing, value added (% of GDP)', 1),
#  ('Manufacturing, value added (current LCU)', 1),
#  ('Agriculture, forestry, and fishing, value added (constant 2015 US$)', 1),
#  ('Price level ratio of PPP conversion factor (GDP) to market exchange rate',
#   1),
#  ('Taxes less subsidies on products (constant LCU)', 1),
#  ('GDP per capita, PPP (constant 2017 international $)', 1),
#  ('GDP per capita (constant 2015 US$)', 1),
#  ('GDP, PPP (constant 2017 international $)', 1),
#  ('GDP (constant 2015 US$)', 1),
#  ('Gross value added at basic prices (GVA) (current LCU)', 1),
#  ('GDP deflator: linked series (base year varies by country)', 1),
#  ('Services, value added (annual % growth)', 1),
#  ('Industry (including construction), value added (constant LCU)', 1),
#  ('Industry (including construction), value added (current US$)', 1),
#  ('Manufacturing, value added (constant 2015 US$)', 1),
#  ('External debt stocks, short-term (DOD, current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, United States (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Norway (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Japan (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Belgium (current US$)', 1),
#  ('Personal remittances, received (% of GDP)', 1),
#  ('Transport services (% of service exports, BoP)', 1),
#  ('Goods exports (BoP, current US$)', 1),
#  ('Communications, computer, etc. (% of service exports, BoP)', 1),
#  ('Grants, excluding technical cooperation (BoP, current US$)', 1),
#  ('Portfolio investment, net (BoP, current US$)', 1),
#  ('Net trade in goods and services (BoP, current US$)', 1),
#  ('Current account balance (BoP, current US$)', 1),
#  ('Foreign direct investment, net outflows (BoP, current US$)', 1),
#  ('Imports of goods and services (BoP, current US$)', 1),
#  ('Cereal yield (kg per hectare)', 1),
#  ('Crop production index (2014-2016 = 100)', 1),
#  ('GDP per person employed (constant 2017 PPP $)', 1),
#  ('Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Employers, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Net ODA received per capita (current US$)', 1),
#  ('Net official development assistance and official aid received (constant 2021 US$)',
#   1),
#  ('Net official flows from UN agencies, UNDP (current US$)', 1),
#  ('Net financial flows, RDB nonconcessional (NFL, current US$)', 1),
#  ('PNG, commercial banks and other creditors (NFL, current US$)', 1),
#  ('Net financial flows, multilateral (NFL, current US$)', 1),
#  ('PPG, IDA (DOD, current US$)', 1),
#  ('Short-term debt (% of total reserves)', 1),
#  ('External debt stocks, long-term (DOD, current US$)', 1),
#  ('Agriculture, forestry, and fishing, value added (annual % growth)', 1),
#  ('Military expenditure (current USD)', 1),
#  ('Mobile cellular subscriptions (per 100 people)', 1),
#  ('Real interest rate (%)', 1),
#  ('Broad money to total reserves ratio', 1),
#  ('Monetary Sector credit to private sector (% GDP)', 1),
#  ('Claims on central government (annual growth as % of broad money)', 1),
#  ('Total reserves (includes gold, current US$)', 1),
#  ('Public and publicly guaranteed debt service (% of exports of goods, services and primary income)',
#   1),
#  ('Agriculture, forestry, and fishing, value added (constant LCU)', 1),
#  ('Agriculture, forestry, and fishing, value added (current US$)', 1),
#  ('Military expenditure (current LCU)', 1),
#  ('Fixed telephone subscriptions', 1),
#  ('Multilateral debt service (TDS, current US$)', 1),
#  ('Debt service (PPG and IMF only, % of exports of goods, services and primary income)',
#   1),
#  ('Debt service on external debt, total (TDS, current US$)', 1),
#  ('Net official development assistance received (constant 2021 US$)', 1),
#  ('Net official flows from UN agencies, UNICEF (current US$)', 1),
#  ('IFC, private nonguaranteed (NFL, US$)', 1),
#  ('Net official flows from UN agencies, IFAD (current US$)', 1),
#  ('Short-term debt (% of total external debt)', 1),
#  ('External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)',
#   1),
#  ('Claims on central government, etc. (% GDP)', 1),
#  ('Lending interest rate (%)', 1),
#  ('Consumer price index (2010 = 100)', 1),
#  ('Broad money (current LCU)', 1),
#  ('Net domestic credit (current LCU)', 1),
#  ('Total reserves in months of imports', 1),
#  ('Domestic credit to private sector by banks (% of GDP)', 1),
#  ('Net financial flows, others (NFL, current US$)', 1),
#  ('IBRD loans and IDA credits (DOD, current US$)', 1),
#  ('Short-term debt (% of exports of goods, services and primary income)', 1),
#  ('External debt stocks, private nonguaranteed (PNG) (DOD, current US$)', 1),
#  ('External debt stocks, total (DOD, current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Sweden (current US$)', 1),
#  ('Military expenditure (% of general government expenditure)', 1),
#  ('Mobile cellular subscriptions', 1),
#  ('Travel services (% of commercial service exports)', 1),
#  ('Commercial service exports (current US$)', 1),
#  ('Urban population growth (annual %)', 1),
#  ('Population, female (% of total population)', 1),
#  ('Age dependency ratio (% of working-age population)', 1),
#  ('Population ages 75-79, male (% of male population)', 1),
#  ('Population ages 65 and above (% of total population)', 1),
#  ('Population ages 65 and above, female (% of female population)', 1),
#  ('Population ages 60-64, male (% of male population)', 1),
#  ('Population ages 50-54, male (% of male population)', 1),
#  ('Population ages 40-44, male (% of male population)', 1),
#  ('Population ages 30-34, male (% of male population)', 1),
#  ('Population ages 20-24, male (% of male population)', 1),
#  ('Population ages 15-64, male (% of male population)', 1),
#  ('Population ages 15-19, male (% of male population)', 1),
#  ('Population ages 05-09, male (% of male population)', 1),
#  ('Population ages 0-14, male (% of male population)', 1),
#  ('Population ages 00-04, male (% of male population)', 1),
#  ('Transport services (% of commercial service exports)', 1),
#  ('Computer, communications and other services (% of commercial service exports)',
#   1),
#  ('Commercial service imports (current US$)', 1),
#  ('Rural population (% of total population)', 1),
#  ('Population, female', 1),
#  ('Population growth (annual %)', 1),
#  ('Population ages 75-79, female (% of female population)', 1),
#  ('Population ages 65 and above, total', 1),
#  ('Population ages 65 and above, female', 1),
#  ('Population ages 60-64, female (% of female population)', 1),
#  ('Population ages 50-54, female (% of female population)', 1),
#  ('Population ages 40-44, female (% of female population)', 1),
#  ('Population ages 30-34, female (% of female population)', 1),
#  ('Population ages 20-24, female (% of female population)', 1),
#  ('Population ages 15-64, male', 1),
#  ('Population ages 15-19, female (% of female population)', 1),
#  ('Population ages 05-09, female (% of female population)', 1),
#  ('Population ages 0-14, male', 1),
#  ('Population ages 00-04, female (% of female population)', 1),
#  ('Domestic credit to private sector (% of GDP)', 1),
#  ('Risk premium on lending (lending rate minus treasury bill rate, %)', 1),
#  ('Deposit interest rate (%)', 1),
#  ('Broad money growth (annual %)', 1),
#  ('Claims on private sector (annual growth as % of broad money)', 1),
#  ('Total reserves (% of total external debt)', 1),
#  ('Net bilateral aid flows from DAC donors, Total (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Netherlands (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Italy (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Spain (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Switzerland (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Austria (current US$)', 1),
#  ('Personal remittances, received (current US$)', 1),
#  ('Foreign direct investment, net inflows (% of GDP)', 1),
#  ('Exports of goods, services and primary income (BoP, current US$)', 1),
#  ('Insurance and financial services (% of service exports, BoP)', 1),
#  ('Foreign direct investment, net (BoP, current US$)', 1),
#  ('Net primary income (BoP, current US$)', 1),
#  ('Personal remittances, paid (current US$)', 1),
#  ('Service imports (BoP, current US$)', 1),
#  ('Primary income payments (BoP, current US$)', 1),
#  ('Cereal production (metric tons)', 1),
#  ('Merchandise exports (current US$)', 1),
#  ('Insurance and financial services (% of commercial service exports)', 1),
#  ('Merchandise trade (% of GDP)', 1),
#  ('Urban population (% of total population)', 1),
#  ('Rural population growth (annual %)', 1),
#  ('Population, male (% of total population)', 1),
#  ('Population, total', 1),
#  ('Age dependency ratio, young (% of working-age population)', 1),
#  ('Population ages 80 and above, male (% of male population)', 1),
#  ('Population ages 70-74, male (% of male population)', 1),
#  ('Population ages 65 and above, male (% of male population)', 1),
#  ('Population ages 65-69, male (% of male population)', 1),
#  ('Population ages 55-59, male (% of male population)', 1),
#  ('Population ages 45-49, male (% of male population)', 1),
#  ('Population ages 35-39, male (% of male population)', 1),
#  ('Population ages 25-29, male (% of male population)', 1),
#  ('Population ages 15-64 (% of total population)', 1),
#  ('Population ages 15-64, female (% of female population)', 1),
#  ('Population ages 10-14, male (% of male population)', 1),
#  ('Population ages 0-14 (% of total population)', 1),
#  ('Population ages 0-14, female (% of female population)', 1),
#  ('Refugee population by country or territory of origin', 1),
#  ('Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services (% of total employment) (modeled ILO estimate)', 1),
#  ('Employment in industry (% of total employment) (modeled ILO estimate)', 1),
#  ('Contributing family workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employers, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Newborns protected against tetanus (%)', 1),
#  ('Net bilateral aid flows from DAC donors, United Kingdom (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, European Union institutions (current US$)',
#   1),
#  ('Personal transfers, receipts (BoP, current US$)', 1),
#  ('Foreign direct investment, net inflows (BoP, current US$)', 1),
#  ('Exports of goods and services (BoP, current US$)', 1),
#  ('Net secondary income (BoP, current US$)', 1),
#  ('Net errors and omissions (BoP, current US$)', 1),
#  ('Net financial account (BoP, current US$)', 1),
#  ('Secondary income, other sectors, payments (BoP, current US$)', 1),
#  ('Goods imports (BoP, current US$)', 1),
#  ('Livestock production index (2014-2016 = 100)', 1),
#  ('Lower secondary school starting age (years)', 1),
#  ('Interest rate spread (lending rate minus deposit rate, %)', 1),
#  ('Inflation, consumer prices (annual %)', 1),
#  ('Broad money (% of GDP)', 1),
#  ('Net foreign assets (current LCU)', 1),
#  ('Total reserves minus gold (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Ireland (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, France (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Germany (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Canada (current US$)', 1),
#  ('Secondary income receipts (BoP, current US$)', 1),
#  ('Travel services (% of service exports, BoP)', 1),
#  ('Service exports (BoP, current US$)', 1),
#  ('Primary income receipts (BoP, current US$)', 1),
#  ('Technical cooperation grants (BoP, current US$)', 1),
#  ('Reserves and related items (BoP, current US$)', 1),
#  ('Net trade in goods (BoP, current US$)', 1),
#  ('Current account balance (% of GDP)', 1),
#  ('Foreign direct investment, net outflows (% of GDP)', 1),
#  ('Imports of goods, services and primary income (BoP, current US$)', 1),
#  ('Trade in services (% of GDP)', 1),
#  ('Food production index (2014-2016 = 100)', 1),
#  ('Merchandise imports (current US$)', 1),
#  ('Urban population', 1),
#  ('Rural population', 1),
#  ('Population, male', 1),
#  ('Age dependency ratio, old (% of working-age population)', 1),
#  ('Population ages 80 and above, female (% of female population)', 1),
#  ('Population ages 70-74, female (% of female population)', 1),
#  ('Population ages 65 and above, male', 1),
#  ('Population ages 65-69, female (% of female population)', 1),
#  ('Population ages 55-59, female (% of female population)', 1),
#  ('Population ages 45-49, female (% of female population)', 1),
#  ('Population ages 35-39, female (% of female population)', 1),
#  ('Population ages 25-29, female (% of female population)', 1),
#  ('Population ages 15-64, total', 1),
#  ('Population ages 15-64, female', 1),
#  ('Population ages 10-14, female (% of female population)', 1),
#  ('Population ages 0-14, total', 1),
#  ('Population ages 0-14, female', 1),
#  ('Refugee population by country or territory of asylum', 1),
#  ('Multilateral debt service (% of public and publicly guaranteed debt service)',
#   1),
#  ('Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)',
#   1),
#  ('Total debt service (% of exports of goods, services and primary income)',
#   1),
#  ('Net ODA received (% of imports of goods, services and primary income)', 1),
#  ('Net official development assistance received (current US$)', 1),
#  ('Net official development assistance and official aid received (current US$)',
#   1),
#  ('Net official flows from UN agencies, UNFPA (current US$)', 1),
#  ('Net financial flows, RDB concessional (NFL, current US$)', 1),
#  ('PPG, official creditors (NFL, US$)', 1),
#  ('Net financial flows, IDA (NFL, current US$)', 1),
#  ('Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)',
#   1),
#  ('Land under cereal production (hectares)', 1),
#  ('Immunization, measles (% of children ages 12-23 months)', 1),
#  ('Primary school starting age (years)', 1),
#  ('Oil rents (% of GDP)', 2),
#  ('Natural gas rents (% of GDP)', 2),
#  ('Adjusted net savings, excluding particulate emission damage (current US$)',
#   2),
#  ('Adjusted net national income (current US$)', 2),
#  ('Adjusted savings: natural resources depletion (% of GNI)', 2),
#  ('Adjusted savings: energy depletion (current US$)', 2),
#  ('Adjusted savings: consumption of fixed capital (current US$)', 2),
#  ('Adjusted savings: carbon dioxide damage (current US$)', 2),
#  ('Total natural resources rents (% of GDP)', 2),
#  ('Adjusted net savings, excluding particulate emission damage (% of GNI)', 2),
#  ('Adjusted savings: gross savings (% of GNI)', 2),
#  ('Adjusted savings: energy depletion (% of GNI)', 2),
#  ('Adjusted savings: consumption of fixed capital (% of GNI)', 2),
#  ('Adjusted savings: carbon dioxide damage (% of GNI)', 2),
#  ('Medium and high-tech manufacturing value added (% manufacturing value added)',
#   2),
#  ('Incidence of HIV, ages 15-24 (per 1,000 uninfected population ages 15-24)',
#   2),
#  ('Children (ages 0-14) newly infected with HIV', 2),
#  ('Prevalence of HIV, female (% ages 15-24)', 2),
#  ('Prevalence of HIV, total (% of population ages 15-49)', 2),
#  ('Probability of dying among adolescents ages 10-14 years (per 1,000)', 2),
#  ('Number of under-five deaths', 2),
#  ('Number of deaths ages 20-24 years', 2),
#  ('Forest rents (% of GDP)', 2),
#  ('Adjusted net savings, including particulate emission damage (current US$)',
#   2),
#  ('Adjusted savings: net national savings (current US$)', 2),
#  ('Adjusted savings: particulate emission damage (current US$)', 2),
#  ('Adjusted savings: mineral depletion (current US$)', 2),
#  ('Adjusted savings: net forest depletion (current US$)', 2),
#  ('Adjusted savings: education expenditure (current US$)', 2),
#  ('Mineral rents (% of GDP)', 2),
#  ('Coal rents (% of GDP)', 2),
#  ('Adjusted net savings, including particulate emission damage (% of GNI)', 2),
#  ('Adjusted net national income per capita (current US$)', 2),
#  ('Adjusted savings: net national savings (% of GNI)', 2),
#  ('Adjusted savings: particulate emission damage (% of GNI)', 2),
#  ('Adjusted savings: mineral depletion (% of GNI)', 2),
#  ('Adjusted savings: net forest depletion (% of GNI)', 2),
#  ('Adjusted savings: education expenditure (% of GNI)', 2),
#  ('Access to electricity, rural (% of rural population)', 2),
#  ('Air transport, freight (million ton-km)', 2),
#  ('Access to electricity, urban (% of urban population)', 2),
#  ('Air transport, passengers carried', 2),
#  ('Access to electricity (% of population)', 2),
#  ('Capture fisheries production (metric tons)', 2),
#  ('Population density (people per sq. km of land area)', 2),
#  ('Individuals using the Internet (% of population)', 2),
#  ('Air transport, registered carrier departures worldwide', 2),
#  ('Export volume index (2015 = 100)', 2),
#  ('Transport services (% of commercial service imports)', 2),
#  ('Import unit value index (2015 = 100)', 2),
#  ('Survival to age 65, female (% of cohort)', 2),
#  ('Life expectancy at birth, female (years)', 2),
#  ('Mortality rate, adult, male (per 1,000 male adults)', 2),
#  ('Incidence of HIV, all (per 1,000 uninfected population)', 2),
#  ('Mortality rate, under-5, female (per 1,000 live births)', 2),
#  ('Probability of dying among youth ages 20-24 years (per 1,000)', 2),
#  ('Number of neonatal deaths', 2),
#  ('Number of infant deaths', 2),
#  ('Number of deaths ages 10-14 years', 2),
#  ('Medium and high-tech exports (% manufactured exports)', 2),
#  ('Import volume index (2015 = 100)', 2),
#  ('Sex ratio at birth (male births per female births)', 2),
#  ('Fertility rate, total (births per woman)', 2),
#  ('Mortality rate, infant, male (per 1,000 live births)', 2),
#  ('Mortality rate, adult, female (per 1,000 female adults)', 2),
#  ('Aquaculture production (metric tons)', 2),
#  ('Travel services (% of service imports, BoP)', 2),
#  ('Surface area (sq. km)', 2),
#  ('Land area (sq. km)', 2),
#  ('Forest area (sq. km)', 2),
#  ('Arable land (% of land area)', 2),
#  ('Agricultural land (sq. km)', 2),
#  ('Export value index (2015 = 100)', 2),
#  ('Net barter terms of trade index (2015 = 100)', 2),
#  ('Computer, communications and other services (% of commercial service imports)',
#   2),
#  ('Life expectancy at birth, male (years)', 2),
#  ('Mortality rate, infant (per 1,000 live births)', 2),
#  ('Death rate, crude (per 1,000 people)', 2),
#  ('Adolescent fertility rate (births per 1,000 women ages 15-19)', 2),
#  ('Net bilateral aid flows from DAC donors, Denmark (current US$)', 2),
#  ('Transport services (% of service imports, BoP)', 2),
#  ('Communications, computer, etc. (% of service imports, BoP)', 2),
#  ('Arable land (hectares per person)', 2),
#  ('Fertilizer consumption (kilograms per hectare of arable land)', 2),
#  ('Young people (ages 15-24) newly infected with HIV', 2),
#  ('Adults (ages 15-49) newly infected with HIV', 2),
#  ('Children (0-14) living with HIV', 2),
#  ('Mortality rate, neonatal (per 1,000 live births)', 2),
#  ('Mortality rate, under-5, male (per 1,000 live births)', 2),
#  ("Women's share of population ages 15+ living with HIV (%)", 2),
#  ('Probability of dying among children ages 5-9 years (per 1,000)', 2),
#  ('Number of deaths ages 15-19 years', 2),
#  ('Total fisheries production (metric tons)', 2),
#  ('Permanent cropland (% of land area)', 2),
#  ('Arable land (hectares)', 2),
#  ('Export unit value index (2015 = 100)', 2),
#  ('Travel services (% of commercial service imports)', 2),
#  ('Import value index (2015 = 100)', 2),
#  ('Survival to age 65, male (% of cohort)', 2),
#  ('Life expectancy at birth, total (years)', 2),
#  ('Mortality rate, infant, female (per 1,000 live births)', 2),
#  ('Birth rate, crude (per 1,000 people)', 2),
#  ('Forest area (% of land area)', 2),
#  ('Agricultural land (% of land area)', 2),
#  ('Incidence of HIV, ages 15-49 (per 1,000 uninfected population ages 15-49)',
#   2),
#  ('Adults (ages 15+) and children (ages 0-14) newly infected with HIV', 2),
#  ('Prevalence of HIV, male (% ages 15-24)', 2),
#  ('Mortality rate, under-5 (per 1,000 live births)', 2),
#  ('Probability of dying among adolescents ages 15-19 years (per 1,000)', 2),
#  ('Number of deaths ages 5-9 years', 2),
#  ('Armed forces personnel, total', 3),
#  ('PPG, IBRD (DOD, current US$)', 3),
#  ('Renewable internal freshwater resources per capita (cubic meters)', 3),
#  ('Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
#   3),
#  ('Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)',
#   3),
#  ('Total greenhouse gas emissions (kt of CO2 equivalent)', 3),
#  ('Renewable energy consumption (% of total final energy consumption)', 3),
#  ('PPG, private creditors (NFL, US$)', 3),
#  ('Net financial flows, IBRD (NFL, current US$)', 3),
#  ('Annual freshwater withdrawals, total (% of internal resources)', 3),
#  ('Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
#   3),
#  ('CO2 emissions (kg per PPP $ of GDP)', 3),
#  ('CO2 emissions (kt)', 3),
#  ('Armed forces personnel (% of total labor force)', 3),
#  ('Merchandise exports by the reporting economy (current US$)', 3),
#  ('Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies within region (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from economies in the Arab World (% of total merchandise imports)',
#   3),
#  ('Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to high-income economies (% of total merchandise exports)',
#   3),
#  ('Merchandise imports by the reporting economy (current US$)', 3),
#  ('Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#   3),
#  ('Annual freshwater withdrawals, total (billion cubic meters)', 3),
#  ('Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
#   3),
#  ('Nitrous oxide emissions (thousand metric tons of CO2 equivalent)', 3),
#  ('Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (metric tons per capita)', 3),
#  ('CO2 emissions (kg per 2015 US$ of GDP)', 3),
#  ('Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#   3),
#  ('Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from high-income economies (% of total merchandise imports)',
#   3),
#  ('Net bilateral aid flows from DAC donors, Australia (current US$)', 3),
#  ('Average precipitation in depth (mm per year)', 3),
#  ('Renewable internal freshwater resources, total (billion cubic meters)', 3),
#  ('Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
#   3),
#  ('Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions (kt of CO2 equivalent)', 3),
#  ('Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (kg per 2017 PPP $ of GDP)', 3),
#  ('Insurance and financial services (% of service imports, BoP)', 3),
#  ('Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   3),
#  ('Insurance and financial services (% of commercial service imports)', 3),
#  ('Industry (including construction), value added per worker (constant 2015 US$)',
#   4),
#  ('School enrollment, primary (% gross)', 4),
#  ('Services, value added per worker (constant 2015 US$)', 4),
#  ('Net bilateral aid flows from DAC donors, Finland (current US$)', 4),
#  ('Stocks traded, total value (% of GDP)', 4),
#  ('Market capitalization of listed domestic companies (current US$)', 4),
#  ('Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)',
#   4),
#  ('Arms imports (SIPRI trend indicator values)', 4),
#  ('Net financial flows, bilateral (NFL, current US$)', 4),
#  ('International tourism, receipts for passenger transport items (current US$)',
#   4),
#  ('School enrollment, primary, male (% gross)', 4),
#  ('International tourism, receipts (% of total exports)', 4),
#  ('Stocks traded, total value (current US$)', 4),
#  ('International tourism, receipts for travel items (current US$)', 4),
#  ('International tourism, receipts (current US$)', 4),
#  ('Market capitalization of listed domestic companies (% of GDP)', 4),
#  ('School enrollment, primary, female (% gross)', 4),
#  ('Primary education, pupils', 4),
#  ('Scientific and technical journal articles', 5),
#  ('Ores and metals exports (% of merchandise exports)', 5),
#  ('Fuel exports (% of merchandise exports)', 5),
#  ('International tourism, expenditures (current US$)', 5),
#  ('Manufactures exports (% of merchandise exports)', 5),
#  ('Food exports (% of merchandise exports)', 5),
#  ('Ores and metals imports (% of merchandise imports)', 5),
#  ('Fuel imports (% of merchandise imports)', 5),
#  ('International tourism, expenditures for travel items (current US$)', 5),
#  ('Agricultural raw materials exports (% of merchandise exports)', 5),
#  ('Manufactures imports (% of merchandise imports)', 5),
#  ('Food imports (% of merchandise imports)', 5),
#  ('Listed domestic companies, total', 5),
#  ('Agricultural raw materials imports (% of merchandise imports)', 5),
#  ('International tourism, expenditures (% of total imports)', 5),
#  ('International tourism, expenditures for passenger transport items (current US$)',
#   5),
#  ('Net official flows from UN agencies, UNHCR (current US$)', 5),
#  ('Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Rule of Law: Standard Error', 6),
#  ('Rule of Law: Number of Sources', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Political Stability and Absence of Violence/Terrorism: Estimate', 6),
#  ('Rule of Law: Percentile Rank', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Standard Error', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Number of Sources',
#   6),
#  ('School enrollment, primary (gross), gender parity index (GPI)', 6),
#  ('Regulatory Quality: Standard Error', 6),
#  ('Regulatory Quality: Number of Sources', 6),
#  ('Rule of Law: Percentile Rank, Lower Bound of 90% Confidence Interval', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank', 6),
#  ('Regulatory Quality: Percentile Rank', 6),
#  ('Rule of Law: Percentile Rank, Upper Bound of 90% Confidence Interval', 6),
#  ('Rule of Law: Estimate', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Use of IMF credit (DOD, current US$)', 6),
#  ('Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Government Effectiveness: Standard Error', 6),
#  ('Government Effectiveness: Number of Sources', 6),
#  ('IMF repurchases and charges (TDS, current US$)', 6),
#  ('Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Estimate', 6),
#  ('Voice and Accountability: Percentile Rank', 6),
#  ('Government Effectiveness: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Government Effectiveness: Estimate', 6),
#  ('S&P Global Equity Indices (annual % change)', 6),
#  ('Control of Corruption: Percentile Rank', 6),
#  ('Voice and Accountability: Standard Error', 6),
#  ('Voice and Accountability: Number of Sources', 6),
#  ('Control of Corruption: Standard Error', 6),
#  ('Control of Corruption: Number of Sources', 6),
#  ('Government Effectiveness: Percentile Rank', 6),
#  ('Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Control of Corruption: Estimate', 6),
#  ('Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Voice and Accountability: Estimate', 6),
#  ('Preprimary education, duration (years)', 6),
#  ('Tuberculosis case detection rate (%, all forms)', 7),
#  ('Prevalence of overweight (modeled estimate, % of children under 5)', 7),
#  ('People using safely managed drinking water services, rural (% of rural population)',
#   7),
#  ('Incidence of tuberculosis (per 100,000 people)', 7),
#  ('People using safely managed sanitation services, rural (% of rural population)',
#   7),
#  ('People practicing open defecation, rural (% of rural population)', 7),
#  ('CO2 emissions from solid fuel consumption (kt)', 7),
#  ('CO2 emissions from liquid fuel consumption (% of total)', 7),
#  ('CO2 emissions from gaseous fuel consumption (% of total)', 7),
#  ('Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#   7),
#  ('People using at least basic sanitation services, urban (% of urban population)',
#   7),
#  ('People using safely managed drinking water services (% of population)', 7),
#  ('People using at least basic drinking water services, urban (% of urban population)',
#   7),
#  ('Proportion of seats held by women in national parliaments (%)', 7),
#  ('CO2 emissions from solid fuel consumption (% of total)', 7),
#  ('Prevalence of stunting, height for age (modeled estimate, % of children under 5)',
#   7),
#  ('People using safely managed sanitation services, urban (% of urban population)',
#   7),
#  ('People practicing open defecation, urban (% of urban population)', 7),
#  ('People using safely managed sanitation services (% of population)', 7),
#  ('People practicing open defecation (% of population)', 7),
#  ('People using at least basic sanitation services (% of population)', 7),
#  ('People using at least basic drinking water services (% of population)', 7),
#  ('CO2 emissions from liquid fuel consumption (kt)', 7),
#  ('CO2 emissions from gaseous fuel consumption (kt)', 7),
#  ('Stocks traded, turnover ratio of domestic shares (%)', 7),
#  ('Vitamin A supplementation coverage rate (% of children ages 6-59 months)',
#   7),
#  ('People using at least basic sanitation services, rural (% of rural population)',
#   7),
#  ('People using safely managed drinking water services, urban (% of urban population)',
#   7),
#  ('People using at least basic drinking water services, rural (% of rural population)',
#   7),
#  ('Tuberculosis treatment success rate (% of new cases)', 8),
#  ('Electricity production from renewable sources, excluding hydroelectric (% of total)',
#   8),
#  ('Electricity production from oil, gas and coal sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, rural (% of rural population)',
#   8),
#  ('Electricity production from oil sources (% of total)', 8),
#  ('Electricity production from hydroelectric sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, urban (% of urban population)',
#   8),
#  ('Renewable electricity output (% of total electricity output)', 8),
#  ('Access to clean fuels and technologies for cooking (% of population)', 8),
#  ('International tourism, number of arrivals', 8),
#  ('Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)',
#   8),
#  ('Antiretroviral therapy coverage (% of people living with HIV)', 8),
#  ('Incidence of malaria (per 1,000 population at risk)', 8),
#  ('Bank liquid reserves to bank assets ratio (%)', 8),
#  ('Electricity production from renewable sources, excluding hydroelectric (kWh)',
#   8),
#  ('Electricity production from natural gas sources (% of total)', 8),
#  ('Electricity production from coal sources (% of total)', 8),
#  ('Out-of-pocket expenditure per capita, PPP (current international $)', 9),
#  ('Domestic general government health expenditure per capita (current US$)',
#   9),
#  ('External health expenditure per capita, PPP (current international $)', 9),
#  ('Current health expenditure per capita (current US$)', 9),
#  ('Lifetime risk of maternal death (%)', 9),
#  ('Domestic private health expenditure (% of current health expenditure)', 9),
#  ('Domestic general government health expenditure per capita, PPP (current international $)',
#   9),
#  ('Domestic general government health expenditure (% of current health expenditure)',
#   9),
#  ('Current health expenditure per capita, PPP (current international $)', 9),
#  ('Domestic private health expenditure per capita, PPP (current international $)',
#   9),
#  ('Out-of-pocket expenditure per capita (current US$)', 9),
#  ('Domestic general government health expenditure (% of general government expenditure)',
#   9),
#  ('External health expenditure per capita (current US$)', 9),
#  ('Current health expenditure (% of GDP)', 9),
#  ('Electricity production from nuclear sources (% of total)', 9),
#  ('Rail lines (total route-km)', 9),
#  ('CO2 emissions from manufacturing industries and construction (% of total fuel combustion)',
#   9),
#  ('Electric power consumption (kWh per capita)', 9),
#  ('Alternative and nuclear energy (% of total energy use)', 9),
#  ('Energy use (kg of oil equivalent per capita)', 9),
#  ('Fossil fuel energy consumption (% of total)', 9),
#  ('GDP per unit of energy use (PPP $ per kg of oil equivalent)', 9),
#  ('Electric power transmission and distribution losses (% of output)', 9),
#  ('CO2 emissions from transport (% of total fuel combustion)', 9),
#  ('CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)',
#   9),
#  ('Tariff rate, most favored nation, simple mean, primary products (%)', 9),
#  ('Binding coverage, primary products (%)', 9),
#  ('Tariff rate, most favored nation, simple mean, all products (%)', 9),
#  ('Binding coverage, all products (%)', 9),
#  ('Tariff rate, most favored nation, simple mean, manufactured products (%)',
#   9),
#  ('Binding coverage, manufactured products (%)', 9),
#  ('Number of maternal deaths', 9),
#  ('Tariff rate, most favored nation, weighted mean, primary products (%)', 9),
#  ('Tariff rate, applied, simple mean, primary products (%)', 9),
#  ('Tariff rate, most favored nation, weighted mean, all products (%)', 9),
#  ('Tariff rate, applied, simple mean, all products (%)', 9),
#  ('Tariff rate, most favored nation, weighted mean, manufactured products (%)',
#   9),
#  ('Tariff rate, applied, simple mean, manufactured products (%)', 9),
#  ('Claims on other sectors of the domestic economy (annual growth as % of broad money)',
#   9),
#  ('CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)',
#   9),
#  ('Tariff rate, applied, weighted mean, primary products (%)', 9),
#  ('Share of tariff lines with international peaks, primary products (%)', 9),
#  ('Tariff rate, applied, weighted mean, all products (%)', 9),
#  ('Share of tariff lines with international peaks, all products (%)', 9),
#  ('Tariff rate, applied, weighted mean, manufactured products (%)', 9),
#  ('Share of tariff lines with international peaks, manufactured products (%)',
#   9),
#  ('Domestic private health expenditure per capita (current US$)', 9),
#  ('Out-of-pocket expenditure (% of current health expenditure)', 9),
#  ('Domestic general government health expenditure (% of GDP)', 9),
#  ('External health expenditure (% of current health expenditure)', 9),
#  ('Maternal mortality ratio (modeled estimate, per 100,000 live births)', 9),
#  ('Lifetime risk of maternal death (1 in: rate varies by country)', 9),
#  ('CO2 emissions from electricity and heat production, total (% of total fuel combustion)',
#   9),
#  ('Combustible renewables and waste (% of total energy)', 9),
#  ('Energy imports, net (% of energy use)', 9),
#  ('Share of tariff lines with specific rates, primary products (%)', 9),
#  ('Bound rate, simple mean, primary products (%)', 9),
#  ('Share of tariff lines with specific rates, all products (%)', 9),
#  ('Bound rate, simple mean, all products (%)', 9),
#  ('Share of tariff lines with specific rates, manufactured products (%)', 9),
#  ('Bound rate, simple mean, manufactured products (%)', 9),
#  ('Prevalence of undernourishment (% of population)', 9),
#  ('CO2 intensity (kg per kg of oil equivalent energy use)', 9),
#  ('Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)', 9),
#  ('GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)',
#   9),
#  ('Energy intensity level of primary energy (MJ/$2017 PPP GDP)', 9),
#  ('Suicide mortality rate, female (per 100,000 female population)', 10),
#  ('Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)',
#   10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, female (%)',
#   10),
#  ('Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
#   10),
#  ('School enrollment, secondary, male (% gross)', 10),
#  ('Primary education, teachers', 10),
#  ('Suicide mortality rate, male (per 100,000 male population)', 10),
#  ('Mortality caused by road traffic injury (per 100,000 population)', 10),
#  ('ICT goods imports (% total goods imports)', 10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)',
#   10),
#  ('Prevalence of anemia among non-pregnant women (% of women ages 15-49)', 10),
#  ('School enrollment, secondary (% gross)', 10),
#  ('Primary education, pupils (% female)', 10),
#  ('Net bilateral aid flows from DAC donors, Greece (current US$)', 10),
#  ('Suicide mortality rate (per 100,000 population)', 10),
#  ('Mortality rate attributed to unintentional poisoning (per 100,000 population)',
#   10),
#  ('Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)',
#   10),
#  ('School enrollment, secondary, female (% gross)', 10),
#  ('Net bilateral aid flows from DAC donors, New Zealand (current US$)', 10),
#  ('Prevalence of anemia among pregnant women (%)', 10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, male (%)',
#   10),
#  ('Prevalence of anemia among children (% of children ages 6-59 months)', 10),
#  ('Secondary education, pupils', 10),
#  ('Primary education, teachers (% female)', 10),
#  ('Statistical performance indicators (SPI): Pillar 1 data use score (scale 0-100)',
#   11),
#  ('Net secondary income (Net current transfers from abroad) (constant LCU)',
#   11),
#  ('Portfolio equity, net inflows (BoP, current US$)', 11),
#  ('Charges for the use of intellectual property, payments (BoP, current US$)',
#   11),
#  ('Methane emissions (% change from 1990)', 11),
#  ('Nitrous oxide emissions (% change from 1990)', 11),
#  ('Total greenhouse gas emissions (% change from 1990)', 11),
#  ('Compulsory education, duration (years)', 11),
#  ('Other greenhouse gas emissions (% change from 1990)', 11),
#  ('Fertilizer consumption (% of fertilizer production)', 11),
#  ('CPIA structural policies cluster average (1=low to 6=high)', 12),
#  ('CPIA social protection rating (1=low to 6=high)', 12),
#  ('CPIA macroeconomic management rating (1=low to 6=high)', 12),
#  ('CPIA fiscal policy rating (1=low to 6=high)', 12),
#  ('CPIA economic management cluster average (1=low to 6=high)', 12),
#  ('Net bilateral aid flows from DAC donors, Czechia (current US$)', 12),
#  ('Statistical performance indicators (SPI): Pillar 3 data products score  (scale 0-100)',
#   12),
#  ('CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high)',
#   12),
#  ('CPIA efficiency of revenue mobilization rating (1=low to 6=high)', 12),
#  ('CPIA equity of public resource use rating (1=low to 6=high)', 12),
#  ('CPIA building human resources rating (1=low to 6=high)', 12),
#  ('CPIA quality of budgetary and financial management rating (1=low to 6=high)',
#   12),
#  ('CPIA business regulatory environment rating (1=low to 6=high)', 12),
#  ('CPIA policies for social inclusion/equity cluster average (1=low to 6=high)',
#   12),
#  ('CPIA property rights and rule-based governance rating (1=low to 6=high)',
#   12),
#  ('IDA resource allocation index (1=low to 6=high)', 12),
#  ('CPIA financial sector rating (1=low to 6=high)', 12),
#  ('CPIA debt policy rating (1=low to 6=high)', 12),
#  ('CPIA trade rating (1=low to 6=high)', 12),
#  ('CPIA public sector management and institutions cluster average (1=low to 6=high)',
#   12),
#  ('CPIA quality of public administration rating (1=low to 6=high)', 12),
#  ('CPIA gender equality rating (1=low to 6=high)', 12),
#  ('CPIA policy and institutions for environmental sustainability rating (1=low to 6=high)',
#   12),
#  ('School enrollment, secondary (gross), gender parity index (GPI)', 12),
# ...
#  ('Net secondary income (Net current transfers from abroad) (current LCU)',
#   15),
#  ('GNI, PPP (current international $)', 15),
#  ('GNI: linked series (current LCU)', 15),
#  ('Net primary income (Net income from abroad) (current US$)', 15),
#  ('GNI, Atlas method (current US$)', 15),
#  ('Net primary income (Net income from abroad) (current LCU)', 15),
#  ('GNI per capita, Atlas method (current US$)', 15),
#  ('GNI (current US$)', 15),
#  ('Public and publicly guaranteed debt service (% of GNI)', 15),
#  ('Total debt service (% of GNI)', 15),
#  ('New business density (new registrations per 1,000 people ages 15-64)', 15),
#  ('Nitrous oxide emissions in energy sector (% of total)', 15),
#  ('Agricultural methane emissions (% of total)', 15),
#  ('External debt stocks (% of GNI)', 15),
#  ('Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
#   15),
#  ('Agricultural nitrous oxide emissions (% of total)', 15),
#  ('Energy related methane emissions (% of total)', 15),
#  ('Net ODA received (% of GNI)', 15),
#  ('Secondary education, teachers, female', 15),
#  ('New businesses registered (number)', 15),
#  ('Depositors with commercial banks (per 1,000 adults)', 15),
#  ('Secondary education, teachers (% female)', 15),
#  ('Net official flows from UN agencies, UNTA (current US$)', 15),
#  ('Secondary education, teachers', 15),
#  ('School enrollment, secondary, private (% of total secondary)', 16),
#  ('Borrowers from commercial banks (per 1,000 adults)', 16),
#  ('Internally displaced persons, new displacement associated with conflict and violence (number of cases)',
#   16),
#  ('Battle-related deaths (number of people)', 16),
#  ('High-technology exports (% of manufactured exports)', 16),
#  ('Agricultural machinery, tractors per 100 sq. km of arable land', 16),
#  ('School enrollment, primary, private (% of total primary)', 16),
#  ('Internally displaced persons, new displacement associated with disasters (number of cases)',
#   16),
#  ('High-technology exports (current US$)', 16),
#  ('Agricultural machinery, tractors', 16),
#  ('School enrollment, preprimary, female (% gross)', 17),
#  ('PPG, bonds (NFL, current US$)', 17),
#  ('PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#   17),
#  ('Portfolio investment, bonds (PPG + PNG) (NFL, current US$)', 17),
#  ('Pupil-teacher ratio, primary', 17),
#  ('School enrollment, preprimary (% gross)', 17),
#  ('Primary government expenditures as a proportion of original approved budget (%)',
#   17),
#  ('School enrollment, preprimary, male (% gross)', 17),
#  ('Nurses and midwives (per 1,000 people)', 18),
#  ('Net bilateral aid flows from DAC donors, Hungary (current US$)', 18),
#  ('Net official flows from UN agencies, WHO (current US$)', 18),
#  ('People with basic handwashing facilities including soap and water, urban (% of urban population)',
#   18),
#  ('People with basic handwashing facilities including soap and water (% of population)',
#   18),
#  ('PNG, bonds (NFL, current US$)', 18),
#  ('People with basic handwashing facilities including soap and water, rural (% of rural population)',
#   18),
#  ('Physicians (per 1,000 people)', 18),
#  ('Gross intake ratio in first grade of primary education, male (% of relevant age group)',
#   19),
#  ('Secure Internet servers (per 1 million people)', 19),
#  ('Pump price for gasoline (US$ per liter)', 19),
#  ('PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)',
#   19),
#  ('Secure Internet servers', 19),
#  ('Population living in slums (% of urban population)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-2 value (% of total)',
#   19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)',
#   19),
#  ('Gross intake ratio in first grade of primary education, female (% of relevant age group)',
#   19),
#  ('Pump price for diesel fuel (US$ per liter)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)',
#   19),
#  ('Net official flows from UN agencies, ILO (current US$)', 19),
#  ('Gross intake ratio in first grade of primary education, total (% of relevant age group)',
#   19),
#  ('Investment in energy with private participation (current US$)', 20),
#  ('Commercial banks and other lending (PPG + PNG) (NFL, current US$)', 20),
#  ('PPG, commercial banks (NFL, current US$)', 20),
#  ('Contraceptive prevalence, any method (% of married women ages 15-49)', 20),
#  ('Pupil-teacher ratio, secondary', 20),
#  ('Contraceptive prevalence, any modern method (% of married women ages 15-49)',
#   20),
#  ('Internally displaced persons, total displaced by conflict and violence (number of people)',
#   20),
#  ('Exclusive breastfeeding (% of children under 6 months)', 21),
#  ('Use of insecticide-treated bed nets (% of under-5 population)', 21),
#  ('Children out of school, primary, male', 21),
#  ('Adjusted net enrollment rate, primary, male (% of primary school age children)',
#   21),
#  ('Over-age students, primary, female (% of female enrollment)', 21),
#  ('School enrollment, primary, male (% net)', 21),
#  ('Children out of school (% of primary school age)', 21),
#  ('Children out of school, primary, female', 21),
#  ('Adjusted net enrollment rate, primary (% of primary school age children)',
#   21),
#  ('Over-age students, primary (% of enrollment)', 21),
#  ('School enrollment, primary (% net)', 21),
#  ('Net capital account (BoP, current US$)', 21),
#  ('Pregnant women receiving prenatal care (%)', 21),
#  ('Children out of school, female (% of female primary school age)', 21),
#  ('Adjusted net enrollment rate, primary, female (% of primary school age children)',
#   21),
#  ('School enrollment, primary, female (% net)', 21),
#  ('Children out of school, male (% of male primary school age)', 21),
#  ('Children out of school, primary', 21),
#  ('Over-age students, primary, male (% of male enrollment)', 21),
#  ('Average transaction cost of sending remittances to a specific country (%)',
#   22),
#  ('School enrollment, tertiary (% gross)', 22),
#  ('Primary completion rate, total (% of relevant age group)', 22),
#  ('Industrial design applications, resident, by count', 22),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (national estimate)',
#   22),
#  ('Employment to population ratio, 15+, total (%) (national estimate)', 22),
#  ('Unemployment, total (% of total labor force) (national estimate)', 22),
#  ('Unemployment, female (% of female labor force) (national estimate)', 22),
#  ('Labor force participation rate, total (% of total population ages 15+) (national estimate)',
#   22),
#  ('Patent applications, nonresidents', 22),
#  ('Patent applications, residents', 22),
#  ('Industrial design applications, nonresident, by count', 22),
#  ('Public private partnerships investment in energy (current US$)', 22),
#  ('Public private partnerships investment in transport (current US$)', 22),
#  ('Investment in transport with private participation (current US$)', 22),
#  ('School enrollment, tertiary, male (% gross)', 22),
#  ('Primary completion rate, female (% of relevant age group)', 22),
#  ('Unmet need for contraception (% of married women ages 15-49)', 22),
#  ('Primary completion rate, male (% of relevant age group)', 22),
#  ('School enrollment, tertiary (gross), gender parity index (GPI)', 22),
#  ('Unemployment, male (% of male labor force) (national estimate)', 22),
#  ('Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
#   22),
#  ('School enrollment, tertiary, female (% gross)', 22),
#  ('Prevalence of severe wasting, weight for height, female (% of children under 5)',
#   23),
#  ('Prevalence of stunting, height for age, female (% of children under 5)',
#   23),
#  ('Prevalence of underweight, weight for age, female (% of children under 5)',
#   23),
#  ('Prevalence of current tobacco use, males (% of male adults)', 23),
#  ('Persistence to last grade of primary, male (% of cohort)', 23),
#  ('Persistence to grade 5, female (% of cohort)', 23),
#  ('Literacy rate, youth female (% of females ages 15-24)', 23),
#  ('Logistics performance index: Overall (1=low to 5=high)', 23),
#  ('Logistics performance index: Efficiency of customs clearance process (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 5 data infrastructure score (scale 0-100)',
#   23),
#  ('Total tax and contribution rate (% of profit)', 23),
#  ('Start-up procedures to register a business, male (number)', 23),
#  ('Time required to start a business, female (days)', 23),
#  ('Cost of business start-up procedures, female (% of GNI per capita)', 23),
#  ('Prevalence of severe wasting, weight for height, male (% of children under 5)',
#   23),
#  ('Prevalence of wasting, weight for height, female (% of children under 5)',
#   23),
#  ('Prevalence of stunting, height for age, male (% of children under 5)', 23),
#  ('Prevalence of overweight, weight for height (% of children under 5)', 23),
#  ('Diarrhea treatment (% of children under 5 who received ORS packet)', 23),
#  ('Prevalence of wasting, weight for height (% of children under 5)', 23),
#  ('Prevalence of stunting, height for age (% of children under 5)', 23),
#  ('Logistics performance index: Ability to track and trace consignments (1=low to 5=high)',
#   23),
#  ('Logistics performance index: Ease of arranging competitively priced shipments (1=low to 5=high)',
#   23),
#  ('Procedures to build a warehouse (number)', 23),
#  ('Tax payments (number)', 23),
#  ('Strength of legal rights index (0=weak to 12=strong)', 23),
#  ('Public credit registry coverage (% of adults)', 23),
#  ('Logistics performance index: Competence and quality of logistics services (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 4 data sources score (scale 0-100)',
#   23),
#  ('Statistical performance indicators (SPI): Overall score (scale 0-100)', 23),
#  ('Profit tax (% of commercial profits)', 23),
#  ('Labor tax and contributions (% of commercial profits)', 23),
#  ('Start-up procedures to register a business, female (number)', 23),
#  ('Time required to start a business (days)', 23),
#  ('Procedures to register property (number)', 23),
#  ('Time to resolve insolvency (years)', 23),
#  ('Start-up procedures to register a business (number)', 23),
#  ('Cost of business start-up procedures (% of GNI per capita)', 23),
#  ('Time required to register property (days)', 23),
#  ('Depth of credit information index (0=low to 8=high)', 23),
#  ('Marine protected areas (% of territorial waters)', 23),
#  ('Logistics performance index: Frequency with which shipments reach consignee within scheduled or expected time (1=low to 5=high)',
#   23),
#  ('Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 2 data services score (scale 0-100)',
#   23),
#  ('Time required to build a warehouse (days)', 23),
#  ('Other taxes payable by businesses (% of commercial profits)', 23),
#  ('Time to prepare and pay taxes (hours)', 23),
#  ('Time required to start a business, male (days)', 23),
#  ('Cost of business start-up procedures, male (% of GNI per capita)', 23),
#  ('Time required to enforce a contract (days)', 23),
#  ('Prevalence of severe food insecurity in the population (%)', 23),
#  ('Prevalence of current tobacco use (% of adults)', 23),
#  ('Persistence to grade 5, total (% of cohort)', 23),
#  ('Female headed households (% of households with a female head)', 23),
#  ('Time required to get electricity (days)', 23),
#  ('Terrestrial protected areas (% of total land area)', 23),
#  ('Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)',
#   23),
#  ('Prevalence of moderate or severe food insecurity in the population (%)',
#   23),
#  ('UHC service coverage index', 23),
#  ('Prevalence of severe wasting, weight for height (% of children under 5)',
#   23),
#  ('Prevalence of wasting, weight for height, male (% of children under 5)',
#   23),
#  ('Prevalence of overweight, weight for height, female (% of children under 5)',
#   23),
#  ('Prevalence of underweight, weight for age (% of children under 5)', 23),
#  ('Prevalence of overweight, weight for height, male (% of children under 5)',
#   23),
#  ('Prevalence of current tobacco use, females (% of female adults)', 23),
#  ('Persistence to last grade of primary, female (% of cohort)', 23),
#  ('Private credit bureau coverage (% of adults)', 23),
#  ('Terrestrial and marine protected areas (% of total territorial area)', 23),
#  ('Prevalence of underweight, weight for age, male (% of children under 5)',
#   23),
#  ('Births attended by skilled health staff (% of total)', 23),
#  ('Persistence to last grade of primary, total (% of cohort)', 23),
#  ('Persistence to grade 5, male (% of cohort)', 23),
#  ('Poverty gap at $3.65 a day (2017 PPP) (%)', 24),
#  ('Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)', 24),
#  ('Income share held by highest 10%', 24),
#  ('Income share held by second 20%', 24),
#  ('Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)',
#   24),
#  ('Diarrhea treatment (% of children under 5 receiving oral rehydration and continued feeding)',
#   24),
#  ('ARI treatment (% of children under 5 taken to a health provider)', 24),
#  ('Railways, goods transported (million ton-km)', 24),
#  ('Investment in ICT with private participation (current US$)', 24),
#  ('Poverty gap at $2.15 a day (2017 PPP) (%)', 24),
#  ('Proportion of people living below 50 percent of median income (%)', 24),
#  ('Income share held by third 20%', 24),
#  ('Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)',
#   24),
#  ('Poverty gap at $6.85 a day (2017 PPP) (%)', 24),
#  ('Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)', 24),
#  ('Income share held by lowest 20%', 24),
#  ('Income share held by highest 20%', 24),
#  ('Net official flows from UN agencies, FAO (current US$)', 24),
#  ('Lead time to export, median case (days)', 24),
#  ('Cost to import, documentary compliance (US$)', 24),
#  ('Time to export, border compliance (hours)', 24),
#  ('Lead time to import, median case (days)', 24),
#  ('Time to import, documentary compliance (hours)', 24),
#  ('Cost to export, border compliance (US$)', 24),
#  ('Net official flows from UN agencies, WFP (current US$)', 24),
#  ('Trademark applications, resident, by count', 24),
#  ('Trained teachers in primary education, male (% of male teachers)', 24),
#  ('Consumption of iodized salt (% of households)', 24),
#  ('Time to import, border compliance (hours)', 24),
#  ('Time to export, documentary compliance (hours)', 24),
#  ('Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)', 24),
#  ('Gini index', 24),
#  ('Income share held by lowest 10%', 24),
#  ('Income share held by fourth 20%', 24),
#  ('Pupil-teacher ratio, upper secondary', 24),
#  ('Trained teachers in primary education (% of total teachers)', 24),
#  ('Cost to import, border compliance (US$)', 24),
#  ('Cost to export, documentary compliance (US$)', 24),
#  ('Pupil-teacher ratio, lower secondary', 24),
#  ('Trained teachers in primary education, female (% of female teachers)', 24),
#  ('International migrant stock (% of population)', 25),
#  ('Share of youth not in education, employment or training, female (% of female youth population)',
#   25),
#  ('Labor force participation rate for ages 15-24, male (%) (national estimate)',
#   25),
#  ('Proportion of population pushed or further pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   25),
#  ('Proportion of population pushed further below the 60% median consumption poverty line by out-of-pocket health care expenditure (%)',
#   25),
#  ('Female genital mutilation prevalence (%)', 25),
#  ("Educational attainment, at least Bachelor's or equivalent, population 25+, male (%) (cumulative)",
#   25),
#  ('Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative)',
#   25),
#  ('Public private partnerships investment in ICT (current US$)', 25),
#  ...]

# %%
# selecting the columns we want to analyse
selected_nigeria_data = nigeria_data[["Year","GDP growth (annual %)","GDP (constant 2015 US$)","Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_nigeria_data
# Out:
# /tmp/ipykernel_106862/2967450993.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_106862/2967450993.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_nigeria_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 35  1994              -1.814924      154713823159.432007
# 36  1995              -0.072665      154601400725.053986
# 37  1996               4.195924      161088358074.458008
# 38  1997               2.937099       165819683303.94101
# 39  1998               2.581254      170099910681.029999
# 40  1999               0.584127      171093510004.148987
# 41  2000               5.015935      179675448843.372986
# 42  2001               5.917685      190308075297.964996
# 43  2002              15.329156      219480696548.006012
# 44  2003               7.347195      235606371240.501007
# 45  2004               9.250558      257401275803.761993
# 46  2005               6.438517       273974099482.93399
# 47  2006               6.059428      290575362867.502991
# 48  2007                6.59113      309727563830.140015
# 49  2008               6.764473      330679000570.778015
# 50  2009               8.036925      357255424171.356018
# 51  2010               8.005656      385856064172.783997
# 52  2011               5.307924      406337011591.349976
# 53  2012               4.230061      423525315758.054016
# 54  2013               6.671335      451780110046.796997
# 55  2014               6.309719      480286163931.150024
# 56  2015               2.652693      493026682800.630005
# 57  2016              -1.616869      485055087455.820007
# 58  2017               0.805887      488964081500.901001
# 59  2018               1.922757      498365674277.734009
# 60  2019               2.208429      509371727735.742981
# 61  2020              -1.794253      500232309808.216003
# 62  2021               3.647187      518476715283.895996
# 63  2022               3.251681      535335926240.995972
# 64  2023                   <NA>                     <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 35                               27141298.417894
# 36                                25583636.30077
# 37                               54088507.945478
# 38                               20321016.103051
# 39                                2363115.767123
# 40                              -11013871.847049
# 41                             -502264890.590381
# 42                             -831771646.906782
# 43                              -133938021.80453
# 44                             -182894058.187303
# 45                             -177818881.723918
# 46                              487949764.234188
# 47                             -1288018525.47576
# 48                             -799672941.059114
# 49                              3401810908.06859
# 50                              345305077.915099
# 51                             -2586452803.88643
# 52                             -3540318310.01121
# 53                           -14992409829.628799
# 54                             -10320930912.9907
# 55                             -1843622657.50655
# 56                             -858700673.503529
# 57                             -1894322228.78134
# 58                           -10331328579.742901
# 59                                 6779467.04952
# 60                             -3090853025.27065
# 61                              3691340692.27872
# 62                             -5343327271.39869
# 63                             -3864707334.29201
# 64                                          <NA>
#
# 0   Inflation, consumer prices (annual %)  \
# 35                              57.031709
# 36                              72.835502
# 37                              29.268293
# 38                               8.529874
# 39                               9.996378
# 40                               6.618373
# 41                               6.933292
# 42                              18.873646
# 43                              12.876579
# 44                              14.031784
# 45                              14.998034
# 46                              17.863493
# 47                               8.225222
# 48                               5.388008
# 49                              11.581075
# 50                              12.537828
# 51                              13.740052
# 52                              10.826137
# 53                              12.224241
# 54                               8.495518
# 55                               8.047411
# 56                               9.009435
# 57                              15.696813
# 58                              16.502266
# 59                              12.095107
# 60                              11.396422
# 61                              13.246023
# 62                              16.952846
# 63                              18.847188
# 64                                   <NA>
#
# 0   Unemployment, total (% of total labor force) (national estimate)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               3.77
# 53                                               <NA>
# 54                                              3.711
# 55                                              4.562
# 56                                              4.311
# 57                                               7.06
# 58                                              8.389
# 59                                               <NA>
# 60                                             10.695
# 61                                               <NA>
# 62                                               <NA>
# 63                                              3.827
# 64                                               <NA>
#
# 0   Population growth (annual %)  \
# 35                      2.574829
# 36                       2.55719
# 37                      2.526853
# 38                      2.522965
# 39                      2.516034
# 40                       2.54262
# 41                      2.602869
# 42                      2.651265
# 43                       2.68289
# 44                      2.692768
# 45                      2.695503
# 46                      2.693693
# 47                      2.695926
# 48                      2.709627
# 49                      2.719687
# 50                      2.727385
# 51                      2.744379
# 52                      2.764062
# 53                      2.749289
# 54                      2.697474
# 55                      2.628124
# 56                      2.541187
# 57                      2.507034
# 58                      2.527317
# 59                      2.496645
# 60                      2.448201
# 61                      2.440609
# 62                      2.406363
# 63                      2.380007
# 64                          <NA>
#
# 0   Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)
# 35                                           46.73724
# 36                                           46.73724
# 37                                           46.73724
# 38                                           46.73724
# 39                                           46.73724
# 40                                           46.73724
# 41                                           46.73724
# 42                                           46.73724
# 43                                           46.73724
# 44                                           46.73724
# 45                                           46.73724
# 46                                           46.73724
# 47                                          49.419861
# 48                                           46.73724
# 49                                           46.73724
# 50                                           46.73724
# 51                                           46.73724
# 52                                           46.73724
# 53                                           46.73724
# 54                                           46.73724
# 55                                           46.73724
# 56                                           46.73724
# 57                                          45.247971
# 58                                           46.73724
# 59                                          44.624809
# 60                                          44.635159
# 61                                           46.73724
# 62                                            49.7584
# 63                                           46.73724
# 64                                           46.73724

# %%
selected_nigeria_data.shape
# Out:
# (30, 8)

# %%
selected_nigeria_data.describe().T
# Out:
#                                                    count                 mean  \
# 0
# Year                                                30.0               2008.5
# GDP growth (annual %)                               29.0             4.371173
# GDP (constant 2015 US$)                             29.0  337886650869.257019
# Portfolio investment, net (BoP, current US$)        29.0    -1880402861.39749
# Inflation, consumer prices (annual %)               29.0            16.367881
# Unemployment, total (% of total labor force) (n...   8.0             5.790625
# Population growth (annual %)                        29.0             2.601476
# Educational attainment, at least completed lowe...  30.0             46.73724
#
#                                                                     std  \
# 0
# Year                                                           8.803408
# GDP growth (annual %)                                           3.72997
# GDP (constant 2015 US$)                             138684159581.200989
# Portfolio investment, net (BoP, current US$)          3983733733.338313
# Inflation, consumer prices (annual %)                         14.450592
# Unemployment, total (% of total labor force) (n...              2.62891
# Population growth (annual %)                                    0.11253
# Educational attainment, at least completed lowe...             0.972428
#
#                                                                     min  \
# 0
# Year                                                             1994.0
# GDP growth (annual %)                                         -1.814924
# GDP (constant 2015 US$)                             154601400725.053986
# Portfolio investment, net (BoP, current US$)        -14992409829.628799
# Inflation, consumer prices (annual %)                          5.388008
# Unemployment, total (% of total labor force) (n...                3.711
# Population growth (annual %)                                   2.380007
# Educational attainment, at least completed lowe...            44.624809
#
#                                                                     25%  \
# 0
# Year                                                            2001.25
# GDP growth (annual %)                                          2.208429
# GDP (constant 2015 US$)                             190308075297.964996
# Portfolio investment, net (BoP, current US$)          -2586452803.88643
# Inflation, consumer prices (annual %)                          9.009435
# Unemployment, total (% of total labor force) (n...              3.81275
# Population growth (annual %)                                   2.522965
# Educational attainment, at least completed lowe...             46.73724
#
#                                                                     50%  \
# 0
# Year                                                             2008.5
# GDP growth (annual %)                                          4.230061
# GDP (constant 2015 US$)                             330679000570.778015
# Portfolio investment, net (BoP, current US$)          -502264890.590381
# Inflation, consumer prices (annual %)                         12.537828
# Unemployment, total (% of total labor force) (n...               4.4365
# Population growth (annual %)                                   2.602869
# Educational attainment, at least completed lowe...             46.73724
#
#                                                                     75%  \
# 0
# Year                                                            2015.75
# GDP growth (annual %)                                           6.59113
# GDP (constant 2015 US$)                             485055087455.820007
# Portfolio investment, net (BoP, current US$)            20321016.103051
# Inflation, consumer prices (annual %)                         16.502266
# Unemployment, total (% of total labor force) (n...              7.39225
# Population growth (annual %)                                   2.695926
# Educational attainment, at least completed lowe...             46.73724
#
#                                                                     max
# 0
# Year                                                             2023.0
# GDP growth (annual %)                                         15.329156
# GDP (constant 2015 US$)                             535335926240.995972
# Portfolio investment, net (BoP, current US$)           3691340692.27872
# Inflation, consumer prices (annual %)                         72.835502
# Unemployment, total (% of total labor force) (n...               10.695
# Population growth (annual %)                                   2.764062
# Educational attainment, at least completed lowe...              49.7584

# %%
import seaborn as sns

# %%
columns = list(selected_nigeria_data.columns)
print(columns)

sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# <Axes: xlabel='GDP (constant 2015 US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_nigeria_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_nigeria_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
sns.pairplot(data = selected_nigeria_data, height = 2)

# %%
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_nigeria_data[ 'GDP growth (annual %)']
X = selected_nigeria_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=42)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  360.29993723227057
# mean_absolute_error :  17.075824128848705
# The value of R^2 for the model is -1817.057114423892 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 4.957199646970604
# The value of slope for GDP (constant 2015 US$) is given by -1.7917234426527774e-11
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -2.886822891681629e-09
# The value of slope for Inflation, consumer prices (annual %) is given by -0.7756690293542168
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by -0.6457337625080607
# The value of slope for Population growth (annual %) is given by 0.015206989814264698
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 0.29491912046114144
