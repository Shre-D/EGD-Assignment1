# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("australia")
australia_data = Data.read(filepath)
australia_data
# Out:
#      Country Name Country Code  \
# 0       Australia          AUS
# 1       Australia          AUS
# 2       Australia          AUS
# 3       Australia          AUS
# 4       Australia          AUS
# ...           ...          ...
# 1473    Australia          AUS
# 1474    Australia          AUS
# 1475    Australia          AUS
# 1476    Australia          AUS
# 1477    Australia          AUS
#
#                                          Indicator Name    Indicator Code  \
# 0            Intentional homicides (per 100,000 people)    VC.IHR.PSRC.P5
# 1     Internally displaced persons, new displacement...       VC.IDP.NWDS
# 2     Voice and Accountability: Percentile Rank, Upp...  VA.PER.RNK.UPPER
# 3                    Voice and Accountability: Estimate            VA.EST
# 4                 High-technology exports (current US$)    TX.VAL.TECH.CD
# ...                                                 ...               ...
# ...

# %%
# cleaning the data
australia_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
australia_data = Data.clean_data(australia_data, australia_columns_to_drop)
australia_data
# Out:
# 0   Year  Intentional homicides (per 100,000 people)  \
# 1   1960                                        <NA>
# 2   1961                                        <NA>
# 3   1962                                        <NA>
# 4   1963                                        <NA>
# 5   1964                                        <NA>
# ..   ...                                         ...
# 60  2019                                    0.887323
# 61  2020                                    0.860925
# 62  2021                                    0.744567
# 63  2022                                        <NA>
# 64  2023                                        <NA>
#
# 0   Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# ...

# %%
# selecting and modifying the data
australia_data["Year"]=australia_data["Year"].astype(int)
australia_data = australia_data.tail(35)
australia_data
interval = 5
australia_data=australia_data.iloc[::interval]
australia_data
# Out:
# 0   Year  Intentional homicides (per 100,000 people)  \
# 30  1989                                        <NA>
# 35  1994                                    1.797197
# 40  1999                                    2.047775
# 45  2004                                    1.319946
# 50  2009                                     1.21417
# 55  2014                                    1.035383
# 60  2019                                    0.887323
#
# 0   Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                               7500
# 55                                               1200
# 60                                              25000
#
# ...

# %%
# checking the number of null values in each column
australia_data.isna().sum()
# Out:
# 0
# Year                                                                                          0
# Intentional homicides (per 100,000 people)                                                    1
# Internally displaced persons, new displacement associated with disasters (number of cases)    4
# Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval             3
# Voice and Accountability: Estimate                                                            3
#                                                                                              ..
# Patent applications, nonresidents                                                             0
# Public private partnerships investment in water and sanitation (current US$)                  7
# Investment in water and sanitation with private participation (current US$)                   7
# Procedures to build a warehouse (number)                                                      4
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = australia_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   0),
#  ('Travel services (% of commercial service imports)', 0),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   0),
#  ('Merchandise imports (current US$)', 0),
#  ('Insurance and financial services (% of commercial service imports)', 0),
#  ('Agricultural raw materials imports (% of merchandise imports)', 0),
#  ('Urban population', 0),
#  ('Rural population', 0),
#  ('Population, male', 0),
# ...

# %%
# selecting the columns we want to analyse
selected_australia_data = australia_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_australia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_australia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_australia_data
# Out:
# /tmp/ipykernel_1871593/2829492088.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_australia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1871593/2829492088.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
selected_australia_data.shape
# Out:
# (7, 8)

# %%
selected_australia_data.describe().T
# Out:
#                                                    count  \
# 0
# Year                                                 7.0
# GDP growth (annual %)                                7.0
# GDP (constant 2015 US$)                              7.0
# Portfolio investment, net (BoP, current US$)         7.0
# Inflation, consumer prices (annual %)                7.0
# Unemployment, total (% of total labor force) (n...   7.0
# Population growth (annual %)                         7.0
# Educational attainment, at least completed lowe...   7.0
#
#                                                                     mean  \
# 0
# Year                                                              2004.0
# GDP growth (annual %)                                           3.398773
# GDP (constant 2015 US$)                             1013658914469.882812
# Portfolio investment, net (BoP, current US$)         -17196463958.710415
# Inflation, consumer prices (annual %)                           2.742819
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_australia_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_australia_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_australia_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_australia_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_australia_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_australia_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_australia_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_australia_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_australia_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)

selected_australia_data['GDP growth (annual %)'] = selected_australia_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_australia_data["GDP (constant 2015 US$)"] = np.log(selected_australia_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# /tmp/ipykernel_1871593/1114023267.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
mean_value = selected_australia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_australia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_australia_data[regression_columns]
selected_australia_data = selected_australia_data.tail(6)
selected_australia_data.reset_index(drop=True, inplace = True)
selected_australia_data
# Out:
# /tmp/ipykernel_1871593/794446311.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_australia_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1871593/794446311.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_australia_data[ 'GDP growth (annual %)']
X = selected_australia_data[regression_columns]

# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=50)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  70.93971171122949
# mean_absolute_error :  8.422571561656778
# The value of R^2 for the model is 15.962405438312066 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 416.88152300198846
# The value of slope for GDP (constant 2015 US$) is given by -5.116387913147778
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -4.4653170050423796e-11
# The value of slope for Inflation, consumer prices (annual %) is given by -14.40718003123513
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by -2.1562241257787744
# The value of slope for Population growth (annual %) is given by -6.541308136652894
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by -2.2889045367016108
