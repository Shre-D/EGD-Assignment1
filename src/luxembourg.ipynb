# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("luxembourg")
luxembourg_data = Data.read(filepath)
luxembourg_data
# Out:
#      Country Name Country Code  \
# 0      Luxembourg          LUX
# 1      Luxembourg          LUX
# 2      Luxembourg          LUX
# 3      Luxembourg          LUX
# 4      Luxembourg          LUX
# ...           ...          ...
# 1473   Luxembourg          LUX
# 1474   Luxembourg          LUX
# 1475   Luxembourg          LUX
# 1476   Luxembourg          LUX
# 1477   Luxembourg          LUX
#
#                                          Indicator Name     Indicator Code  \
# 0     Internally displaced persons, total displaced ...        VC.IDP.TOCV
# 1              Voice and Accountability: Standard Error         VA.STD.ERR
# 2           Voice and Accountability: Number of Sources          VA.NO.SRC
# 3     High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS
# 4                       Export value index (2015 = 100)  TX.VAL.MRCH.XD.WD
# ...                                                 ...                ...
# ...

# %%
# cleaning the data
luxembourg_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
luxembourg_data = Data.clean_data(luxembourg_data, luxembourg_columns_to_drop)
luxembourg_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 1                                       <NA>
# 2                                       <NA>
# ...

# %%
# selecting and modifying the data
luxembourg_data["Year"]=luxembourg_data["Year"].astype(int)
luxembourg_data = luxembourg_data.tail(35)
interval = 5
luxembourg_data=luxembourg_data.iloc[::interval]
luxembourg_data
# Out:
# 0   Year  \
# 30  1989
# 35  1994
# 40  1999
# 45  2004
# 50  2009
# 55  2014
# 60  2019
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                               <NA>
# 55                                               <NA>
# 60                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 30                                      <NA>
# 35                                      <NA>
# 40                                      <NA>
# 45                                  0.228559
# 50                                  0.166748
# 55                                  0.172793
# 60                                  0.155717
#
# ...

# %%
# checking the number of null values in each column
luxembourg_data.isna().sum()
# Out:
# 0
# Year                                                                                         0
# Internally displaced persons, total displaced by conflict and violence (number of people)    7
# Voice and Accountability: Standard Error                                                     3
# Voice and Accountability: Number of Sources                                                  3
# High-technology exports (% of manufactured exports)                                          4
#                                                                                             ..
# Forest area (% of land area)                                                                 3
# Urban land area where elevation is below 5 meters (sq. km)                                   7
# Land under cereal production (hectares)                                                      3
# Agricultural land (% of land area)                                                           3
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = luxembourg_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Tariff rate, applied, weighted mean, primary products (%)', 0),
#  ('Share of tariff lines with international peaks, primary products (%)', 0),
#  ('Tariff rate, applied, weighted mean, all products (%)', 0),
#  ('Share of tariff lines with international peaks, all products (%)', 0),
#  ('Tariff rate, applied, weighted mean, manufactured products (%)', 0),
#  ('Share of tariff lines with international peaks, manufactured products (%)',
#   0),
#  ('Urban population (% of total population)', 0),
#  ('Rural population growth (annual %)', 0),
#  ('Population, male (% of total population)', 0),
#  ('Population, total', 0),
#  ('Age dependency ratio, young (% of working-age population)', 0),
#  ('Population ages 80 and above, male (% of male population)', 0),
#  ('Population ages 70-74, male (% of male population)', 0),
#  ('Population ages 65 and above, male (% of male population)', 0),
#  ('Population ages 65-69, male (% of male population)', 0),
# ...

# %%
# selecting the columns we want to analyse
selected_luxembourg_data = luxembourg_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)"]]
selected_luxembourg_data
# Out:
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 30  1989               9.798065       23938905603.769501
# 35  1994                3.82092       30172289931.437901
# 40  1999               8.175182       37750651303.918297
# 45  2004               4.231891         45943524157.4617
# 50  2009              -3.238954       52055333610.139801
# 55  2014               2.623086       58738350255.759697
# 60  2019               2.915848       66557495896.737801
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 30                                          <NA>
# 35                                          <NA>
# 40                                          <NA>
# 45                             -52178664071.7164
# 50                            51720239188.356697
# 55                          -127940645440.186005
# 60                             -68670375447.7873
#
# 0   Inflation, consumer prices (annual %)  \
# 30                               3.370959
# ...

# %%
selected_luxembourg_data.shape
# Out:
# (7, 7)

# %%
selected_luxembourg_data.describe().T
# Out:
#                                                    count                mean  \
# 0
# Year                                                 7.0              2004.0
# GDP growth (annual %)                                7.0            4.046577
# GDP (constant 2015 US$)                              7.0  45022364394.174965
# Portfolio investment, net (BoP, current US$)         4.0 -49267361442.833252
# Inflation, consumer prices (annual %)                7.0            1.650929
# Unemployment, total (% of total labor force) (n...   7.0            4.162857
# Population growth (annual %)                         7.0            1.611146
#
#                                                                    std  \
# 0
# Year                                                         10.801234
# GDP growth (annual %)                                         4.214936
# GDP (constant 2015 US$)                             15384603264.696413
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_luxembourg_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_luxembourg_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_luxembourg_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_luxembourg_data['GDP growth (annual %)'] = selected_luxembourg_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_luxembourg_data["GDP (constant 2015 US$)"] = np.log(selected_luxembourg_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)']
# /tmp/ipykernel_1402615/2476107539.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_luxembourg_data['GDP growth (annual %)'] = selected_luxembourg_data['GDP (constant 2015 US$)'].pct_change() * 100
# ...

# %%
selected_luxembourg_data[regression_columns]
selected_luxembourg_data = selected_luxembourg_data.tail(6)
selected_luxembourg_data.reset_index(drop=True, inplace = True)
selected_luxembourg_data
# Out:
# 0  Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 0  1994              26.038719                 24.13019
# 1  1999              25.116958                24.354269
# 2  2004                21.7026                24.550679
# 3  2009              13.302875                24.675573
# 4  2014              12.838294                24.796359
# 5  2019              13.311824                24.921332
#
# 0  Portfolio investment, net (BoP, current US$)  \
# 0                                          <NA>
# 1                                          <NA>
# 2                             -52178664071.7164
# 3                            51720239188.356697
# 4                          -127940645440.186005
# 5                             -68670375447.7873
#
# 0  Inflation, consumer prices (annual %)  \
# 0                               2.194765
# 1                               1.025197
# 2                               2.225679
# 3                               0.368042
# ...

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_luxembourg_data[ 'GDP growth (annual %)']
X = selected_luxembourg_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=40)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  23.65982154234358
# mean_absolute_error :  4.864136258611962
# The value of R^2 for the model is 56.97756339929207 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 103.71209961246842
# The value of slope for GDP (constant 2015 US$) is given by -2.787536762909421
# The value of slope for Portfolio investment, net (BoP, current US$) is given by 4.0042191784550596e-11
# The value of slope for Inflation, consumer prices (annual %) is given by 5.548392737317524
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by -3.4510916728349628
# The value of slope for Population growth (annual %) is given by -4.353485946204737
