# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("luxembourg")
luxembourg_data = Data.read(filepath)
luxembourg_data
# Out:
#      Country Name Country Code  \
# 0      Luxembourg          LUX
# 1      Luxembourg          LUX
# 2      Luxembourg          LUX
# 3      Luxembourg          LUX
# 4      Luxembourg          LUX
# ...           ...          ...
# 1473   Luxembourg          LUX
# 1474   Luxembourg          LUX
# 1475   Luxembourg          LUX
# 1476   Luxembourg          LUX
# 1477   Luxembourg          LUX
#
#                                          Indicator Name     Indicator Code  \
# 0     Internally displaced persons, total displaced ...        VC.IDP.TOCV
# 1              Voice and Accountability: Standard Error         VA.STD.ERR
# 2           Voice and Accountability: Number of Sources          VA.NO.SRC
# 3     High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS
# 4                       Export value index (2015 = 100)  TX.VAL.MRCH.XD.WD
# ...                                                 ...                ...
# 1473                       Forest area (% of land area)     AG.LND.FRST.ZS
# 1474  Urban land area where elevation is below 5 met...  AG.LND.EL5M.UR.K2
# 1475            Land under cereal production (hectares)     AG.LND.CREL.HA
# 1476                 Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 1477                   Agricultural machinery, tractors     AG.AGR.TRAC.NO
#
#       1960  1961  1962  1963  1964  1965  ...          2015          2016  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN  ...      0.169729      0.159271
# 2      NaN   NaN   NaN   NaN   NaN   NaN  ...      7.000000      8.000000
# 3      NaN   NaN   NaN   NaN   NaN   NaN  ...      7.106326      7.967048
# 4      NaN   NaN   NaN   NaN   NaN   NaN  ...    100.000000     92.163258
# ...    ...   ...   ...   ...   ...   ...  ...           ...           ...
# 1473   NaN   NaN   NaN   NaN   NaN   NaN  ...     34.453827     34.453827
# 1474   NaN   NaN   NaN   NaN   NaN   NaN  ...      0.000000           NaN
# 1475   NaN   NaN   NaN   NaN   NaN   NaN  ...  29287.000000  27855.000000
# 1476   NaN   NaN   NaN   NaN   NaN   NaN  ...     50.989334     50.748895
# 1477   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN           NaN
#
#               2017          2018          2019          2020          2021  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1         0.161407      0.164489      0.155717      0.119025      0.110341
# 2         8.000000      8.000000      7.000000      7.000000      9.000000
# 3         6.968730      6.973219      6.573374      5.618945      6.074862
# 4        91.957511     95.757994     95.987389     80.745161     96.991194
# ...            ...           ...           ...           ...           ...
# 1473     34.453827     34.453827     34.453827     34.453827     34.453827
# 1474           NaN           NaN           NaN           NaN           NaN
# 1475  27960.000000  26300.000000  27390.000000  25490.000000  26310.000000
# 1476     50.945829     51.101590     51.114408     51.325715     51.587906
# 1477           NaN           NaN           NaN           NaN           NaN
#
#               2022  2023  Unnamed: 68
# 0              NaN   NaN          NaN
# 1         0.109385   NaN          NaN
# 2         9.000000   NaN          NaN
# 3         5.866256   NaN          NaN
# 4              NaN   NaN          NaN
# ...            ...   ...          ...
# 1473           NaN   NaN          NaN
# 1474           NaN   NaN          NaN
# 1475  27730.000000   NaN          NaN
# 1476           NaN   NaN          NaN
# 1477           NaN   NaN          NaN
#
# [1478 rows x 69 columns]

# %%
# cleaning the data
luxembourg_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
luxembourg_data = Data.clean_data(luxembourg_data, luxembourg_columns_to_drop)
luxembourg_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# 5                                       <NA>
# ..                                       ...
# 60                                  0.155717
# 61                                  0.119025
# 62                                  0.110341
# 63                                  0.109385
# 64                                      <NA>
#
# 0   Voice and Accountability: Number of Sources  \
# 1                                          <NA>
# 2                                          <NA>
# 3                                          <NA>
# 4                                          <NA>
# 5                                          <NA>
# ..                                          ...
# 60                                            7
# 61                                            7
# 62                                            9
# 63                                            9
# 64                                         <NA>
#
# 0   High-technology exports (% of manufactured exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                           6.573374
# 61                                           5.618945
# 62                                           6.074862
# 63                                           5.866256
# 64                                               <NA>
#
# 0   Export value index (2015 = 100)  \
# 1                              <NA>
# 2                              <NA>
# 3                              <NA>
# 4                              <NA>
# 5                              <NA>
# ..                              ...
# 60                        95.987389
# 61                        80.745161
# 62                        96.991194
# 63                             <NA>
# 64                             <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                           0.770106
# 61                                           0.931473
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                            2.97422
# 61                                           3.131646
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports (current US$)  \
# 1                                <NA>
# 2                                <NA>
# 3                                <NA>
# 4                                <NA>
# 5                                <NA>
# ..                                ...
# 60                        16451000000
# 61                        13839000000
# 62                        16800000000
# 63                        17274000000
# 64                               <NA>
#
# 0   Insurance and financial services (% of commercial service exports)  ...  \
# 1                                                <NA>                   ...
# 2                                                <NA>                   ...
# 3                                                <NA>                   ...
# 4                                                <NA>                   ...
# 5                                                <NA>                   ...
# ..                                                ...                   ...
# 60                                          58.710171                   ...
# 61                                          56.846301                   ...
# 62                                          56.139169                   ...
# 63                                          54.856269                   ...
# 64                                               <NA>                   ...
#
# 0   Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                            0.99267
# 61                                            0.99257
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Literacy rate, adult male (% of males ages 15 and above)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Literacy rate, youth (ages 15-24), gender parity index (GPI)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Forest area (% of land area)  \
# 1                           <NA>
# 2                           <NA>
# 3                           <NA>
# 4                           <NA>
# 5                           <NA>
# ..                           ...
# 60                     34.453827
# 61                     34.453827
# 62                     34.453827
# 63                          <NA>
# 64                          <NA>
#
# 0   Urban land area where elevation is below 5 meters (sq. km)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Land under cereal production (hectares)  \
# 1                                      <NA>
# 2                                      <NA>
# 3                                      <NA>
# 4                                      <NA>
# 5                                      <NA>
# ..                                      ...
# 60                                    27390
# 61                                    25490
# 62                                    26310
# 63                                    27730
# 64                                     <NA>
#
# 0   Agricultural land (% of land area)  Agricultural machinery, tractors
# 1                                 <NA>                              <NA>
# 2                                 <NA>                              <NA>
# 3                                 <NA>                              <NA>
# 4                                 <NA>                              <NA>
# 5                                 <NA>                              <NA>
# ..                                 ...                               ...
# 60                           51.114408                              <NA>
# 61                           51.325715                              <NA>
# 62                           51.587906                              <NA>
# 63                                <NA>                              <NA>
# 64                                <NA>                              <NA>
#
# [64 rows x 1479 columns]

# %%
# selecting and modifying the data
luxembourg_data["Year"]=luxembourg_data["Year"].astype(int)
luxembourg_data = luxembourg_data.tail(30)
luxembourg_data
# Out:
# 0   Year  \
# 35  1994
# 36  1995
# 37  1996
# 38  1997
# 39  1998
# 40  1999
# 41  2000
# 42  2001
# 43  2002
# 44  2003
# 45  2004
# 46  2005
# 47  2006
# 48  2007
# 49  2008
# 50  2009
# 51  2010
# 52  2011
# 53  2012
# 54  2013
# 55  2014
# 56  2015
# 57  2016
# 58  2017
# 59  2018
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 35                                      <NA>
# 36                                      <NA>
# 37                                  0.242733
# 38                                      <NA>
# 39                                  0.258143
# 40                                      <NA>
# 41                                  0.241134
# 42                                      <NA>
# 43                                  0.237351
# 44                                  0.232991
# 45                                  0.228559
# 46                                  0.231447
# 47                                  0.178238
# 48                                  0.175854
# 49                                  0.169332
# 50                                  0.166748
# 51                                  0.163703
# 52                                  0.161986
# 53                                  0.157095
# 54                                  0.151881
# 55                                  0.172793
# 56                                  0.169729
# 57                                  0.159271
# 58                                  0.161407
# 59                                  0.164489
# 60                                  0.155717
# 61                                  0.119025
# 62                                  0.110341
# 63                                  0.109385
# 64                                      <NA>
#
# 0   Voice and Accountability: Number of Sources  \
# 35                                         <NA>
# 36                                         <NA>
# 37                                            5
# 38                                         <NA>
# 39                                            5
# 40                                         <NA>
# 41                                            6
# 42                                         <NA>
# 43                                            5
# 44                                            6
# 45                                            6
# 46                                            6
# 47                                            7
# 48                                            7
# 49                                            8
# 50                                            9
# 51                                            9
# 52                                            9
# 53                                            9
# 54                                            9
# 55                                            7
# 56                                            7
# 57                                            8
# 58                                            8
# 59                                            8
# 60                                            7
# 61                                            7
# 62                                            9
# 63                                            9
# 64                                         <NA>
#
# 0   High-technology exports (% of manufactured exports)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                          10.709934
# 49                                           8.010869
# 50                                          10.319885
# 51                                           8.776427
# 52                                           9.046389
# 53                                           8.680391
# 54                                           6.843395
# 55                                           5.972498
# 56                                           7.106326
# 57                                           7.967048
# 58                                            6.96873
# 59                                           6.973219
# 60                                           6.573374
# 61                                           5.618945
# 62                                           6.074862
# 63                                           5.866256
# 64                                               <NA>
#
# 0   Export value index (2015 = 100)  \
# 35                             <NA>
# 36                        45.219681
# 37                         42.07023
# 38                        40.837731
# 39                         46.22253
# 40                        47.905941
# 41                        48.760779
# 42                        56.938752
# 43                        59.596027
# 44                        77.582792
# 45                        94.810051
# 46                       109.673789
# 47                       133.630008
# 48                       130.638469
# 49                       149.914853
# 50                       124.502759
# 51                       115.223984
# 52                       121.746082
# 53                       109.884926
# 54                       107.725044
# 55                       111.434452
# 56                            100.0
# 57                        92.163258
# 58                        91.957511
# 59                        95.757994
# 60                        95.987389
# 61                        80.745161
# 62                        96.991194
# 63                             <NA>
# 64                             <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                           1.009115
# 39                                           0.994721
# 40                                           0.787256
# 41                                           0.527199
# 42                                           0.672763
# 43                                           0.536878
# 44                                           0.481531
# 45                                           0.385936
# 46                                           0.333931
# 47                                           0.301882
# 48                                           0.330143
# 49                                           0.359915
# 50                                           0.502475
# 51                                           0.644045
# 52                                           1.072481
# 53                                           1.192471
# 54                                           0.675077
# 55                                           0.841104
# 56                                           0.909067
# 57                                             0.7853
# 58                                           0.893856
# 59                                            0.99894
# 60                                           0.770106
# 61                                           0.931473
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                           1.451019
# 39                                           1.055828
# 40                                           0.812649
# 41                                           0.964388
# 42                                           0.902078
# 43                                           1.019525
# 44                                           0.906656
# 45                                           1.254574
# 46                                           1.762508
# 47                                           2.473121
# 48                                           3.471788
# 49                                           2.714648
# 50                                           2.085808
# 51                                           3.526544
# 52                                           4.882338
# 53                                           5.090099
# 54                                           4.149627
# 55                                           2.421747
# 56                                           2.178024
# 57                                           2.335777
# 58                                           2.461344
# 59                                           2.813278
# 60                                            2.97422
# 61                                           3.131646
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports (current US$)  \
# 35                               <NA>
# 36                               <NA>
# 37                               <NA>
# 38                               <NA>
# 39                               <NA>
# 40                         8203000000
# 41                         8378000000
# 42                         9759000000
# 43                        10214000000
# 44                        13297000000
# 45                        16250000000
# 46                        19120000000
# 47                        22980000000
# 48                        22933000000
# 49                        25694000000
# 50                        21339000000
# 51                        19748000000
# 52                        20866000000
# 53                        18833000000
# 54                        18441000000
# 55                        19099000000
# 56                        17139000000
# 57                        15796000000
# 58                        15761000000
# 59                        16412000000
# 60                        16451000000
# 61                        13839000000
# 62                        16800000000
# 63                        17274000000
# 64                               <NA>
#
# 0   Insurance and financial services (% of commercial service exports)  ...  \
# 35                                               <NA>                   ...
# 36                                               <NA>                   ...
# 37                                               <NA>                   ...
# 38                                               <NA>                   ...
# 39                                               <NA>                   ...
# 40                                          66.809437                   ...
# 41                                          70.450612                   ...
# 42                                          68.079061                   ...
# 43                                          66.515863                   ...
# 44                                          64.079777                   ...
# 45                                          64.026642                   ...
# 46                                          67.229301                   ...
# 47                                          71.422987                   ...
# 48                                          73.242757                   ...
# 49                                           69.06119                   ...
# 50                                           66.55868                   ...
# 51                                          67.466536                   ...
# 52                                          65.808954                   ...
# 53                                          64.394054                   ...
# 54                                          63.856429                   ...
# 55                                          63.574679                   ...
# 56                                          63.602473                   ...
# 57                                          61.454004                   ...
# 58                                          62.096975                   ...
# 59                                          60.178955                   ...
# 60                                          58.710171                   ...
# 61                                          56.846301                   ...
# 62                                          56.139169                   ...
# 63                                          54.856269                   ...
# 64                                               <NA>                   ...
#
# 0   Learning poverty: Share of Male Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                           3.825619
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Learning poverty: Share of Female Children at the End-of-Primary age below minimum reading proficiency adjusted by Out-of-School Children (%)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                           2.031479
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                             1.0287
# 41                                            1.03481
# 42                                            1.03093
# 43                                            1.02813
# 44                                            1.02568
# 45                                            1.02372
# 46                                            1.02759
# 47                                            1.02146
# 48                                            1.01653
# 49                                            1.01804
# 50                                               <NA>
# 51                                            1.02115
# 52                                            1.02649
# 53                                            1.02053
# 54                                            1.01679
# 55                                            1.01379
# 56                                            1.02045
# 57                                             1.0161
# 58                                            1.00946
# 59                                            1.00028
# 60                                            0.99267
# 61                                            0.99257
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Literacy rate, adult male (% of males ages 15 and above)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Literacy rate, youth (ages 15-24), gender parity index (GPI)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Forest area (% of land area)  \
# 35                          <NA>
# 36                          <NA>
# 37                          <NA>
# 38                          <NA>
# 39                          <NA>
# 40                          <NA>
# 41                     33.676965
# 42                     33.754651
# 43                     33.832338
# 44                     33.910024
# 45                      33.98771
# 46                     34.065396
# 47                     34.143082
# 48                     34.220769
# 49                     34.298455
# 50                     34.376141
# 51                     34.453827
# 52                     34.453827
# 53                     34.453827
# 54                     34.453827
# 55                     34.453827
# 56                     34.453827
# 57                     34.453827
# 58                     34.453827
# 59                     34.453827
# 60                     34.453827
# 61                     34.453827
# 62                     34.453827
# 63                          <NA>
# 64                          <NA>
#
# 0   Urban land area where elevation is below 5 meters (sq. km)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                                  0
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                                  0
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Land under cereal production (hectares)  \
# 35                                     <NA>
# 36                                     <NA>
# 37                                     <NA>
# 38                                     <NA>
# 39                                     <NA>
# 40                                     <NA>
# 41                                    28680
# 42                                    28061
# 43                                    29408
# 44                                    28907
# 45                                    27981
# 46                                    28496
# 47                                    28849
# 48                                    28513
# 49                                    31233
# 50                                    30403
# 51                                    29711
# 52                                    28805
# 53                                    27782
# 54                                    29039
# 55                                    28399
# 56                                    29287
# 57                                    27855
# 58                                    27960
# 59                                    26300
# 60                                    27390
# 61                                    25490
# 62                                    26310
# 63                                    27730
# 64                                     <NA>
#
# 0   Agricultural land (% of land area)  Agricultural machinery, tractors
# 35                                <NA>                              <NA>
# 36                                <NA>                              <NA>
# 37                                <NA>                              <NA>
# 38                                <NA>                              <NA>
# 39                                <NA>                              <NA>
# 40                                <NA>                              <NA>
# 41                           49.719164                              7165
# 42                           49.719164                              7284
# 43                           49.719164                              7042
# 44                           49.719164                              6926
# 45                           49.719164                              6787
# 46                           50.107595                              6898
# 47                           50.107595                              6673
# 48                           50.884457                              6421
# 49                           50.884457                              6446
# 50                           50.767928                              <NA>
# 51                           50.899995                              <NA>
# 52                           50.989334                              <NA>
# 53                           51.047598                              <NA>
# 54                           50.837846                              <NA>
# 55                           50.880573                              <NA>
# 56                           50.989334                              <NA>
# 57                           50.748895                              <NA>
# 58                           50.945829                              <NA>
# 59                            51.10159                              <NA>
# 60                           51.114408                              <NA>
# 61                           51.325715                              <NA>
# 62                           51.587906                              <NA>
# 63                                <NA>                              <NA>
# 64                                <NA>                              <NA>
#
# [30 rows x 1479 columns]

# %%
# checking the number of null values in each column
luxembourg_data.isna().sum()
# Out:
# 0
# Year                                                                                          0
# Internally displaced persons, total displaced by conflict and violence (number of people)    30
# Voice and Accountability: Standard Error                                                      6
# Voice and Accountability: Number of Sources                                                   6
# High-technology exports (% of manufactured exports)                                          14
#                                                                                              ..
# Forest area (% of land area)                                                                  8
# Urban land area where elevation is below 5 meters (sq. km)                                   28
# Land under cereal production (hectares)                                                       7
# Agricultural land (% of land area)                                                            8
# Agricultural machinery, tractors                                                             21
# Length: 1479, dtype: int64

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = luxembourg_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Unemployment, male (% of male labor force) (modeled ILO estimate)', 0),
#  ('Women Business and the Law Index Score (scale 1-100)', 0),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, total (%) (modeled ILO estimate)', 0),
#  ('Employment to population ratio, 15+, female (%) (modeled ILO estimate)', 0),
#  ('Net migration', 0),
#  ('Unemployment, total (% of total labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, female (% of female labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force, total', 0),
#  ('Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, male (%) (modeled ILO estimate)', 0),
#  ('Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Labor force, female (% of total labor force)', 0),
#  ('Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Urban population (% of total population)', 1),
#  ('Rural population growth (annual %)', 1),
#  ('Population, male (% of total population)', 1),
#  ('Population, total', 1),
#  ('Age dependency ratio, young (% of working-age population)', 1),
#  ('Population ages 80 and above, male (% of male population)', 1),
#  ('Population ages 70-74, male (% of male population)', 1),
#  ('Population ages 65 and above, male (% of male population)', 1),
#  ('Population ages 65-69, male (% of male population)', 1),
#  ('Population ages 55-59, male (% of male population)', 1),
#  ('Population ages 45-49, male (% of male population)', 1),
#  ('Population ages 35-39, male (% of male population)', 1),
#  ('Population ages 25-29, male (% of male population)', 1),
#  ('Population ages 15-64 (% of total population)', 1),
#  ('Population ages 15-64, female (% of female population)', 1),
#  ('Population ages 10-14, male (% of male population)', 1),
#  ('Population ages 0-14 (% of total population)', 1),
#  ('Population ages 0-14, female (% of female population)', 1),
#  ('Taxes less subsidies on products (current US$)', 1),
#  ('GNI per capita, PPP (constant 2017 international $)', 1),
#  ('GNI per capita (constant 2015 US$)', 1),
#  ('GNI, PPP (current international $)', 1),
#  ('GNI: linked series (current LCU)', 1),
#  ('Gross domestic income (constant LCU)', 1),
#  ('GDP per capita (constant LCU)', 1),
#  ('GDP per capita (current US$)', 1),
#  ('GDP (constant LCU)', 1),
#  ('GDP (current LCU)', 1),
#  ('Discrepancy in expenditure estimate of GDP (constant LCU)', 1),
#  ('Inflation, GDP deflator: linked series (annual %)', 1),
#  ('External balance on goods and services (% of GDP)', 1),
#  ('Imports of goods and services (% of GDP)', 1),
#  ('Imports of goods and services (current LCU)', 1),
#  ('External balance on goods and services (current LCU)', 1),
#  ('Imports of goods and services (annual % growth)', 1),
#  ('Gross capital formation (% of GDP)', 1),
#  ('Gross capital formation (current LCU)', 1),
#  ('Changes in inventories (current US$)', 1),
#  ('Gross fixed capital formation (constant 2015 US$)', 1),
#  ('Exports of goods and services (constant 2015 US$)', 1),
#  ('Gross national expenditure (constant LCU)', 1),
#  ('Gross national expenditure deflator (base year varies by country)', 1),
#  ('Final consumption expenditure (constant 2015 US$)', 1),
#  ('Households and NPISHs Final consumption expenditure, PPP (constant 2017 international $)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (constant LCU)', 1),
#  ('Households and NPISHs Final consumption expenditure (current LCU)', 1),
#  ('General government final consumption expenditure (annual % growth)', 1),
#  ('Military expenditure (current USD)', 1),
#  ('Lower secondary school starting age (years)', 1),
#  ('External balance on goods and services (current US$)', 1),
#  ('Imports of goods and services (constant 2015 US$)', 1),
#  ('Gross capital formation (constant LCU)', 1),
#  ('Gross capital formation (current US$)', 1),
#  ('Gross fixed capital formation (% of GDP)', 1),
#  ('Gross fixed capital formation (current LCU)', 1),
#  ('Exports of goods and services (% of GDP)', 1),
#  ('Exports of goods and services (current LCU)', 1),
#  ('Gross national expenditure (constant 2015 US$)', 1),
#  ('Final consumption expenditure (% of GDP)', 1),
#  ('Final consumption expenditure (current LCU)', 1),
#  ('Households and NPISHs Final consumption expenditure, PPP (current international $)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (annual % growth)', 1),
#  ('Households and NPISHs Final consumption expenditure (current US$)', 1),
#  ('General government final consumption expenditure (constant 2015 US$)', 1),
#  ('Individuals using the Internet (% of population)', 1),
#  ('Net ODA provided, total (current US$)', 1),
#  ('Urban population growth (annual %)', 1),
#  ('Population, female (% of total population)', 1),
#  ('Age dependency ratio (% of working-age population)', 1),
#  ('Population ages 75-79, male (% of male population)', 1),
#  ('Population ages 65 and above (% of total population)', 1),
#  ('Population ages 65 and above, female (% of female population)', 1),
#  ('Population ages 60-64, male (% of male population)', 1),
#  ('Population ages 50-54, male (% of male population)', 1),
#  ('Population ages 40-44, male (% of male population)', 1),
#  ('Population ages 30-34, male (% of male population)', 1),
#  ('Population ages 20-24, male (% of male population)', 1),
#  ('Population ages 15-64, male (% of male population)', 1),
#  ('Population ages 15-19, male (% of male population)', 1),
#  ('Population ages 05-09, male (% of male population)', 1),
#  ('Population ages 0-14, male (% of male population)', 1),
#  ('Population ages 00-04, male (% of male population)', 1),
#  ('Gross capital formation (annual % growth)', 1),
#  ('Gross fixed capital formation (constant LCU)', 1),
#  ('Gross fixed capital formation (current US$)', 1),
#  ('Exports of goods and services (constant LCU)', 1),
#  ('Exports of goods and services (current US$)', 1),
#  ('Gross national expenditure (current LCU)', 1),
#  ('Final consumption expenditure (constant LCU)', 1),
#  ('Final consumption expenditure (current US$)', 1),
#  ('Households and NPISHs Final consumption expenditure per capita growth (annual %)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (constant 2015 US$)',
#   1),
#  ('General government final consumption expenditure (% of GDP)', 1),
#  ('General government final consumption expenditure (current LCU)', 1),
#  ('Military expenditure (% of GDP)', 1),
#  ('Fixed telephone subscriptions (per 100 people)', 1),
#  ('Consumer price index (2010 = 100)', 1),
#  ('Rural population (% of total population)', 1),
#  ('Population, female', 1),
#  ('Population growth (annual %)', 1),
#  ('Population ages 75-79, female (% of female population)', 1),
#  ('Population ages 65 and above, total', 1),
#  ('Population ages 65 and above, female', 1),
#  ('Population ages 60-64, female (% of female population)', 1),
#  ('Population ages 50-54, female (% of female population)', 1),
#  ('Population ages 40-44, female (% of female population)', 1),
#  ('Population ages 30-34, female (% of female population)', 1),
#  ('Population ages 20-24, female (% of female population)', 1),
#  ('Population ages 15-64, male', 1),
#  ('Population ages 15-19, female (% of female population)', 1),
#  ('Population ages 05-09, female (% of female population)', 1),
#  ('Population ages 0-14, male', 1),
#  ('Population ages 00-04, female (% of female population)', 1),
#  ('Part time employment, total (% of total employment)', 1),
#  ('Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, total (%) (national estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, female (%) (national estimate)',
#   1),
#  ('Employment in services (% of total employment) (modeled ILO estimate)', 1),
#  ('Employment in industry (% of total employment) (modeled ILO estimate)', 1),
#  ('Contributing family workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employers, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment to population ratio, ages 15-24, male (%) (national estimate)',
#   1),
#  ('Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Net ODA provided to the least developed countries (% of GNI)', 1),
#  ('Stocks traded, total value (% of GDP)', 1),
#  ('Market capitalization of listed domestic companies (current US$)', 1),
#  ('Inflation, consumer prices (annual %)', 1),
#  ('Stocks traded, turnover ratio of domestic shares (%)', 1),
#  ('Market capitalization of listed domestic companies (% of GDP)', 1),
#  ('Part time employment, female (% of total female employment)', 1),
#  ('Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, male (%) (national estimate)',
#   1),
#  ('Employment in services, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employers, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Employment to population ratio, ages 15-24, total (%) (national estimate)',
#   1),
#  ('Employment to population ratio, ages 15-24, female (%) (national estimate)',
#   1),
#  ('Immunization, DPT (% of children ages 12-23 months)', 1),
#  ('Secondary education, duration (years)', 1),
#  ('Primary education, duration (years)', 1),
#  ('PPP conversion factor, private consumption (LCU per international $)', 1),
#  ('DEC alternative conversion factor (LCU per US$)', 1),
#  ('GNI per capita, PPP (current international $)', 1),
#  ('GNI per capita (current LCU)', 1),
#  ('GNI (constant LCU)', 1),
#  ('GNI (current LCU)', 1),
#  ('Gross domestic savings (% of GDP)', 1),
#  ('GDP per capita growth (annual %)', 1),
#  ('GDP growth (annual %)', 1),
#  ('GDP (current US$)', 1),
#  ('Discrepancy in expenditure estimate of GDP (current LCU)', 1),
#  ('Inflation, GDP deflator (annual %)', 1),
#  ('Real effective exchange rate index (2010 = 100)', 1),
#  ('PPP conversion factor, GDP (LCU per international $)', 1),
#  ('Taxes less subsidies on products (current LCU)', 1),
#  ('Net primary income (Net income from abroad) (current US$)', 1),
#  ('GNI per capita growth (annual %)', 1),
#  ('GNI, PPP (constant 2017 international $)', 1),
#  ('GNI (constant 2015 US$)', 1),
#  ('GNI, Atlas method (current US$)', 1),
#  ('Gross domestic savings (current US$)', 1),
#  ('GDP per capita, PPP (current international $)', 1),
#  ('GDP per capita (current LCU)', 1),
#  ('GDP, PPP (current international $)', 1),
#  ('GDP: linked series (current LCU)', 1),
#  ('Gross value added at basic prices (GVA) (current US$)', 1),
#  ('GDP deflator (base year varies by country)', 1),
#  ('Exports as a capacity to import (constant LCU)', 1),
#  ('Trade (% of GDP)', 1),
#  ('Stocks traded, total value (current US$)', 1),
#  ('Urban population', 1),
#  ('Rural population', 1),
#  ('Population, male', 1),
#  ('Age dependency ratio, old (% of working-age population)', 1),
#  ('Population ages 80 and above, female (% of female population)', 1),
#  ('Population ages 70-74, female (% of female population)', 1),
#  ('Population ages 65 and above, male', 1),
#  ('Population ages 65-69, female (% of female population)', 1),
#  ('Population ages 55-59, female (% of female population)', 1),
#  ('Population ages 45-49, female (% of female population)', 1),
#  ('Population ages 35-39, female (% of female population)', 1),
#  ('Population ages 25-29, female (% of female population)', 1),
#  ('Population ages 15-64, total', 1),
#  ('Population ages 15-64, female', 1),
#  ('Population ages 10-14, female (% of female population)', 1),
#  ('Population ages 0-14, total', 1),
#  ('Population ages 0-14, female', 1),
#  ('Refugee population by country or territory of asylum', 1),
#  ('Unemployment, male (% of male labor force) (national estimate)', 1),
#  ('Price level ratio of PPP conversion factor (GDP) to market exchange rate',
#   1),
#  ('Terms of trade adjustment (constant LCU)', 1),
#  ('Taxes less subsidies on products (constant LCU)', 1),
#  ('Net primary income (Net income from abroad) (current LCU)', 1),
#  ('GNI per capita (constant LCU)', 1),
#  ('GNI per capita, Atlas method (current US$)', 1),
#  ('GNI growth (annual %)', 1),
#  ('GNI (current US$)', 1),
#  ('Gross domestic savings (current LCU)', 1),
#  ('GDP per capita, PPP (constant 2017 international $)', 1),
#  ('GDP per capita (constant 2015 US$)', 1),
#  ('GDP, PPP (constant 2017 international $)', 1),
#  ('GDP (constant 2015 US$)', 1),
#  ('Gross value added at basic prices (GVA) (current LCU)', 1),
#  ('GDP deflator: linked series (base year varies by country)', 1),
#  ('External balance on goods and services (constant LCU)', 1),
#  ('Imports of goods and services (constant LCU)', 1),
#  ('Imports of goods and services (current US$)', 1),
#  ('Gross capital formation (constant 2015 US$)', 1),
#  ('Changes in inventories (current LCU)', 1),
#  ('Gross fixed capital formation (annual % growth)', 1),
#  ('Exports of goods and services (annual % growth)', 1),
#  ('Gross national expenditure (% of GDP)', 1),
#  ('Gross national expenditure (current US$)', 1),
#  ('Final consumption expenditure (annual % growth)', 1),
#  ('Households and NPISHs final consumption expenditure (% of GDP)', 1),
#  ('Households and NPISHs Final consumption expenditure per capita (constant 2015 US$)',
#   1),
#  ('Households and NPISHs final consumption expenditure: linked series (current LCU)',
#   1),
#  ('General government final consumption expenditure (constant LCU)', 1),
#  ('General government final consumption expenditure (current US$)', 1),
#  ('Military expenditure (current LCU)', 1),
#  ('Fixed telephone subscriptions', 1),
#  ('Net ODA provided, total (constant 2021 US$)', 1),
#  ('Net ODA provided, to the least developed countries (current US$)', 1),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (national estimate)',
#   1),
#  ('Part time employment, male (% of total male employment)', 1),
#  ('Labor force participation rate, female (% of female population ages 15+) (national estimate)',
#   1),
#  ('Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Employment to population ratio, 15+, total (%) (national estimate)', 1),
#  ('Employment to population ratio, 15+, female (%) (national estimate)', 1),
#  ('Self-employed, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Listed domestic companies, total', 1),
#  ('Unemployment, total (% of total labor force) (national estimate)', 1),
#  ('Unemployment, female (% of female labor force) (national estimate)', 1),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (national estimate)',
#   1),
#  ('GDP per person employed (constant 2017 PPP $)', 1),
#  ('Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment to population ratio, 15+, male (%) (national estimate)', 1),
#  ('Self-employed, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Employers, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Immunization, measles (% of children ages 12-23 months)', 1),
#  ('Primary school starting age (years)', 1),
#  ('Tariff rate, applied, weighted mean, primary products (%)', 2),
#  ('Share of tariff lines with international peaks, primary products (%)', 2),
#  ('Tariff rate, applied, weighted mean, all products (%)', 2),
#  ('Share of tariff lines with international peaks, all products (%)', 2),
#  ('Tariff rate, applied, weighted mean, manufactured products (%)', 2),
#  ('Share of tariff lines with international peaks, manufactured products (%)',
#   2),
#  ('Life expectancy at birth, male (years)', 2),
#  ('Mortality rate, infant (per 1,000 live births)', 2),
#  ('Death rate, crude (per 1,000 people)', 2),
#  ('Adolescent fertility rate (births per 1,000 women ages 15-19)', 2),
#  ('Net secondary income (Net current transfers from abroad) (current LCU)', 2),
#  ('Total natural resources rents (% of GDP)', 2),
#  ('Gross value added at basic prices (GVA) (constant LCU)', 2),
#  ('Adjusted net national income per capita (annual % growth)', 2),
#  ('Adjusted net national income (constant 2015 US$)', 2),
#  ('Adjusted savings: energy depletion (% of GNI)', 2),
#  ('Adjusted savings: consumption of fixed capital (% of GNI)', 2),
#  ('Adjusted savings: carbon dioxide damage (% of GNI)', 2),
#  ('Services, value added (% of GDP)', 2),
#  ('Services, value added (current LCU)', 2),
#  ('Medium and high-tech manufacturing value added (% manufacturing value added)',
#   2),
#  ('Industry (including construction), value added (constant 2015 US$)', 2),
#  ('Manufacturing, value added (constant LCU)', 2),
#  ('Manufacturing, value added (current US$)', 2),
#  ('Agriculture, forestry, and fishing, value added (% of GDP)', 2),
#  ('Agriculture, forestry, and fishing, value added (current LCU)', 2),
#  ('Mobile cellular subscriptions (per 100 people)', 2),
#  ('Patent applications, nonresidents', 2),
#  ('Young people (ages 15-24) newly infected with HIV', 2),
#  ('Adults (ages 15-49) newly infected with HIV', 2),
#  ('Mortality rate, neonatal (per 1,000 live births)', 2),
#  ('Mortality rate, under-5, male (per 1,000 live births)', 2),
#  ("Women's share of population ages 15+ living with HIV (%)", 2),
#  ('Probability of dying among children ages 5-9 years (per 1,000)', 2),
#  ('Number of deaths ages 15-19 years', 2),
#  ('Military expenditure (% of general government expenditure)', 2),
#  ('Mobile cellular subscriptions', 2),
#  ('Air transport, registered carrier departures worldwide', 2),
#  ('Access to electricity (% of population)', 2),
#  ('Tariff rate, most favored nation, simple mean, primary products (%)', 2),
#  ('Tariff rate, most favored nation, simple mean, all products (%)', 2),
#  ('Tariff rate, most favored nation, simple mean, manufactured products (%)',
#   2),
#  ('Survival to age 65, female (% of cohort)', 2),
#  ('Life expectancy at birth, female (years)', 2),
#  ('Mortality rate, adult, male (per 1,000 male adults)', 2),
#  ('Expense (% of GDP)', 2),
#  ('Interest payments (% of expense)', 2),
#  ('Goods and services expense (current LCU)', 2),
#  ('Taxes on income, profits and capital gains (% of revenue)', 2),
#  ('Other taxes (% of revenue)', 2),
#  ('Taxes on goods and services (current LCU)', 2),
#  ('Revenue, excluding grants (current LCU)', 2),
#  ('Capture fisheries production (metric tons)', 2),
#  ('Medium and high-tech exports (% manufactured exports)', 2),
#  ('Tariff rate, most favored nation, weighted mean, primary products (%)', 2),
#  ('Tariff rate, applied, simple mean, primary products (%)', 2),
#  ('Tariff rate, most favored nation, weighted mean, all products (%)', 2),
#  ('Tariff rate, applied, simple mean, all products (%)', 2),
#  ('Tariff rate, most favored nation, weighted mean, manufactured products (%)',
#   2),
#  ('Tariff rate, applied, simple mean, manufactured products (%)', 2),
#  ('Sex ratio at birth (male births per female births)', 2),
#  ('Fertility rate, total (births per woman)', 2),
#  ('Mortality rate, infant, male (per 1,000 live births)', 2),
#  ('Mortality rate, adult, female (per 1,000 female adults)', 2),
#  ('Subsidies and other transfers (% of expense)', 2),
#  ('Other expense (% of expense)', 2),
#  ('Interest payments (current LCU)', 2),
#  ('Compensation of employees (current LCU)', 2),
#  ('Tax revenue (% of GDP)', 2),
#  ('Social contributions (current LCU)', 2),
#  ('Net lending (+) / net borrowing (-) (current LCU)', 2),
#  ('Total reserves (includes gold, current US$)', 2),
#  ('Access to electricity, urban (% of urban population)', 2),
#  ('Labor force with intermediate education, male (% of male working-age population with intermediate education)',
#   2),
#  ('Labor force with basic education, female (% of female working-age population with basic education)',
#   2),
#  ('Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)', 2),
#  ('Gini index', 2),
#  ('Income share held by lowest 10%', 2),
#  ('Income share held by fourth 20%', 2),
#  ('Personal remittances, received (% of GDP)', 2),
#  ('Subsidies and other transfers (current LCU)', 2),
#  ('Other expense (current LCU)', 2),
#  ('Goods and services expense (% of expense)', 2),
#  ('Taxes on income, profits and capital gains (% of total taxes)', 2),
#  ('Tax revenue (current LCU)', 2),
#  ('Taxes on goods and services (% of revenue)', 2),
#  ('Revenue, excluding grants (% of GDP)', 2),
#  ('Total reserves minus gold (current US$)', 2),
#  ('Labor force with basic education (% of total working-age population with basic education)',
#   2),
#  ('Labor force with advanced education, male (% of male working-age population with advanced education)',
#   2),
#  ('Poverty gap at $3.65 a day (2017 PPP) (%)', 2),
#  ('Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)', 2),
#  ('Income share held by highest 10%', 2),
#  ('Income share held by second 20%', 2),
#  ('Incidence of HIV, ages 15-24 (per 1,000 uninfected population ages 15-24)',
#   2),
#  ('Prevalence of HIV, female (% ages 15-24)', 2),
#  ('Prevalence of HIV, total (% of population ages 15-49)', 2),
#  ('Probability of dying among adolescents ages 10-14 years (per 1,000)', 2),
#  ('Number of under-five deaths', 2),
#  ('Number of deaths ages 20-24 years', 2),
#  ('Net secondary income (Net current transfers from abroad) (current US$)', 2),
#  ('Oil rents (% of GDP)', 2),
#  ('Natural gas rents (% of GDP)', 2),
#  ('Gross value added at basic prices (GVA) (constant 2015 US$)', 2),
#  ('Adjusted net national income per capita (constant 2015 US$)', 2),
#  ('Adjusted net national income (current US$)', 2),
#  ('Adjusted savings: natural resources depletion (% of GNI)', 2),
#  ('Adjusted savings: energy depletion (current US$)', 2),
#  ('Adjusted savings: consumption of fixed capital (current US$)', 2),
#  ('Adjusted savings: carbon dioxide damage (current US$)', 2),
#  ('Services, value added (constant LCU)', 2),
#  ('Services, value added (current US$)', 2),
#  ('Other manufacturing (% of value added in manufacturing)', 2),
#  ('Industry (including construction), value added (% of GDP)', 2),
#  ('Industry (including construction), value added (current LCU)', 2),
#  ('Forest rents (% of GDP)', 2),
#  ('Adjusted net national income (annual % growth)', 2),
#  ('Adjusted savings: particulate emission damage (current US$)', 2),
#  ('Adjusted savings: mineral depletion (current US$)', 2),
#  ('Adjusted savings: net forest depletion (current US$)', 2),
#  ('Adjusted savings: education expenditure (current US$)', 2),
#  ('Services, value added (constant 2015 US$)', 2),
#  ('Manufacturing, value added (% of GDP)', 2),
#  ('Manufacturing, value added (current LCU)', 2),
#  ('Agriculture, forestry, and fishing, value added (constant 2015 US$)', 2),
#  ('Expense (current LCU)', 2),
#  ('Interest payments (% of revenue)', 2),
#  ('Compensation of employees (% of expense)', 2),
#  ('Taxes on income, profits and capital gains (current LCU)', 2),
#  ('Other taxes (current LCU)', 2),
#  ('Social contributions (% of revenue)', 2),
#  ('Net lending (+) / net borrowing (-) (% of GDP)', 2),
#  ('Personal remittances, received (current US$)', 2),
#  ('Personal remittances, paid (current US$)', 2),
#  ('Intentional homicides (per 100,000 people)', 2),
#  ('Share of tariff lines with specific rates, primary products (%)', 2),
#  ('Share of tariff lines with specific rates, all products (%)', 2),
#  ('Share of tariff lines with specific rates, manufactured products (%)', 2),
#  ('Survival to age 65, male (% of cohort)', 2),
#  ('Life expectancy at birth, total (years)', 2),
#  ('Mortality rate, infant, female (per 1,000 live births)', 2),
#  ('Birth rate, crude (per 1,000 people)', 2),
#  ('Incidence of HIV, all (per 1,000 uninfected population)', 2),
#  ('Mortality rate, under-5, female (per 1,000 live births)', 2),
#  ('Probability of dying among youth ages 20-24 years (per 1,000)', 2),
#  ('Number of neonatal deaths', 2),
#  ('Number of infant deaths', 2),
#  ('Number of deaths ages 10-14 years', 2),
#  ('Mineral rents (% of GDP)', 2),
#  ('Coal rents (% of GDP)', 2),
#  ('Adjusted net national income per capita (current US$)', 2),
#  ('Adjusted savings: particulate emission damage (% of GNI)', 2),
#  ('Adjusted savings: mineral depletion (% of GNI)', 2),
#  ('Adjusted savings: net forest depletion (% of GNI)', 2),
#  ('Adjusted savings: education expenditure (% of GNI)', 2),
#  ('Machinery and transport equipment (% of value added in manufacturing)', 2),
#  ('Industry (including construction), value added (constant LCU)', 2),
#  ('Industry (including construction), value added (current US$)', 2),
#  ('Manufacturing, value added (constant 2015 US$)', 2),
#  ('Agriculture, forestry, and fishing, value added (constant LCU)', 2),
#  ('Agriculture, forestry, and fishing, value added (current US$)', 2),
#  ('Air transport, passengers carried', 2),
#  ('Patent applications, residents', 2),
#  ('Access to electricity, rural (% of rural population)', 2),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (national estimate)',
#   2),
#  ('Labor force with intermediate education, female (% of female working-age population with intermediate education)',
#   2),
#  ('Labor force participation rate, male (% of male population ages 15+) (national estimate)',
#   2),
#  ('Labor force with advanced education (% of total working-age population with advanced education)',
#   2),
#  ('Poverty gap at $2.15 a day (2017 PPP) (%)', 2),
#  ('Proportion of people living below 50 percent of median income (%)', 2),
#  ('Income share held by third 20%', 2),
#  ('Labor force with intermediate education (% of total working-age population with intermediate education)',
#   2),
#  ('Labor force participation rate, total (% of total population ages 15+) (national estimate)',
#   2),
#  ('Ratio of female to male labor force participation rate (%) (national estimate)',
#   2),
#  ('Labor force with basic education, male (% of male working-age population with basic education)',
#   2),
#  ('Labor force with advanced education, female (% of female working-age population with advanced education)',
#   2),
#  ('Poverty gap at $6.85 a day (2017 PPP) (%)', 2),
#  ('Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)', 2),
#  ('Income share held by lowest 20%', 2),
#  ('Income share held by highest 20%', 2),
#  ('Incidence of HIV, ages 15-49 (per 1,000 uninfected population ages 15-49)',
#   2),
#  ('Adults (ages 15+) and children (ages 0-14) newly infected with HIV', 2),
#  ('Prevalence of HIV, male (% ages 15-24)', 2),
#  ('Mortality rate, under-5 (per 1,000 live births)', 2),
#  ('Probability of dying among adolescents ages 15-19 years (per 1,000)', 2),
#  ('Number of deaths ages 5-9 years', 2),
#  ('Export value index (2015 = 100)', 3),
#  ('Chemicals (% of value added in manufacturing)', 3),
#  ('Agriculture, forestry, and fishing, value added (annual % growth)', 3),
#  ('Rail lines (total route-km)', 3),
#  ('School enrollment, secondary, female (% gross)', 3),
#  ('Armed forces personnel (% of total labor force)', 3),
#  ('Railways, passengers carried (million passenger-km)', 3),
#  ('Binding coverage, primary products (%)', 3),
#  ('Binding coverage, all products (%)', 3),
#  ('Binding coverage, manufactured products (%)', 3),
#  ('Armed forces personnel, total', 3),
#  ('Railways, goods transported (million ton-km)', 3),
#  ('Annual freshwater withdrawals, total (% of internal resources)', 3),
#  ('Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
#   3),
#  ('CO2 emissions (kg per PPP $ of GDP)', 3),
#  ('CO2 emissions (kt)', 3),
#  ('Taxes on goods and services (% value added of industry and services)', 3),
#  ('Renewable internal freshwater resources per capita (cubic meters)', 3),
#  ('Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
#   3),
#  ('Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)',
#   3),
#  ('Total greenhouse gas emissions (kt of CO2 equivalent)', 3),
#  ('Renewable energy consumption (% of total final energy consumption)', 3),
#  ('Renewable internal freshwater resources, total (billion cubic meters)', 3),
#  ('Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions (kt of CO2 equivalent)', 3),
#  ('Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (kg per 2017 PPP $ of GDP)', 3),
#  ('School enrollment, secondary, male (% gross)', 3),
#  ('School enrollment, primary (% gross)', 3),
#  ('Manufacturing, value added (annual % growth)', 3),
#  ('Food, beverages and tobacco (% of value added in manufacturing)', 3),
#  ('Industry (including construction), value added (annual % growth)', 3),
#  ('Annual freshwater withdrawals, total (billion cubic meters)', 3),
#  ('Nitrous oxide emissions (thousand metric tons of CO2 equivalent)', 3),
#  ('Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (metric tons per capita)', 3),
#  ('CO2 emissions (kg per 2015 US$ of GDP)', 3),
#  ('Import value index (2015 = 100)', 3),
#  ('Bound rate, simple mean, primary products (%)', 3),
#  ('Bound rate, simple mean, all products (%)', 3),
#  ('Bound rate, simple mean, manufactured products (%)', 3),
#  ('Government expenditure on education, total (% of government expenditure)',
#   3),
#  ('School enrollment, secondary (% gross)', 3),
#  ('Services, value added (annual % growth)', 3),
#  ('Average precipitation in depth (mm per year)', 3),
#  ('Secondary education, pupils', 3),
#  ('Primary education, pupils', 3),
#  ('International tourism, receipts for travel items (current US$)', 4),
#  ('Immunization, HepB3 (% of one-year-old children)', 4),
#  ('School enrollment, preprimary (% gross)', 4),
#  ('International tourism, number of arrivals', 4),
#  ('International tourism, expenditures for travel items (current US$)', 4),
#  ('Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
#   4),
#  ('Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
#   4),
#  ('Hospital beds (per 1,000 people)', 4),
#  ('Proportion of seats held by women in national parliaments (%)', 4),
#  ('School enrollment, secondary (gross), gender parity index (GPI)', 4),
#  ('Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)',
#   5),
#  ('Air transport, freight (million ton-km)', 5),
#  ('Compulsory education, duration (years)', 5),
#  ('Scientific and technical journal articles', 5),
#  ('Industry (including construction), value added per worker (constant 2015 US$)',
#   5),
#  ('Services, value added per worker (constant 2015 US$)', 5),
#  ('Voice and Accountability: Standard Error', 6),
#  ('Voice and Accountability: Number of Sources', 6),
#  ('Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#   6),
#  ('Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#   6),
#  ('Merchandise exports (current US$)', 6),
#  ('Insurance and financial services (% of commercial service exports)', 6),
#  ('Agricultural raw materials exports (% of merchandise exports)', 6),
#  ('Computer, communications and other services (% of commercial service imports)',
#   6),
#  ('Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#   6),
#  ('Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
#   6),
#  ('Merchandise imports from high-income economies (% of total merchandise imports)',
#   6),
#  ('Manufactures imports (% of merchandise imports)', 6),
#  ('Food imports (% of merchandise imports)', 6),
#  ('Merchandise trade (% of GDP)', 6),
#  ('Rule of Law: Percentile Rank', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Standard Error', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Number of Sources',
#   6),
#  ('Gross savings (% of GDP)', 6),
#  ('Government expenditure on education, total (% of GDP)', 6),
#  ('Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Travel services (% of commercial service exports)', 6),
#  ('Commercial service exports (current US$)', 6),
#  ('Merchandise exports by the reporting economy (current US$)', 6),
#  ('Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#   6),
#  ('Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#   6),
#  ('Ores and metals exports (% of merchandise exports)', 6),
#  ('Fuel exports (% of merchandise exports)', 6),
#  ('Transport services (% of commercial service imports)', 6),
#  ('Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#   6),
#  ('Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
#   6),
#  ('Merchandise imports from economies in the Arab World (% of total merchandise imports)',
#   6),
#  ('Government Effectiveness: Standard Error', 6),
#  ('Government Effectiveness: Number of Sources', 6),
#  ('Total reserves in months of imports', 6),
#  ('Voice and Accountability: Percentile Rank', 6),
#  ('Transport services (% of commercial service exports)', 6),
#  ('Computer, communications and other services (% of commercial service exports)',
#   6),
#  ('Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#   6),
#  ('Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#   6),
#  ('Merchandise exports to high-income economies (% of total merchandise exports)',
#   6),
#  ('Manufactures exports (% of merchandise exports)', 6),
#  ('Food exports (% of merchandise exports)', 6),
#  ('Commercial service imports (current US$)', 6),
#  ('Merchandise imports by the reporting economy (current US$)', 6),
#  ('Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
#   6),
#  ('Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#   6),
#  ('Ores and metals imports (% of merchandise imports)', 6),
#  ('Fuel imports (% of merchandise imports)', 6),
#  ('Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Unemployment with basic education, female (% of female labor force with basic education)',
#   6),
#  ('Net ODA provided, total (% of GNI)', 6),
#  ('Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Transport services (% of service exports, BoP)', 6),
#  ('Goods exports (BoP, current US$)', 6),
#  ('Communications, computer, etc. (% of service exports, BoP)', 6),
#  ('Net trade in goods and services (BoP, current US$)', 6),
#  ('Current account balance (BoP, current US$)', 6),
#  ('Charges for the use of intellectual property, payments (BoP, current US$)',
#   6),
#  ('Imports of goods and services (BoP, current US$)', 6),
#  ('Government Effectiveness: Percentile Rank', 6),
#  ('Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Control of Corruption: Estimate', 6),
#  ('Secondary income receipts (BoP, current US$)', 6),
#  ('Travel services (% of service exports, BoP)', 6),
#  ('Service exports (BoP, current US$)', 6),
#  ('Primary income receipts (BoP, current US$)', 6),
#  ('Net trade in goods (BoP, current US$)', 6),
#  ('Current account balance (% of GDP)', 6),
#  ('Imports of goods, services and primary income (BoP, current US$)', 6),
#  ('Insurance and financial services (% of service imports, BoP)', 6),
#  ('Trade in services (% of GDP)', 6),
#  ('Unemployment with basic education (% of total labor force with basic education)',
#   6),
#  ('Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Rule of Law: Standard Error', 6),
#  ('Rule of Law: Number of Sources', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Political Stability and Absence of Violence/Terrorism: Estimate', 6),
#  ('Gross savings (% of GNI)', 6),
#  ('Regulatory Quality: Standard Error', 6),
#  ('Regulatory Quality: Number of Sources', 6),
#  ('Rule of Law: Percentile Rank, Lower Bound of 90% Confidence Interval', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank', 6),
#  ('Gross savings (current US$)', 6),
#  ('Government Effectiveness: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Government Effectiveness: Estimate', 6),
#  ('Control of Corruption: Percentile Rank', 6),
#  ('Exports of goods, services and primary income (BoP, current US$)', 6),
#  ('Insurance and financial services (% of service exports, BoP)', 6),
#  ('ICT service exports (% of service exports, BoP)', 6),
#  ('Net primary income (BoP, current US$)', 6),
#  ('Travel services (% of service imports, BoP)', 6),
#  ('Service imports (BoP, current US$)', 6),
#  ('Primary income payments (BoP, current US$)', 6),
#  ('Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Voice and Accountability: Estimate', 6),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   6),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   6),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   6),
#  ('Travel services (% of commercial service imports)', 6),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   6),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   6),
#  ('Merchandise imports (current US$)', 6),
#  ('Insurance and financial services (% of commercial service imports)', 6),
#  ('Agricultural raw materials imports (% of merchandise imports)', 6),
#  ('International tourism, number of departures', 6),
#  ('Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Estimate', 6),
#  ('Regulatory Quality: Percentile Rank', 6),
#  ('Rule of Law: Percentile Rank, Upper Bound of 90% Confidence Interval', 6),
#  ('Rule of Law: Estimate', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Gross savings (current LCU)', 6),
#  ('Unemployment with intermediate education, female (% of female labor force with intermediate education)',
#   6),
#  ('Control of Corruption: Standard Error', 6),
#  ('Control of Corruption: Number of Sources', 6),
#  ('Charges for the use of intellectual property, receipts (BoP, current US$)',
#   6),
#  ('Exports of goods and services (BoP, current US$)', 6),
#  ('ICT service exports (BoP, current US$)', 6),
#  ('Net secondary income (BoP, current US$)', 6),
#  ('Secondary income, other sectors, payments (BoP, current US$)', 6),
#  ('Transport services (% of service imports, BoP)', 6),
#  ('Goods imports (BoP, current US$)', 6),
#  ('Communications, computer, etc. (% of service imports, BoP)', 6),
#  ('Unemployment with intermediate education (% of total labor force with intermediate education)',
#   6),
#  ('Unemployment with basic education, male (% of male labor force with basic education)',
#   6),
#  ('Physicians (per 1,000 people)', 6),
#  ('Adjusted net savings, excluding particulate emission damage (% of GNI)', 7),
#  ('Adjusted savings: gross savings (% of GNI)', 7),
#  ('People using safely managed sanitation services (% of population)', 7),
#  ('People practicing open defecation (% of population)', 7),
#  ('People using at least basic sanitation services (% of population)', 7),
#  ('People using at least basic drinking water services (% of population)', 7),
#  ('Secondary education, general pupils', 7),
#  ('Net investment in nonfinancial assets (current LCU)', 7),
#  ('Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#   7),
#  ('CO2 emissions from solid fuel consumption (kt)', 7),
#  ('CO2 emissions from liquid fuel consumption (% of total)', 7),
#  ('CO2 emissions from gaseous fuel consumption (% of total)', 7),
#  ('Unemployment with intermediate education, male (% of male labor force with intermediate education)',
#   7),
#  ('People using safely managed sanitation services, urban (% of urban population)',
#   7),
#  ('People practicing open defecation, urban (% of urban population)', 7),
#  ('Cereal yield (kg per hectare)', 7),
#  ('Crop production index (2014-2016 = 100)', 7),
#  ('Net investment in nonfinancial assets (% of GDP)', 7),
#  ('CO2 emissions from liquid fuel consumption (kt)', 7),
#  ('CO2 emissions from gaseous fuel consumption (kt)', 7),
#  ('Food production index (2014-2016 = 100)', 7),
#  ('Tuberculosis case detection rate (%, all forms)', 7),
#  ('Nurses and midwives (per 1,000 people)', 7),
#  ('People using safely managed drinking water services, rural (% of rural population)',
#   7),
#  ('Secondary education, vocational pupils', 7),
#  ('Secondary education, general pupils (% female)', 7),
#  ('Adjusted net savings, excluding particulate emission damage (current US$)',
#   7),
#  ('Adjusted net savings, including particulate emission damage (current US$)',
#   7),
#  ('Adjusted savings: net national savings (current US$)', 7),
#  ('CO2 emissions from solid fuel consumption (% of total)', 7),
#  ('Cereal production (metric tons)', 7),
#  ('People using at least basic sanitation services, urban (% of urban population)',
#   7),
#  ('People using safely managed drinking water services (% of population)', 7),
#  ('People using at least basic drinking water services, urban (% of urban population)',
#   7),
#  ('Secondary education, pupils (% female)', 7),
#  ('Adjusted net savings, including particulate emission damage (% of GNI)', 7),
#  ('Adjusted savings: net national savings (% of GNI)', 7),
#  ('Incidence of tuberculosis (per 100,000 people)', 7),
#  ('People using safely managed sanitation services, rural (% of rural population)',
#   7),
#  ('People practicing open defecation, rural (% of rural population)', 7),
#  ('Livestock production index (2014-2016 = 100)', 7),
#  ('People using at least basic sanitation services, rural (% of rural population)',
#   7),
#  ('People using safely managed drinking water services, urban (% of urban population)',
#   7),
#  ('People using at least basic drinking water services, rural (% of rural population)',
#   7),
#  ('Secondary education, vocational pupils (% female)', 7),
#  ('Land under cereal production (hectares)', 7),
#  ('Net barter terms of trade index (2015 = 100)', 8),
#  ('Fixed broadband subscriptions (per 100 people)', 8),
#  ('Children out of school, female (% of female primary school age)', 8),
#  ('School enrollment, primary, private (% of total primary)', 8),
#  ('Fixed broadband subscriptions', 8),
#  ('Energy use (kg of oil equivalent per capita)', 8),
#  ('Fossil fuel energy consumption (% of total)', 8),
#  ('GDP per unit of energy use (PPP $ per kg of oil equivalent)', 8),
#  ('Renewable electricity output (% of total electricity output)', 8),
#  ('Access to clean fuels and technologies for cooking (% of population)', 8),
#  ('Export volume index (2015 = 100)', 8),
#  ('ICT goods imports (% total goods imports)', 8),
#  ('Import unit value index (2015 = 100)', 8),
#  ('Claims on central government, etc. (% GDP)', 8),
#  ('Net domestic credit (current LCU)', 8),
#  ('Domestic credit to private sector by banks (% of GDP)', 8),
#  ('Population density (people per sq. km of land area)', 8),
#  ('Import volume index (2015 = 100)', 8),
#  ('Monetary Sector credit to private sector (% GDP)', 8),
#  ('Alternative and nuclear energy (% of total energy use)', 8),
#  ('Electricity production from oil sources (% of total)', 8),
#  ('Electricity production from hydroelectric sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, urban (% of urban population)',
#   8),
#  ('CO2 intensity (kg per kg of oil equivalent energy use)', 8),
#  ('Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)', 8),
#  ('GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)',
#   8),
#  ('Electricity production from renewable sources, excluding hydroelectric (kWh)',
#   8),
#  ('Electricity production from natural gas sources (% of total)', 8),
#  ('Electricity production from coal sources (% of total)', 8),
#  ('Energy intensity level of primary energy (MJ/$2017 PPP GDP)', 8),
#  ('Domestic private health expenditure per capita (current US$)', 8),
#  ('Out-of-pocket expenditure (% of current health expenditure)', 8),
#  ('Domestic general government health expenditure (% of GDP)', 8),
#  ('Net foreign assets (current LCU)', 8),
#  ('Combustible renewables and waste (% of total energy)', 8),
#  ('Energy imports, net (% of energy use)', 8),
#  ('Permanent cropland (% of land area)', 8),
#  ('Arable land (hectares)', 8),
#  ('Out-of-pocket expenditure per capita, PPP (current international $)', 8),
#  ('Domestic general government health expenditure per capita (current US$)',
#   8),
#  ('Current health expenditure per capita (current US$)', 8),
#  ('Maternal mortality ratio (national estimate, per 100,000 live births)', 8),
#  ('Adolescents out of school, female (% of female lower secondary school age)',
#   8),
#  ('School enrollment, secondary, private (% of total secondary)', 8),
#  ('Children out of school, primary, male', 8),
#  ('Domestic credit to private sector (% of GDP)', 8),
#  ('Surface area (sq. km)', 8),
#  ('Land area (sq. km)', 8),
#  ('Forest area (sq. km)', 8),
#  ('Arable land (% of land area)', 8),
#  ('Agricultural land (sq. km)', 8),
#  ('ICT goods exports (% of total goods exports)', 8),
#  ('Export unit value index (2015 = 100)', 8),
#  ('Antiretroviral therapy coverage (% of people living with HIV)', 8),
#  ('Adolescents out of school (% of lower secondary school age)', 8),
#  ('Children out of school (% of primary school age)', 8),
#  ('Children out of school, primary, female', 8),
#  ('School enrollment, primary, male (% gross)', 8),
#  ('Electricity production from renewable sources, excluding hydroelectric (% of total)',
#   8),
#  ('Electricity production from nuclear sources (% of total)', 8),
# ...
#   9),
#  ('Electric power consumption (kWh per capita)', 9),
#  ('Low-birthweight babies (% of births)', 9),
#  ('Portfolio equity, net inflows (BoP, current US$)', 9),
#  ('Portfolio investment, net (BoP, current US$)', 9),
#  ('Foreign direct investment, net outflows (BoP, current US$)', 9),
#  ('CO2 emissions from electricity and heat production, total (% of total fuel combustion)',
#   9),
#  ('Reserves and related items (BoP, current US$)', 9),
#  ('Foreign direct investment, net outflows (% of GDP)', 9),
#  ('Lifetime risk of maternal death (%)', 9),
#  ('School enrollment, tertiary (% gross)', 9),
#  ('School enrollment, primary (gross), gender parity index (GPI)', 9),
#  ('CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)',
#   9),
#  ('Foreign direct investment, net inflows (% of GDP)', 9),
#  ('Net capital account (BoP, current US$)', 9),
#  ('Foreign direct investment, net (BoP, current US$)', 9),
#  ('Prevalence of undernourishment (% of population)', 9),
#  ('Number of maternal deaths', 9),
#  ('Personal transfers, receipts (BoP, current US$)', 9),
#  ('Foreign direct investment, net inflows (BoP, current US$)', 9),
#  ('Net errors and omissions (BoP, current US$)', 9),
#  ('Net financial account (BoP, current US$)', 9),
#  ('School enrollment, secondary (% net)', 9),
#  ('School enrollment, primary and secondary (gross), gender parity index (GPI)',
#   9),
#  ('Share of youth not in education, employment or training, total (% of youth population)',
#   10),
#  ('Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)',
#   10),
#  ('School enrollment, secondary, male (% net)', 10),
#  ('Researchers in R&D (per million people)', 10),
#  ('Suicide mortality rate (per 100,000 population)', 10),
#  ('Mortality rate attributed to unintentional poisoning (per 100,000 population)',
#   10),
#  ('Research and development expenditure (% of GDP)', 10),
#  ('Share of youth not in education, employment or training, female (% of female youth population)',
#   10),
#  ('Unemployment with advanced education, male (% of male labor force with advanced education)',
#   10),
#  ('Suicide mortality rate, female (per 100,000 female population)', 10),
#  ('Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)',
#   10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, female (%)',
#   10),
#  ('Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
#   10),
#  ('School enrollment, preprimary, female (% gross)', 10),
#  ('Net secondary income (Net current transfers from abroad) (constant LCU)',
#   10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)',
#   10),
#  ('Prevalence of anemia among non-pregnant women (% of women ages 15-49)', 10),
#  ('School enrollment, secondary, female (% net)', 10),
#  ('Pupil-teacher ratio, preprimary', 10),
#  ('Share of youth not in education, employment or training, male (% of male youth population)',
#   10),
#  ('Suicide mortality rate, male (per 100,000 male population)', 10),
#  ('Fertilizer consumption (kilograms per hectare of arable land)', 10),
#  ('Unemployment with advanced education, female (% of female labor force with advanced education)',
#   10),
#  ('Mortality caused by road traffic injury (per 100,000 population)', 10),
#  ('Prevalence of anemia among pregnant women (%)', 10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, male (%)',
#   10),
#  ('Prevalence of anemia among children (% of children ages 6-59 months)', 10),
#  ('School enrollment, preprimary, male (% gross)', 10),
#  ('International tourism, receipts (current US$)', 11),
#  ('International tourism, expenditures (current US$)', 11),
#  ('International tourism, receipts for passenger transport items (current US$)',
#   11),
#  ('Statistical performance indicators (SPI): Pillar 1 data use score (scale 0-100)',
#   11),
#  ('Nitrous oxide emissions (% change from 1990)', 11),
#  ('International tourism, receipts (% of total exports)', 11),
#  ('Methane emissions (% change from 1990)', 11),
#  ('Other greenhouse gas emissions (% change from 1990)', 11),
#  ('Primary education, teachers', 11),
#  ('Total greenhouse gas emissions (% change from 1990)', 11),
#  ('International tourism, expenditures (% of total imports)', 11),
#  ('International tourism, expenditures for passenger transport items (current US$)',
#   11),
#  ('Current education expenditure, secondary (% of total expenditure in secondary public institutions)',
#   11),
#  ('Statistical performance indicators (SPI): Pillar 3 data products score  (scale 0-100)',
#   12),
#  ('Commercial bank branches (per 100,000 adults)', 12),
#  ('Female share of employment in senior and middle management (%)', 12),
#  ('Over-age students, primary, female (% of female enrollment)', 12),
#  ('Automated teller machines (ATMs) (per 100,000 adults)', 12),
#  ('Risk of impoverishing expenditure for surgical care (% of people at risk)',
#   12),
#  ('Pupil-teacher ratio, secondary', 12),
#  ('Adjusted net enrollment rate, primary (% of primary school age children)',
#   12),
#  ('Over-age students, primary (% of enrollment)', 12),
#  ('School enrollment, primary (% net)', 12),
#  ('Primary education, pupils (% female)', 12),
#  ('Risk of catastrophic expenditure for surgical care (% of people at risk)',
#   12),
#  ('Primary education, teachers (% female)', 12),
#  ('Over-age students, primary, male (% of male enrollment)', 12),
#  ('S&P Global Equity Indices (annual % change)', 13),
#  ('High-technology exports (% of manufactured exports)', 14),
#  ('Adjusted net enrollment rate, primary, female (% of primary school age children)',
#   14),
#  ('School enrollment, primary, female (% net)', 14),
#  ('GHG net emissions/removals by LUCF (Mt of CO2 equivalent)', 14),
#  ('Adjusted net enrollment rate, primary, male (% of primary school age children)',
#   14),
#  ('School enrollment, primary, male (% net)', 14),
#  ('High-technology exports (current US$)', 14),
#  ('Secondary education, teachers', 14),
#  ('Secondary education, teachers (% female)', 15),
#  ('Pupil-teacher ratio, primary', 15),
#  ('Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
#   15),
#  ('Bank capital to assets ratio (%)', 15),
#  ('Agricultural nitrous oxide emissions (% of total)', 15),
#  ('Energy related methane emissions (% of total)', 15),
#  ('Nitrous oxide emissions in energy sector (% of total)', 15),
#  ('Agricultural methane emissions (% of total)', 15),
#  ('Primary government expenditures as a proportion of original approved budget (%)',
#   15),
#  ('Lower secondary completion rate, female (% of relevant age group)', 15),
#  ('Repeaters, primary, total (% of total enrollment)', 15),
#  ('Secondary education, teachers, female', 15),
#  ('Lower secondary completion rate, total (% of relevant age group)', 15),
#  ('Lower secondary completion rate, male (% of relevant age group)', 15),
#  ('Gross intake ratio in first grade of primary education, total (% of relevant age group)',
#   15),
#  ('Procedures to build a warehouse (number)', 16),
#  ('Tax payments (number)', 16),
#  ('Repeaters, primary, male (% of male enrollment)', 16),
#  ('Gross intake ratio in first grade of primary education, female (% of relevant age group)',
#   16),
#  ('Time required to build a warehouse (days)', 16),
#  ('Other taxes payable by businesses (% of commercial profits)', 16),
#  ('Time to prepare and pay taxes (hours)', 16),
#  ('Time required to start a business, male (days)', 16),
#  ('Cost of business start-up procedures, male (% of GNI per capita)', 16),
#  ('Time required to enforce a contract (days)', 16),
#  ('Total tax and contribution rate (% of profit)', 16),
#  ('Start-up procedures to register a business, male (number)', 16),
#  ('Time required to start a business, female (days)', 16),
#  ('Cost of business start-up procedures, female (% of GNI per capita)', 16),
#  ('Start-up procedures to register a business (number)', 16),
#  ('Cost of business start-up procedures (% of GNI per capita)', 16),
#  ('Time required to register property (days)', 16),
#  ('Public credit registry coverage (% of adults)', 16),
#  ('Private credit bureau coverage (% of adults)', 16),
#  ('Gross intake ratio in first grade of primary education, male (% of relevant age group)',
#   16),
#  ('Textiles and clothing (% of value added in manufacturing)', 16),
#  ('Technicians in R&D (per million people)', 16),
#  ('Repeaters, primary, female (% of female enrollment)', 16),
#  ('Profit tax (% of commercial profits)', 16),
#  ('Labor tax and contributions (% of commercial profits)', 16),
#  ('Start-up procedures to register a business, female (number)', 16),
#  ('Time required to start a business (days)', 16),
#  ('Procedures to register property (number)', 16),
#  ('Time to resolve insolvency (years)', 16),
#  ('School enrollment, tertiary (gross), gender parity index (GPI)', 17),
#  ('Intentional homicides, male (per 100,000 male)', 17),
#  ('Intentional homicides, female (per 100,000 female)', 17),
#  ('PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#   17),
#  ('School enrollment, tertiary, male (% gross)', 17),
#  ('School enrollment, tertiary, female (% gross)', 17),
#  ('Primary completion rate, male (% of relevant age group)', 18),
#  ('Bank nonperforming loans to total gross loans (%)', 18),
#  ('Current education expenditure, primary (% of total expenditure in primary public institutions)',
#   18),
#  ('Primary completion rate, total (% of relevant age group)', 18),
#  ('Government expenditure per student, secondary (% of GDP per capita)', 18),
#  ('Primary completion rate, female (% of relevant age group)', 18),
#  ('Secure Internet servers (per 1 million people)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-2 value (% of total)',
#   19),
#  ('Pump price for gasoline (US$ per liter)', 19),
#  ('PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)',
#   19),
#  ('External health expenditure (% of current health expenditure)', 19),
#  ('Proportion of population pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   19),
#  ('Proportion of population pushed further below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   19),
#  ('Pump price for diesel fuel (US$ per liter)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)',
#   19),
#  ('External health expenditure per capita, PPP (current international $)', 19),
#  ('Proportion of population pushed or further pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   19),
#  ('Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)',
#   19),
#  ('Proportion of population pushed further below the 60% median consumption poverty line by out-of-pocket health care expenditure (%)',
#   19),
#  ('Time required to get electricity (days)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)',
#   19),
#  ('Arms imports (SIPRI trend indicator values)', 19),
#  ('Secure Internet servers', 19),
#  ('Proportion of population pushed or further pushed below the 60% median consumption poverty line by out-of-pocket health expenditure (%)',
#   19),
#  ('Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)',
#   19),
#  ('Proportion of population pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   19),
#  ('External health expenditure per capita (current US$)', 19),
#  ('Proportion of population pushed or further pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   19),
#  ('Proportion of population pushed below the 60% median consumption poverty line by out-of-pocket health expenditure (%)',
#   19),
#  ('Proportion of population pushed further below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   19),
#  ('Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)',
#   20),
#  ('New business density (new registrations per 1,000 people ages 15-64)', 20),
#  ('Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)',
#   20),
#  ('New businesses registered (number)', 20),
#  ('Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)',
#   20),
#  ('Educational attainment, at least completed upper secondary, population 25+, male (%) (cumulative)',
#   20),
#  ('Educational attainment, at least completed short-cycle tertiary, population 25+, male (%) (cumulative)',
#   20),
#  ('Educational attainment, at least completed upper secondary, population 25+, female (%) (cumulative)',
#   20),
#  ('Current education expenditure, total (% of total expenditure in public institutions)',
#   21),
#  ('Agricultural machinery, tractors per 100 sq. km of arable land', 21),
#  ('Agricultural machinery, tractors', 21),
#  ('Tertiary education, academic staff (% female)', 22),
#  ('Net intake rate in grade 1 (% of official school-age population)', 22),
#  ('Persistence to grade 5, female (% of cohort)', 22),
#  ('Current education expenditure, tertiary (% of total expenditure in tertiary public institutions)',
#   22),
#  ('Persistence to grade 5, total (% of cohort)', 22),
#  ('Net intake rate in grade 1, male (% of official school-age population)',
#   22),
#  ('Persistence to grade 5, male (% of cohort)', 22),
#  ('Net intake rate in grade 1, female (% of official school-age population)',
#   22),
#  ('Prevalence of moderate or severe food insecurity in the population (%)',
#   23),
#  ('Logistics performance index: Ability to track and trace consignments (1=low to 5=high)',
#   23),
#  ('Logistics performance index: Ease of arranging competitively priced shipments (1=low to 5=high)',
#   23),
#  ('Prevalence of current tobacco use, females (% of female adults)', 23),
#  ('Pupil-teacher ratio, upper secondary', 23),
#  ('Logistics performance index: Frequency with which shipments reach consignee within scheduled or expected time (1=low to 5=high)',
#   23),
#  ('Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 2 data services score (scale 0-100)',
#   23),
#  ('Prevalence of severe food insecurity in the population (%)', 23),
#  ('Logistics performance index: Overall (1=low to 5=high)', 23),
#  ('Logistics performance index: Efficiency of customs clearance process (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 5 data infrastructure score (scale 0-100)',
#   23),
#  ('Depth of credit information index (0=low to 8=high)', 23),
#  ('Strength of legal rights index (0=weak to 12=strong)', 23),
#  ('UHC service coverage index', 23),
#  ('Terrestrial and marine protected areas (% of total territorial area)', 23),
#  ('Prevalence of current tobacco use, males (% of male adults)', 23),
#  ('Government expenditure per student, primary (% of GDP per capita)', 23),
#  ('Terrestrial protected areas (% of total land area)', 23),
#  ('Prevalence of current tobacco use (% of adults)', 23),
#  ('Logistics performance index: Competence and quality of logistics services (1=low to 5=high)',
#   23),
#  ('Statistical performance indicators (SPI): Pillar 4 data sources score (scale 0-100)',
#   23),
#  ('Statistical performance indicators (SPI): Overall score (scale 0-100)', 23),
#  ('Pupil-teacher ratio, lower secondary', 23),
#  ('Time to import, documentary compliance (hours)', 24),
#  ('Cost to export, border compliance (US$)', 24),
#  ('Cost to import, documentary compliance (US$)', 24),
#  ('Time to export, border compliance (hours)', 24),
#  ('Cost to import, border compliance (US$)', 24),
#  ('Cost to export, documentary compliance (US$)', 24),
#  ('Time to import, border compliance (hours)', 24),
#  ...]

# %%
# selecting the columns we want to analyse
selected_luxembourg_data = luxembourg_data[["Year","GDP growth (annual %)","GDP (constant 2015 US$)","Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_luxembourg_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_luxembourg_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_luxembourg_data
# Out:
# /tmp/ipykernel_106701/4063301294.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_luxembourg_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_106701/4063301294.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_luxembourg_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 35  1994                3.82092       30172289931.437901
# 36  1995                 1.4322          30604417464.514
# 37  1996               1.398074       31032290015.654701
# 38  1997               5.419833       32714188401.911301
# 39  1998               6.674512       34897700894.558197
# 40  1999               8.175182       37750651303.918297
# 41  2000                6.93813       40369840661.378502
# 42  2001               3.074355       41610952875.960503
# 43  2002               3.225417       42953079582.156601
# 44  2003               2.619379         44078183347.9207
# 45  2004               4.231891         45943524157.4617
# 46  2005               2.482875       47084244317.161301
# 47  2006               6.016715       49917169128.358597
# 48  2007               8.098668       53959794734.691399
# 49  2008              -0.300176       53797820276.327698
# 50  2009              -3.238954       52055333610.139801
# 51  2010               3.760414       54012829450.863297
# 52  2011               1.044299       54576884723.712097
# 53  2012               1.649902       55477349852.562897
# 54  2013                3.17179         57236975164.3722
# 55  2014               2.623086       58738350255.759697
# 56  2015               2.269784       60071584216.137497
# 57  2016                4.97819         63062062076.8293
# 58  2017               1.317188       63892707778.498802
# 59  2018               1.219322       64671765568.805801
# 60  2019               2.915848       66557495896.737801
# 61  2020               -0.90983       65951935965.676498
# 62  2021               7.168402       70679635853.890198
# 63  2022               1.380186         71655146215.6371
# 64  2023                   <NA>                     <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 35                                          <NA>
# 36                                          <NA>
# 37                                          <NA>
# 38                                          <NA>
# 39                                          <NA>
# 40                                          <NA>
# 41                                          <NA>
# 42                                          <NA>
# 43                           -70457147023.414307
# 44                           -21090958159.426102
# 45                             -52178664071.7164
# 46                           -48148171119.397903
# 47                           -74608712602.692307
# 48                          -133127727320.548004
# 49                             -37777017540.1968
# 50                            51720239188.356697
# 51                           -69243702043.196304
# 52                          -117269426410.317001
# 53                          -333562474941.080994
# 54                          -106982811091.199005
# 55                          -127940645440.186005
# 56                          -173572152442.359985
# 57                          -138872347802.540009
# 58                           -68327836956.364998
# 59                          -108492171832.820007
# 60                             -68670375447.7873
# 61                              1758039003.98455
# 62                             -207717027730.444
# 63                          -100555014600.313995
# 64                                          <NA>
#
# 0   Inflation, consumer prices (annual %)  \
# 35                               2.194765
# 36                               1.867694
# 37                                1.18386
# 38                               1.367513
# 39                                0.95857
# 40                               1.025197
# 41                               3.150767
# 42                               2.663821
# 43                               2.074086
# 44                                2.04984
# 45                               2.225679
# 46                               2.487697
# 47                               2.666315
# 48                               2.312459
# 49                                3.40188
# 50                               0.368042
# 51                               2.273679
# 52                               3.410683
# 53                               2.662842
# 54                                1.73404
# 55                               0.628544
# 56                               0.474743
# 57                               0.290833
# 58                                 1.7308
# 59                               1.528195
# 60                               1.743321
# 61                               0.819957
# 62                                2.52692
# 63                               6.336008
# 64                                   <NA>
#
# 0   Unemployment, total (% of total labor force) (national estimate)  \
# 35                                               3.48
# 36                                              2.918
# 37                                              3.286
# 38                                              2.527
# 39                                              2.763
# 40                                               2.39
# 41                                              2.345
# 42                                              1.805
# 43                                              2.621
# 44                                              3.675
# 45                                              5.113
# 46                                              4.488
# 47                                              4.731
# 48                                              4.065
# 49                                               5.06
# 50                                              5.122
# 51                                              4.361
# 52                                              4.902
# 53                                               5.14
# 54                                              5.848
# 55                                              5.852
# 56                                              6.669
# 57                                              6.291
# 58                                              5.522
# 59                                              5.585
# 60                                              5.595
# 61                                              6.773
# 62                                              5.247
# 63                                              4.585
# 64                                               <NA>
#
# 0   Population growth (annual %)  \
# 35                       1.36184
# 36                      1.404742
# 37                      1.361144
# 38                      1.253502
# 39                      1.243871
# 40                      1.350621
# 41                      1.344083
# 42                      1.190456
# 43                      1.047661
# 44                      1.215201
# 45                      1.421333
# 46                      1.530055
# 47                      1.595052
# 48                      1.544387
# 49                      1.787497
# 50                      1.851775
# 51                      1.825406
# 52                      2.222661
# 53                      2.401542
# 54                      2.311176
# 55                      2.356979
# 56                      2.359951
# 57                      2.155312
# 58                      2.430976
# 59                      1.928838
# 60                      1.962845
# 61                      1.666359
# 62                      1.518349
# 63                      2.016668
# 64                          <NA>
#
# 0   Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)
# 35                                           71.44976
# 36                                           71.44976
# 37                                           71.44976
# 38                                           71.44976
# 39                                           71.44976
# 40                                           71.44976
# 41                                           71.44976
# 42                                          71.018791
# 43                                           71.44976
# 44                                          65.444931
# 45                                           71.44976
# 46                                           71.44976
# 47                                           71.44976
# 48                                          77.885559
# 49                                           71.44976
# 50                                           71.44976
# 51                                           71.44976
# 52                                           71.44976
# 53                                           71.44976
# 54                                           71.44976
# 55                                           71.44976
# 56                                           71.44976
# 57                                           71.44976
# 58                                           71.44976
# 59                                           71.44976
# 60                                           71.44976
# 61                                           71.44976
# 62                                           71.44976
# 63                                           71.44976
# 64                                           71.44976

# %%
selected_luxembourg_data.shape
# Out:
# (30, 8)

# %%
selected_luxembourg_data.describe().T
# Out:
#                                                    count                mean  \
# 0
# Year                                                30.0              2008.5
# GDP growth (annual %)                               29.0             3.19509
# GDP (constant 2015 US$)                             29.0  50880213921.483955
# Portfolio investment, net (BoP, current US$)        21.0 -95481719351.602859
# Inflation, consumer prices (annual %)               29.0            2.005474
# Unemployment, total (% of total labor force) (n...  29.0            4.439966
# Population growth (annual %)                        29.0            1.712423
# Educational attainment, at least completed lowe...  30.0            71.44976
#
#                                                                    std  \
# 0
# Year                                                          8.803408
# GDP growth (annual %)                                         2.707674
# GDP (constant 2015 US$)                             12524271293.391617
# Portfolio investment, net (BoP, current US$)        79950865385.568695
# Inflation, consumer prices (annual %)                          1.20894
# Unemployment, total (% of total labor force) (n...            1.401682
# Population growth (annual %)                                  0.425942
# Educational attainment, at least completed lowe...            1.636472
#
#                                                                     min  \
# 0
# Year                                                             1994.0
# GDP growth (annual %)                                         -3.238954
# GDP (constant 2015 US$)                              30172289931.437901
# Portfolio investment, net (BoP, current US$)       -333562474941.080994
# Inflation, consumer prices (annual %)                          0.290833
# Unemployment, total (% of total labor force) (n...                1.805
# Population growth (annual %)                                   1.047661
# Educational attainment, at least completed lowe...            65.444931
#
#                                                                     25%  \
# 0
# Year                                                            2001.25
# GDP growth (annual %)                                          1.398074
# GDP (constant 2015 US$)                              41610952875.960503
# Portfolio investment, net (BoP, current US$)       -127940645440.186005
# Inflation, consumer prices (annual %)                           1.18386
# Unemployment, total (% of total labor force) (n...                3.286
# Population growth (annual %)                                   1.361144
# Educational attainment, at least completed lowe...             71.44976
#
#                                                                    50%  \
# 0
# Year                                                            2008.5
# GDP growth (annual %)                                         2.915848
# GDP (constant 2015 US$)                             53797820276.327698
# Portfolio investment, net (BoP, current US$)       -74608712602.692307
# Inflation, consumer prices (annual %)                          2.04984
# Unemployment, total (% of total labor force) (n...               4.731
# Population growth (annual %)                                  1.595052
# Educational attainment, at least completed lowe...            71.44976
#
#                                                                    75%  \
# 0
# Year                                                           2015.75
# GDP growth (annual %)                                          4.97819
# GDP (constant 2015 US$)                             60071584216.137497
# Portfolio investment, net (BoP, current US$)         -52178664071.7164
# Inflation, consumer prices (annual %)                          2.52692
# Unemployment, total (% of total labor force) (n...               5.522
# Population growth (annual %)                                  2.016668
# Educational attainment, at least completed lowe...            71.44976
#
#                                                                    max
# 0
# Year                                                            2023.0
# GDP growth (annual %)                                         8.175182
# GDP (constant 2015 US$)                               71655146215.6371
# Portfolio investment, net (BoP, current US$)        51720239188.356697
# Inflation, consumer prices (annual %)                         6.336008
# Unemployment, total (% of total labor force) (n...               6.773
# Population growth (annual %)                                  2.430976
# Educational attainment, at least completed lowe...           77.885559

# %%
import seaborn as sns

# %%
columns = list(selected_luxembourg_data.columns)
print(columns)

sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# <Axes: xlabel='GDP (constant 2015 US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_luxembourg_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_luxembourg_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
sns.pairplot(data = selected_luxembourg_data, height = 2)

# %%
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_luxembourg_data[ 'GDP growth (annual %)']
X = selected_luxembourg_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=42)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  6.3539196850414035
# mean_absolute_error :  2.4265100505924346
# The value of R^2 for the model is 33.36395904660012 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 10.143219510963727
# The value of slope for GDP (constant 2015 US$) is given by 4.060836593855169e-12
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -2.4698969717653148e-11
# The value of slope for Inflation, consumer prices (annual %) is given by -0.18510288420616955
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by 0.06533853358431453
# The value of slope for Population growth (annual %) is given by -5.607406968580333
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 0.0
