# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("us")
us_data = Data.read(filepath)
us_data
# Out:
#        Country Name Country Code  \
# 0     United States          USA
# 1     United States          USA
# 2     United States          USA
# 3     United States          USA
# 4     United States          USA
# ...             ...          ...
# 1481  United States          USA
# 1482  United States          USA
# 1483  United States          USA
# 1484  United States          USA
# 1485  United States          USA
#
#                                          Indicator Name        Indicator Code  \
# 0            Intentional homicides (per 100,000 people)        VC.IHR.PSRC.P5
# 1     Internally displaced persons, new displacement...           VC.IDP.NWDS
# 2     Voice and Accountability: Percentile Rank, Upp...      VA.PER.RNK.UPPER
# 3                    Voice and Accountability: Estimate                VA.EST
# 4                 High-technology exports (current US$)        TX.VAL.TECH.CD
# ...                                                 ...                   ...
# ...

# %%
# cleaning the data
us_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
us_data = Data.clean_data(us_data, us_columns_to_drop)
us_data
# Out:
# 0   Year  Intentional homicides (per 100,000 people)  \
# 1   1960                                        <NA>
# 2   1961                                        <NA>
# 3   1962                                        <NA>
# 4   1963                                        <NA>
# 5   1964                                        <NA>
# ..   ...                                         ...
# 59  2018                                    4.929848
# 60  2019                                    4.985947
# 61  2020                                    6.420751
# 62  2021                                    6.807466
# 63  2022                                        <NA>
#
# 0   Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# ...

# %%
# selecting and modifying the data
us_data["Year"]=us_data["Year"].astype(int)
us_data = us_data.tail(30)
us_data
# Out:
# 0   Year  Intentional homicides (per 100,000 people)  \
# 34  1993                                    9.477558
# 35  1994                                    8.893766
# 36  1995                                    8.132935
# 37  1996                                    7.303399
# 38  1997                                      6.6844
# 39  1998                                    6.153678
# 40  1999                                    5.559822
# 41  2000                                     5.51915
# 42  2001                                    6.667239
# 43  2002                                    5.628225
# 44  2003                                        <NA>
# 45  2004                                        <NA>
# 46  2005                                        <NA>
# 47  2006                                    5.774419
# 48  2007                                    5.657597
# 49  2008                                    5.386089
# 50  2009                                    4.991377
# ...

# %%
# checking the number of null values in each column
us_data.isna().sum()
# Out:
# 0
# Year                                                                                           0
# Intentional homicides (per 100,000 people)                                                     4
# Internally displaced persons, new displacement associated with disasters (number of cases)    16
# Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval              6
# Voice and Accountability: Estimate                                                             6
#                                                                                               ..
# Total tax and contribution rate (% of profit)                                                 23
# Number of visits or required meetings with tax officials (average for affected firms)         30
# Start-up procedures to register a business, male (number)                                     23
# Time required to start a business, female (days)                                              23
# ...

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = us_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Travel services (% of commercial service imports)', 0),
#  ('Merchandise imports (current US$)', 0),
#  ('Insurance and financial services (% of commercial service imports)', 0),
#  ('Agricultural raw materials imports (% of merchandise imports)', 0),
#  ('Urban population', 0),
#  ('Rural population', 0),
#  ('Population, male', 0),
#  ('Age dependency ratio, old (% of working-age population)', 0),
#  ('Population ages 80 and above, female (% of female population)', 0),
#  ('Population ages 70-74, female (% of female population)', 0),
#  ('Population ages 65 and above, male', 0),
#  ('Population ages 65-69, female (% of female population)', 0),
#  ('Population ages 55-59, female (% of female population)', 0),
#  ('Population ages 45-49, female (% of female population)', 0),
#  ('Population ages 35-39, female (% of female population)', 0),
#  ('Population ages 25-29, female (% of female population)', 0),
#  ('Population ages 15-64, total', 0),
# ...

# %%
# selecting the columns we want to analyse
selected_us_data = us_data[["Year","GDP growth (annual %)","GDP per capita (current US$)","Foreign direct investment, net outflows (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Taxes on income, profits and capital gains (current LCU)"]]
selected_us_data
# Out:
# 0   Year  GDP growth (annual %)  GDP per capita (current US$)  \
# 34  1993               2.751781                  26387.293734
# 35  1994               4.028793                  27694.853416
# 36  1995               2.684217                  28690.875701
# 37  1996               3.772565                  29967.712718
# 38  1997               4.447175                   31459.13898
# 39  1998               4.481394                  32853.676952
# 40  1999               4.794499                  34515.390227
# 41  2000               4.077159                  36329.956073
# 42  2001               0.954339                  37133.623113
# 43  2002               1.695943                  37997.759657
# 44  2003               2.796209                  39490.274956
# 45  2004               3.852553                  41724.631629
# 46  2005                3.48322                  44123.407068
# 47  2006               2.782811                   46302.00088
# ...

# %%
selected_us_data.shape
# Out:
# (30, 8)

# %%
selected_us_data.describe().T
# Out:
#                                                    count                 mean  \
# 0
# Year                                                30.0               2007.5
# GDP growth (annual %)                               30.0             2.459115
# GDP per capita (current US$)                        30.0         46998.681189
# Foreign direct investment, net outflows (BoP, c...  30.0  252435766666.666656
# Inflation, consumer prices (annual %)               30.0             2.490589
# Unemployment, total (% of total labor force) (n...  30.0             5.751933
# Population growth (annual %)                        30.0             0.872741
# Taxes on income, profits and capital gains (cur...  30.0      1402021170000.0
#
#                                                                     std  \
# 0
# Year                                                           8.803408
# GDP growth (annual %)                                          1.855378
# ...

# %%
import seaborn as sns

# %%
columns = list(selected_us_data.columns)
print(columns)

sns.scatterplot(x='GDP per capita (current US$)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP per capita (current US$)', 'Foreign direct investment, net outflows (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Taxes on income, profits and capital gains (current LCU)']
# <Axes: xlabel='GDP per capita (current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Foreign direct investment, net outflows (BoP, current US$)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Foreign direct investment, net outflows (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Taxes on income, profits and capital gains (current LCU)',y='GDP growth (annual %)',hue='Year',data=selected_us_data)
# Out:
# <Axes: xlabel='Taxes on income, profits and capital gains (current LCU)', ylabel='GDP growth (annual %)'>
