# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("vietnam")
vietnam_data = Data.read(filepath)
vietnam_data
# Out:
#      Country Name Country Code  \
# 0        Viet Nam          VNM
# 1        Viet Nam          VNM
# 2        Viet Nam          VNM
# 3        Viet Nam          VNM
# 4        Viet Nam          VNM
# ...           ...          ...
# 1473     Viet Nam          VNM
# 1474     Viet Nam          VNM
# 1475     Viet Nam          VNM
# 1476     Viet Nam          VNM
# 1477     Viet Nam          VNM
#
#                                          Indicator Name     Indicator Code  \
# 0     Internally displaced persons, total displaced ...        VC.IDP.TOCV
# 1              Voice and Accountability: Standard Error         VA.STD.ERR
# 2           Voice and Accountability: Number of Sources          VA.NO.SRC
# 3     High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS
# 4                       Export value index (2015 = 100)  TX.VAL.MRCH.XD.WD
# ...                                                 ...                ...
# 1473  Charges for the use of intellectual property, ...     BM.GSR.ROYL.CD
# 1474   Imports of goods and services (BoP, current US$)     BM.GSR.GNFS.CD
# 1475                      Cereal yield (kg per hectare)     AG.YLD.CREL.KG
# 1476            Crop production index (2014-2016 = 100)     AG.PRD.CROP.XD
# 1477                           Rural land area (sq. km)  AG.LND.TOTL.RU.K2
#
#       1960     1961     1962    1963     1964     1965  ...          2015  \
# 0      NaN      NaN      NaN     NaN      NaN      NaN  ...           NaN
# 1      NaN      NaN      NaN     NaN      NaN      NaN  ...  1.301289e-01
# 2      NaN      NaN      NaN     NaN      NaN      NaN  ...  1.100000e+01
# 3      NaN      NaN      NaN     NaN      NaN      NaN  ...  3.636831e+01
# 4      NaN      NaN      NaN     NaN      NaN      NaN  ...  1.000000e+02
# ...    ...      ...      ...     ...      ...      ...  ...           ...
# 1473   NaN      NaN      NaN     NaN      NaN      NaN  ...           NaN
# 1474   NaN      NaN      NaN     NaN      NaN      NaN  ...  1.706580e+11
# 1475   NaN  1856.40  1953.30  2070.9  1909.80  1898.40  ...  5.601200e+03
# 1476   NaN    14.54    15.46    15.4    15.63    15.37  ...  1.009800e+02
# 1477   NaN      NaN      NaN     NaN      NaN      NaN  ...  2.976267e+05
#
#               2016          2017          2018          2019          2020  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1     1.257415e-01  1.237170e-01  1.267790e-01  1.206971e-01  1.260253e-01
# 2     1.100000e+01  1.200000e+01  1.200000e+01  1.100000e+01  1.000000e+01
# 3     3.805575e+01  4.173807e+01  4.075012e+01  4.043340e+01  4.174008e+01
# 4     1.089570e+02  1.326716e+02  1.503713e+02  1.630631e+02  1.743927e+02
# ...            ...           ...           ...           ...           ...
# 1473           NaN           NaN           NaN           NaN           NaN
# 1474  1.822970e+11  2.213730e+11  2.456274e+11  2.616828e+11  2.698080e+11
# 1475  5.441000e+03  5.434400e+03  5.685400e+03  5.715800e+03  5.797300e+03
# 1476  9.963000e+01  1.015300e+02  1.047000e+02  1.054400e+02  1.060100e+02
# 1477           NaN           NaN           NaN           NaN           NaN
#
#               2021          2022  2023  Unnamed: 68
# 0              NaN           NaN   NaN          NaN
# 1     1.278834e-01  1.254373e-01   NaN          NaN
# 2     1.000000e+01  1.000000e+01   NaN          NaN
# 3     4.153961e+01  3.863281e+01   NaN          NaN
# 4     2.072811e+02           NaN   NaN          NaN
# ...            ...           ...   ...          ...
# 1473           NaN           NaN   NaN          NaN
# 1474  3.383270e+11  3.711110e+11   NaN          NaN
# 1475  5.947100e+03  5.905200e+03   NaN          NaN
# 1476  1.092400e+02  1.095500e+02   NaN          NaN
# 1477           NaN           NaN   NaN          NaN
#
# [1478 rows x 69 columns]

# %%
# cleaning the data
vietnam_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
vietnam_data = Data.clean_data(vietnam_data, vietnam_columns_to_drop)
vietnam_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# 5                                       <NA>
# ..                                       ...
# 60                                  0.120697
# 61                                  0.126025
# 62                                  0.127883
# 63                                  0.125437
# 64                                      <NA>
#
# 0   Voice and Accountability: Number of Sources  \
# 1                                          <NA>
# 2                                          <NA>
# 3                                          <NA>
# 4                                          <NA>
# 5                                          <NA>
# ..                                          ...
# 60                                           11
# 61                                           10
# 62                                           10
# 63                                           10
# 64                                         <NA>
#
# 0   High-technology exports (% of manufactured exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          40.433396
# 61                                          41.740077
# 62                                          41.539608
# 63                                          38.632807
# 64                                               <NA>
#
# 0   Export value index (2015 = 100)  \
# 1                              <NA>
# 2                              <NA>
# 3                              <NA>
# 4                              <NA>
# 5                              <NA>
# ..                              ...
# 60                       163.063094
# 61                       174.392708
# 62                       207.281059
# 63                             <NA>
# 64                             <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)  \
# 1                                            1.650943
# 2                                            0.872093
# 3                                            3.588556
# 4                                            0.926376
# 5                                                <NA>
# ..                                                ...
# 60                                           0.705903
# 61                                           0.679074
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                            0.004632
# 5                                                <NA>
# ..                                                ...
# 60                                           1.585503
# 61                                           1.608039
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports (current US$)  \
# 1                            86000000
# 2                            71000000
# 3                            33000000
# 4                            45000000
# 5                            28000000
# ..                                ...
# 60                       264268000000
# 61                       282629000000
# 62                       335978000000
# 63                       371288000000
# 64                               <NA>
#
# 0   Insurance and financial services (% of commercial service exports)  ...  \
# 1                                                <NA>                   ...
# 2                                                <NA>                   ...
# 3                                                <NA>                   ...
# 4                                                <NA>                   ...
# 5                                                <NA>                   ...
# ..                                                ...                   ...
# 60                                               <NA>                   ...
# 61                                               <NA>                   ...
# 62                                               <NA>                   ...
# 63                                               <NA>                   ...
# 64                                               <NA>                   ...
#
# 0   Grants, excluding technical cooperation (BoP, current US$)  \
# 1                                           191880000
# 2                                           163660000
# 3                                           172110000
# 4                                           222650000
# 5                                           232450000
# ..                                                ...
# 60                                          347060000
# 61                                          492110000
# 62                                          576900000
# 63                                          480280000
# 64                                               <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
# 5                                           <NA>
# ..                                           ...
# 60                                   -2997000000
# 61                                    1256000000
# 62                                    -281000000
# 63                                   -1512000000
# 64                                          <NA>
#
# 0   Net trade in goods and services (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                        19143247000
# 61                                        20421000000
# 62                                         1799000000
# 63                                        13093000000
# 64                                               <NA>
#
# 0   Current account balance (BoP, current US$)  \
# 1                                         <NA>
# 2                                         <NA>
# 3                                         <NA>
# 4                                         <NA>
# 5                                         <NA>
# ..                                         ...
# 60                               13101247000.0
# 61                               15060000000.0
# 62                               -4628000000.0
# 63                               -1074000000.0
# 64                                        <NA>
#
# 0   Foreign direct investment, net outflows (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          485000000
# 61                                          380000000
# 62                                          319000000
# 63                                         2674000000
# 64                                               <NA>
#
# 0   Charges for the use of intellectual property, payments (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Imports of goods and services (BoP, current US$)  \
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
# 5                                               <NA>
# ..                                               ...
# 60                                      261682753000
# 61                                      269808000000
# 62                                      338327000000
# 63                                      371111000000
# 64                                              <NA>
#
# 0   Cereal yield (kg per hectare)  Crop production index (2014-2016 = 100)  \
# 1                            <NA>                                     <NA>
# 2                          1856.4                                    14.54
# 3                          1953.3                                    15.46
# 4                          2070.9                                     15.4
# 5                          1909.8                                    15.63
# ..                            ...                                      ...
# 60                         5715.8                                   105.44
# 61                         5797.3                                   106.01
# 62                         5947.1                                   109.24
# 63                         5905.2                                   109.55
# 64                           <NA>                                     <NA>
#
# 0   Rural land area (sq. km)
# 1                       <NA>
# 2                       <NA>
# 3                       <NA>
# 4                       <NA>
# 5                       <NA>
# ..                       ...
# 60                      <NA>
# 61                      <NA>
# 62                      <NA>
# 63                      <NA>
# 64                      <NA>
#
# [64 rows x 1479 columns]

# %%
# selecting and modifying the data
vietnam_data["Year"]=vietnam_data["Year"].astype(int)
vietnam_data = vietnam_data.tail(35)
vietnam_data
interval = 5
vietnam_data=vietnam_data.iloc[::interval]
vietnam_data
# Out:
# 0   Year  \
# 30  1989
# 35  1994
# 40  1999
# 45  2004
# 50  2009
# 55  2014
# 60  2019
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                               <NA>
# 55                                               <NA>
# 60                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 30                                      <NA>
# 35                                      <NA>
# 40                                      <NA>
# 45                                  0.150908
# 50                                  0.115317
# 55                                  0.127796
# 60                                  0.120697
#
# 0   Voice and Accountability: Number of Sources  \
# 30                                         <NA>
# 35                                         <NA>
# 40                                         <NA>
# 45                                           11
# 50                                           15
# 55                                           12
# 60                                           11
#
# 0   High-technology exports (% of manufactured exports)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                          10.523358
# 55                                          32.054854
# 60                                          40.433396
#
# 0   Export value index (2015 = 100)  \
# 30                         1.203581
# 35                         2.507357
# 40                         7.121232
# 45                        16.342243
# 50                        35.230588
# 55                         92.68975
# 60                       163.063094
#
# 0   Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)  \
# 30                                           0.000485
# 35                                           0.009274
# 40                                           1.008312
# 45                                           0.975034
# 50                                           1.500467
# 55                                           1.041722
# 60                                           0.705903
#
# 0   Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)  \
# 30                                           0.511891
# 35                                           2.472704
# 40                                           1.376059
# 45                                           1.180791
# 50                                             1.5102
# 55                                           2.516987
# 60                                           1.585503
#
# 0   Merchandise exports (current US$)  \
# 30                         1946000000
# 35                         4054000000
# 40                        11541000000
# 45                        26485000000
# 50                        57096000000
# 55                       150217000000
# 60                       264268000000
#
# 0   Insurance and financial services (% of commercial service exports)  ...  \
# 30                                               <NA>                   ...
# 35                                               <NA>                   ...
# 40                                               <NA>                   ...
# 45                                               <NA>                   ...
# 50                                               <NA>                   ...
# 55                                               <NA>                   ...
# 60                                               <NA>                   ...
#
# 0   Grants, excluding technical cooperation (BoP, current US$)  \
# 30                                           44250000
# 35                                          443710000
# 40                                          263810000
# 45                                          401740000
# 50                                          613650000
# 55                                          535590000
# 60                                          347060000
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 30                                          <NA>
# 35                                          <NA>
# 40                                          <NA>
# 45                                          <NA>
# 50                                      71000000
# 55                                     -93000000
# 60                                   -2997000000
#
# 0   Net trade in goods and services (BoP, current US$)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                          425000000
# 45                                        -3159000000
# 50                                       -10028000000
# 55                                         8596000000
# 60                                        19143247000
#
# 0   Current account balance (BoP, current US$)  \
# 30                                        <NA>
# 35                                        <NA>
# 40                                1177000000.0
# 45                                -957000000.0
# 50                               -6608000000.0
# 55                                9359000000.0
# 60                               13101247000.0
#
# 0   Foreign direct investment, net outflows (BoP, current US$)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                          700000000
# 55                                         1150000000
# 60                                          485000000
#
# 0   Charges for the use of intellectual property, payments (BoP, current US$)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               <NA>
# 45                                               <NA>
# 50                                               <NA>
# 55                                               <NA>
# 60                                               <NA>
#
# 0   Imports of goods and services (BoP, current US$)  \
# 30                                              <NA>
# 35                                              <NA>
# 40                                       13608000000
# 45                                       33511000000
# 50                                       72890000000
# 55                                      152591000000
# 60                                      261682753000
#
# 0   Cereal yield (kg per hectare)  Crop production index (2014-2016 = 100)  \
# 30                         3089.2                                    32.04
# 35                         3458.7                                    40.75
# 40                         3971.2                                    55.85
# 45                         4690.9                                    70.93
# 50                         5080.3                                    80.85
# 55                         5577.8                                     99.4
# 60                         5715.8                                   105.44
#
# 0   Rural land area (sq. km)
# 30                      <NA>
# 35                      <NA>
# 40                      <NA>
# 45                      <NA>
# 50                      <NA>
# 55                      <NA>
# 60                      <NA>
#
# [7 rows x 1479 columns]

# %%
# checking the number of null values in each column
vietnam_data.isna().sum()
# Out:
# 0
# Year                                                                                         0
# Internally displaced persons, total displaced by conflict and violence (number of people)    7
# Voice and Accountability: Standard Error                                                     3
# Voice and Accountability: Number of Sources                                                  3
# High-technology exports (% of manufactured exports)                                          4
#                                                                                             ..
# Charges for the use of intellectual property, payments (BoP, current US$)                    7
# Imports of goods and services (BoP, current US$)                                             2
# Cereal yield (kg per hectare)                                                                0
# Crop production index (2014-2016 = 100)                                                      0
# Rural land area (sq. km)                                                                     7
# Length: 1479, dtype: int64

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = vietnam_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Export value index (2015 = 100)', 0),
#  ('Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#   0),
#  ('Merchandise exports (current US$)', 0),
#  ('Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from high-income economies (% of total merchandise imports)',
#   0),
#  ('Merchandise trade (% of GDP)', 0),
#  ('Urban population (% of total population)', 0),
#  ('Rural population growth (annual %)', 0),
#  ('Population, male (% of total population)', 0),
#  ('Population, total', 0),
#  ('Age dependency ratio, young (% of working-age population)', 0),
#  ('Population ages 80 and above, male (% of male population)', 0),
#  ('Population ages 70-74, male (% of male population)', 0),
#  ('Population ages 65 and above, male (% of male population)', 0),
#  ('Population ages 65-69, male (% of male population)', 0),
#  ('Population ages 55-59, male (% of male population)', 0),
#  ('Population ages 45-49, male (% of male population)', 0),
#  ('Population ages 35-39, male (% of male population)', 0),
#  ('Population ages 25-29, male (% of male population)', 0),
#  ('Population ages 15-64 (% of total population)', 0),
#  ('Population ages 15-64, female (% of female population)', 0),
#  ('Population ages 10-14, male (% of male population)', 0),
#  ('Population ages 0-14 (% of total population)', 0),
#  ('Population ages 0-14, female (% of female population)', 0),
#  ('Life expectancy at birth, male (years)', 0),
#  ('Mortality rate, infant (per 1,000 live births)', 0),
#  ('Death rate, crude (per 1,000 people)', 0),
#  ('Adolescent fertility rate (births per 1,000 women ages 15-19)', 0),
#  ('Refugee population by country or territory of origin', 0),
#  ('Mortality rate, neonatal (per 1,000 live births)', 0),
#  ('Mortality rate, under-5, male (per 1,000 live births)', 0),
#  ('Women Business and the Law Index Score (scale 1-100)', 0),
#  ('Lower secondary school starting age (years)', 0),
#  ('School enrollment, preprimary (% gross)', 0),
#  ('Exports of goods and services (constant LCU)', 0),
#  ('Exports of goods and services (current US$)', 0),
#  ('Fixed telephone subscriptions (per 100 people)', 0),
#  ('DEC alternative conversion factor (LCU per US$)', 0),
#  ('Net secondary income (Net current transfers from abroad) (current US$)', 0),
#  ('GNI per capita (current LCU)', 0),
#  ('GNI (current LCU)', 0),
#  ('Oil rents (% of GDP)', 0),
#  ('GDP per capita growth (annual %)', 0),
#  ('Natural gas rents (% of GDP)', 0),
#  ('GDP growth (annual %)', 0),
#  ('GDP (current US$)', 0),
#  ('Inflation, GDP deflator (annual %)', 0),
#  ('Adjusted net national income (current US$)', 0),
#  ('Adjusted savings: natural resources depletion (% of GNI)', 0),
#  ('Adjusted savings: energy depletion (current US$)', 0),
#  ('Adjusted savings: consumption of fixed capital (current US$)', 0),
#  ('Services, value added (constant LCU)', 0),
#  ('Services, value added (current US$)', 0),
#  ('Industry (including construction), value added (% of GDP)', 0),
#  ('Industry (including construction), value added (current LCU)', 0),
#  ('Manufacturing, value added (annual % growth)', 0),
#  ('Renewable internal freshwater resources, total (billion cubic meters)', 0),
#  ('Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
#   0),
#  ('Total fisheries production (metric tons)', 0),
#  ('Population in largest city', 0),
#  ('Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, France (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Germany (current US$)', 0),
#  ('Technical cooperation grants (BoP, current US$)', 0),
#  ('Food production index (2014-2016 = 100)', 0),
#  ('Permanent cropland (% of land area)', 0),
#  ('Arable land (hectares)', 0),
#  ('Fertilizer consumption (% of fertilizer production)', 0),
#  ('Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   0),
#  ('Import value index (2015 = 100)', 0),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   0),
#  ('Merchandise imports (current US$)', 0),
#  ('Urban population', 0),
#  ('Rural population', 0),
#  ('Population, male', 0),
#  ('Age dependency ratio, old (% of working-age population)', 0),
#  ('Population ages 80 and above, female (% of female population)', 0),
#  ('Population ages 70-74, female (% of female population)', 0),
#  ('Population ages 65 and above, male', 0),
#  ('Population ages 65-69, female (% of female population)', 0),
#  ('Population ages 55-59, female (% of female population)', 0),
#  ('Population ages 45-49, female (% of female population)', 0),
#  ('Population ages 35-39, female (% of female population)', 0),
#  ('Population ages 25-29, female (% of female population)', 0),
#  ('Population ages 15-64, total', 0),
#  ('Population ages 15-64, female', 0),
#  ('Population ages 10-14, female (% of female population)', 0),
#  ('Population ages 0-14, total', 0),
#  ('Population ages 0-14, female', 0),
#  ('Survival to age 65, male (% of cohort)', 0),
#  ('Life expectancy at birth, total (years)', 0),
#  ('Mortality rate, infant, female (per 1,000 live births)', 0),
#  ('Birth rate, crude (per 1,000 people)', 0),
#  ('Net primary income (Net income from abroad) (current US$)', 0),
#  ('GNI, Atlas method (current US$)', 0),
#  ('GDP per capita (current LCU)', 0),
#  ('Forest rents (% of GDP)', 0),
#  ('GDP deflator (base year varies by country)', 0),
#  ('Exports as a capacity to import (constant LCU)', 0),
#  ('Adjusted savings: mineral depletion (current US$)', 0),
#  ('Adjusted savings: net forest depletion (current US$)', 0),
#  ('Adjusted savings: education expenditure (current US$)', 0),
#  ('Services, value added (constant 2015 US$)', 0),
#  ('Industry (including construction), value added (annual % growth)', 0),
#  ('Agriculture, forestry, and fishing, value added (constant 2015 US$)', 0),
#  ('Trade (% of GDP)', 0),
#  ('Merchandise exports by the reporting economy (current US$)', 0),
#  ('Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies within region (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#   0),
#  ('Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
#   0),
#  ('Urban population growth (annual %)', 0),
#  ('Population, female (% of total population)', 0),
#  ('Age dependency ratio (% of working-age population)', 0),
#  ('Population ages 75-79, male (% of male population)', 0),
#  ('Population ages 65 and above (% of total population)', 0),
#  ('Population ages 65 and above, female (% of female population)', 0),
#  ('Population ages 60-64, male (% of male population)', 0),
#  ('Population ages 50-54, male (% of male population)', 0),
#  ('Population ages 40-44, male (% of male population)', 0),
#  ('Population ages 30-34, male (% of male population)', 0),
#  ('Population ages 20-24, male (% of male population)', 0),
#  ('Population ages 15-64, male (% of male population)', 0),
#  ('Population ages 15-19, male (% of male population)', 0),
#  ('Population ages 05-09, male (% of male population)', 0),
#  ('Population ages 0-14, male (% of male population)', 0),
#  ('Population ages 00-04, male (% of male population)', 0),
#  ('Survival to age 65, female (% of cohort)', 0),
#  ('Life expectancy at birth, female (years)', 0),
#  ('Mortality rate, adult, male (per 1,000 male adults)', 0),
#  ('External balance on goods and services (current US$)', 0),
#  ('Imports of goods and services (constant 2015 US$)', 0),
#  ('Gross capital formation (constant LCU)', 0),
#  ('Exports of goods and services (% of GDP)', 0),
#  ('Exports of goods and services (current LCU)', 0),
#  ('Mobile cellular subscriptions', 0),
#  ('Air transport, registered carrier departures worldwide', 0),
#  ('Immunization, DPT (% of children ages 12-23 months)', 0),
#  ('Number of under-five deaths', 0),
#  ('Secondary education, duration (years)', 0),
#  ('Primary education, teachers', 0),
#  ('School enrollment, primary (% gross)', 0),
#  ('Primary education, duration (years)', 0),
#  ('Agriculture, forestry, and fishing, value added (annual % growth)', 0),
#  ('External balance on goods and services (current LCU)', 0),
#  ('Exports of goods and services (constant 2015 US$)', 0),
#  ('Mobile cellular subscriptions (per 100 people)', 0),
#  ('Patent applications, nonresidents', 0),
#  ('Multilateral debt service (% of public and publicly guaranteed debt service)',
#   0),
#  ('Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)',
#   0),
#  ('Net official development assistance received (current US$)', 0),
#  ('Net official development assistance and official aid received (current US$)',
#   0),
#  ('Net official flows from UN agencies, UNFPA (current US$)', 0),
#  ('PPG, official creditors (NFL, US$)', 0),
#  ('Net financial flows, IDA (NFL, current US$)', 0),
#  ('Land under cereal production (hectares)', 0),
#  ('Agricultural land (% of land area)', 0),
#  ('Newborns protected against tetanus (%)', 0),
#  ('Annual freshwater withdrawals, total (billion cubic meters)', 0),
#  ('Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
#   0),
#  ('Aquaculture production (metric tons)', 0),
#  ('Population in urban agglomerations of more than 1 million', 0),
#  ('Renewable internal freshwater resources per capita (cubic meters)', 0),
#  ('Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
#   0),
#  ('Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)',
#   0),
#  ('Population in the largest city (% of urban population)', 0),
#  ('Net bilateral aid flows from DAC donors, European Union institutions (current US$)',
#   0),
#  ('Net bilateral aid flows from DAC donors, Australia (current US$)', 0),
#  ('Foreign direct investment, net inflows (BoP, current US$)', 0),
#  ('Livestock production index (2014-2016 = 100)', 0),
#  ('Average precipitation in depth (mm per year)', 0),
#  ('Arable land (hectares per person)', 0),
#  ('Fertilizer consumption (kilograms per hectare of arable land)', 0),
#  ('Multilateral debt service (TDS, current US$)', 0),
#  ('Debt service on external debt, total (TDS, current US$)', 0),
#  ('Net official development assistance received (constant 2021 US$)', 0),
#  ('Net official flows from UN agencies, UNICEF (current US$)', 0),
#  ('PPG, private creditors (NFL, US$)', 0),
#  ('Commercial banks and other lending (PPG + PNG) (NFL, current US$)', 0),
#  ('IFC, private nonguaranteed (NFL, US$)', 0),
#  ('Short-term debt (% of total external debt)', 0),
#  ('External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)',
#   0),
#  ('External debt stocks (% of GNI)', 0),
#  ('Immunization, measles (% of children ages 12-23 months)', 0),
#  ('Mortality rate, under-5 (per 1,000 live births)', 0),
#  ('Primary education, pupils', 0),
#  ('Primary school starting age (years)', 0),
#  ('Agriculture, forestry, and fishing, value added (constant LCU)', 0),
#  ('Agriculture, forestry, and fishing, value added (current US$)', 0),
#  ('Imports of goods and services (constant LCU)', 0),
#  ('Imports of goods and services (current US$)', 0),
#  ('Gross capital formation (constant 2015 US$)', 0),
#  ('Fixed telephone subscriptions', 0),
#  ('Air transport, passengers carried', 0),
#  ('Patent applications, residents', 0),
#  ('Public and publicly guaranteed debt service (% of GNI)', 0),
#  ('Total debt service (% of GNI)', 0),
#  ('Net ODA received per capita (current US$)', 0),
#  ('Net official development assistance and official aid received (constant 2021 US$)',
#   0),
#  ('Net official flows from UN agencies, UNDP (current US$)', 0),
#  ('Net financial flows, multilateral (NFL, current US$)', 0),
#  ('PPG, IDA (DOD, current US$)', 0),
#  ('External debt stocks, long-term (DOD, current US$)', 0),
#  ('Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#   0),
#  ('Merchandise exports to high-income economies (% of total merchandise exports)',
#   0),
#  ('Merchandise imports by the reporting economy (current US$)', 0),
#  ('Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#   0),
#  ('Rural population (% of total population)', 0),
#  ('Population, female', 0),
#  ('Population growth (annual %)', 0),
#  ('Sex ratio at birth (male births per female births)', 0),
#  ('Population ages 75-79, female (% of female population)', 0),
#  ('Population ages 65 and above, total', 0),
#  ('Population ages 65 and above, female', 0),
#  ('Population ages 60-64, female (% of female population)', 0),
#  ('Population ages 50-54, female (% of female population)', 0),
#  ('Population ages 40-44, female (% of female population)', 0),
#  ('Population ages 30-34, female (% of female population)', 0),
#  ('Population ages 20-24, female (% of female population)', 0),
#  ('Population ages 15-64, male', 0),
#  ('Population ages 15-19, female (% of female population)', 0),
#  ('Population ages 05-09, female (% of female population)', 0),
#  ('Population ages 0-14, male', 0),
#  ('Population ages 00-04, female (% of female population)', 0),
#  ('Fertility rate, total (births per woman)', 0),
#  ('Mortality rate, infant, male (per 1,000 live births)', 0),
#  ('Mortality rate, adult, female (per 1,000 female adults)', 0),
#  ('IMF repurchases and charges (TDS, current US$)', 0),
#  ('Net ODA received (% of GNI)', 0),
#  ('PPG, commercial banks (NFL, current US$)', 0),
#  ('Net financial flows, others (NFL, current US$)', 0),
#  ('Net financial flows, bilateral (NFL, current US$)', 0),
#  ('IBRD loans and IDA credits (DOD, current US$)', 0),
#  ('External debt stocks, total (DOD, current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Sweden (current US$)', 0),
#  ('Net migration', 0),
#  ('Net bilateral aid flows from DAC donors, Total (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Netherlands (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Italy (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Switzerland (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Austria (current US$)', 0),
#  ('Foreign direct investment, net inflows (% of GDP)', 0),
#  ('Surface area (sq. km)', 0),
#  ('Cereal production (metric tons)', 0),
#  ('Land area (sq. km)', 0),
#  ('Arable land (% of land area)', 0),
#  ('Agricultural land (sq. km)', 0),
#  ('Mortality rate, under-5, female (per 1,000 live births)', 0),
#  ('Number of neonatal deaths', 0),
#  ('Number of infant deaths', 0),
#  ('Official exchange rate (LCU per US$, period average)', 0),
#  ('Net secondary income (Net current transfers from abroad) (current LCU)', 0),
#  ('Gross domestic income (constant LCU)', 0),
#  ('Total natural resources rents (% of GDP)', 0),
#  ('GDP per capita (constant LCU)', 0),
#  ('GDP per capita (current US$)', 0),
#  ('GDP (constant LCU)', 0),
#  ('GDP (current LCU)', 0),
#  ('Adjusted savings: energy depletion (% of GNI)', 0),
#  ('Adjusted savings: consumption of fixed capital (% of GNI)', 0),
#  ('Services, value added (% of GDP)', 0),
#  ('Services, value added (current LCU)', 0),
#  ('Industry (including construction), value added (constant 2015 US$)', 0),
#  ('Manufacturing, value added (constant LCU)', 0),
#  ('Agriculture, forestry, and fishing, value added (% of GDP)', 0),
#  ('Agriculture, forestry, and fishing, value added (current LCU)', 0),
#  ('External balance on goods and services (% of GDP)', 0),
#  ('Imports of goods and services (% of GDP)', 0),
#  ('Imports of goods and services (current LCU)', 0),
#  ('Terms of trade adjustment (constant LCU)', 0),
#  ('Net primary income (Net income from abroad) (current LCU)', 0),
#  ('GNI per capita, Atlas method (current US$)', 0),
#  ('GNI (current US$)', 0),
#  ('GDP per capita (constant 2015 US$)', 0),
#  ('GDP (constant 2015 US$)', 0),
#  ('Mineral rents (% of GDP)', 0),
#  ('Coal rents (% of GDP)', 0),
#  ('Adjusted net national income per capita (current US$)', 0),
#  ('Adjusted savings: mineral depletion (% of GNI)', 0),
#  ('Adjusted savings: net forest depletion (% of GNI)', 0),
#  ('Adjusted savings: education expenditure (% of GNI)', 0),
#  ('Services, value added (annual % growth)', 0),
#  ('Industry (including construction), value added (constant LCU)', 0),
#  ('Industry (including construction), value added (current US$)', 0),
#  ('Manufacturing, value added (constant 2015 US$)', 0),
#  ('Annual freshwater withdrawals, total (% of internal resources)', 0),
#  ('Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
#   0),
#  ('Capture fisheries production (metric tons)', 0),
#  ('Population in urban agglomerations of more than 1 million (% of total population)',
#   0),
#  ('Population density (people per sq. km of land area)', 0),
#  ('External debt stocks, short-term (DOD, current US$)', 0),
#  ('Use of IMF credit (DOD, current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, United States (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Norway (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Japan (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Finland (current US$)', 0),
#  ('Net bilateral aid flows from DAC donors, Belgium (current US$)', 0),
#  ('Grants, excluding technical cooperation (BoP, current US$)', 0),
#  ('Cereal yield (kg per hectare)', 0),
#  ('Crop production index (2014-2016 = 100)', 0),
#  ('Tariff rate, applied, weighted mean, primary products (%)', 1),
#  ('Share of tariff lines with international peaks, primary products (%)', 1),
#  ('Tariff rate, applied, weighted mean, all products (%)', 1),
#  ('Share of tariff lines with international peaks, all products (%)', 1),
#  ('Tariff rate, applied, weighted mean, manufactured products (%)', 1),
#  ('Share of tariff lines with international peaks, manufactured products (%)',
#   1),
#  ('Unemployment, male (% of male labor force) (modeled ILO estimate)', 1),
#  ('Young people (ages 15-24) newly infected with HIV', 1),
#  ('Adults (ages 15-49) newly infected with HIV', 1),
#  ('Children (0-14) living with HIV', 1),
#  ("Women's share of population ages 15+ living with HIV (%)", 1),
#  ('Probability of dying among children ages 5-9 years (per 1,000)', 1),
#  ('Number of deaths ages 15-19 years', 1),
#  ('Secondary education, general pupils', 1),
#  ('Pupil-teacher ratio, primary', 1),
#  ('Gross capital formation (annual % growth)', 1),
#  ('Changes in inventories (constant LCU)', 1),
#  ('Gross fixed capital formation (constant LCU)', 1),
#  ('Final consumption expenditure (constant LCU)', 1),
#  ('Households and NPISHs Final consumption expenditure (constant 2015 US$)',
#   1),
#  ('Armed forces personnel, total', 1),
#  ('GNI per capita, PPP (current international $)', 1),
#  ('Adjusted savings: carbon dioxide damage (current US$)', 1),
#  ('Industry (including construction), value added per worker (constant 2015 US$)',
#   1),
#  ('CO2 emissions from electricity and heat production, total (% of total fuel combustion)',
#   1),
#  ('Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   1),
#  ('Methane emissions (kt of CO2 equivalent)', 1),
#  ('Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#   1),
#  ('CO2 emissions (kg per 2017 PPP $ of GDP)', 1),
#  ('CO2 emissions from liquid fuel consumption (kt)', 1),
#  ('CO2 emissions from gaseous fuel consumption (kt)', 1),
#  ('Net bilateral aid flows from DAC donors, New Zealand (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Ireland (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Canada (current US$)', 1),
#  ('Share of tariff lines with specific rates, primary products (%)', 1),
#  ('Share of tariff lines with specific rates, all products (%)', 1),
#  ('Share of tariff lines with specific rates, manufactured products (%)', 1),
#  ('PPP conversion factor, GDP (LCU per international $)', 1),
#  ('GDP per capita, PPP (current international $)', 1),
#  ('GDP, PPP (current international $)', 1),
#  ('GDP: linked series (current LCU)', 1),
#  ('Adjusted savings: particulate emission damage (current US$)', 1),
#  ('Merchandise imports from economies in the Arab World (% of total merchandise imports)',
#   1),
#  ('Tariff rate, most favored nation, simple mean, primary products (%)', 1),
#  ('Tariff rate, most favored nation, simple mean, all products (%)', 1),
#  ('Tariff rate, most favored nation, simple mean, manufactured products (%)',
#   1),
#  ('Gross national expenditure (constant 2015 US$)', 1),
#  ('General government final consumption expenditure (constant 2015 US$)', 1),
#  ('Individuals using the Internet (% of population)', 1),
#  ('Incidence of HIV, ages 15-24 (per 1,000 uninfected population ages 15-24)',
#   1),
#  ('Children (ages 0-14) newly infected with HIV', 1),
#  ('Prevalence of HIV, female (% ages 15-24)', 1),
#  ('Prevalence of HIV, total (% of population ages 15-49)', 1),
#  ('Probability of dying among adolescents ages 10-14 years (per 1,000)', 1),
#  ('Number of deaths ages 20-24 years', 1),
#  ('School enrollment, tertiary (% gross)', 1),
#  ('Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)',
#   1),
#  ('Imports of goods and services (annual % growth)', 1),
#  ('Gross fixed capital formation (constant 2015 US$)', 1),
#  ('Gross national expenditure (constant LCU)', 1),
#  ('Final consumption expenditure (constant 2015 US$)', 1),
#  ('Households and NPISHs Final consumption expenditure, PPP (constant 2017 international $)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (constant LCU)', 1),
#  ('Electricity production from renewable sources, excluding hydroelectric (kWh)',
#   1),
#  ('Electricity production from natural gas sources (% of total)', 1),
#  ('Electricity production from coal sources (% of total)', 1),
#  ('Net financial flows, RDB concessional (NFL, current US$)', 1),
#  ('Forest area (% of land area)', 1),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#   1),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, total (%) (national estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, female (%) (national estimate)',
#   1),
#  ('Employment in services (% of total employment) (modeled ILO estimate)', 1),
#  ('Employment in industry (% of total employment) (modeled ILO estimate)', 1),
#  ('Contributing family workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment to population ratio, 15+, total (%) (modeled ILO estimate)', 1),
#  ('Employment to population ratio, 15+, female (%) (modeled ILO estimate)', 1),
#  ('Self-employed, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employers, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Prevalence of underweight, weight for age (% of children under 5)', 1),
#  ('CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)',
#   1),
#  ('Nitrous oxide emissions (thousand metric tons of CO2 equivalent)', 1),
#  ('Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#   1),
#  ('Methane emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   1),
#  ('CO2 emissions from solid fuel consumption (% of total)', 1),
#  ('CO2 emissions (metric tons per capita)', 1),
#  ('CO2 emissions (kg per 2015 US$ of GDP)', 1),
#  ('CO2 emissions from manufacturing industries and construction (% of total fuel combustion)',
#   1),
#  ('Total greenhouse gas emissions (kt of CO2 equivalent)', 1),
#  ('CO2 emissions from solid fuel consumption (kt)', 1),
#  ('CO2 emissions from liquid fuel consumption (% of total)', 1),
#  ('CO2 emissions from gaseous fuel consumption (% of total)', 1),
#  ('Electric power consumption (kWh per capita)', 1),
#  ('Renewable energy consumption (% of total final energy consumption)', 1),
#  ('Electricity production from oil sources (% of total)', 1),
#  ('Electricity production from hydroelectric sources (% of total)', 1),
#  ('Net bilateral aid flows from DAC donors, Luxembourg (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, United Kingdom (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Denmark (current US$)', 1),
#  ('Labor force participation rate, male (% of male population ages 15+) (national estimate)',
#   1),
#  ('Labor force participation rate, female (% of female population ages 15+) (national estimate)',
#   1),
#  ('Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#   1),
#  ('Employment in services, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
#   1),
#  ('Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
#   1),
#  ('Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Electric power transmission and distribution losses (% of output)', 1),
#  ('Net official flows from UN agencies, IFAD (current US$)', 1),
#  ('Incidence of HIV, ages 15-49 (per 1,000 uninfected population ages 15-49)',
#   1),
#  ('Adults (ages 15+) and children (ages 0-14) newly infected with HIV', 1),
#  ('Prevalence of HIV, male (% ages 15-24)', 1),
#  ('Probability of dying among adolescents ages 15-19 years (per 1,000)', 1),
#  ('Number of deaths ages 5-9 years', 1),
#  ('Exports of goods and services (annual % growth)', 1),
#  ('Households and NPISHs Final consumption expenditure per capita (constant 2015 US$)',
#   1),
#  ('General government final consumption expenditure (constant LCU)', 1),
#  ('Arms imports (SIPRI trend indicator values)', 1),
#  ('Electricity production from renewable sources, excluding hydroelectric (% of total)',
#   1),
#  ('Electricity production from nuclear sources (% of total)', 1),
#  ('Electricity production from oil, gas and coal sources (% of total)', 1),
#  ('Medium and high-tech exports (% manufactured exports)', 1),
#  ('Tariff rate, most favored nation, weighted mean, primary products (%)', 1),
#  ('Tariff rate, applied, simple mean, primary products (%)', 1),
#  ('Tariff rate, most favored nation, weighted mean, all products (%)', 1),
#  ('Tariff rate, applied, simple mean, all products (%)', 1),
#  ('Tariff rate, most favored nation, weighted mean, manufactured products (%)',
#   1),
#  ('Tariff rate, applied, simple mean, manufactured products (%)', 1),
#  ('Labor force, female (% of total labor force)', 1),
#  ('Labor force participation rate, total (% of total population ages 15+) (national estimate)',
#   1),
#  ('Ratio of female to male labor force participation rate (%) (national estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#   1),
#  ('GDP per person employed (constant 2017 PPP $)', 1),
#  ('Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Employers, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
#   1),
#  ('Employment in agriculture (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Prevalence of wasting, weight for height (% of children under 5)', 1),
#  ('Prevalence of stunting, height for age (% of children under 5)', 1),
#  ('PPG, other private creditors (NFL, current US$)', 1),
#  ('Unemployment, total (% of total labor force) (modeled ILO estimate)', 1),
#  ('Unemployment, female (% of female labor force) (modeled ILO estimate)', 1),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   1),
#  ('Labor force, total', 1),
#  ('Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#   1),
#  ('Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Labor force participation rate for ages 15-24, male (%) (national estimate)',
#   1),
#  ('Employment in services, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employment to population ratio, 15+, male (%) (modeled ILO estimate)', 1),
#  ('Employers, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Forest area (sq. km)', 1),
#  ('Incidence of HIV, all (per 1,000 uninfected population)', 1),
#  ('Probability of dying among youth ages 20-24 years (per 1,000)', 1),
#  ('Number of deaths ages 10-14 years', 1),
#  ('GNI, PPP (current international $)', 1),
#  ('GNI: linked series (current LCU)', 1),
#  ('Inflation, GDP deflator: linked series (annual %)', 1),
#  ('Adjusted savings: carbon dioxide damage (% of GNI)', 1),
#  ('Medium and high-tech manufacturing value added (% manufacturing value added)',
#   1),
#  ('Price level ratio of PPP conversion factor (GDP) to market exchange rate',
#   1),
#  ('GDP per capita, PPP (constant 2017 international $)', 1),
#  ('GDP, PPP (constant 2017 international $)', 1),
#  ('GDP deflator: linked series (base year varies by country)', 1),
#  ('Adjusted savings: particulate emission damage (% of GNI)', 1),
#  ('Services, value added per worker (constant 2015 US$)', 1),
#  ('CO2 emissions from transport (% of total fuel combustion)', 1),
#  ('CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)',
#   1),
#  ('Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#   1),
#  ('CO2 emissions (kg per PPP $ of GDP)', 1),
#  ('CO2 emissions (kt)', 1),
#  ('Agricultural raw materials exports (% of merchandise exports)', 2),
#  ('Manufactures imports (% of merchandise imports)', 2),
#  ('Food imports (% of merchandise imports)', 2),
#  ('Pupil-teacher ratio, tertiary', 2),
#  ('School enrollment, primary, private (% of total primary)', 2),
#  ('Compulsory education, duration (years)', 2),
#  ('Gross fixed capital formation (current US$)', 2),
#  ('Gross national expenditure (current LCU)', 2),
#  ('Final consumption expenditure (current US$)', 2),
#  ('Households and NPISHs Final consumption expenditure per capita growth (annual %)',
#   2),
#  ('General government final consumption expenditure (% of GDP)', 2),
#  ('General government final consumption expenditure (current LCU)', 2),
#  ('Military expenditure (% of GDP)', 2),
#  ('Railways, goods transported (million ton-km)', 2),
#  ('PPP conversion factor, private consumption (LCU per international $)', 2),
#  ('Gross savings (% of GNI)', 2),
#  ('GNI (constant LCU)', 2),
#  ('Gross domestic savings (% of GDP)', 2),
#  ('Discrepancy in expenditure estimate of GDP (current LCU)', 2),
#  ('Adjusted net savings, excluding particulate emission damage (current US$)',
#   2),
#  ('Adjusted net national income per capita (constant 2015 US$)', 2),
#  ('Other manufacturing (% of value added in manufacturing)', 2),
#  ('Interest rate spread (lending rate minus deposit rate, %)', 2),
#  ('Inflation, consumer prices (annual %)', 2),
#  ('Broad money (% of GDP)', 2),
#  ('Net foreign assets (current LCU)', 2),
#  ('Total reserves minus gold (current US$)', 2),
#  ('Combustible renewables and waste (% of total energy)', 2),
#  ('Energy imports, net (% of energy use)', 2),
#  ('Secondary income receipts (BoP, current US$)', 2),
#  ('Service exports (BoP, current US$)', 2),
#  ('Primary income receipts (BoP, current US$)', 2),
#  ('Reserves and related items (BoP, current US$)', 2),
#  ('Net trade in goods (BoP, current US$)', 2),
#  ('Current account balance (% of GDP)', 2),
#  ('Imports of goods, services and primary income (BoP, current US$)', 2),
#  ('Trade in services (% of GDP)', 2),
#  ('Agricultural raw materials imports (% of merchandise imports)', 2),
#  ('Refugee population by country or territory of asylum', 2),
#  ('Unemployment, male (% of male labor force) (national estimate)', 2),
#  ('Gross savings (current US$)', 2),
#  ('GNI per capita growth (annual %)', 2),
#  ('GNI, PPP (constant 2017 international $)', 2),
#  ('GNI (constant 2015 US$)', 2),
#  ('Gross domestic savings (current US$)', 2),
#  ('Adjusted net savings, including particulate emission damage (current US$)',
#   2),
#  ('Adjusted net national income (annual % growth)', 2),
#  ('Adjusted savings: net national savings (current US$)', 2),
#  ('Textiles and clothing (% of value added in manufacturing)', 2),
#  ('Food, beverages and tobacco (% of value added in manufacturing)', 2),
#  ('Commercial service exports (current US$)', 2),
#  ('Ores and metals exports (% of merchandise exports)', 2),
#  ('Fuel exports (% of merchandise exports)', 2),
#  ('International tourism, number of arrivals', 2),
#  ('Gross capital formation (current US$)', 2),
#  ('Gross fixed capital formation (% of GDP)', 2),
#  ('Gross fixed capital formation (current LCU)', 2),
#  ('Final consumption expenditure (% of GDP)', 2),
#  ('Final consumption expenditure (current LCU)', 2),
#  ('Households and NPISHs Final consumption expenditure, PPP (current international $)',
#   2),
#  ('Households and NPISHs Final consumption expenditure (annual % growth)', 2),
#  ('Households and NPISHs Final consumption expenditure (current US$)', 2),
#  ('Armed forces personnel (% of total labor force)', 2),
#  ('Railways, passengers carried (million passenger-km)', 2),
#  ('Scientific and technical journal articles', 2),
#  ('School enrollment, preprimary, female (% gross)', 2),
#  ('School enrollment, primary (gross), gender parity index (GPI)', 2),
#  ('Literacy rate, youth female (% of females ages 15-24)', 2),
#  ('Gross capital formation (% of GDP)', 2),
#  ('Gross capital formation (current LCU)', 2),
#  ('Changes in inventories (current US$)', 2),
#  ('Gross national expenditure deflator (base year varies by country)', 2),
#  ('Households and NPISHs Final consumption expenditure (current LCU)', 2),
#  ('General government final consumption expenditure (annual % growth)', 2),
#  ('Military expenditure (current USD)', 2),
#  ('Rail lines (total route-km)', 2),
#  ('Air transport, freight (million ton-km)', 2),
#  ('CO2 intensity (kg per kg of oil equivalent energy use)', 2),
#  ('Total debt service (% of exports of goods, services and primary income)',
#   2),
#  ('Net ODA received (% of imports of goods, services and primary income)', 2),
#  ('Prevalence of severe wasting, weight for height (% of children under 5)',
#   2),
#  ('Domestic credit to private sector (% of GDP)', 2),
#  ('Deposit interest rate (%)', 2),
#  ('Broad money growth (annual %)', 2),
#  ('Claims on private sector (annual growth as % of broad money)', 2),
#  ('Total reserves (% of total external debt)', 2),
#  ('Real interest rate (%)', 2),
#  ('Broad money to total reserves ratio', 2),
#  ('Monetary Sector credit to private sector (% GDP)', 2),
#  ('Claims on central government (annual growth as % of broad money)', 2),
#  ('Total reserves (includes gold, current US$)', 2),
#  ('Alternative and nuclear energy (% of total energy use)', 2),
#  ('Access to electricity, urban (% of urban population)', 2),
#  ('Public and publicly guaranteed debt service (% of exports of goods, services and primary income)',
#   2),
#  ('Exports of goods and services (BoP, current US$)', 2),
#  ('Net secondary income (BoP, current US$)', 2),
#  ('Net errors and omissions (BoP, current US$)', 2),
#  ('Net financial account (BoP, current US$)', 2),
#  ('Goods imports (BoP, current US$)', 2),
#  ('Employment to population ratio, 15+, total (%) (national estimate)', 2),
#  ('Employment to population ratio, 15+, female (%) (national estimate)', 2),
#  ('Prevalence of overweight, weight for height (% of children under 5)', 2),
#  ('Energy use (kg of oil equivalent per capita)', 2),
#  ('Fossil fuel energy consumption (% of total)', 2),
#  ('Renewable electricity output (% of total electricity output)', 2),
#  ('Access to electricity (% of population)', 2),
#  ('Debt service (PPG and IMF only, % of exports of goods, services and primary income)',
#   2),
#  ('Portfolio investment, bonds (PPG + PNG) (NFL, current US$)', 2),
#  ('Primary education, teachers (% female)', 2),
#  ('School enrollment, primary, female (% gross)', 2),
#  ('School enrollment, preprimary, male (% gross)', 2),
#  ('Preprimary education, duration (years)', 2),
#  ('Changes in inventories (current LCU)', 2),
#  ('Gross fixed capital formation (annual % growth)', 2),
#  ('Gross national expenditure (% of GDP)', 2),
#  ('Gross national expenditure (current US$)', 2),
#  ('Final consumption expenditure (annual % growth)', 2),
#  ('Households and NPISHs final consumption expenditure (% of GDP)', 2),
#  ('Households and NPISHs final consumption expenditure: linked series (current LCU)',
#   2),
#  ('General government final consumption expenditure (current US$)', 2),
#  ('Military expenditure (current LCU)', 2),
#  ('Access to electricity, rural (% of rural population)', 2),
#  ('Net ODA received (% of gross capital formation)', 2),
#  ('Net financial flows, RDB nonconcessional (NFL, current US$)', 2),
#  ('PPG, bonds (NFL, current US$)', 2),
#  ('Short-term debt (% of total reserves)', 2),
#  ('Manufactures exports (% of merchandise exports)', 2),
#  ('Food exports (% of merchandise exports)', 2),
#  ('Commercial service imports (current US$)', 2),
#  ('Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
#   2),
#  ('Ores and metals imports (% of merchandise imports)', 2),
#  ('Fuel imports (% of merchandise imports)', 2),
#  ('Unemployment, total (% of total labor force) (national estimate)', 2),
#  ('Unemployment, female (% of female labor force) (national estimate)', 2),
#  ('Employment to population ratio, 15+, male (%) (national estimate)', 2),
#  ('Net financial flows, IMF nonconcessional (NFL, current US$)', 2),
#  ('Short-term debt (% of exports of goods, services and primary income)', 2),
#  ('Net bilateral aid flows from DAC donors, Spain (current US$)', 2),
#  ('Exports of goods, services and primary income (BoP, current US$)', 2),
#  ('Foreign direct investment, net (BoP, current US$)', 2),
#  ('Net primary income (BoP, current US$)', 2),
#  ('Service imports (BoP, current US$)', 2),
#  ('Primary income payments (BoP, current US$)', 2),
#  ('Proportion of seats held by women in national parliaments (%)', 2),
#  ('School enrollment, primary, male (% gross)', 2),
#  ('Gross savings (% of GDP)', 2),
#  ('GNI per capita, PPP (constant 2017 international $)', 2),
#  ('GNI per capita (constant 2015 US$)', 2),
#  ('Adjusted net savings, excluding particulate emission damage (% of GNI)', 2),
#  ('Adjusted net national income per capita (annual % growth)', 2),
#  ('Adjusted net national income (constant 2015 US$)', 2),
#  ('Adjusted savings: gross savings (% of GNI)', 2),
#  ('Chemicals (% of value added in manufacturing)', 2),
#  ('Gross savings (current LCU)', 2),
#  ('GNI per capita (constant LCU)', 2),
#  ('GNI growth (annual %)', 2),
#  ('Gross domestic savings (current LCU)', 2),
#  ('Adjusted net savings, including particulate emission damage (% of GNI)', 2),
#  ('Adjusted savings: net national savings (% of GNI)', 2),
#  ('Machinery and transport equipment (% of value added in manufacturing)', 2),
#  ('Claims on central government, etc. (% GDP)', 2),
#  ('Lending interest rate (%)', 2),
#  ('Consumer price index (2010 = 100)', 2),
#  ('Broad money (current LCU)', 2),
#  ('Net domestic credit (current LCU)', 2),
#  ('Total reserves in months of imports', 2),
#  ('Domestic credit to private sector by banks (% of GDP)', 2),
#  ('Goods exports (BoP, current US$)', 2),
#  ('Net trade in goods and services (BoP, current US$)', 2),
#  ('Current account balance (BoP, current US$)', 2),
#  ('Imports of goods and services (BoP, current US$)', 2),
#  ('Voice and Accountability: Standard Error', 3),
#  ('Voice and Accountability: Number of Sources', 3),
#  ('Net barter terms of trade index (2015 = 100)', 3),
#  ('International tourism, receipts (current US$)', 3),
#  ('People using safely managed sanitation services (% of population)', 3),
#  ('Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)',
#   3),
#  ('People practicing open defecation (% of population)', 3),
#  ('Maternal mortality ratio (modeled estimate, per 100,000 live births)', 3),
#  ('People using at least basic sanitation services (% of population)', 3),
#  ('Lifetime risk of maternal death (1 in: rate varies by country)', 3),
#  ('Incidence of malaria (per 1,000 population at risk)', 3),
#  ('Immunization, HepB3 (% of one-year-old children)', 3),
#  ('People using at least basic drinking water services (% of population)', 3),
#  ('Trained teachers in lower secondary education (% of total teachers)', 3),
#  ('Trained teachers in primary education (% of total teachers)', 3),
#  ('Literacy rate, youth total (% of people ages 15-24)', 3),
#  ('Container port traffic (TEU: 20 foot equivalent units)', 3),
#  ('Statistical performance indicators (SPI): Pillar 1 data use score (scale 0-100)',
#   3),
#  ('Statistical Capacity Score (Overall Average) (scale 0 - 100)', 3),
#  ('Start-up procedures to register a business, male (number)', 3),
#  ('Time required to start a business, female (days)', 3),
#  ('Cost of business start-up procedures, female (% of GNI per capita)', 3),
#  ('Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   3),
#  ('Rule of Law: Standard Error', 3),
#  ('Rule of Law: Number of Sources', 3),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   3),
#  ('Political Stability and Absence of Violence/Terrorism: Estimate', 3),
#  ('Private credit bureau coverage (% of adults)', 3),
#  ('Government Effectiveness: Percentile Rank', 3),
#  ('Other greenhouse gas emissions (% change from 1990)', 3),
#  ('Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   3),
#  ('Control of Corruption: Estimate', 3),
#  ('Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   3),
#  ('Voice and Accountability: Estimate', 3),
#  ('ICT goods exports (% of total goods exports)', 3),
#  ('Export unit value index (2015 = 100)', 3),
#  ('Prevalence of undernourishment (% of population)', 3),
#  ('Regulatory Quality: Standard Error', 3),
#  ('Regulatory Quality: Number of Sources', 3),
#  ('Rule of Law: Percentile Rank, Lower Bound of 90% Confidence Interval', 3),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank', 3),
#  ('Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   3),
#  ('Export volume index (2015 = 100)', 3),
#  ('ICT goods imports (% total goods imports)', 3),
#  ('Import unit value index (2015 = 100)', 3),
#  ('Contraceptive prevalence, any method (% of married women ages 15-49)', 3),
#  ('Fixed broadband subscriptions', 3),
#  ('Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)',
#   3),
#  ('Time required to start a business, male (days)', 3),
#  ('Cost of business start-up procedures, male (% of GNI per capita)', 3),
#  ('Time required to enforce a contract (days)', 3),
#  ('Lifetime risk of maternal death (%)', 3),
#  ('People using safely managed drinking water services, rural (% of rural population)',
#   3),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, female (%)',
#   3),
#  ('Prevalence of anemia among women of reproductive age (% of women ages 15-49)',
#   3),
#  ('Secondary education, general pupils (% female)', 3),
#  ('Literacy rate, adult female (% of females ages 15 and above)', 3),
#  ('Fixed broadband subscriptions (per 100 people)', 3),
#  ('Source data assessment of statistical capacity (scale 0 - 100)', 3),
#  ('Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)', 3),
#  ('GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)',
#   3),
#  ('Energy intensity level of primary energy (MJ/$2017 PPP GDP)', 3),
#  ('Net official flows from UN agencies, UNTA (current US$)', 3),
#  ('Employment to population ratio, ages 15-24, male (%) (national estimate)',
#   3),
#  ('Domestic private health expenditure per capita (current US$)', 3),
#  ('Out-of-pocket expenditure (% of current health expenditure)', 3),
#  ('Domestic general government health expenditure (% of GDP)', 3),
#  ('External health expenditure (% of current health expenditure)', 3),
#  ('Suicide mortality rate (per 100,000 population)', 3),
#  ('Prevalence of stunting, height for age (modeled estimate, % of children under 5)',
#   3),
#  ('People using safely managed sanitation services, urban (% of urban population)',
#   3),
#  ('Mortality rate attributed to unintentional poisoning (per 100,000 population)',
#   3),
#  ('People practicing open defecation, urban (% of urban population)', 3),
#  ('Low-birthweight babies (% of births)', 3),
#  ('Government Effectiveness: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   3),
#  ('Government Effectiveness: Estimate', 3),
#  ('Risk premium on lending (lending rate minus treasury bill rate, %)', 3),
#  ('Automated teller machines (ATMs) (per 100,000 adults)', 3),
#  ('Total greenhouse gas emissions (% change from 1990)', 3),
#  ('Public credit registry coverage (% of adults)', 3),
#  ('Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   3),
#  ('Nitrous oxide emissions in energy sector (% of total)', 3),
#  ('Methane emissions (% change from 1990)', 3),
#  ('Agricultural methane emissions (% of total)', 3),
#  ('Access to clean fuels and technologies for cooking, urban (% of urban population)',
#   3),
#  ('Control of Corruption: Standard Error', 3),
#  ('Control of Corruption: Number of Sources', 3),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (national estimate)',
#   3),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (national estimate)',
#   3),
# ...
#   3),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, male (%)',
#   3),
#  ('Prevalence of anemia among children (% of children ages 6-59 months)', 3),
#  ('Trained teachers in lower secondary education, female (% of female teachers)',
#   3),
#  ('Pupil-teacher ratio, lower secondary', 3),
#  ('Trained teachers in primary education, female (% of female teachers)', 3),
#  ('Literacy rate, adult male (% of males ages 15 and above)', 3),
#  ('Literacy rate, youth (ages 15-24), gender parity index (GPI)', 3),
#  ('Methodology assessment of statistical capacity (scale 0 - 100)', 3),
#  ('Public private partnerships investment in energy (current US$)', 3),
#  ('Investment in energy with private participation (current US$)', 3),
#  ('Start-up procedures to register a business, female (number)', 3),
#  ('Time required to start a business (days)', 3),
#  ('Procedures to register property (number)', 3),
#  ('Time to resolve insolvency (years)', 3),
#  ('Access to clean fuels and technologies for cooking, rural (% of rural population)',
#   3),
#  ('Voice and Accountability: Percentile Rank', 3),
#  ('Import volume index (2015 = 100)', 3),
#  ('International tourism, receipts (% of total exports)', 3),
#  ('Contraceptive prevalence, any modern method (% of married women ages 15-49)',
#   3),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (national estimate)',
#   3),
#  ('Domestic private health expenditure per capita, PPP (current international $)',
#   3),
#  ('Out-of-pocket expenditure per capita (current US$)', 3),
#  ('Domestic general government health expenditure (% of general government expenditure)',
#   3),
#  ('External health expenditure per capita (current US$)', 3),
#  ('Current health expenditure (% of GDP)', 3),
#  ('Tuberculosis treatment success rate (% of new cases)', 3),
#  ('Mortality caused by road traffic injury (per 100,000 population)', 3),
#  ('Employment to population ratio, ages 15-24, total (%) (national estimate)',
#   3),
#  ('Employment to population ratio, ages 15-24, female (%) (national estimate)',
#   3),
#  ('Out-of-pocket expenditure per capita, PPP (current international $)', 3),
#  ('Domestic general government health expenditure per capita (current US$)',
#   3),
#  ('External health expenditure per capita, PPP (current international $)', 3),
#  ('Current health expenditure per capita (current US$)', 3),
#  ('Tuberculosis case detection rate (%, all forms)', 3),
#  ('Suicide mortality rate, female (per 100,000 female population)', 3),
#  ('Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)',
#   3),
#  ('Prevalence of overweight (modeled estimate, % of children under 5)', 3),
#  ('Net bilateral aid flows from DAC donors, Greece (current US$)', 3),
#  ('Control of Corruption: Percentile Rank', 3),
#  ('Personal remittances, received (current US$)', 3),
#  ('People using at least basic sanitation services, urban (% of urban population)',
#   3),
#  ('Risk of impoverishing expenditure for surgical care (% of people at risk)',
#   3),
#  ('Number of maternal deaths', 3),
#  ('Hospital beds (per 1,000 people)', 3),
#  ('Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)',
#   3),
#  ('Antiretroviral therapy coverage (% of people living with HIV)', 3),
#  ('People using safely managed drinking water services (% of population)', 3),
#  ('People using at least basic drinking water services, urban (% of urban population)',
#   3),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)',
#   3),
#  ('Prevalence of anemia among non-pregnant women (% of women ages 15-49)', 3),
#  ('Trained teachers in lower secondary education, male (% of male teachers)',
#   3),
#  ('Trained teachers in primary education, male (% of male teachers)', 3),
#  ('Primary education, pupils (% female)', 3),
#  ('Pupil-teacher ratio, preprimary', 3),
#  ('Literacy rate, adult total (% of people ages 15 and above)', 3),
#  ('Literacy rate, youth male (% of males ages 15-24)', 3),
#  ('Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   3),
#  ('Regulatory Quality: Estimate', 3),
#  ('Rule of Law: Percentile Rank', 3),
#  ('Political Stability and Absence of Violence/Terrorism: Standard Error', 3),
#  ('Political Stability and Absence of Violence/Terrorism: Number of Sources',
#   3),
#  ('Regulatory Quality: Percentile Rank', 3),
#  ('Rule of Law: Percentile Rank, Upper Bound of 90% Confidence Interval', 3),
#  ('Rule of Law: Estimate', 3),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   3),
#  ('Start-up procedures to register a business (number)', 3),
#  ('Cost of business start-up procedures (% of GNI per capita)', 3),
#  ('Time required to register property (days)', 3),
#  ('Government Effectiveness: Standard Error', 3),
#  ('Government Effectiveness: Number of Sources', 3),
#  ('Nitrous oxide emissions (% change from 1990)', 3),
#  ('Agricultural nitrous oxide emissions (% of total)', 3),
#  ('Energy related methane emissions (% of total)', 3),
#  ('Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   3),
#  ('Personal remittances, received (% of GDP)', 3),
#  ('High-technology exports (% of manufactured exports)', 4),
#  ('Share of youth not in education, employment or training, total (% of youth population)',
#   4),
#  ('People with basic handwashing facilities including soap and water (% of population)',
#   4),
#  ('Government expenditure on education, total (% of GDP)', 4),
#  ('Tertiary education, academic staff (% female)', 4),
#  ('Educational attainment, at least completed lower secondary, population 25+, female (%) (cumulative)',
#   4),
#  ('Gross intake ratio in first grade of primary education, female (% of relevant age group)',
#   4),
#  ('School enrollment, tertiary (gross), gender parity index (GPI)', 4),
#  ('Total tax and contribution rate (% of profit)', 4),
#  ('Primary government expenditures as a proportion of original approved budget (%)',
#   4),
#  ('Commercial bank branches (per 100,000 adults)', 4),
#  ('Stocks traded, turnover ratio of domestic shares (%)', 4),
#  ('Market capitalization of listed domestic companies (% of GDP)', 4),
#  ('Foreign direct investment, net outflows (% of GDP)', 4),
#  ('Internally displaced persons, new displacement associated with disasters (number of cases)',
#   4),
#  ('High-technology exports (current US$)', 4),
#  ('Bound rate, simple mean, primary products (%)', 4),
#  ('Bound rate, simple mean, all products (%)', 4),
#  ('Bound rate, simple mean, manufactured products (%)', 4),
#  ('International tourism, expenditures (% of total imports)', 4),
#  ('Manufacturing, value added (% of GDP)', 4),
#  ('Manufacturing, value added (current LCU)', 4),
#  ('Binding coverage, primary products (%)', 4),
#  ('Binding coverage, all products (%)', 4),
#  ('Binding coverage, manufactured products (%)', 4),
#  ('International tourism, expenditures (current US$)', 4),
#  ('Military expenditure (% of general government expenditure)', 4),
#  ('Public private partnerships investment in transport (current US$)', 4),
#  ('Investment in transport with private participation (current US$)', 4),
#  ('Time required to build a warehouse (days)', 4),
#  ('Other taxes payable by businesses (% of commercial profits)', 4),
#  ('Time to prepare and pay taxes (hours)', 4),
#  ('Prevalence of underweight, weight for age, female (% of children under 5)',
#   4),
#  ('Educational attainment, at least completed short-cycle tertiary, population 25+, female (%) (cumulative)',
#   4),
#  ('Educational attainment, at least completed lower secondary, population 25+, male (%) (cumulative)',
#   4),
#  ('Gross intake ratio in first grade of primary education, male (% of relevant age group)',
#   4),
#  ('Trained teachers in preprimary education (% of total teachers)', 4),
#  ('Statistical performance indicators (SPI): Pillar 3 data products score  (scale 0-100)',
#   4),
#  ('Procedures to build a warehouse (number)', 4),
#  ('Tax payments (number)', 4),
#  ('Net official flows from UN agencies, UNHCR (current US$)', 4),
#  ('Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)',
#   4),
#  ('Agricultural machinery, tractors', 4),
#  ('Part time employment, total (% of total employment)', 4),
#  ('Prevalence of wasting, weight for height, male (% of children under 5)', 4),
#  ('People with basic handwashing facilities including soap and water, urban (% of urban population)',
#   4),
#  ('Time required to get electricity (days)', 4),
#  ('Bank nonperforming loans to total gross loans (%)', 4),
#  ('Net bilateral aid flows from DAC donors, Poland (current US$)', 4),
#  ('Listed domestic companies, total', 4),
#  ('Agricultural machinery, tractors per 100 sq. km of arable land', 4),
#  ('Share of youth not in education, employment or training, male (% of male youth population)',
#   4),
#  ('Part time employment, male (% of total male employment)', 4),
#  ('Prevalence of severe wasting, weight for height, male (% of children under 5)',
#   4),
#  ('Prevalence of wasting, weight for height, female (% of children under 5)',
#   4),
#  ('Prevalence of stunting, height for age, male (% of children under 5)', 4),
#  ('Prevalence of underweight, weight for age, male (% of children under 5)',
#   4),
#  ('People with basic handwashing facilities including soap and water, rural (% of rural population)',
#   4),
#  ('School enrollment, tertiary, female (% gross)', 4),
#  ('Educational attainment, at least completed short-cycle tertiary, population 25+, male (%) (cumulative)',
#   4),
#  ('Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)',
#   4),
#  ('Children out of school, primary', 4),
#  ('Gross intake ratio in first grade of primary education, total (% of relevant age group)',
#   4),
#  ('Liner shipping connectivity index (maximum value in 2004 = 100)', 4),
#  ('Profit tax (% of commercial profits)', 4),
#  ('Labor tax and contributions (% of commercial profits)', 4),
#  ('PNG, commercial banks and other creditors (NFL, current US$)', 4),
#  ('Net official flows from UN agencies, WFP (current US$)', 4),
#  ('Net official flows from UN agencies, UNAIDS (current US$)', 4),
#  ('Net official flows from UN agencies, IAEA (current US$)', 4),
#  ('External debt stocks, private nonguaranteed (PNG) (DOD, current US$)', 4),
#  ('Share of youth not in education, employment or training, female (% of female youth population)',
#   4),
#  ('Part time employment, female (% of total female employment)', 4),
#  ('Prevalence of severe wasting, weight for height, female (% of children under 5)',
#   4),
#  ('Prevalence of stunting, height for age, female (% of children under 5)', 4),
#  ('Net bilateral aid flows from DAC donors, Portugal (current US$)', 4),
#  ('Stocks traded, total value (current US$)', 4),
#  ('S&P Global Equity Indices (annual % change)', 4),
#  ('Government expenditure on education, total (% of government expenditure)',
#   4),
#  ('School enrollment, tertiary, male (% gross)', 4),
#  ('Educational attainment, at least completed short-cycle tertiary, population 25+, total (%) (cumulative)',
#   4),
#  ('Children out of school (% of primary school age)', 4),
#  ('Over-age students, primary (% of enrollment)', 4),
#  ('Trained teachers in preprimary education, female (% of female teachers)',
#   4),
#  ('Manufacturing, value added (current US$)', 4),
#  ('Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
#   4),
#  ('Bank capital to assets ratio (%)', 4),
#  ('Net bilateral aid flows from DAC donors, Hungary (current US$)', 4),
#  ('Net bilateral aid flows from DAC donors, Czechia (current US$)', 4),
#  ('Stocks traded, total value (% of GDP)', 4),
#  ('Market capitalization of listed domestic companies (current US$)', 4),
#  ('Portfolio investment, net (BoP, current US$)', 4),
#  ('Foreign direct investment, net outflows (BoP, current US$)', 4),
#  ('Prevalence of overweight, weight for height, male (% of children under 5)',
#   5),
#  ('Progression to secondary school (%)', 5),
#  ('Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)',
#   5),
#  ('Educational attainment, at least completed post-secondary, population 25+, male (%) (cumulative)',
#   5),
#  ('Repeaters, primary, male (% of male enrollment)', 5),
#  ('Persistence to last grade of primary, female (% of cohort)', 5),
#  ('Primary completion rate, male (% of relevant age group)', 5),
#  ('Trained teachers in preprimary education, male (% of male teachers)', 5),
#  ('Secure Internet servers (per 1 million people)', 5),
#  ('CPIA structural policies cluster average (1=low to 6=high)', 5),
#  ('CPIA social protection rating (1=low to 6=high)', 5),
#  ('CPIA macroeconomic management rating (1=low to 6=high)', 5),
#  ('CPIA fiscal policy rating (1=low to 6=high)', 5),
#  ('CPIA economic management cluster average (1=low to 6=high)', 5),
#  ('Trademark applications, nonresident, by count', 5),
#  ('Industrial design applications, resident, by count', 5),
#  ('Gross value added at basic prices (GVA) (constant 2015 US$)', 5),
#  ('Cost to import, border compliance (US$)', 5),
#  ('Cost to export, documentary compliance (US$)', 5),
#  ('Pump price for diesel fuel (US$ per liter)', 5),
#  ('Intentional homicides (per 100,000 people)', 5),
#  ('Taxes less subsidies on products (current LCU)', 5),
#  ('Gross value added at basic prices (GVA) (current US$)', 5),
#  ('CPIA trade rating (1=low to 6=high)', 5),
#  ('CPIA public sector management and institutions cluster average (1=low to 6=high)',
#   5),
#  ('CPIA quality of public administration rating (1=low to 6=high)', 5),
#  ('CPIA gender equality rating (1=low to 6=high)', 5),
#  ('CPIA policy and institutions for environmental sustainability rating (1=low to 6=high)',
#   5),
#  ('Trademark applications, resident, by count', 5),
#  ('Nurses and midwives (per 1,000 people)', 5),
#  ('Adolescents out of school, female (% of female lower secondary school age)',
#   5),
#  ('Educational attainment, at least completed post-secondary, population 25+, total (%) (cumulative)',
#   5),
#  ('Repeaters, primary, total (% of total enrollment)', 5),
#  ('Persistence to last grade of primary, male (% of cohort)', 5),
#  ('Persistence to grade 5, female (% of cohort)', 5),
#  ('Primary completion rate, total (% of relevant age group)', 5),
#  ('CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high)',
#   5),
#  ('CPIA efficiency of revenue mobilization rating (1=low to 6=high)', 5),
#  ('CPIA equity of public resource use rating (1=low to 6=high)', 5),
#  ('CPIA building human resources rating (1=low to 6=high)', 5),
#  ('CPIA quality of budgetary and financial management rating (1=low to 6=high)',
#   5),
#  ('CPIA business regulatory environment rating (1=low to 6=high)', 5),
#  ('Net official flows from UN agencies, ILO (current US$)', 5),
#  ('Unemployment with intermediate education, male (% of male labor force with intermediate education)',
#   5),
#  ('Unemployment with basic education, female (% of female labor force with basic education)',
#   5),
#  ('Labor force with intermediate education, male (% of male working-age population with intermediate education)',
#   5),
#  ('Labor force with basic education, female (% of female working-age population with basic education)',
#   5),
#  ('Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)', 5),
#  ('Gini index', 5),
#  ('Income share held by lowest 10%', 5),
#  ('Income share held by fourth 20%', 5),
#  ('Proportion of population pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   5),
#  ('Proportion of population pushed further below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   5),
#  ('Prevalence of overweight, weight for height, female (% of children under 5)',
#   5),
#  ('Time to import, border compliance (hours)', 5),
#  ('Time to export, documentary compliance (hours)', 5),
#  ('New businesses registered (number)', 5),
#  ('Strength of legal rights index (0=weak to 12=strong)', 5),
#  ('Cost to import, documentary compliance (US$)', 5),
#  ('Time to export, border compliance (hours)', 5),
#  ...]

# %%
# selecting the columns we want to analyse
selected_vietnam_data = vietnam_data[["Year","GDP growth (annual %)",'GDP (constant 2015 US$)',"Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_vietnam_data
# Out:
# /tmp/ipykernel_1928911/2537745285.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1928911/2537745285.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 30  1989               7.364513         42871159122.6828
# 35  1994               8.838981       61014304826.638397
# 40  1999               4.773587       87581401291.570099
# 45  2004               7.536411      121387725604.567001
# 50  2009               5.397898      166620063722.290985
# 55  2014               6.422243      223632762207.559998
# 60  2019               7.359263      314947640805.601013
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 30                                          <NA>
# 35                                          <NA>
# 40                                          <NA>
# 45                                          <NA>
# 50                                      71000000
# 55                                     -93000000
# 60                                   -2997000000
#
# 0   Inflation, consumer prices (annual %)  \
# 30                                   <NA>
# 35                                   <NA>
# 40                               4.117102
# 45                               7.754947
# 50                               6.716983
# 55                               4.084554
# 60                               2.795824
#
# 0   Unemployment, total (% of total labor force) (national estimate)  \
# 30                                               <NA>
# 35                                               <NA>
# 40                                               2.33
# 45                                               2.14
# 50                                              1.737
# 55                                              1.256
# 60                                              1.681
#
# 0   Population growth (annual %)  \
# 30                      2.206737
# 35                      1.844018
# 40                      1.282176
# 45                      1.020116
# 50                      1.029392
# 55                      1.066399
# 60                      0.904491
#
# 0   Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)
# 30                                           13.32489
# 35                                          47.888069
# 40                                          47.888069
# 45                                          47.888069
# 50                                          64.999527
# 55                                          47.888069
# 60                                           65.33979

# %%
selected_vietnam_data.shape
# Out:
# (7, 8)

# %%
selected_vietnam_data.describe().T
# Out:
#                                                    count                 mean  \
# 0
# Year                                                 7.0               2004.0
# GDP growth (annual %)                                7.0             6.813271
# GDP (constant 2015 US$)                              7.0  145436436797.272919
# Portfolio investment, net (BoP, current US$)         3.0   -1006333333.333333
# Inflation, consumer prices (annual %)                5.0             5.093882
# Unemployment, total (% of total labor force) (n...   5.0               1.8288
# Population growth (annual %)                         7.0              1.33619
# Educational attainment, at least completed lowe...   7.0            47.888069
#
#                                                                   std  \
# 0
# Year                                                        10.801234
# GDP growth (annual %)                                        1.387137
# GDP (constant 2015 US$)                             97356507945.49913
# Portfolio investment, net (BoP, current US$)        1725916954.355954
# Inflation, consumer prices (annual %)                        2.059711
# Unemployment, total (% of total labor force) (n...           0.420244
# Population growth (annual %)                                 0.495284
# Educational attainment, at least completed lowe...          17.281869
#
#                                                                  min  \
# 0
# Year                                                          1989.0
# GDP growth (annual %)                                       4.773587
# GDP (constant 2015 US$)                             42871159122.6828
# Portfolio investment, net (BoP, current US$)           -2997000000.0
# Inflation, consumer prices (annual %)                       2.795824
# Unemployment, total (% of total labor force) (n...             1.256
# Population growth (annual %)                                0.904491
# Educational attainment, at least completed lowe...          13.32489
#
#                                                                    25%  \
# 0
# Year                                                            1996.5
# GDP growth (annual %)                                          5.91007
# GDP (constant 2015 US$)                             74297853059.104248
# Portfolio investment, net (BoP, current US$)             -1545000000.0
# Inflation, consumer prices (annual %)                         4.084554
# Unemployment, total (% of total labor force) (n...               1.681
# Population growth (annual %)                                  1.024754
# Educational attainment, at least completed lowe...           47.888069
#
#                                                                     50%  \
# 0
# Year                                                             2004.0
# GDP growth (annual %)                                          7.359263
# GDP (constant 2015 US$)                             121387725604.567001
# Portfolio investment, net (BoP, current US$)                -93000000.0
# Inflation, consumer prices (annual %)                          4.117102
# Unemployment, total (% of total labor force) (n...                1.737
# Population growth (annual %)                                   1.066399
# Educational attainment, at least completed lowe...            47.888069
#
#                                                                     75%  \
# 0
# Year                                                             2011.5
# GDP growth (annual %)                                          7.450462
# GDP (constant 2015 US$)                             195126412964.925476
# Portfolio investment, net (BoP, current US$)                -11000000.0
# Inflation, consumer prices (annual %)                          6.716983
# Unemployment, total (% of total labor force) (n...                 2.14
# Population growth (annual %)                                   1.563097
# Educational attainment, at least completed lowe...            56.443798
#
#                                                                     max
# 0
# Year                                                             2019.0
# GDP growth (annual %)                                          8.838981
# GDP (constant 2015 US$)                             314947640805.601013
# Portfolio investment, net (BoP, current US$)                 71000000.0
# Inflation, consumer prices (annual %)                          7.754947
# Unemployment, total (% of total labor force) (n...                 2.33
# Population growth (annual %)                                   2.206737
# Educational attainment, at least completed lowe...             65.33979

# %%
import seaborn as sns

# %%
columns = list(selected_vietnam_data.columns)
print(columns)

grid = sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
grid.set(xscale="log")
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# [None]

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_vietnam_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
# sns.pairplot(data = selected_vietnam_data, height = 2)

# %%
import numpy as np
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
selected_vietnam_data['GDP growth (annual %)'] = selected_vietnam_data['GDP (constant 2015 US$)'].pct_change() * 100 
selected_vietnam_data["GDP (constant 2015 US$)"] = np.log(selected_vietnam_data["GDP (constant 2015 US$)"])
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# /tmp/ipykernel_1928911/83733472.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_vietnam_data['GDP growth (annual %)'] = selected_vietnam_data['GDP (constant 2015 US$)'].pct_change() * 100
# /tmp/ipykernel_1928911/83733472.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_vietnam_data["GDP (constant 2015 US$)"] = np.log(selected_vietnam_data["GDP (constant 2015 US$)"])

# %%
mean_value = selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_vietnam_data[regression_columns]
selected_vietnam_data = selected_vietnam_data.tail(6)
selected_vietnam_data.reset_index(drop=True, inplace = True)
# Out:
# /tmp/ipykernel_1928911/4067085343.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_1928911/4067085343.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_vietnam_data[ 'GDP growth (annual %)']
X = selected_vietnam_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.1, random_state=50)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  10.473851537220689
# mean_absolute_error :  3.2363330386752054
# The value of R^2 for the model is 52.233286640745334 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by 37.34530827541327
# The value of slope for GDP (constant 2015 US$) is given by 2.414703576213267e-19
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -1.1635654230972089e-09
# The value of slope for Inflation, consumer prices (annual %) is given by -1.4871333312838518e-18
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by -2.1238482299036425e-20
# The value of slope for Population growth (annual %) is given by -4.736974253788504e-20
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 1.2904781233305871e-19
