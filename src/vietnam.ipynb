# %%
import pandas as pd

class Data:

    def __init__(self, country: str , skiprows: int = 3) -> None:
        self.skiprows = skiprows
        self.country = country
    
    def make_filepath(country: str) -> str:
        filepath = "../data/"+ country + "_data.csv"
        return filepath

    def read(filepath: str, skiprows: int=3) -> pd.core.frame.DataFrame:
        data = pd.read_csv(filepath,skiprows=skiprows)
        return data
    
    def clean_data(df: pd.core.frame.DataFrame, columns_to_drop: list) -> pd.core.frame.DataFrame:
        df = df.drop(columns_to_drop, axis = 1)
        df = df.T.reset_index()
        df.columns = df.iloc[0]
        df = df[1:]
        df = df.rename(columns={"Indicator Name":"Year"})
        df = df[:-1].convert_dtypes()
        return df

filepath = Data.make_filepath("vietnam")
vietnam_data = Data.read(filepath)
vietnam_data
# Out:
#      Country Name Country Code  \
# 0        Viet Nam          VNM
# 1        Viet Nam          VNM
# 2        Viet Nam          VNM
# 3        Viet Nam          VNM
# 4        Viet Nam          VNM
# ...           ...          ...
# 1473     Viet Nam          VNM
# 1474     Viet Nam          VNM
# 1475     Viet Nam          VNM
# 1476     Viet Nam          VNM
# 1477     Viet Nam          VNM
#
#                                          Indicator Name     Indicator Code  \
# 0     Internally displaced persons, total displaced ...        VC.IDP.TOCV
# 1              Voice and Accountability: Standard Error         VA.STD.ERR
# 2           Voice and Accountability: Number of Sources          VA.NO.SRC
# 3     High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS
# 4                       Export value index (2015 = 100)  TX.VAL.MRCH.XD.WD
# ...                                                 ...                ...
# 1473  Charges for the use of intellectual property, ...     BM.GSR.ROYL.CD
# 1474   Imports of goods and services (BoP, current US$)     BM.GSR.GNFS.CD
# 1475                      Cereal yield (kg per hectare)     AG.YLD.CREL.KG
# 1476            Crop production index (2014-2016 = 100)     AG.PRD.CROP.XD
# 1477                           Rural land area (sq. km)  AG.LND.TOTL.RU.K2
#
#       1960     1961     1962    1963     1964     1965  ...          2015  \
# 0      NaN      NaN      NaN     NaN      NaN      NaN  ...           NaN
# 1      NaN      NaN      NaN     NaN      NaN      NaN  ...  1.301289e-01
# 2      NaN      NaN      NaN     NaN      NaN      NaN  ...  1.100000e+01
# 3      NaN      NaN      NaN     NaN      NaN      NaN  ...  3.636831e+01
# 4      NaN      NaN      NaN     NaN      NaN      NaN  ...  1.000000e+02
# ...    ...      ...      ...     ...      ...      ...  ...           ...
# 1473   NaN      NaN      NaN     NaN      NaN      NaN  ...           NaN
# 1474   NaN      NaN      NaN     NaN      NaN      NaN  ...  1.706580e+11
# 1475   NaN  1856.40  1953.30  2070.9  1909.80  1898.40  ...  5.601200e+03
# 1476   NaN    14.54    15.46    15.4    15.63    15.37  ...  1.009800e+02
# 1477   NaN      NaN      NaN     NaN      NaN      NaN  ...  2.976267e+05
#
#               2016          2017          2018          2019          2020  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1     1.257415e-01  1.237170e-01  1.267790e-01  1.206971e-01  1.260253e-01
# 2     1.100000e+01  1.200000e+01  1.200000e+01  1.100000e+01  1.000000e+01
# 3     3.805575e+01  4.173807e+01  4.075012e+01  4.043340e+01  4.174008e+01
# 4     1.089570e+02  1.326716e+02  1.503713e+02  1.630631e+02  1.743927e+02
# ...            ...           ...           ...           ...           ...
# 1473           NaN           NaN           NaN           NaN           NaN
# 1474  1.822970e+11  2.213730e+11  2.456274e+11  2.616828e+11  2.698080e+11
# 1475  5.441000e+03  5.434400e+03  5.685400e+03  5.715800e+03  5.797300e+03
# 1476  9.963000e+01  1.015300e+02  1.047000e+02  1.054400e+02  1.060100e+02
# 1477           NaN           NaN           NaN           NaN           NaN
#
#               2021          2022  2023  Unnamed: 68
# 0              NaN           NaN   NaN          NaN
# 1     1.278834e-01  1.254373e-01   NaN          NaN
# 2     1.000000e+01  1.000000e+01   NaN          NaN
# 3     4.153961e+01  3.863281e+01   NaN          NaN
# 4     2.072811e+02           NaN   NaN          NaN
# ...            ...           ...   ...          ...
# 1473           NaN           NaN   NaN          NaN
# 1474  3.383270e+11  3.711110e+11   NaN          NaN
# 1475  5.947100e+03  5.905200e+03   NaN          NaN
# 1476  1.092400e+02  1.095500e+02   NaN          NaN
# 1477           NaN           NaN   NaN          NaN
#
# [1478 rows x 69 columns]

# %%
# cleaning the data
vietnam_columns_to_drop = ["Country Name", "Country Code", "Indicator Code"]
vietnam_data = Data.clean_data(vietnam_data, vietnam_columns_to_drop)
vietnam_data
# Out:
# 0   Year  \
# 1   1960
# 2   1961
# 3   1962
# 4   1963
# 5   1964
# ..   ...
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 1                                       <NA>
# 2                                       <NA>
# 3                                       <NA>
# 4                                       <NA>
# 5                                       <NA>
# ..                                       ...
# 60                                  0.120697
# 61                                  0.126025
# 62                                  0.127883
# 63                                  0.125437
# 64                                      <NA>
#
# 0   Voice and Accountability: Number of Sources  \
# 1                                          <NA>
# 2                                          <NA>
# 3                                          <NA>
# 4                                          <NA>
# 5                                          <NA>
# ..                                          ...
# 60                                           11
# 61                                           10
# 62                                           10
# 63                                           10
# 64                                         <NA>
#
# 0   High-technology exports (% of manufactured exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          40.433396
# 61                                          41.740077
# 62                                          41.539608
# 63                                          38.632807
# 64                                               <NA>
#
# 0   Export value index (2015 = 100)  \
# 1                              <NA>
# 2                              <NA>
# 3                              <NA>
# 4                              <NA>
# 5                              <NA>
# ..                              ...
# 60                       163.063094
# 61                       174.392708
# 62                       207.281059
# 63                             <NA>
# 64                             <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)  \
# 1                                            1.650943
# 2                                            0.872093
# 3                                            3.588556
# 4                                            0.926376
# 5                                                <NA>
# ..                                                ...
# 60                                           0.705903
# 61                                           0.679074
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                            0.004632
# 5                                                <NA>
# ..                                                ...
# 60                                           1.585503
# 61                                           1.608039
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports (current US$)  \
# 1                            86000000
# 2                            71000000
# 3                            33000000
# 4                            45000000
# 5                            28000000
# ..                                ...
# 60                       264268000000
# 61                       282629000000
# 62                       335978000000
# 63                       371288000000
# 64                               <NA>
#
# 0   Insurance and financial services (% of commercial service exports)  ...  \
# 1                                                <NA>                   ...
# 2                                                <NA>                   ...
# 3                                                <NA>                   ...
# 4                                                <NA>                   ...
# 5                                                <NA>                   ...
# ..                                                ...                   ...
# 60                                               <NA>                   ...
# 61                                               <NA>                   ...
# 62                                               <NA>                   ...
# 63                                               <NA>                   ...
# 64                                               <NA>                   ...
#
# 0   Grants, excluding technical cooperation (BoP, current US$)  \
# 1                                           191880000
# 2                                           163660000
# 3                                           172110000
# 4                                           222650000
# 5                                           232450000
# ..                                                ...
# 60                                          347060000
# 61                                          492110000
# 62                                          576900000
# 63                                          480280000
# 64                                               <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
# 5                                           <NA>
# ..                                           ...
# 60                                   -2997000000
# 61                                    1256000000
# 62                                    -281000000
# 63                                   -1512000000
# 64                                          <NA>
#
# 0   Net trade in goods and services (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                        19143247000
# 61                                        20421000000
# 62                                         1799000000
# 63                                        13093000000
# 64                                               <NA>
#
# 0   Current account balance (BoP, current US$)  \
# 1                                         <NA>
# 2                                         <NA>
# 3                                         <NA>
# 4                                         <NA>
# 5                                         <NA>
# ..                                         ...
# 60                               13101247000.0
# 61                               15060000000.0
# 62                               -4628000000.0
# 63                               -1074000000.0
# 64                                        <NA>
#
# 0   Foreign direct investment, net outflows (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                          485000000
# 61                                          380000000
# 62                                          319000000
# 63                                         2674000000
# 64                                               <NA>
#
# 0   Charges for the use of intellectual property, payments (BoP, current US$)  \
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# ..                                                ...
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Imports of goods and services (BoP, current US$)  \
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
# 5                                               <NA>
# ..                                               ...
# 60                                      261682753000
# 61                                      269808000000
# 62                                      338327000000
# 63                                      371111000000
# 64                                              <NA>
#
# 0   Cereal yield (kg per hectare)  Crop production index (2014-2016 = 100)  \
# 1                            <NA>                                     <NA>
# 2                          1856.4                                    14.54
# 3                          1953.3                                    15.46
# 4                          2070.9                                     15.4
# 5                          1909.8                                    15.63
# ..                            ...                                      ...
# 60                         5715.8                                   105.44
# 61                         5797.3                                   106.01
# 62                         5947.1                                   109.24
# 63                         5905.2                                   109.55
# 64                           <NA>                                     <NA>
#
# 0   Rural land area (sq. km)
# 1                       <NA>
# 2                       <NA>
# 3                       <NA>
# 4                       <NA>
# 5                       <NA>
# ..                       ...
# 60                      <NA>
# 61                      <NA>
# 62                      <NA>
# 63                      <NA>
# 64                      <NA>
#
# [64 rows x 1479 columns]

# %%
# selecting and modifying the data
vietnam_data["Year"]=vietnam_data["Year"].astype(int)
vietnam_data = vietnam_data.tail(30)
vietnam_data
# Out:
# 0   Year  \
# 35  1994
# 36  1995
# 37  1996
# 38  1997
# 39  1998
# 40  1999
# 41  2000
# 42  2001
# 43  2002
# 44  2003
# 45  2004
# 46  2005
# 47  2006
# 48  2007
# 49  2008
# 50  2009
# 51  2010
# 52  2011
# 53  2012
# 54  2013
# 55  2014
# 56  2015
# 57  2016
# 58  2017
# 59  2018
# 60  2019
# 61  2020
# 62  2021
# 63  2022
# 64  2023
#
# 0   Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Voice and Accountability: Standard Error  \
# 35                                      <NA>
# 36                                      <NA>
# 37                                   0.20881
# 38                                      <NA>
# 39                                  0.214446
# 40                                      <NA>
# 41                                   0.20282
# 42                                      <NA>
# 43                                  0.164575
# 44                                  0.157154
# 45                                  0.150908
# 46                                   0.14961
# 47                                  0.115202
# 48                                   0.11678
# 49                                  0.113509
# 50                                  0.115317
# 51                                  0.113882
# 52                                  0.112237
# 53                                  0.112144
# 54                                  0.110641
# 55                                  0.127796
# 56                                  0.130129
# 57                                  0.125741
# 58                                  0.123717
# 59                                  0.126779
# 60                                  0.120697
# 61                                  0.126025
# 62                                  0.127883
# 63                                  0.125437
# 64                                      <NA>
#
# 0   Voice and Accountability: Number of Sources  \
# 35                                         <NA>
# 36                                         <NA>
# 37                                            6
# 38                                         <NA>
# 39                                            6
# 40                                         <NA>
# 41                                            7
# 42                                         <NA>
# 43                                            9
# 44                                           10
# 45                                           11
# 46                                           12
# 47                                           15
# 48                                           15
# 49                                           15
# 50                                           15
# 51                                           15
# 52                                           16
# 53                                           16
# 54                                           15
# 55                                           12
# 56                                           11
# 57                                           11
# 58                                           12
# 59                                           12
# 60                                           11
# 61                                           10
# 62                                           10
# 63                                           10
# 64                                         <NA>
#
# 0   High-technology exports (% of manufactured exports)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                           8.829552
# 50                                          10.523358
# 51                                          13.128452
# 52                                          18.809498
# 53                                          27.160797
# 54                                           33.59562
# 55                                          32.054854
# 56                                          36.368312
# 57                                          38.055746
# 58                                          41.738067
# 59                                          40.750121
# 60                                          40.433396
# 61                                          41.740077
# 62                                          41.539608
# 63                                          38.632807
# 64                                               <NA>
#
# 0   Export value index (2015 = 100)  \
# 35                         2.507357
# 36                         3.362238
# 37                         4.476608
# 38                         5.667491
# 39                          5.77609
# 40                         7.121232
# 41                         8.936557
# 42                         9.273459
# 43                        10.308232
# 44                        12.432878
# 45                        16.342243
# 46                        20.017937
# 47                        24.574266
# 48                        29.963967
# 49                        38.679008
# 50                        35.230588
# 51                        44.572746
# 52                        59.794453
# 53                        70.668815
# 54                        81.469247
# 55                         92.68975
# 56                            100.0
# 57                       108.957019
# 58                       132.671586
# 59                       150.371283
# 60                       163.063094
# 61                       174.392708
# 62                       207.281059
# 63                             <NA>
# 64                             <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)  \
# 35                                           0.009274
# 36                                           0.090624
# 37                                           0.145842
# 38                                           0.317228
# 39                                           0.446976
# 40                                           1.008312
# 41                                           0.747295
# 42                                           0.678358
# 43                                           0.456814
# 44                                           0.677311
# 45                                           0.975034
# 46                                           1.169836
# 47                                           0.836677
# 48                                           0.685273
# 49                                            1.04853
# 50                                           1.500467
# 51                                            1.34937
# 52                                           2.634363
# 53                                           1.213795
# 54                                           1.223063
# 55                                           1.041722
# 56                                           1.337732
# 57                                           1.050829
# 58                                           0.823564
# 59                                           0.683402
# 60                                           0.705903
# 61                                           0.679074
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)  \
# 35                                           2.472704
# 36                                           1.596492
# 37                                           1.456199
# 38                                           1.709481
# 39                                           1.718312
# 40                                           1.376059
# 41                                           1.225129
# 42                                           1.639462
# 43                                           1.517644
# 44                                           1.122243
# 45                                           1.180791
# 46                                           1.126713
# 47                                           1.624358
# 48                                           1.697317
# 49                                           2.162733
# 50                                             1.5102
# 51                                           2.150929
# 52                                           2.441936
# 53                                           2.461271
# 54                                           2.620439
# 55                                           2.516987
# 56                                            2.01906
# 57                                           1.907451
# 58                                           2.152407
# 59                                           1.734816
# 60                                           1.585503
# 61                                           1.608039
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Merchandise exports (current US$)  \
# 35                         4054000000
# 36                         5449000000
# 37                         7255000000
# 38                         9185000000
# 39                         9361000000
# 40                        11541000000
# 41                        14483000000
# 42                        15029000000
# 43                        16706000000
# 44                        20149000000
# 45                        26485000000
# 46                        32442000000
# 47                        39826000000
# 48                        48561000000
# 49                        62685000000
# 50                        57096000000
# 51                        72237000000
# 52                        96906000000
# 53                       114529000000
# 54                       132033000000
# 55                       150217000000
# 56                       162065000000
# 57                       176581000000
# 58                       215014000000
# 59                       243699000000
# 60                       264268000000
# 61                       282629000000
# 62                       335978000000
# 63                       371288000000
# 64                               <NA>
#
# 0   Insurance and financial services (% of commercial service exports)  ...  \
# 35                                               <NA>                   ...
# 36                                               <NA>                   ...
# 37                                               <NA>                   ...
# 38                                               <NA>                   ...
# 39                                               <NA>                   ...
# 40                                               <NA>                   ...
# 41                                               <NA>                   ...
# 42                                               <NA>                   ...
# 43                                               <NA>                   ...
# 44                                               <NA>                   ...
# 45                                               <NA>                   ...
# 46                                               <NA>                   ...
# 47                                               <NA>                   ...
# 48                                               <NA>                   ...
# 49                                               <NA>                   ...
# 50                                               <NA>                   ...
# 51                                               <NA>                   ...
# 52                                               <NA>                   ...
# 53                                               <NA>                   ...
# 54                                               <NA>                   ...
# 55                                               <NA>                   ...
# 56                                               <NA>                   ...
# 57                                               <NA>                   ...
# 58                                               <NA>                   ...
# 59                                               <NA>                   ...
# 60                                               <NA>                   ...
# 61                                               <NA>                   ...
# 62                                               <NA>                   ...
# 63                                               <NA>                   ...
# 64                                               <NA>                   ...
#
# 0   Grants, excluding technical cooperation (BoP, current US$)  \
# 35                                          443710000
# 36                                          336510000
# 37                                          231150000
# 38                                          255520000
# 39                                          236380000
# 40                                          263810000
# 41                                          237350000
# 42                                          263640000
# 43                                          242640000
# 44                                          319670000
# 45                                          401740000
# 46                                          504410000
# 47                                          549060000
# 48                                          644430000
# 49                                          751640000
# 50                                          613650000
# 51                                          651150000
# 52                                          667320000
# 53                                          605490000
# 54                                          640110000
# 55                                          535590000
# 56                                          450660000
# 57                                          398200000
# 58                                          437490000
# 59                                          425690000
# 60                                          347060000
# 61                                          492110000
# 62                                          576900000
# 63                                          480280000
# 64                                               <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 35                                          <NA>
# 36                                          <NA>
# 37                                          <NA>
# 38                                          <NA>
# 39                                          <NA>
# 40                                          <NA>
# 41                                          <NA>
# 42                                          <NA>
# 43                                          <NA>
# 44                                          <NA>
# 45                                          <NA>
# 46                                    -865000000
# 47                                   -1313000000
# 48                                   -6243000000
# 49                                     578000000
# 50                                      71000000
# 51                                   -2370000000
# 52                                   -1412000000
# 53                                   -1286000000
# 54                                   -1466000000
# 55                                     -93000000
# 56                                      65000000
# 57                                    -228000000
# 58                                   -2069000000
# 59                                   -3021000000
# 60                                   -2997000000
# 61                                    1256000000
# 62                                    -281000000
# 63                                   -1512000000
# 64                                          <NA>
#
# 0   Net trade in goods and services (BoP, current US$)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                        -2836000000
# 38                                        -1870000000
# 39                                        -1519000000
# 40                                          425000000
# 41                                         -175000000
# 42                                          -91000000
# 43                                        -1804000000
# 44                                        -3359000000
# 45                                        -3159000000
# 46                                        -2735189000
# 47                                        -2783741800
# 48                                       -11193100000
# 49                                       -13733000000
# 50                                       -10028000000
# 51                                        -7597000000
# 52                                        -3430000000
# 53                                         7446000000
# 54                                         5604000000
# 55                                         8596000000
# 56                                         2609000000
# 57                                         6784000000
# 58                                         6816000000
# 59                                        12860129000
# 60                                        19143247000
# 61                                        20421000000
# 62                                         1799000000
# 63                                        13093000000
# 64                                               <NA>
#
# 0   Current account balance (BoP, current US$)  \
# 35                                        <NA>
# 36                                        <NA>
# 37                               -2020000000.0
# 38                               -1528000000.0
# 39                               -1074000000.0
# 40                                1177000000.0
# 41                                1106000000.0
# 42                                 682000000.0
# 43                                -604000000.0
# 44                               -1931000000.0
# 45                                -957000000.0
# 46                            -560189000.00001
# 47                                -163741800.0
# 48                               -6953100000.0
# 49                              -10823000000.0
# 50                               -6608000000.0
# 51                               -4276000000.0
# 52                                 236000000.0
# 53                                9429000000.0
# 54                                7745000000.0
# 55                                9359000000.0
# 56                               -2041000000.0
# 57                                 625000000.0
# 58                               -1649000000.0
# 59                            5899353000.00003
# 60                               13101247000.0
# 61                               15060000000.0
# 62                               -4628000000.0
# 63                               -1074000000.0
# 64                                        <NA>
#
# 0   Foreign direct investment, net outflows (BoP, current US$)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                           65000000
# 47                                           85000000
# 48                                          184000000
# 49                                          300000000
# 50                                          700000000
# 51                                          900000000
# 52                                          950000000
# 53                                         1200000000
# 54                                         1956000000
# 55                                         1150000000
# 56                                         1100000000
# 57                                         1000000000
# 58                                          480000000
# 59                                          598000000
# 60                                          485000000
# 61                                          380000000
# 62                                          319000000
# 63                                         2674000000
# 64                                               <NA>
#
# 0   Charges for the use of intellectual property, payments (BoP, current US$)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               <NA>
# 38                                               <NA>
# 39                                               <NA>
# 40                                               <NA>
# 41                                               <NA>
# 42                                               <NA>
# 43                                               <NA>
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48                                               <NA>
# 49                                               <NA>
# 50                                               <NA>
# 51                                               <NA>
# 52                                               <NA>
# 53                                               <NA>
# 54                                               <NA>
# 55                                               <NA>
# 56                                               <NA>
# 57                                               <NA>
# 58                                               <NA>
# 59                                               <NA>
# 60                                               <NA>
# 61                                               <NA>
# 62                                               <NA>
# 63                                               <NA>
# 64                                               <NA>
#
# 0   Imports of goods and services (BoP, current US$)  \
# 35                                              <NA>
# 36                                              <NA>
# 37                                       12334000000
# 38                                       13585000000
# 39                                       13496000000
# 40                                       13608000000
# 41                                       17325000000
# 42                                       17928000000
# 43                                       21458000000
# 44                                       26780000000
# 45                                       33511000000
# 46                                       39358189000
# 47                                       47709741800
# 48                                       65784100000
# 49                                       83424000000
# 50                                       72890000000
# 51                                       87294000000
# 52                                      109215000000
# 53                                      116868000000
# 54                                      137139000000
# 55                                      152591000000
# 56                                      170658000000
# 57                                      182297000000
# 58                                      221373000000
# 59                                      245627371000
# 60                                      261682753000
# 61                                      269808000000
# 62                                      338327000000
# 63                                      371111000000
# 64                                              <NA>
#
# 0   Cereal yield (kg per hectare)  Crop production index (2014-2016 = 100)  \
# 35                         3458.7                                    40.75
# 36                         3570.0                                    43.39
# 37                         3666.3                                    46.55
# 38                         3758.3                                    49.21
# 39                         3876.0                                    51.37
# 40                         3971.2                                    55.85
# 41                         4112.4                                    58.98
# 42                         4167.3                                    60.51
# 43                         4440.9                                    64.59
# 44                         4506.7                                    67.07
# 45                         4690.9                                    70.93
# 46                         4726.2                                    71.73
# 47                         4749.8                                    74.28
# 48                         4846.2                                    77.54
# 49                         4897.6                                    80.53
# 50                         5080.3                                    80.85
# 51                         5177.5                                    83.27
# 52                         5381.2                                    87.26
# 53                         5462.0                                    94.36
# 54                         5425.5                                    96.35
# 55                         5577.8                                     99.4
# 56                         5601.2                                   100.98
# 57                         5441.0                                    99.63
# 58                         5434.4                                   101.53
# 59                         5685.4                                    104.7
# 60                         5715.8                                   105.44
# 61                         5797.3                                   106.01
# 62                         5947.1                                   109.24
# 63                         5905.2                                   109.55
# 64                           <NA>                                     <NA>
#
# 0   Rural land area (sq. km)
# 35                      <NA>
# 36                      <NA>
# 37                      <NA>
# 38                      <NA>
# 39                      <NA>
# 40                      <NA>
# 41             301519.869475
# 42                      <NA>
# 43                      <NA>
# 44                      <NA>
# 45                      <NA>
# 46                      <NA>
# 47                      <NA>
# 48                      <NA>
# 49                      <NA>
# 50                      <NA>
# 51                      <NA>
# 52                      <NA>
# 53                      <NA>
# 54                      <NA>
# 55                      <NA>
# 56             297626.662056
# 57                      <NA>
# 58                      <NA>
# 59                      <NA>
# 60                      <NA>
# 61                      <NA>
# 62                      <NA>
# 63                      <NA>
# 64                      <NA>
#
# [30 rows x 1479 columns]

# %%
# checking the number of null values in each column
vietnam_data.isna().sum()
# Out:
# 0
# Year                                                                                          0
# Internally displaced persons, total displaced by conflict and violence (number of people)    30
# Voice and Accountability: Standard Error                                                      6
# Voice and Accountability: Number of Sources                                                   6
# High-technology exports (% of manufactured exports)                                          15
#                                                                                              ..
# Charges for the use of intellectual property, payments (BoP, current US$)                    30
# Imports of goods and services (BoP, current US$)                                              3
# Cereal yield (kg per hectare)                                                                 1
# Crop production index (2014-2016 = 100)                                                       1
# Rural land area (sq. km)                                                                     28
# Length: 1479, dtype: int64

# %%
# sorting the data according to no of null values in every column, in ascending order
sorted_cols = vietnam_data.isna().sum().to_dict()
sorted(sorted_cols.items(), key=lambda x: x[1])
# Out:
# [('Year', 0),
#  ('Unemployment, male (% of male labor force) (modeled ILO estimate)', 0),
#  ('Women Business and the Law Index Score (scale 1-100)', 0),
#  ('Population in largest city', 0),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, total (%) (modeled ILO estimate)', 0),
#  ('Employment to population ratio, 15+, female (%) (modeled ILO estimate)', 0),
#  ('Population in urban agglomerations of more than 1 million', 0),
#  ('Population in the largest city (% of urban population)', 0),
#  ('Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Labor force, female (% of total labor force)', 0),
#  ('Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#   0),
#  ('Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate)',
#   0),
#  ('Net migration', 0),
#  ('Unemployment, total (% of total labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, female (% of female labor force) (modeled ILO estimate)', 0),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (modeled ILO estimate)',
#   0),
#  ('Labor force, total', 0),
#  ('Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)',
#   0),
#  ('Ratio of female to male labor force participation rate (%) (modeled ILO estimate)',
#   0),
#  ('Employment to population ratio, 15+, male (%) (modeled ILO estimate)', 0),
#  ('Population in urban agglomerations of more than 1 million (% of total population)',
#   0),
#  ('Merchandise exports (current US$)', 1),
#  ('Merchandise trade (% of GDP)', 1),
#  ('Urban population (% of total population)', 1),
#  ('Rural population growth (annual %)', 1),
#  ('Population, male (% of total population)', 1),
#  ('Population, total', 1),
#  ('Age dependency ratio, young (% of working-age population)', 1),
#  ('Population ages 80 and above, male (% of male population)', 1),
#  ('Population ages 70-74, male (% of male population)', 1),
#  ('Population ages 65 and above, male (% of male population)', 1),
#  ('Population ages 65-69, male (% of male population)', 1),
#  ('Population ages 55-59, male (% of male population)', 1),
#  ('Population ages 45-49, male (% of male population)', 1),
#  ('Population ages 35-39, male (% of male population)', 1),
#  ('Population ages 25-29, male (% of male population)', 1),
#  ('Population ages 15-64 (% of total population)', 1),
#  ('Population ages 15-64, female (% of female population)', 1),
#  ('Population ages 10-14, male (% of male population)', 1),
#  ('Population ages 0-14 (% of total population)', 1),
#  ('Population ages 0-14, female (% of female population)', 1),
#  ('Refugee population by country or territory of origin', 1),
#  ('Lower secondary school starting age (years)', 1),
#  ('Gross capital formation (annual % growth)', 1),
#  ('Changes in inventories (constant LCU)', 1),
#  ('Gross fixed capital formation (constant LCU)', 1),
#  ('Exports of goods and services (constant LCU)', 1),
#  ('Exports of goods and services (current US$)', 1),
#  ('Final consumption expenditure (constant LCU)', 1),
#  ('Households and NPISHs Final consumption expenditure (constant 2015 US$)',
#   1),
#  ('DEC alternative conversion factor (LCU per US$)', 1),
#  ('Net secondary income (Net current transfers from abroad) (current US$)', 1),
#  ('GNI per capita, PPP (current international $)', 1),
#  ('GNI per capita (current LCU)', 1),
#  ('GNI (current LCU)', 1),
#  ('GDP per capita growth (annual %)', 1),
#  ('GDP growth (annual %)', 1),
#  ('GDP (current US$)', 1),
#  ('Inflation, GDP deflator (annual %)', 1),
#  ('Services, value added (constant LCU)', 1),
#  ('Services, value added (current US$)', 1),
#  ('Industry (including construction), value added (% of GDP)', 1),
#  ('Industry (including construction), value added (current LCU)', 1),
#  ('Manufacturing, value added (annual % growth)', 1),
#  ('Net bilateral aid flows from DAC donors, New Zealand (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Ireland (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, France (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Germany (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Canada (current US$)', 1),
#  ('Technical cooperation grants (BoP, current US$)', 1),
#  ('Food production index (2014-2016 = 100)', 1),
#  ('Merchandise imports (current US$)', 1),
#  ('Urban population', 1),
#  ('Rural population', 1),
#  ('Population, male', 1),
#  ('Age dependency ratio, old (% of working-age population)', 1),
#  ('Population ages 80 and above, female (% of female population)', 1),
#  ('Population ages 70-74, female (% of female population)', 1),
#  ('Population ages 65 and above, male', 1),
#  ('Population ages 65-69, female (% of female population)', 1),
#  ('Population ages 55-59, female (% of female population)', 1),
#  ('Population ages 45-49, female (% of female population)', 1),
#  ('Population ages 35-39, female (% of female population)', 1),
#  ('Population ages 25-29, female (% of female population)', 1),
#  ('Population ages 15-64, total', 1),
#  ('Population ages 15-64, female', 1),
#  ('Population ages 10-14, female (% of female population)', 1),
#  ('Population ages 0-14, total', 1),
#  ('Population ages 0-14, female', 1),
#  ('PPP conversion factor, GDP (LCU per international $)', 1),
#  ('Net primary income (Net income from abroad) (current US$)', 1),
#  ('GNI, Atlas method (current US$)', 1),
#  ('GDP per capita, PPP (current international $)', 1),
#  ('GDP per capita (current LCU)', 1),
#  ('GDP, PPP (current international $)', 1),
#  ('GDP: linked series (current LCU)', 1),
#  ('GDP deflator (base year varies by country)', 1),
#  ('Exports as a capacity to import (constant LCU)', 1),
#  ('Services, value added (constant 2015 US$)', 1),
#  ('Industry (including construction), value added (annual % growth)', 1),
#  ('Agriculture, forestry, and fishing, value added (constant 2015 US$)', 1),
#  ('Trade (% of GDP)', 1),
#  ('Urban population growth (annual %)', 1),
#  ('Population, female (% of total population)', 1),
#  ('Age dependency ratio (% of working-age population)', 1),
#  ('Population ages 75-79, male (% of male population)', 1),
#  ('Population ages 65 and above (% of total population)', 1),
#  ('Population ages 65 and above, female (% of female population)', 1),
#  ('Population ages 60-64, male (% of male population)', 1),
#  ('Population ages 50-54, male (% of male population)', 1),
#  ('Population ages 40-44, male (% of male population)', 1),
#  ('Population ages 30-34, male (% of male population)', 1),
#  ('Population ages 20-24, male (% of male population)', 1),
#  ('Population ages 15-64, male (% of male population)', 1),
#  ('Population ages 15-19, male (% of male population)', 1),
#  ('Population ages 05-09, male (% of male population)', 1),
#  ('Population ages 0-14, male (% of male population)', 1),
#  ('Population ages 00-04, male (% of male population)', 1),
#  ('External balance on goods and services (current US$)', 1),
#  ('Imports of goods and services (constant 2015 US$)', 1),
#  ('Gross capital formation (constant LCU)', 1),
#  ('Exports of goods and services (% of GDP)', 1),
#  ('Exports of goods and services (current LCU)', 1),
#  ('Gross national expenditure (constant 2015 US$)', 1),
#  ('General government final consumption expenditure (constant 2015 US$)', 1),
#  ('Individuals using the Internet (% of population)', 1),
#  ('Mobile cellular subscriptions', 1),
#  ('Immunization, DPT (% of children ages 12-23 months)', 1),
#  ('Secondary education, duration (years)', 1),
#  ('Primary education, teachers', 1),
#  ('School enrollment, primary (% gross)', 1),
#  ('Primary education, duration (years)', 1),
#  ('Agriculture, forestry, and fishing, value added (annual % growth)', 1),
#  ('External balance on goods and services (current LCU)', 1),
#  ('Imports of goods and services (annual % growth)', 1),
#  ('Gross fixed capital formation (constant 2015 US$)', 1),
#  ('Exports of goods and services (constant 2015 US$)', 1),
#  ('Gross national expenditure (constant LCU)', 1),
#  ('Final consumption expenditure (constant 2015 US$)', 1),
#  ('Households and NPISHs Final consumption expenditure, PPP (constant 2017 international $)',
#   1),
#  ('Households and NPISHs Final consumption expenditure (constant LCU)', 1),
#  ('Mobile cellular subscriptions (per 100 people)', 1),
#  ('Multilateral debt service (% of public and publicly guaranteed debt service)',
#   1),
#  ('Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)',
#   1),
#  ('Net official development assistance received (current US$)', 1),
#  ('Net official development assistance and official aid received (current US$)',
#   1),
#  ('Net official flows from UN agencies, UNFPA (current US$)', 1),
#  ('Net financial flows, RDB concessional (NFL, current US$)', 1),
#  ('PPG, official creditors (NFL, US$)', 1),
#  ('Net financial flows, IDA (NFL, current US$)', 1),
#  ('Land under cereal production (hectares)', 1),
#  ('Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services (% of total employment) (modeled ILO estimate)', 1),
#  ('Employment in industry (% of total employment) (modeled ILO estimate)', 1),
#  ('Contributing family workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employers, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Newborns protected against tetanus (%)', 1),
#  ('Net bilateral aid flows from DAC donors, Luxembourg (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, United Kingdom (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Denmark (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, European Union institutions (current US$)',
#   1),
#  ('Net bilateral aid flows from DAC donors, Australia (current US$)', 1),
#  ('Foreign direct investment, net inflows (BoP, current US$)', 1),
#  ('Livestock production index (2014-2016 = 100)', 1),
#  ('Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, female (% of female employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Multilateral debt service (TDS, current US$)', 1),
#  ('Debt service on external debt, total (TDS, current US$)', 1),
#  ('Net official development assistance received (constant 2021 US$)', 1),
#  ('Net official flows from UN agencies, UNICEF (current US$)', 1),
#  ('PPG, private creditors (NFL, US$)', 1),
#  ('Commercial banks and other lending (PPG + PNG) (NFL, current US$)', 1),
#  ('IFC, private nonguaranteed (NFL, US$)', 1),
#  ('Net official flows from UN agencies, IFAD (current US$)', 1),
#  ('Short-term debt (% of total external debt)', 1),
#  ('External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)',
#   1),
#  ('External debt stocks (% of GNI)', 1),
#  ('Immunization, measles (% of children ages 12-23 months)', 1),
#  ('Primary education, pupils', 1),
#  ('Primary school starting age (years)', 1),
#  ('Agriculture, forestry, and fishing, value added (constant LCU)', 1),
#  ('Agriculture, forestry, and fishing, value added (current US$)', 1),
#  ('Imports of goods and services (constant LCU)', 1),
#  ('Imports of goods and services (current US$)', 1),
#  ('Gross capital formation (constant 2015 US$)', 1),
#  ('Exports of goods and services (annual % growth)', 1),
#  ('Households and NPISHs Final consumption expenditure per capita (constant 2015 US$)',
#   1),
#  ('General government final consumption expenditure (constant LCU)', 1),
#  ('Public and publicly guaranteed debt service (% of GNI)', 1),
#  ('Total debt service (% of GNI)', 1),
#  ('Net ODA received per capita (current US$)', 1),
#  ('Net official development assistance and official aid received (constant 2021 US$)',
#   1),
#  ('Net official flows from UN agencies, UNDP (current US$)', 1),
#  ('Net financial flows, multilateral (NFL, current US$)', 1),
#  ('PPG, IDA (DOD, current US$)', 1),
#  ('External debt stocks, long-term (DOD, current US$)', 1),
#  ('Rural population (% of total population)', 1),
#  ('Population, female', 1),
#  ('Population growth (annual %)', 1),
#  ('Population ages 75-79, female (% of female population)', 1),
#  ('Population ages 65 and above, total', 1),
#  ('Population ages 65 and above, female', 1),
#  ('Population ages 60-64, female (% of female population)', 1),
#  ('Population ages 50-54, female (% of female population)', 1),
#  ('Population ages 40-44, female (% of female population)', 1),
#  ('Population ages 30-34, female (% of female population)', 1),
#  ('Population ages 20-24, female (% of female population)', 1),
#  ('Population ages 15-64, male', 1),
#  ('Population ages 15-19, female (% of female population)', 1),
#  ('Population ages 05-09, female (% of female population)', 1),
#  ('Population ages 0-14, male', 1),
#  ('Population ages 00-04, female (% of female population)', 1),
#  ('GDP per person employed (constant 2017 PPP $)', 1),
#  ('Wage and salaried workers, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Self-employed, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Employers, male (% of male employment) (modeled ILO estimate)', 1),
#  ('Employment in agriculture (% of total employment) (modeled ILO estimate)',
#   1),
#  ('IMF repurchases and charges (TDS, current US$)', 1),
#  ('Net ODA received (% of GNI)', 1),
#  ('PPG, commercial banks (NFL, current US$)', 1),
#  ('Net financial flows, others (NFL, current US$)', 1),
#  ('Net financial flows, bilateral (NFL, current US$)', 1),
#  ('IBRD loans and IDA credits (DOD, current US$)', 1),
#  ('External debt stocks, total (DOD, current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Sweden (current US$)', 1),
#  ('Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#   1),
#  ('Employment in services, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Employment in industry, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Contributing family workers, female (% of female employment) (modeled ILO estimate)',
#   1),
#  ('Wage and salaried workers, total (% of total employment) (modeled ILO estimate)',
#   1),
#  ('Vulnerable employment, male (% of male employment) (modeled ILO estimate)',
#   1),
#  ('Employers, total (% of total employment) (modeled ILO estimate)', 1),
#  ('Net bilateral aid flows from DAC donors, Total (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Netherlands (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Italy (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Switzerland (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Austria (current US$)', 1),
#  ('Foreign direct investment, net inflows (% of GDP)', 1),
#  ('Cereal production (metric tons)', 1),
#  ('Official exchange rate (LCU per US$, period average)', 1),
#  ('Net secondary income (Net current transfers from abroad) (current LCU)', 1),
#  ('GNI, PPP (current international $)', 1),
#  ('GNI: linked series (current LCU)', 1),
#  ('Gross domestic income (constant LCU)', 1),
#  ('GDP per capita (constant LCU)', 1),
#  ('GDP per capita (current US$)', 1),
#  ('GDP (constant LCU)', 1),
#  ('GDP (current LCU)', 1),
#  ('Inflation, GDP deflator: linked series (annual %)', 1),
#  ('Services, value added (% of GDP)', 1),
#  ('Services, value added (current LCU)', 1),
#  ('Industry (including construction), value added (constant 2015 US$)', 1),
#  ('Manufacturing, value added (constant LCU)', 1),
#  ('Agriculture, forestry, and fishing, value added (% of GDP)', 1),
#  ('Agriculture, forestry, and fishing, value added (current LCU)', 1),
#  ('External balance on goods and services (% of GDP)', 1),
#  ('Imports of goods and services (% of GDP)', 1),
#  ('Imports of goods and services (current LCU)', 1),
#  ('Price level ratio of PPP conversion factor (GDP) to market exchange rate',
#   1),
#  ('Terms of trade adjustment (constant LCU)', 1),
#  ('Net primary income (Net income from abroad) (current LCU)', 1),
#  ('GNI per capita, Atlas method (current US$)', 1),
#  ('GNI (current US$)', 1),
#  ('GDP per capita, PPP (constant 2017 international $)', 1),
#  ('GDP per capita (constant 2015 US$)', 1),
#  ('GDP, PPP (constant 2017 international $)', 1),
#  ('GDP (constant 2015 US$)', 1),
#  ('GDP deflator: linked series (base year varies by country)', 1),
#  ('Services, value added (annual % growth)', 1),
#  ('Industry (including construction), value added (constant LCU)', 1),
#  ('Industry (including construction), value added (current US$)', 1),
#  ('Manufacturing, value added (constant 2015 US$)', 1),
#  ('External debt stocks, short-term (DOD, current US$)', 1),
#  ('Use of IMF credit (DOD, current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Norway (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Japan (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Finland (current US$)', 1),
#  ('Net bilateral aid flows from DAC donors, Belgium (current US$)', 1),
#  ('Grants, excluding technical cooperation (BoP, current US$)', 1),
#  ('Cereal yield (kg per hectare)', 1),
#  ('Crop production index (2014-2016 = 100)', 1),
#  ('Export value index (2015 = 100)', 2),
#  ('Life expectancy at birth, male (years)', 2),
#  ('Mortality rate, infant (per 1,000 live births)', 2),
#  ('Death rate, crude (per 1,000 people)', 2),
#  ('Adolescent fertility rate (births per 1,000 women ages 15-19)', 2),
#  ('Young people (ages 15-24) newly infected with HIV', 2),
#  ('Adults (ages 15-49) newly infected with HIV', 2),
#  ('Children (0-14) living with HIV', 2),
#  ('Mortality rate, neonatal (per 1,000 live births)', 2),
#  ('Mortality rate, under-5, male (per 1,000 live births)', 2),
#  ("Women's share of population ages 15+ living with HIV (%)", 2),
#  ('Probability of dying among children ages 5-9 years (per 1,000)', 2),
#  ('Number of deaths ages 15-19 years', 2),
#  ('School enrollment, preprimary (% gross)', 2),
#  ('Gross fixed capital formation (current US$)', 2),
#  ('Gross national expenditure (current LCU)', 2),
#  ('Final consumption expenditure (current US$)', 2),
#  ('Households and NPISHs Final consumption expenditure per capita growth (annual %)',
#   2),
#  ('General government final consumption expenditure (% of GDP)', 2),
#  ('General government final consumption expenditure (current LCU)', 2),
#  ('Fixed telephone subscriptions (per 100 people)', 2),
#  ('PPP conversion factor, private consumption (LCU per international $)', 2),
#  ('GNI (constant LCU)', 2),
#  ('Gross domestic savings (% of GDP)', 2),
#  ('Oil rents (% of GDP)', 2),
#  ('Natural gas rents (% of GDP)', 2),
#  ('Discrepancy in expenditure estimate of GDP (current LCU)', 2),
#  ('Adjusted net national income (current US$)', 2),
#  ('Adjusted savings: natural resources depletion (% of GNI)', 2),
#  ('Adjusted savings: energy depletion (current US$)', 2),
#  ('Adjusted savings: consumption of fixed capital (current US$)', 2),
#  ('Adjusted savings: carbon dioxide damage (current US$)', 2),
#  ('Broad money (% of GDP)', 2),
#  ('Net foreign assets (current LCU)', 2),
#  ('Total reserves minus gold (current US$)', 2),
#  ('Total fisheries production (metric tons)', 2),
#  ('Permanent cropland (% of land area)', 2),
#  ('Arable land (hectares)', 2),
#  ('Fertilizer consumption (% of fertilizer production)', 2),
#  ('Import value index (2015 = 100)', 2),
#  ('Survival to age 65, male (% of cohort)', 2),
#  ('Life expectancy at birth, total (years)', 2),
#  ('Mortality rate, infant, female (per 1,000 live births)', 2),
#  ('Birth rate, crude (per 1,000 people)', 2),
#  ('GNI, PPP (constant 2017 international $)', 2),
#  ('GNI (constant 2015 US$)', 2),
#  ('Gross domestic savings (current US$)', 2),
#  ('Forest rents (% of GDP)', 2),
#  ('Adjusted savings: particulate emission damage (current US$)', 2),
#  ('Adjusted savings: mineral depletion (current US$)', 2),
#  ('Adjusted savings: net forest depletion (current US$)', 2),
#  ('Adjusted savings: education expenditure (current US$)', 2),
#  ('Survival to age 65, female (% of cohort)', 2),
#  ('Life expectancy at birth, female (years)', 2),
#  ('Mortality rate, adult, male (per 1,000 male adults)', 2),
#  ('Gross capital formation (current US$)', 2),
#  ('Gross fixed capital formation (% of GDP)', 2),
#  ('Gross fixed capital formation (current LCU)', 2),
#  ('Final consumption expenditure (% of GDP)', 2),
#  ('Final consumption expenditure (current LCU)', 2),
#  ('Households and NPISHs Final consumption expenditure, PPP (current international $)',
#   2),
#  ('Households and NPISHs Final consumption expenditure (annual % growth)', 2),
#  ('Households and NPISHs Final consumption expenditure (current US$)', 2),
#  ('Air transport, registered carrier departures worldwide', 2),
#  ('Incidence of HIV, ages 15-24 (per 1,000 uninfected population ages 15-24)',
#   2),
#  ('Children (ages 0-14) newly infected with HIV', 2),
#  ('Prevalence of HIV, female (% ages 15-24)', 2),
#  ('Prevalence of HIV, total (% of population ages 15-49)', 2),
#  ('Probability of dying among adolescents ages 10-14 years (per 1,000)', 2),
#  ('Number of under-five deaths', 2),
#  ('Number of deaths ages 20-24 years', 2),
#  ('Gross capital formation (% of GDP)', 2),
#  ('Gross capital formation (current LCU)', 2),
#  ('Changes in inventories (current US$)', 2),
#  ('Gross national expenditure deflator (base year varies by country)', 2),
#  ('Households and NPISHs Final consumption expenditure (current LCU)', 2),
#  ('General government final consumption expenditure (annual % growth)', 2),
#  ('Patent applications, nonresidents', 2),
#  ('Forest area (% of land area)', 2),
#  ('Agricultural land (% of land area)', 2),
#  ('Domestic credit to private sector (% of GDP)', 2),
#  ('Total reserves (% of total external debt)', 2),
#  ('Aquaculture production (metric tons)', 2),
#  ('Broad money to total reserves ratio', 2),
#  ('Monetary Sector credit to private sector (% GDP)', 2),
#  ('Total reserves (includes gold, current US$)', 2),
#  ('Arable land (hectares per person)', 2),
#  ('Fertilizer consumption (kilograms per hectare of arable land)', 2),
#  ('Incidence of HIV, ages 15-49 (per 1,000 uninfected population ages 15-49)',
#   2),
#  ('Adults (ages 15+) and children (ages 0-14) newly infected with HIV', 2),
#  ('Prevalence of HIV, male (% ages 15-24)', 2),
#  ('Mortality rate, under-5 (per 1,000 live births)', 2),
#  ('Probability of dying among adolescents ages 15-19 years (per 1,000)', 2),
#  ('Number of deaths ages 5-9 years', 2),
#  ('Changes in inventories (current LCU)', 2),
#  ('Gross fixed capital formation (annual % growth)', 2),
#  ('Gross national expenditure (% of GDP)', 2),
#  ('Gross national expenditure (current US$)', 2),
#  ('Final consumption expenditure (annual % growth)', 2),
#  ('Households and NPISHs final consumption expenditure (% of GDP)', 2),
#  ('Households and NPISHs final consumption expenditure: linked series (current LCU)',
#   2),
#  ('General government final consumption expenditure (current US$)', 2),
#  ('Arms imports (SIPRI trend indicator values)', 2),
#  ('Fixed telephone subscriptions', 2),
#  ('Air transport, passengers carried', 2),
#  ('Patent applications, residents', 2),
#  ('Net ODA received (% of gross capital formation)', 2),
#  ('Short-term debt (% of total reserves)', 2),
#  ('Medium and high-tech exports (% manufactured exports)', 2),
#  ('Sex ratio at birth (male births per female births)', 2),
#  ('Fertility rate, total (births per woman)', 2),
#  ('Mortality rate, infant, male (per 1,000 live births)', 2),
#  ('Mortality rate, adult, female (per 1,000 female adults)', 2),
#  ('Surface area (sq. km)', 2),
#  ('Land area (sq. km)', 2),
#  ('Forest area (sq. km)', 2),
#  ('Arable land (% of land area)', 2),
#  ('Agricultural land (sq. km)', 2),
#  ('Incidence of HIV, all (per 1,000 uninfected population)', 2),
#  ('Mortality rate, under-5, female (per 1,000 live births)', 2),
#  ('Probability of dying among youth ages 20-24 years (per 1,000)', 2),
#  ('Number of neonatal deaths', 2),
#  ('Number of infant deaths', 2),
#  ('Number of deaths ages 10-14 years', 2),
#  ('GNI per capita, PPP (constant 2017 international $)', 2),
#  ('GNI per capita (constant 2015 US$)', 2),
#  ('Total natural resources rents (% of GDP)', 2),
#  ('Adjusted savings: energy depletion (% of GNI)', 2),
#  ('Adjusted savings: consumption of fixed capital (% of GNI)', 2),
#  ('Adjusted savings: carbon dioxide damage (% of GNI)', 2),
#  ('Medium and high-tech manufacturing value added (% manufacturing value added)',
#   2),
#  ('GNI per capita (constant LCU)', 2),
#  ('Gross domestic savings (current LCU)', 2),
#  ('Mineral rents (% of GDP)', 2),
#  ('Coal rents (% of GDP)', 2),
#  ('Adjusted net national income per capita (current US$)', 2),
#  ('Adjusted savings: particulate emission damage (% of GNI)', 2),
#  ('Adjusted savings: mineral depletion (% of GNI)', 2),
#  ('Adjusted savings: net forest depletion (% of GNI)', 2),
#  ('Adjusted savings: education expenditure (% of GNI)', 2),
#  ('Claims on central government, etc. (% GDP)', 2),
#  ('Consumer price index (2010 = 100)', 2),
#  ('Broad money (current LCU)', 2),
#  ('Net domestic credit (current LCU)', 2),
#  ('Domestic credit to private sector by banks (% of GDP)', 2),
#  ('Capture fisheries production (metric tons)', 2),
#  ('Population density (people per sq. km of land area)', 2),
#  ('Net bilateral aid flows from DAC donors, United States (current US$)', 2),
#  ('Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in Europe & Central Asia (% of total merchandise exports)',
#   3),
#  ('Merchandise imports by the reporting economy, residual (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Latin America & the Caribbean (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from high-income economies (% of total merchandise imports)',
#   3),
#  ('Gross savings (% of GNI)', 3),
#  ('Adjusted net national income per capita (constant 2015 US$)', 3),
#  ('Inflation, consumer prices (annual %)', 3),
#  ('Renewable internal freshwater resources, total (billion cubic meters)', 3),
#  ('Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
#   3),
#  ('Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions (kt of CO2 equivalent)', 3),
#  ('Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (kg per 2017 PPP $ of GDP)', 3),
#  ('Secondary income receipts (BoP, current US$)', 3),
#  ('Service exports (BoP, current US$)', 3),
#  ('Primary income receipts (BoP, current US$)', 3),
#  ('Reserves and related items (BoP, current US$)', 3),
#  ('Net trade in goods (BoP, current US$)', 3),
#  ('Current account balance (% of GDP)', 3),
#  ('Imports of goods, services and primary income (BoP, current US$)', 3),
#  ('Trade in services (% of GDP)', 3),
#  ('Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in South Asia (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in East Asia & Pacific (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to economies in the Arab World (% of total merchandise exports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in Europe & Central Asia (% of total merchandise imports)',
#   3),
#  ('Gross savings (current US$)', 3),
#  ('GNI per capita growth (annual %)', 3),
#  ('Commercial service exports (current US$)', 3),
#  ('Merchandise exports by the reporting economy (current US$)', 3),
#  ('Merchandise exports to low- and middle-income economies in Middle East & North Africa (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies outside region (% of total merchandise exports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies within region (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from low- and middle-income economies in East Asia & Pacific (% of total merchandise imports)',
#   3),
#  ('Merchandise imports from economies in the Arab World (% of total merchandise imports)',
#   3),
#  ('Rail lines (total route-km)', 3),
#  ('Total debt service (% of exports of goods, services and primary income)',
#   3),
#  ('Net ODA received (% of imports of goods, services and primary income)', 3),
#  ('Broad money growth (annual %)', 3),
#  ('Claims on private sector (annual growth as % of broad money)', 3),
#  ('Annual freshwater withdrawals, total (billion cubic meters)', 3),
#  ('Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
#   3),
#  ('Nitrous oxide emissions (thousand metric tons of CO2 equivalent)', 3),
#  ('Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#   3),
#  ('Methane emissions in energy sector (thousand metric tons of CO2 equivalent)',
#   3),
#  ('CO2 emissions (metric tons per capita)', 3),
#  ('CO2 emissions (kg per 2015 US$ of GDP)', 3),
#  ('Real interest rate (%)', 3),
#  ('Claims on central government (annual growth as % of broad money)', 3),
#  ('Renewable internal freshwater resources per capita (cubic meters)', 3),
#  ('Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
#   3),
#  ('Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)',
#   3),
#  ('Total greenhouse gas emissions (kt of CO2 equivalent)', 3),
#  ('Renewable energy consumption (% of total final energy consumption)', 3),
#  ('Public and publicly guaranteed debt service (% of exports of goods, services and primary income)',
#   3),
#  ('Exports of goods and services (BoP, current US$)', 3),
#  ('Net secondary income (BoP, current US$)', 3),
#  ('Net errors and omissions (BoP, current US$)', 3),
#  ('Net financial account (BoP, current US$)', 3),
#  ('Goods imports (BoP, current US$)', 3),
#  ('Average precipitation in depth (mm per year)', 3),
#  ('Debt service (PPG and IMF only, % of exports of goods, services and primary income)',
#   3),
#  ('Merchandise exports by the reporting economy, residual (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to low- and middle-income economies in Latin America & the Caribbean (% of total merchandise exports)',
#   3),
#  ('Merchandise exports to high-income economies (% of total merchandise exports)',
#   3),
#  ('Commercial service imports (current US$)', 3),
#  ('Merchandise imports by the reporting economy (current US$)', 3),
#  ('Merchandise imports from low- and middle-income economies outside region (% of total merchandise imports)',
#   3),
#  ('Short-term debt (% of exports of goods, services and primary income)', 3),
#  ('Net bilateral aid flows from DAC donors, Spain (current US$)', 3),
#  ('Exports of goods, services and primary income (BoP, current US$)', 3),
#  ('Foreign direct investment, net (BoP, current US$)', 3),
#  ('Net primary income (BoP, current US$)', 3),
#  ('Service imports (BoP, current US$)', 3),
#  ('Primary income payments (BoP, current US$)', 3),
#  ('Gross savings (% of GDP)', 3),
#  ('Adjusted net national income (constant 2015 US$)', 3),
#  ('Gross savings (current LCU)', 3),
#  ('GNI growth (annual %)', 3),
#  ('Lending interest rate (%)', 3),
#  ('Total reserves in months of imports', 3),
#  ('Annual freshwater withdrawals, total (% of internal resources)', 3),
#  ('Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
#   3),
#  ('CO2 emissions (kg per PPP $ of GDP)', 3),
#  ('CO2 emissions (kt)', 3),
#  ('Goods exports (BoP, current US$)', 3),
#  ('Net trade in goods and services (BoP, current US$)', 3),
#  ('Current account balance (BoP, current US$)', 3),
#  ('Imports of goods and services (BoP, current US$)', 3),
#  ('Agricultural raw materials exports (% of merchandise exports)', 4),
#  ('Manufactures imports (% of merchandise imports)', 4),
#  ('Food imports (% of merchandise imports)', 4),
#  ('Armed forces personnel, total', 4),
#  ('Railways, goods transported (million ton-km)', 4),
#  ('Adjusted net savings, excluding particulate emission damage (current US$)',
#   4),
#  ('Industry (including construction), value added per worker (constant 2015 US$)',
#   4),
#  ('Interest rate spread (lending rate minus deposit rate, %)', 4),
#  ('Agricultural raw materials imports (% of merchandise imports)', 4),
#  ('Adjusted net savings, including particulate emission damage (current US$)',
#   4),
#  ('Adjusted net national income (annual % growth)', 4),
#  ('Adjusted savings: net national savings (current US$)', 4),
#  ('Ores and metals exports (% of merchandise exports)', 4),
#  ('Fuel exports (% of merchandise exports)', 4),
#  ('International tourism, number of arrivals', 4),
#  ('Armed forces personnel (% of total labor force)', 4),
#  ('Railways, passengers carried (million passenger-km)', 4),
#  ('School enrollment, preprimary, female (% gross)', 4),
#  ('Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)',
#   4),
#  ('Air transport, freight (million ton-km)', 4),
#  ('Deposit interest rate (%)', 4),
#  ('School enrollment, preprimary, male (% gross)', 4),
#  ('Manufactures exports (% of merchandise exports)', 4),
#  ('Food exports (% of merchandise exports)', 4),
#  ('Ores and metals imports (% of merchandise imports)', 4),
#  ('Fuel imports (% of merchandise imports)', 4),
#  ('Proportion of seats held by women in national parliaments (%)', 4),
#  ('Adjusted net savings, excluding particulate emission damage (% of GNI)', 4),
#  ('Adjusted net national income per capita (annual % growth)', 4),
#  ('Adjusted savings: gross savings (% of GNI)', 4),
#  ('Adjusted net savings, including particulate emission damage (% of GNI)', 4),
#  ('Adjusted savings: net national savings (% of GNI)', 4),
#  ('Services, value added per worker (constant 2015 US$)', 4),
#  ('Secondary education, general pupils', 5),
#  ('Pupil-teacher ratio, primary', 5),
#  ('Compulsory education, duration (years)', 5),
#  ('Scientific and technical journal articles', 5),
#  ('School enrollment, tertiary (% gross)', 5),
#  ('Access to electricity, urban (% of urban population)', 5),
#  ('Access to electricity (% of population)', 5),
#  ('Portfolio investment, bonds (PPG + PNG) (NFL, current US$)', 5),
#  ('Primary education, teachers (% female)', 5),
#  ('School enrollment, primary, female (% gross)', 5),
#  ('Preprimary education, duration (years)', 5),
#  ('Access to electricity, rural (% of rural population)', 5),
#  ('PPG, bonds (NFL, current US$)', 5),
#  ('PPG, other private creditors (NFL, current US$)', 5),
#  ('School enrollment, primary, male (% gross)', 5),
#  ('Voice and Accountability: Standard Error', 6),
#  ('Voice and Accountability: Number of Sources', 6),
#  ('School enrollment, primary, private (% of total primary)', 6),
#  ('Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Rule of Law: Standard Error', 6),
#  ('Rule of Law: Number of Sources', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Political Stability and Absence of Violence/Terrorism: Estimate', 6),
#  ('Other manufacturing (% of value added in manufacturing)', 6),
#  ('Government Effectiveness: Percentile Rank', 6),
#  ('Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Control of Corruption: Estimate', 6),
#  ('Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Voice and Accountability: Estimate', 6),
#  ('Unemployment, male (% of male labor force) (national estimate)', 6),
#  ('Regulatory Quality: Standard Error', 6),
#  ('Regulatory Quality: Number of Sources', 6),
#  ('Rule of Law: Percentile Rank, Lower Bound of 90% Confidence Interval', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank', 6),
#  ('Textiles and clothing (% of value added in manufacturing)', 6),
#  ('Food, beverages and tobacco (% of value added in manufacturing)', 6),
#  ('Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('School enrollment, primary (gross), gender parity index (GPI)', 6),
#  ('Labor force participation rate for ages 15-24, total (%) (national estimate)',
#   6),
#  ('Labor force participation rate for ages 15-24, female (%) (national estimate)',
#   6),
#  ('Government Effectiveness: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Government Effectiveness: Estimate', 6),
#  ('Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Control of Corruption: Standard Error', 6),
#  ('Control of Corruption: Number of Sources', 6),
#  ('Labor force participation rate, male (% of male population ages 15+) (national estimate)',
#   6),
#  ('Labor force participation rate, female (% of female population ages 15+) (national estimate)',
#   6),
#  ('Employment to population ratio, 15+, total (%) (national estimate)', 6),
#  ('Employment to population ratio, 15+, female (%) (national estimate)', 6),
#  ('Voice and Accountability: Percentile Rank', 6),
#  ('Merchandise imports from low- and middle-income economies in Middle East & North Africa (% of total merchandise imports)',
#   6),
#  ('Unemployment, total (% of total labor force) (national estimate)', 6),
#  ('Unemployment, female (% of female labor force) (national estimate)', 6),
#  ('Labor force participation rate, total (% of total population ages 15+) (national estimate)',
#   6),
#  ('Ratio of female to male labor force participation rate (%) (national estimate)',
#   6),
#  ('Employment to population ratio, 15+, male (%) (national estimate)', 6),
#  ('Labor force participation rate for ages 15-24, male (%) (national estimate)',
#   6),
#  ('Control of Corruption: Percentile Rank', 6),
#  ('Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval',
#   6),
#  ('Regulatory Quality: Estimate', 6),
#  ('Rule of Law: Percentile Rank', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Standard Error', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Number of Sources',
#   6),
#  ('Chemicals (% of value added in manufacturing)', 6),
#  ('Regulatory Quality: Percentile Rank', 6),
#  ('Rule of Law: Percentile Rank, Upper Bound of 90% Confidence Interval', 6),
#  ('Rule of Law: Estimate', 6),
#  ('Political Stability and Absence of Violence/Terrorism: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('Machinery and transport equipment (% of value added in manufacturing)', 6),
#  ('Government Effectiveness: Standard Error', 6),
#  ('Government Effectiveness: Number of Sources', 6),
#  ('Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval',
#   6),
#  ('People using safely managed sanitation services (% of population)', 7),
#  ('People practicing open defecation (% of population)', 7),
#  ('People using at least basic sanitation services (% of population)', 7),
#  ('People using at least basic drinking water services (% of population)', 7),
#  ('CO2 emissions from liquid fuel consumption (kt)', 7),
#  ('CO2 emissions from gaseous fuel consumption (kt)', 7),
#  ('People using safely managed drinking water services, rural (% of rural population)',
#   7),
#  ('Prevalence of stunting, height for age (modeled estimate, % of children under 5)',
#   7),
#  ('People using safely managed sanitation services, urban (% of urban population)',
#   7),
#  ('People practicing open defecation, urban (% of urban population)', 7),
#  ('Prevalence of underweight, weight for age (% of children under 5)', 7),
#  ('CO2 emissions from solid fuel consumption (% of total)', 7),
#  ('CO2 emissions from solid fuel consumption (kt)', 7),
#  ('CO2 emissions from liquid fuel consumption (% of total)', 7),
#  ('CO2 emissions from gaseous fuel consumption (% of total)', 7),
#  ('Incidence of tuberculosis (per 100,000 people)', 7),
#  ('People using safely managed sanitation services, rural (% of rural population)',
#   7),
#  ('People practicing open defecation, rural (% of rural population)', 7),
#  ('People using at least basic sanitation services, rural (% of rural population)',
#   7),
#  ('People using safely managed drinking water services, urban (% of urban population)',
#   7),
#  ('People using at least basic drinking water services, rural (% of rural population)',
#   7),
#  ('Prevalence of stunting, height for age (% of children under 5)', 7),
#  ('Tuberculosis case detection rate (%, all forms)', 7),
#  ('Prevalence of overweight (modeled estimate, % of children under 5)', 7),
#  ('Personal remittances, received (current US$)', 7),
#  ('People using at least basic sanitation services, urban (% of urban population)',
#   7),
#  ('People using safely managed drinking water services (% of population)', 7),
#  ('People using at least basic drinking water services, urban (% of urban population)',
#   7),
#  ('Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)',
#   7),
#  ('Personal remittances, received (% of GDP)', 7),
#  ('Net barter terms of trade index (2015 = 100)', 8),
#  ('Tariff rate, applied, weighted mean, primary products (%)', 8),
#  ('Share of tariff lines with international peaks, primary products (%)', 8),
#  ('Tariff rate, applied, weighted mean, all products (%)', 8),
#  ('Share of tariff lines with international peaks, all products (%)', 8),
#  ('Tariff rate, applied, weighted mean, manufactured products (%)', 8),
#  ('Share of tariff lines with international peaks, manufactured products (%)',
#   8),
#  ('Incidence of malaria (per 1,000 population at risk)', 8),
#  ('Tertiary education, academic staff (% female)', 8),
#  ('Container port traffic (TEU: 20 foot equivalent units)', 8),
#  ('Export unit value index (2015 = 100)', 8),
#  ('Share of tariff lines with specific rates, primary products (%)', 8),
#  ('Share of tariff lines with specific rates, all products (%)', 8),
#  ('Share of tariff lines with specific rates, manufactured products (%)', 8),
#  ('Export volume index (2015 = 100)', 8),
#  ('Import unit value index (2015 = 100)', 8),
#  ('Tariff rate, most favored nation, simple mean, primary products (%)', 8),
#  ('Tariff rate, most favored nation, simple mean, all products (%)', 8),
#  ('Tariff rate, most favored nation, simple mean, manufactured products (%)',
#   8),
#  ('Contraceptive prevalence, any method (% of married women ages 15-49)', 8),
#  ('Electricity production from renewable sources, excluding hydroelectric (kWh)',
#   8),
#  ('Electricity production from natural gas sources (% of total)', 8),
#  ('Electricity production from coal sources (% of total)', 8),
#  ('Electricity production from oil sources (% of total)', 8),
#  ('Electricity production from hydroelectric sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, urban (% of urban population)',
#   8),
#  ('Renewable electricity output (% of total electricity output)', 8),
#  ('Access to clean fuels and technologies for cooking (% of population)', 8),
#  ('Electricity production from renewable sources, excluding hydroelectric (% of total)',
#   8),
#  ('Electricity production from oil, gas and coal sources (% of total)', 8),
#  ('Access to clean fuels and technologies for cooking, rural (% of rural population)',
#   8),
#  ('Net financial flows, RDB nonconcessional (NFL, current US$)', 8),
#  ('Tariff rate, most favored nation, weighted mean, primary products (%)', 8),
#  ('Tariff rate, applied, simple mean, primary products (%)', 8),
#  ('Tariff rate, most favored nation, weighted mean, all products (%)', 8),
#  ('Tariff rate, applied, simple mean, all products (%)', 8),
#  ('Tariff rate, most favored nation, weighted mean, manufactured products (%)',
#   8),
#  ('Tariff rate, applied, simple mean, manufactured products (%)', 8),
#  ('Import volume index (2015 = 100)', 8),
#  ('Contraceptive prevalence, any modern method (% of married women ages 15-49)',
#   8),
#  ('Tuberculosis treatment success rate (% of new cases)', 8),
#  ('Prevalence of wasting, weight for height (% of children under 5)', 8),
#  ('Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)',
#   8),
#  ('Antiretroviral therapy coverage (% of people living with HIV)', 8),
#  ('Maternal mortality ratio (modeled estimate, per 100,000 live births)', 9),
#  ('Lifetime risk of maternal death (1 in: rate varies by country)', 9),
#  ('Pupil-teacher ratio, tertiary', 9),
#  ('Trained teachers in lower secondary education (% of total teachers)', 9),
#  ('CO2 emissions from electricity and heat production, total (% of total fuel combustion)',
#   9),
#  ('ICT goods exports (% of total goods exports)', 9),
#  ('Prevalence of undernourishment (% of population)', 9),
#  ('ICT goods imports (% total goods imports)', 9),
#  ('Fixed broadband subscriptions', 9),
#  ('Lifetime risk of maternal death (%)', 9),
#  ('Secondary education, general pupils (% female)', 9),
#  ('Fixed broadband subscriptions (per 100 people)', 9),
#  ('Energy intensity level of primary energy (MJ/$2017 PPP GDP)', 9),
#  ('Domestic private health expenditure per capita (current US$)', 9),
#  ('Out-of-pocket expenditure (% of current health expenditure)', 9),
#  ('Domestic general government health expenditure (% of GDP)', 9),
#  ('External health expenditure (% of current health expenditure)', 9),
#  ('Low-birthweight babies (% of births)', 9),
#  ('CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)',
#   9),
#  ('CO2 emissions from manufacturing industries and construction (% of total fuel combustion)',
#   9),
#  ('Electric power consumption (kWh per capita)', 9),
#  ('Domestic private health expenditure (% of current health expenditure)', 9),
#  ('Domestic general government health expenditure per capita, PPP (current international $)',
#   9),
#  ('Domestic general government health expenditure (% of current health expenditure)',
#   9),
#  ('Current health expenditure per capita, PPP (current international $)', 9),
#  ('Electric power transmission and distribution losses (% of output)', 9),
#  ('Pupil-teacher ratio, lower secondary', 9),
#  ('Public private partnerships investment in energy (current US$)', 9),
#  ('Investment in energy with private participation (current US$)', 9),
#  ('Electricity production from nuclear sources (% of total)', 9),
#  ('Domestic private health expenditure per capita, PPP (current international $)',
#   9),
#  ('Out-of-pocket expenditure per capita (current US$)', 9),
#  ('Domestic general government health expenditure (% of general government expenditure)',
#   9),
#  ('External health expenditure per capita (current US$)', 9),
#  ('Current health expenditure (% of GDP)', 9),
#  ('Out-of-pocket expenditure per capita, PPP (current international $)', 9),
#  ('Domestic general government health expenditure per capita (current US$)',
#   9),
# ...
#  ('Fossil fuel energy consumption (% of total)', 10),
#  ('GDP per unit of energy use (PPP $ per kg of oil equivalent)', 10),
#  ('Prevalence of anemia among pregnant women (%)', 10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, male (%)',
#   10),
#  ('Prevalence of anemia among children (% of children ages 6-59 months)', 10),
#  ('Mortality caused by road traffic injury (per 100,000 population)', 10),
#  ('Net financial flows, IMF nonconcessional (NFL, current US$)', 10),
#  ('Suicide mortality rate, female (per 100,000 female population)', 10),
#  ('Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)',
#   10),
#  ('Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)',
#   10),
#  ('Prevalence of anemia among non-pregnant women (% of women ages 15-49)', 10),
#  ('Trained teachers in primary education (% of total teachers)', 11),
#  ('School enrollment, tertiary (gross), gender parity index (GPI)', 11),
#  ('Statistical performance indicators (SPI): Pillar 1 data use score (scale 0-100)',
#   11),
#  ('Other greenhouse gas emissions (% change from 1990)', 11),
#  ('Risk premium on lending (lending rate minus treasury bill rate, %)', 11),
#  ('Total greenhouse gas emissions (% change from 1990)', 11),
#  ('Methane emissions (% change from 1990)', 11),
#  ('School enrollment, tertiary, female (% gross)', 11),
#  ('School enrollment, tertiary, male (% gross)', 11),
#  ('Pupil-teacher ratio, preprimary', 11),
#  ('Nitrous oxide emissions (% change from 1990)', 11),
#  ('International tourism, receipts (current US$)', 12),
#  ('People with basic handwashing facilities including soap and water (% of population)',
#   12),
#  ('Foreign direct investment, net outflows (% of GDP)', 12),
#  ('Refugee population by country or territory of asylum', 12),
#  ('Manufacturing, value added (% of GDP)', 12),
#  ('Manufacturing, value added (current LCU)', 12),
#  ('Statistical performance indicators (SPI): Pillar 3 data products score  (scale 0-100)',
#   12),
#  ('Prevalence of severe wasting, weight for height (% of children under 5)',
#   12),
#  ('People with basic handwashing facilities including soap and water, urban (% of urban population)',
#   12),
#  ('Automated teller machines (ATMs) (per 100,000 adults)', 12),
#  ('Net bilateral aid flows from DAC donors, Poland (current US$)', 12),
#  ('People with basic handwashing facilities including soap and water, rural (% of rural population)',
#   12),
#  ('Risk of catastrophic expenditure for surgical care (% of people at risk)',
#   12),
#  ('Trained teachers in lower secondary education, female (% of female teachers)',
#   12),
#  ('International tourism, receipts (% of total exports)', 12),
#  ('Risk of impoverishing expenditure for surgical care (% of people at risk)',
#   12),
#  ('Trained teachers in lower secondary education, male (% of male teachers)',
#   12),
#  ('Over-age students, primary (% of enrollment)', 12),
#  ('Manufacturing, value added (current US$)', 12),
#  ('Net bilateral aid flows from DAC donors, Hungary (current US$)', 12),
#  ('Net bilateral aid flows from DAC donors, Czechia (current US$)', 12),
#  ('Portfolio investment, net (BoP, current US$)', 12),
#  ('Foreign direct investment, net outflows (BoP, current US$)', 12),
#  ('Military expenditure (% of GDP)', 13),
#  ('Statistical Capacity Score (Overall Average) (scale 0 - 100)', 13),
#  ('Start-up procedures to register a business, male (number)', 13),
#  ('Time required to start a business, female (days)', 13),
#  ('Cost of business start-up procedures, female (% of GNI per capita)', 13),
#  ('Periodicity and timeliness assessment of statistical capacity (scale 0 - 100)',
#   13),
#  ('Time required to start a business, male (days)', 13),
#  ('Cost of business start-up procedures, male (% of GNI per capita)', 13),
#  ('Time required to enforce a contract (days)', 13),
#  ('Military expenditure (current USD)', 13),
#  ('Source data assessment of statistical capacity (scale 0 - 100)', 13),
#  ('Trained teachers in primary education, female (% of female teachers)', 13),
#  ('Military expenditure (current LCU)', 13),
#  ('Methodology assessment of statistical capacity (scale 0 - 100)', 13),
#  ('Start-up procedures to register a business, female (number)', 13),
#  ('Time required to start a business (days)', 13),
#  ('Time to resolve insolvency (years)', 13),
#  ('Net official flows from UN agencies, IAEA (current US$)', 13),
#  ('Trained teachers in primary education, male (% of male teachers)', 13),
#  ('Start-up procedures to register a business (number)', 13),
#  ('Cost of business start-up procedures (% of GNI per capita)', 13),
#  ('Private credit bureau coverage (% of adults)', 14),
#  ('International tourism, expenditures (% of total imports)', 14),
#  ('International tourism, expenditures (current US$)', 14),
#  ('Military expenditure (% of general government expenditure)', 14),
#  ('Employment to population ratio, ages 15-24, male (%) (national estimate)',
#   14),
#  ('Public credit registry coverage (% of adults)', 14),
#  ('Unemployment, youth total (% of total labor force ages 15-24) (national estimate)',
#   14),
#  ('Unemployment, youth female (% of female labor force ages 15-24) (national estimate)',
#   14),
#  ('Liner shipping connectivity index (maximum value in 2004 = 100)', 14),
#  ('Procedures to register property (number)', 14),
#  ('Unemployment, youth male (% of male labor force ages 15-24) (national estimate)',
#   14),
#  ('Net official flows from UN agencies, UNAIDS (current US$)', 14),
#  ('Employment to population ratio, ages 15-24, total (%) (national estimate)',
#   14),
#  ('Employment to population ratio, ages 15-24, female (%) (national estimate)',
#   14),
#  ('Net bilateral aid flows from DAC donors, Greece (current US$)', 14),
#  ('S&P Global Equity Indices (annual % change)', 14),
#  ('Time required to register property (days)', 14),
#  ('High-technology exports (% of manufactured exports)', 15),
#  ('Share of youth not in education, employment or training, total (% of youth population)',
#   15),
#  ('Government expenditure on education, total (% of GDP)', 15),
#  ('Total tax and contribution rate (% of profit)', 15),
#  ('Market capitalization of listed domestic companies (% of GDP)', 15),
#  ('Internally displaced persons, new displacement associated with disasters (number of cases)',
#   15),
#  ('High-technology exports (current US$)', 15),
#  ('Time required to build a warehouse (days)', 15),
#  ('Other taxes payable by businesses (% of commercial profits)', 15),
#  ('Time to prepare and pay taxes (hours)', 15),
#  ('Primary completion rate, total (% of relevant age group)', 15),
#  ('Procedures to build a warehouse (number)', 15),
#  ('Tax payments (number)', 15),
#  ('Net official flows from UN agencies, UNTA (current US$)', 15),
#  ('Nitrous oxide emissions in energy sector (% of total)', 15),
#  ('Agricultural methane emissions (% of total)', 15),
#  ('Listed domestic companies, total', 15),
#  ('Share of youth not in education, employment or training, male (% of male youth population)',
#   15),
#  ('Physicians (per 1,000 people)', 15),
#  ('Children out of school, primary', 15),
#  ('Profit tax (% of commercial profits)', 15),
#  ('Labor tax and contributions (% of commercial profits)', 15),
#  ('External debt stocks, private nonguaranteed (PNG) (DOD, current US$)', 15),
#  ('Share of youth not in education, employment or training, female (% of female youth population)',
#   15),
#  ('Net bilateral aid flows from DAC donors, Portugal (current US$)', 15),
#  ('Government expenditure on education, total (% of government expenditure)',
#   15),
#  ('Children out of school (% of primary school age)', 15),
#  ('Business extent of disclosure index (0=less disclosure to 10=more disclosure)',
#   15),
#  ('Agricultural nitrous oxide emissions (% of total)', 15),
#  ('Energy related methane emissions (% of total)', 15),
#  ('Market capitalization of listed domestic companies (current US$)', 15),
#  ('Primary government expenditures as a proportion of original approved budget (%)',
#   16),
#  ('Commercial bank branches (per 100,000 adults)', 16),
#  ('Stocks traded, turnover ratio of domestic shares (%)', 16),
#  ('Bound rate, simple mean, primary products (%)', 16),
#  ('Bound rate, simple mean, all products (%)', 16),
#  ('Bound rate, simple mean, manufactured products (%)', 16),
#  ('Binding coverage, primary products (%)', 16),
#  ('Binding coverage, all products (%)', 16),
#  ('Binding coverage, manufactured products (%)', 16),
#  ('Investment in transport with private participation (current US$)', 16),
#  ('Trained teachers in preprimary education (% of total teachers)', 16),
#  ('Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)',
#   16),
#  ('Part time employment, total (% of total employment)', 16),
#  ('Bank nonperforming loans to total gross loans (%)', 16),
#  ('Part time employment, male (% of total male employment)', 16),
#  ('PNG, commercial banks and other creditors (NFL, current US$)', 16),
#  ('Part time employment, female (% of total female employment)', 16),
#  ('Female share of employment in senior and middle management (%)', 16),
#  ('Stocks traded, total value (current US$)', 16),
#  ('Bank capital to assets ratio (%)', 16),
#  ('Stocks traded, total value (% of GDP)', 16),
#  ('Gross value added at basic prices (GVA) (constant 2015 US$)', 17),
#  ('Taxes less subsidies on products (current LCU)', 17),
#  ('Gross value added at basic prices (GVA) (current US$)', 17),
#  ('Public private partnerships investment in transport (current US$)', 17),
#  ('Repeaters, primary, total (% of total enrollment)', 17),
#  ('Net official flows from UN agencies, UNHCR (current US$)', 17),
#  ('Unemployment with intermediate education, male (% of male labor force with intermediate education)',
#   17),
#  ('Unemployment with basic education, female (% of female labor force with basic education)',
#   17),
#  ('Labor force with intermediate education, male (% of male working-age population with intermediate education)',
#   17),
#  ('Labor force with basic education, female (% of female working-age population with basic education)',
#   17),
#  ('PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#   17),
#  ('Unemployment with intermediate education, female (% of female labor force with intermediate education)',
#   17),
#  ('Unemployment with advanced education (% of total labor force with advanced education)',
#   17),
#  ('Labor force with intermediate education, female (% of female working-age population with intermediate education)',
#   17),
#  ('Labor force with advanced education (% of total working-age population with advanced education)',
#   17),
#  ('Net financial flows, IBRD (NFL, current US$)', 17),
#  ('Gross intake ratio in first grade of primary education, total (% of relevant age group)',
#   17),
#  ('External balance on goods and services (constant LCU)', 17),
#  ('Unemployment with intermediate education (% of total labor force with intermediate education)',
#   17),
#  ('Unemployment with basic education, male (% of male labor force with basic education)',
#   17),
#  ('Unemployment with advanced education, female (% of female labor force with advanced education)',
#   17),
#  ('Labor force with intermediate education (% of total working-age population with intermediate education)',
#   17),
#  ('Labor force with basic education, male (% of male working-age population with basic education)',
#   17),
#  ('Labor force with advanced education, female (% of female working-age population with advanced education)',
#   17),
#  ('Unemployment with basic education (% of total labor force with basic education)',
#   17),
#  ('Unemployment with advanced education, male (% of male labor force with advanced education)',
#   17),
#  ('Labor force with basic education (% of total working-age population with basic education)',
#   17),
#  ('Labor force with advanced education, male (% of male working-age population with advanced education)',
#   17),
#  ('Hospital beds (per 1,000 people)', 17),
#  ('Adjusted net enrollment rate, primary (% of primary school age children)',
#   17),
#  ('School enrollment, primary (% net)', 17),
#  ('Taxes less subsidies on products (current US$)', 17),
#  ('Gross value added at basic prices (GVA) (constant LCU)', 17),
#  ('Discrepancy in expenditure estimate of GDP (constant LCU)', 17),
#  ('Taxes less subsidies on products (constant LCU)', 17),
#  ('Gross value added at basic prices (GVA) (current LCU)', 17),
#  ('PPG, IBRD (DOD, current US$)', 17),
#  ('Trademark applications, nonresident, by count', 18),
#  ('Industrial design applications, resident, by count', 18),
#  ('Trademark applications, resident, by count', 18),
#  ('Nurses and midwives (per 1,000 people)', 18),
#  ('Poverty headcount ratio at $6.85 a day (2017 PPP) (% of population)', 18),
#  ('Gini index', 18),
#  ('Income share held by lowest 10%', 18),
#  ('Income share held by fourth 20%', 18),
#  ('Poverty gap at $2.15 a day (2017 PPP) (%)', 18),
#  ('Proportion of people living below 50 percent of median income (%)', 18),
#  ('Income share held by third 20%', 18),
#  ('Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)',
#   18),
#  ('Net official flows from UN agencies, WHO (current US$)', 18),
#  ('Industrial design applications, nonresident, by count', 18),
#  ('Poverty gap at $6.85 a day (2017 PPP) (%)', 18),
#  ('Poverty headcount ratio at $3.65 a day (2017 PPP) (% of population)', 18),
#  ('Income share held by lowest 20%', 18),
#  ('Income share held by highest 20%', 18),
#  ('Poverty gap at $3.65 a day (2017 PPP) (%)', 18),
#  ('Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)', 18),
#  ('Income share held by highest 10%', 18),
#  ('Income share held by second 20%', 18),
#  ('Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)',
#   18),
#  ('Adolescents out of school (% of lower secondary school age)', 18),
#  ('Lower secondary completion rate, total (% of relevant age group)', 18),
#  ('Net bilateral aid flows from DAC donors, Slovak Republic (current US$)',
#   18),
#  ('Repeaters, primary, male (% of male enrollment)', 19),
#  ('Gross intake ratio in first grade of primary education, female (% of relevant age group)',
#   19),
#  ('Primary completion rate, male (% of relevant age group)', 19),
#  ('Secure Internet servers (per 1 million people)', 19),
#  ('CPIA structural policies cluster average (1=low to 6=high)', 19),
#  ('CPIA social protection rating (1=low to 6=high)', 19),
#  ('CPIA macroeconomic management rating (1=low to 6=high)', 19),
#  ('CPIA fiscal policy rating (1=low to 6=high)', 19),
#  ('CPIA economic management cluster average (1=low to 6=high)', 19),
#  ('Pump price for diesel fuel (US$ per liter)', 19),
#  ('PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-3 value (% of total)',
#   19),
#  ('Intentional homicides (per 100,000 people)', 19),
#  ('CPIA trade rating (1=low to 6=high)', 19),
#  ('CPIA public sector management and institutions cluster average (1=low to 6=high)',
#   19),
#  ('CPIA quality of public administration rating (1=low to 6=high)', 19),
#  ('CPIA gender equality rating (1=low to 6=high)', 19),
#  ('CPIA policy and institutions for environmental sustainability rating (1=low to 6=high)',
#   19),
#  ('Prevalence of underweight, weight for age, female (% of children under 5)',
#   19),
#  ('Gross intake ratio in first grade of primary education, male (% of relevant age group)',
#   19),
#  ('CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high)',
#   19),
#  ('CPIA efficiency of revenue mobilization rating (1=low to 6=high)', 19),
#  ('CPIA equity of public resource use rating (1=low to 6=high)', 19),
#  ('CPIA building human resources rating (1=low to 6=high)', 19),
#  ('CPIA quality of budgetary and financial management rating (1=low to 6=high)',
#   19),
#  ('CPIA business regulatory environment rating (1=low to 6=high)', 19),
#  ('Net official flows from UN agencies, ILO (current US$)', 19),
#  ('Proportion of population pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
#   19),
#  ...]

# %%
# selecting the columns we want to analyse
selected_vietnam_data = vietnam_data[["Year","GDP growth (annual %)","GDP (constant 2015 US$)","Portfolio investment, net (BoP, current US$)","Inflation, consumer prices (annual %)","Unemployment, total (% of total labor force) (national estimate)","Population growth (annual %)","Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"]]
mean_value = selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].mean() 
selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
selected_vietnam_data
# Out:
# /tmp/ipykernel_108108/3941304282.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# /tmp/ipykernel_108108/3941304282.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_vietnam_data["Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)"].fillna(value=mean_value, inplace=True)
# 0   Year  GDP growth (annual %)  GDP (constant 2015 US$)  \
# 35  1994               8.838981       61014304826.638397
# 36  1995                9.54048       66835362482.484596
# 37  1996               9.340017         73077797034.1306
# 38  1997               8.152084       79035160538.462601
# 39  1998               5.764455       83591107164.247101
# 40  1999               4.773587       87581401291.570099
# 41  2000               6.787316       93525828108.839005
# 42  2001               6.192893       99317782863.095993
# 43  2002               6.320821      105595482130.707001
# 44  2003               6.899063      112880581486.059006
# 45  2004               7.536411      121387725604.567001
# 46  2005               7.547248      130549157968.492996
# 47  2006               6.977955      139658819217.109985
# 48  2007               7.129504       149615800998.36499
# 49  2008               5.661771      158086705343.274994
# 50  2009               5.397898      166620063722.290985
# 51  2010               6.423245      177322478338.403992
# 52  2011               6.413169      188694468366.268005
# 53  2012               5.504545      199081239731.687988
# 54  2013               5.553511      210137237901.389008
# 55  2014               6.422243      223632762207.559998
# 56  2015               6.987154      239258328381.740997
# 57  2016               6.690009      255264731908.123993
# 58  2017                6.94019      272980590259.187012
# 59  2018               7.465007      293358610036.841003
# 60  2019               7.359263      314947640805.601013
# 61  2020               2.865413      323972192107.065002
# 62  2021               2.561564      332270947495.801025
# 63  2022               8.019792       358918387605.51001
# 64  2023                   <NA>                     <NA>
#
# 0   Portfolio investment, net (BoP, current US$)  \
# 35                                          <NA>
# 36                                          <NA>
# 37                                          <NA>
# 38                                          <NA>
# 39                                          <NA>
# 40                                          <NA>
# 41                                          <NA>
# 42                                          <NA>
# 43                                          <NA>
# 44                                          <NA>
# 45                                          <NA>
# 46                                    -865000000
# 47                                   -1313000000
# 48                                   -6243000000
# 49                                     578000000
# 50                                      71000000
# 51                                   -2370000000
# 52                                   -1412000000
# 53                                   -1286000000
# 54                                   -1466000000
# 55                                     -93000000
# 56                                      65000000
# 57                                    -228000000
# 58                                   -2069000000
# 59                                   -3021000000
# 60                                   -2997000000
# 61                                    1256000000
# 62                                    -281000000
# 63                                   -1512000000
# 64                                          <NA>
#
# 0   Inflation, consumer prices (annual %)  \
# 35                                   <NA>
# 36                                   <NA>
# 37                                  5.675
# 38                               3.209526
# 39                               7.266198
# 40                               4.117102
# 41                              -1.710337
# 42                              -0.431545
# 43                               3.830828
# 44                               3.234648
# 45                               7.754947
# 46                               8.284572
# 47                               7.418017
# 48                               8.344449
# 49                              23.115448
# 50                               6.716983
# 51                               9.207466
# 52                              18.677732
# 53                               9.094703
# 54                               6.592675
# 55                               4.084554
# 56                               0.631201
# 57                               2.668248
# 58                               3.520257
# 59                               3.539628
# 60                               2.795824
# 61                               3.220934
# 62                               1.834716
# 63                               3.156507
# 64                                   <NA>
#
# 0   Unemployment, total (% of total labor force) (national estimate)  \
# 35                                               <NA>
# 36                                               <NA>
# 37                                               1.93
# 38                                               2.87
# 39                                               2.29
# 40                                               2.33
# 41                                               2.26
# 42                                               2.76
# 43                                               2.12
# 44                                               2.25
# 45                                               2.14
# 46                                               <NA>
# 47                                               <NA>
# 48                                              2.026
# 49                                               <NA>
# 50                                              1.737
# 51                                              1.114
# 52                                              0.999
# 53                                              1.027
# 54                                              1.316
# 55                                              1.256
# 56                                              1.849
# 57                                              1.848
# 58                                              1.874
# 59                                              1.161
# 60                                              1.681
# 61                                              2.103
# 62                                              2.385
# 63                                              1.535
# 64                                               <NA>
#
# 0   Population growth (annual %)  \
# 35                      1.844018
# 36                      1.720296
# 37                      1.596932
# 38                       1.47303
# 39                      1.396774
# 40                      1.282176
# 41                      1.116867
# 42                      1.028394
# 43                      1.027718
# 44                      1.028293
# 45                      1.020116
# 46                      1.004362
# 47                      0.969169
# 48                      0.960768
# 49                      0.980255
# 50                      1.029392
# 51                       1.06743
# 52                      1.067493
# 53                      1.072013
# 54                       1.07638
# 55                      1.066399
# 56                      1.042271
# 57                      1.009227
# 58                       0.96872
# 59                       0.93284
# 60                      0.904491
# 61                      0.906299
# 62                      0.844182
# 63                      0.734794
# 64                          <NA>
#
# 0   Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)
# 35                                          65.169659
# 36                                          65.169659
# 37                                          65.169659
# 38                                          65.169659
# 39                                          65.169659
# 40                                          65.169659
# 41                                          65.169659
# 42                                          65.169659
# 43                                          65.169659
# 44                                          65.169659
# 45                                          65.169659
# 46                                          65.169659
# 47                                          65.169659
# 48                                          65.169659
# 49                                          65.169659
# 50                                          64.999527
# 51                                          65.169659
# 52                                          65.169659
# 53                                          65.169659
# 54                                          65.169659
# 55                                          65.169659
# 56                                          65.169659
# 57                                          65.169659
# 58                                          65.169659
# 59                                          65.169659
# 60                                           65.33979
# 61                                          65.169659
# 62                                          65.169659
# 63                                          65.169659
# 64                                          65.169659

# %%
selected_vietnam_data.shape
# Out:
# (30, 8)

# %%
selected_vietnam_data.describe().T
# Out:
#                                                    count                 mean  \
# 0
# Year                                                30.0               2008.5
# GDP growth (annual %)                               29.0             6.622951
# GDP (constant 2015 US$)                             29.0  176490092962.948761
# Portfolio investment, net (BoP, current US$)        18.0   -1288111111.111111
# Inflation, consumer prices (annual %)               27.0             5.772233
# Unemployment, total (% of total labor force) (n...  24.0             1.869208
# Population growth (annual %)                        29.0             1.109348
# Educational attainment, at least completed lowe...  30.0            65.169659
#
#                                                                    std  \
# 0
# Year                                                          8.803408
# GDP growth (annual %)                                         1.566946
# GDP (constant 2015 US$)                             90090364716.223129
# Portfolio investment, net (BoP, current US$)         1710358231.788227
# Inflation, consumer prices (annual %)                         5.241212
# Unemployment, total (% of total labor force) (n...            0.525582
# Population growth (annual %)                                  0.258166
# Educational attainment, at least completed lowe...            0.044679
#
#                                                                    min  \
# 0
# Year                                                            1994.0
# GDP growth (annual %)                                         2.561564
# GDP (constant 2015 US$)                             61014304826.638397
# Portfolio investment, net (BoP, current US$)             -6243000000.0
# Inflation, consumer prices (annual %)                        -1.710337
# Unemployment, total (% of total labor force) (n...               0.999
# Population growth (annual %)                                  0.734794
# Educational attainment, at least completed lowe...           64.999527
#
#                                                                    25%  \
# 0
# Year                                                           2001.25
# GDP growth (annual %)                                         5.764455
# GDP (constant 2015 US$)                             99317782863.095993
# Portfolio investment, net (BoP, current US$)             -1929750000.0
# Inflation, consumer prices (annual %)                         3.183017
# Unemployment, total (% of total labor force) (n...             1.48025
# Population growth (annual %)                                  0.969169
# Educational attainment, at least completed lowe...           65.169659
#
#                                                                     50%  \
# 0
# Year                                                             2008.5
# GDP growth (annual %)                                          6.787316
# GDP (constant 2015 US$)                             158086705343.274994
# Portfolio investment, net (BoP, current US$)              -1299500000.0
# Inflation, consumer prices (annual %)                          4.084554
# Unemployment, total (% of total labor force) (n...                1.902
# Population growth (annual %)                                   1.028394
# Educational attainment, at least completed lowe...            65.169659
#
#                                                                     75%  \
# 0
# Year                                                            2015.75
# GDP growth (annual %)                                          7.465007
# GDP (constant 2015 US$)                             239258328381.740997
# Portfolio investment, net (BoP, current US$)               -126750000.0
# Inflation, consumer prices (annual %)                          7.586482
# Unemployment, total (% of total labor force) (n...               2.2525
# Population growth (annual %)                                    1.07638
# Educational attainment, at least completed lowe...            65.169659
#
#                                                                    max
# 0
# Year                                                            2023.0
# GDP growth (annual %)                                          9.54048
# GDP (constant 2015 US$)                             358918387605.51001
# Portfolio investment, net (BoP, current US$)              1256000000.0
# Inflation, consumer prices (annual %)                        23.115448
# Unemployment, total (% of total labor force) (n...                2.87
# Population growth (annual %)                                  1.844018
# Educational attainment, at least completed lowe...            65.33979

# %%
import seaborn as sns

# %%
columns = list(selected_vietnam_data.columns)
print(columns)

sns.scatterplot(x="GDP (constant 2015 US$)",y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# <Axes: xlabel='GDP (constant 2015 US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Portfolio investment, net (BoP, current US$)",y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Portfolio investment, net (BoP, current US$)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Inflation, consumer prices (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Inflation, consumer prices (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Unemployment, total (% of total labor force) (national estimate)',y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Unemployment, total (% of total labor force) (national estimate)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x='Population growth (annual %)',y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Population growth (annual %)', ylabel='GDP growth (annual %)'>

# %%
sns.scatterplot(x="Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)",y='GDP growth (annual %)',hue='Year',data=selected_vietnam_data)
# Out:
# <Axes: xlabel='Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)', ylabel='GDP growth (annual %)'>

# %%
sns.lineplot(data=selected_vietnam_data, x="Year", y="GDP growth (annual %)")
# Out:
# <Axes: xlabel='Year', ylabel='GDP growth (annual %)'>

# %%
sns.pairplot(data = selected_vietnam_data, height = 2)

# %%
print(columns)

def make_regression_columns(columns: list, excluded_cols: list) -> list:
    cols = columns
    for col in excluded_cols:
        print(col)
        cols.remove(col)
    return cols

regression_columns = make_regression_columns(columns, ["Year", "GDP growth (annual %)"])
print(regression_columns)
# Out:
# ['Year', 'GDP growth (annual %)', 'GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']
# Year
# GDP growth (annual %)
# ['GDP (constant 2015 US$)', 'Portfolio investment, net (BoP, current US$)', 'Inflation, consumer prices (annual %)', 'Unemployment, total (% of total labor force) (national estimate)', 'Population growth (annual %)', 'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
y = selected_vietnam_data[ 'GDP growth (annual %)']
X = selected_vietnam_data[regression_columns]
# Combining X and y into a single DataFrame
combined_data = X.copy()  # Creating a copy of X
combined_data['GDP growth (annual %)'] = y  # Adding y as a new column
# Drop rows with any NaN value from combined_data
combined_data_dropped = combined_data.dropna(how='any')

# Separate features (X) and target variable (y) from combined_data_dropped
X = combined_data_dropped.drop(columns='GDP growth (annual %)')
y = combined_data_dropped['GDP growth (annual %)']
# creating train and test sets 
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=42)

# %%
# creating a regression model 
model = LinearRegression() 
  
# fitting the model 
model.fit(X_train, y_train) 
  
# making predictions 
predictions = model.predict(X_test) 


# model evaluation 
print('mean_squared_error : ', mean_squared_error(y_test, predictions)) 
print('mean_absolute_error : ', mean_absolute_error(y_test, predictions)) 
print(f"The value of R^2 for the model is {model.score(X,y)*100} %")
# Out:
# mean_squared_error :  7.7004500500101205
# mean_absolute_error :  2.1983523644499554
# The value of R^2 for the model is -34.74316725954658 %

# %%
print(f"The intercept is given by {model.intercept_}")

coeffecients = model.coef_
for index, col in enumerate(regression_columns):
    print(f"The value of slope for {col} is given by {coeffecients[index]}")
# Out:
# The intercept is given by -687.6329467890889
# The value of slope for GDP (constant 2015 US$) is given by -2.6693562900451174e-11
# The value of slope for Portfolio investment, net (BoP, current US$) is given by -5.685963156733706e-10
# The value of slope for Inflation, consumer prices (annual %) is given by -0.15145970327722635
# The value of slope for Unemployment, total (% of total labor force) (national estimate) is given by -0.27791706729446713
# The value of slope for Population growth (annual %) is given by -13.018707408616738
# The value of slope for Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative) is given by 10.960392788517622
